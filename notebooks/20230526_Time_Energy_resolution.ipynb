# %% [markdown]
# <h1> ______________________________________ </h1>
#
# <h1> Time and Energy resolution calculation </h1>
# <h1> ______________________________________ </h1>
#
# <p style="font-size: 17px; color: black;"> In this Notebook we calculate the energy and time resolution of our photosensor (SiPM Hamamatsu in this case) the following way:</p>
#
# - <p style="font-size: 17px; color: black; font-weight: bold;"> Time resolution: </p>
# <p style="font-size: 17px; color: black;"> We set a voltage threshold and we measure the time difference between when our signal and our trigger waveform pass that threshold. The std of that time difference distribution will be our time resolution. The time resolution is not the same for all signals so we differentiate among signals of 1pe, 2pe, 3pe, etc. </p>
#
#
# - <p style="font-size: 17px; color: black; font-weight: bold;"> Energy resolution: </p>
# <p style="font-size: 17px; color: black;"> We save for each waveform the value of the peak, then we do the distribution of that value for each waveform type, ie we do different distributions separating waveforms corresponding to 1pe, 2pe, 3pe, etc. The std of that peak distribution will be our energy resolution. </p>

# %% [markdown]
# <h1> ____________ </h1>
# <h2> This version </h2>
# <h1> ____________ </h1>
#
# -  <p style="font-size: 17px; color: black;"> 10K events WITH B2 FIBERS. </p>
# -  <p style="font-size: 17px; color: black;"> The photosensor signal saturates (there are values considered inf). </p>
# -  <p style="font-size: 17px; color: black;"> Waveforms include just 1 peak. </p>
# -  <p style="font-size: 17px; color: black;"> Signal happens AFTER THE TRIGGER. </p>
#
#
# -  <p style="font-size: 17px; color: black;"> Use interpolation to get the EXACT time at which the waveform cuts the threshold. This way we can basically work with a function intead of the data. </p>
#
#
# -  <p style="font-size: 17px; color: black;"> Calculate chi2 with a built in function instead of manually. </p>
# -  <p style="font-size: 17px; color: black;"> Variable bining in the distributions as sqrt(Nevents). </p>
#
#
# -  <p style="font-size: 17px; color: black;"> Instead of obtaining the Npe peaks ad hoc we do it finding the peaks in the maximums distribution. </p>
# -  <p style="font-size: 17px; color: black;"> Same way use this distribution to determine dV from each peak to get rid of the in between events. </p>
#
#
# -  <p style="font-size: 17px; color: black;"> We can choose between a variable or a fixed threshold with fix_th = True/False. </p>
#
#
# -  <p style="font-size: 17px; color: black;"> Energy distribution in % instead of absolute values. </p>
# -  <p style="font-size: 17px; color: black;"> Fit the sigma vs $ N_{pe} $ plot to the corresponding cuadratic sum of terms. </p>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
import math

# %%
import scipy
from scipy import stats, integrate
from scipy.signal import find_peaks
from scipy.interpolate import interp1d
from scipy.optimize import root, root_scalar

# %%
import os

# %% [markdown]
# <h1> _________________________________________________________________________________________________________ </h1>

# %% [markdown]
# <h1> __________________________ </h1>
# <h2> Functions </h2>
#
# -  <p style="font-size: 17px; color: black;"> <b> gauss(x, a,  mu, sigma): </b> Gaussian normalized to $a$. </p>
#
#
# -  <p style="font-size: 17px; color: black;"> <b> f_cut(x, f, val): </b> To find the cut of a $f(x)$ function with a certain value $val$ we first use <b> f_cut </b> to move $f(x) \rightarrow f(x) - val$ and then find it's roots, ie, $f(x) - val = 0$. </p>
#
#
# -  <p style="font-size: 17px; color: black;"> <b> resolution_eq(E, a, b, c): </b> Resolution equation to which our results should fit. </p>

# %%
# Gaussian
# note: pdf are normilized to 1 so we have yo add an amplitude param
def gauss(x, a,  mu, sigma):
# def gauss(x,  mu, sigma):
    
    gaussian = stats.norm.pdf(np.sort(x), mu, sigma) 
    
    return (a/gaussian.sum())*gaussian 
#     return (x.sum()/gaussian.sum())*gaussian 

# Function offsetting
# To find the cut of a function with a certain value first we offset the function then find the roots
def f_cut(x, f, val):
    return f(x) - val

# Resolution equation
def resolution_eq(E, a, b, c):
    
    res = np.sqrt( (a/np.sqrt(E))**2 + (b/E)**2 + c**2)
    
    return res

# %% [markdown]
# <h1> __________________________ </h1>
# <h2> Data </h2>

# %% [markdown]
# -  <p style="font-size: 17px; color: black;"> <b> Reading the file </b> </p>

# %% [markdown]
# -  <p style="font-size: 17px; color: black;"> File's path </p>

# %%
filename = []

path = '/home/investigator/mariandbt/python/data/'
path = path + '20230525' + '_t_res_b2/'

# %% [markdown]
# -  <p style="font-size: 17px; color: black;"> Read the file. </p>

# %%
data = []

# Get all files in the folder
files = os.listdir(path)
max_files_used = int(len(files)/3)
# max_files_used = int(300)
# max_files_used = int(len(files))

print('We are using %s files out of %s'%(max_files_used, len(files)))
count = 0

# Loop through each file 
for file_name in files[:max_files_used]:
    file = os.path.join(path, file_name)
    
    if (count%300 == 0):
        print(' %s files read so long '%(count))
        
    with open(file,'r', encoding='ascii') as fp:
        for i, line in enumerate(fp):
            if i > 15:
                data.append(np.asarray(line.split(','), dtype=float))
    count += 1
                
                
fp.close()

print('DONE READING!')
# Out:
# We are using 3333 files out of 10000
#  0 files read so long
#  300 files read so long
#  600 files read so long
#  900 files read so long
#  1200 files read so long
#  1500 files read so long
#  1800 files read so long
#  2100 files read so long
#  2400 files read so long
#  2700 files read so long
#  3000 files read so long
#  3300 files read so long
# DONE READING!

# %%
len(files)
max_files_used
# Out:
# 3333

# %% [markdown]
# -  <p style="font-size: 17px; color: black;"> Make a copy of the data to work with, this way it's easier to re-start the copy instead of re-reading the file. </p>

# %%
waveform = np.array(data)

# %%
# n_frames = int(len(files))
n_frames = int(max_files_used)
n_points = int(len(waveform)/n_frames)

print('n_points = ', n_points)
print('n_frames = ', n_frames)
# Out:
# n_points =  6250
# n_frames =  3333

# %% [markdown]
# <h1> __________________________ </h1>
# <h2> Global parameters </h2>

# %% [markdown]
# -  <p style="font-size: 17px; color: black;"> <b> Analysis parameters </b> </p>
#
#  -  <p style="font-size: 17px; color: black;"> <b> time, LED, signal: </b> Respectively, the time, signal of the trigger, and signal of the photosensor. These are the avriables we'll use ALL along and are adjusted to the propper units. </p>
#
#  -  <p style="font-size: 17px; color: black;"> <b> Offsets: </b> Both the trigger (LED) and the photosensor signal have an offset with respect to 0, so we correct the both before working. </p>
#
#  -  <p style="font-size: 17px; color: black;"> <b> waveform_saturation: </b> The signal saturates at certain value. </p>
#
#  -  <p style="font-size: 17px; color: black;"> <b> dV: </b> When separating signals to differentiate between different photo-electron signals we define a validity region around the selected $N_{pe}$ value with width $dV$. </p>
#
#  -  <p style="font-size: 17px; color: black;"> <b> fix_th: </b> True if we want to use a fixed threshold (determined after the multi-pe peaks). If not, the threshold at which to measure the time difference between signal and trigger is variable depending on each waveform. </p>

# %%
time = waveform[:, 0]*1e6 # [us]
LED = waveform[:, 2]*1e3 # [mV]
signal = waveform[:, 1]*1e3 # [mV]

# Offsets
offset_LED = LED[LED < 0].mean(); LED = LED - offset_LED

offset_signal = signal[signal < 0].mean(); signal = signal - offset_signal

# %%
# Satturation correction
waveform_saturation = signal.max()
waveform_saturation = np.inf
signal = np.where(signal < waveform_saturation, signal, signal[signal < waveform_saturation].max())

# %%
dV = 25 # [mV] Voltage difference from the multi-pe peaks we're considering

# %%
fix_th = False # True if we want to use a fixed threshold (determined after the multi-pe peaks)

# %% [markdown]
# <h1> __________________________ </h1>
# <h2> Analysis </h2>

# %% [markdown]
# <h2> Determination of the $N_{pe}$ peaks </h2>

# %% [markdown]
# -  <p style="font-size: 17px; color: black;"> Use a peak distribution and select this distribution peaks as the $N_{pe}$ values and $dV$ as the validity region around these value to consider a certain signal part of that $N_{pe}$ group. </p>

# %% [markdown]
# -  <p style="font-size: 17px; color: black;"> Save the maximum of each waveform to do the distribution later. Since there are some waveforms that saturate we pick the second highest valid value. </p>

# %%
pe_peaks = []

for frame in range(n_frames):
    
    ss = signal[frame*n_points: (frame + 1)*n_points].copy() # [mV]
    pe_peaks.append(ss.max())
    
pe_peaks = np.array(pe_peaks)

# %% [markdown]
# -  <p style="font-size: 17px; color: black;"> Set the parameters to later find the peaks in the distribution and determine the acceptance region around this peak. </p>

# %%
height_min = n_frames/250. # height threshold to which consider a peak
height_min = 10. # height threshold to which consider a peak
dist_min = 10. # min distance between peaks required
dif_min = None # min height difference between the peak point and their neighbours

# %% [markdown]
# - <p style="font-size: 17px; color: black;"> Waveform's maximums distribution and location of the photo-electrons peaks and the acceptance region around.

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10,3), constrained_layout=True)
events, bins, bars = ax.hist(pe_peaks, 100, 
                             density=False, 
                             label='Multi-photo-electron spectrum', 
                             histtype='step')
x_ax = bins[:-1]
diffs = np.abs(np.diff(bins))
# accept_region = np.array(dV/diffs, dtype = int) # instead of defining the acceptance region by Voltage we define it in terms of bins
accept_region = dV*np.ones(len(x_ax))

peaks, _ = find_peaks(events, height=height_min, threshold=dif_min, distance=dist_min)

for ii in range(len(peaks)):
    ax.fill_between([(x_ax[peaks] - accept_region[peaks])[ii], 
                     (x_ax[peaks] + accept_region[peaks])[ii]], 
                    events[peaks].max(), 
                    color = 'magenta', alpha = 0.3, label = r'Peak regions ($\pm$ %.2f mV)'%(dV)) 

ax.plot(x_ax[peaks], events[peaks], 'o', label = 'Identified peaks')
ax.plot(x_ax, height_min*np.ones(len(x_ax)), label = 'Minimum height considered for a peak')

ax.set_xlabel('Pe signal [mV]')
ax.set_ylabel('Counts')

hand, labl = ax.get_legend_handles_labels()
hand, labl = np.array(hand), np.array(labl)
not_duplicated = ~pd.DataFrame(labl).duplicated()

ax.legend(hand[not_duplicated], labl[not_duplicated], loc = 'best')
# ax.legend(loc='best')

# %%
signal_pe = x_ax[peaks]
signal_pe = signal_pe[signal_pe > 50] # to make sure not to include the 0 pe
n_pe = len(signal_pe)
print('Npe = ', n_pe)
print('Npe values = ', signal_pe)
# Out:
# Npe =  6
# Npe values =  [ 92.32791022 172.32791022 252.32791022 332.32791022 412.32791022
#  556.32791022]

# %%
import matplotlib as mpl
import copy

fig, ax = plt.subplots(1,1)

my_cmap = copy.copy(plt.get_cmap('plasma')) # copy the default cmap
my_cmap.set_bad(my_cmap.colors[0]) #  set the color of invalid or masked values in the colormap


counts, xedges, yedges, im = ax.hist2d(time[:500*n_points], signal[:500*n_points], 
                                       bins=100, rasterized=True, 
                                       range=((time.min(),time.max()), (signal.min(), signal.max())), 
                                       cmap=my_cmap, norm=mpl.colors.LogNorm(vmin = 1))

for ii in range(n_pe):
    ax.plot(0.083, signal_pe[ii], 'ow', markersize = 3, label = '%s pe'%(ii))
    


ax.set_xlabel(r"Time [$\mathrm{\mu}$s]", size='larger')
ax.set_ylabel("Voltage [mV]", size='larger')

# ax.legend(loc = 'best')

fig.colorbar(im, ax = ax, orientation='vertical')
# fig.savefig("waveforms.pdf")

# %% [markdown]
# <p style="font-size: 17px; color: black;"> Set fixed threshold to 50% of the single photo-electron

# %%
th_fixed = .5*signal_pe[0] # [mV] Height at which we measure the time difference between LED and Signal

# %% [markdown]
# <p style="font-size: 17px; color: black; font-weight: bold"> Waveform

# %% [markdown]
# <p style="font-size: 17px; color: black;"> Interpolate the waveform to create a function

# %%
frame = 23
frame = 789
frame = 3151
# frame = 1755; th = 57.38 # [mV]
# frame = 2031; th = 131.43 # [mV]
# frame = 266; th = 114.13 # [mV]
# frame = 1712
# frame = 4954

# %%
tt = time[frame*n_points: (frame + 1)*n_points].copy()  # [us]
ss = signal[frame*n_points: (frame + 1)*n_points].copy() # [mV]
ll = LED[frame*n_points: (frame + 1)*n_points].copy() # [mV]

# %% [markdown]
# <p style="font-size: 17px; color: black;"> Time region where to look for signal

# %%
tt_min = 0. # [us]
tt_max = 0.4 # [us]

tt_region_mask = (tt > tt_min) & (tt < tt_max) # Where to look for the signal

# %% [markdown]
# <p style="font-size: 17px; color: black;"> Threshold to consider a peak in this waveform

# %%
th = max(0.8*signal_pe[0], min(0.8*ss[tt_region_mask].max(), 0.8*ll.max()))

if fix_th:
    th = th_fixed
            
print('threshold = %.2f mV'%(th))
# Out:
# threshold = 445.06 mV

# %% [markdown]
# <p style="font-size: 17px; color: black;"> Data waveform

# %%
fig, ax = plt.subplots(1, 1, figsize = (15, 5), constrained_layout=True)

ax.plot(tt, ll, label = 'LED')
ax.plot(tt, ss, label = 'signal')
ax.plot(tt, th*np.ones(len(tt)), label = 'threshold')

ax.fill_between([tt_min, tt_max], max(ll.max(), ss.max()), 
                color = 'peachpuff', alpha = 0.5, label = r'Time region for signal') 

ax.set_ylabel('Voltage [mV]');
ax.set_xlabel('Time [us]');
ax.set_title('Data waveform', size = 20);
ax.legend(loc = 'best')

# %% [markdown]
# <p style="font-size: 17px; color: black;"> Waveform interpolation and finding the cut with the threshold

# %%
# Define the interpolation functions
f_ss = interp1d(tt, ss)
f_ll = interp1d(tt, ll)

# Define the intervals where to search for roots
t0 = tt[ss - th < 0.][0]
tf_ss = tt[(tt > tt_min) & (ss - th > 0.)][0]
tf_ll = tt[ll - th > 0.][0]

# Find the roots of the new function for val = th
root_ss = root_scalar(f_cut, args=(f_ss, th,), bracket=[t0, tf_ss]).root
root_ll = root_scalar(f_cut, args=(f_ll, th,), bracket=[tt.min(), tf_ll]).root

dt = np.fabs(root_ss - root_ll)
print('dt = %.2f us'%(dt))
# Out:
# dt = 0.07 us

# %%
fig, ax = plt.subplots(1, 1, figsize = (15, 5), constrained_layout=True)

ax.plot(tt, f_ll(tt), label = 'LED interpolation')
ax.plot(tt, f_ss(tt), label = 'Signal interpolation')
ax.plot(tt, th*np.ones(len(tt)), label = 'threshold')

ax.fill_between([tt_min, tt_max], max(ll.max(), ss.max()), 
                color = 'peachpuff', alpha = 0.5, label = r'Time region for signal') 

ax.plot(root_ss, th, 'o', markersize = 5, label = 'Signal cut with threshold')
ax.plot(root_ll, th, 'o', markersize = 5, label = 'LED cut with threshold')
ax.plot(np.linspace(root_ss, root_ll, len(tt)), th*np.ones(len(tt)), '-m', label = 'dt = %.2f us'%(dt))

ax.set_ylabel('Voltage [mV]');
ax.set_xlabel('Time [us]');
ax.set_title('Interpolated waveform', size = 20);
ax.legend(loc = 'best')

# %% [markdown]
# <p style="font-size: 17px; color: black;"> Difference in time calculation for all frames

# %% [markdown]
# <p style="font-size: 15px; color: black;"> Note how we're working with the fact that the signal appears in a certain time region to constrain the valid region of signal we use using the mask

# %%
dt = []
s_peak = []

try:
    for frame in range(n_frames):

        tt = time[frame*n_points: (frame + 1)*n_points].copy()  # [us]
        ss = signal[frame*n_points: (frame + 1)*n_points].copy() # [mV]
        ll = LED[frame*n_points: (frame + 1)*n_points].copy() # [mV]
        
        tt_region_mask = (tt > tt_min) & (tt < tt_max) # Where to look for the signal

        th = max(0.8*signal_pe[0], min(0.8*ss[tt_region_mask].max(), 0.8*ll.max()))
        
        if fix_th:
            th = th_fixed
        
        if ss[tt_region_mask].max() < th: 
            print('NO SIGNAL HERE! frame = %s; th = %.2f # [mV]'%(frame, th))
            continue
            
        if ss[tt_region_mask][0] > th: 
            print('This is not signal, it is the tail of a noise pulse! frame = %s; th = %.2f # [mV]'%(frame, th))
            continue

        # Define the interpolation functions
        f_ss = interp1d(tt, ss) 
        f_ll = interp1d(tt, ll)
        
        # Define the intervals where to search for roots
        t0 = tt[ss - th < 0.][0]
        tf_ss = tt[(tt > tt_min) & (ss - th > 0.)][0]
        tf_ll = tt[ll - th > 0.][0]

        # Find the roots of the new function for val = th
        root_ss = root_scalar(f_cut, args=(f_ss, th,), bracket=[t0, tf_ss]).root
        root_ll = root_scalar(f_cut, args=(f_ll, th,), bracket=[tt.min(), tf_ll]).root

        s_peak.append(ss.max())
        dt.append(np.fabs(root_ss - root_ll))
    
except Exception as e:
    print("Python sais:", str(e))
    print("Marian sais: Error accured in frame ", frame)
    
dt = np.array(dt)
s_peak = np.array(s_peak)
# Out:
# This is not signal, it is the tail of a noise pulse! frame = 4; th = 137.86 # [mV]
# NO SIGNAL HERE! frame = 33; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 35; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 43; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 47; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 53; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 64; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 65; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 66; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 73; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 80; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 93; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 113; th = 73.86 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 132; th = 118.66 # [mV]
# NO SIGNAL HERE! frame = 140; th = 73.86 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 144; th = 125.06 # [mV]
# NO SIGNAL HERE! frame = 154; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 160; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 162; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 193; th = 73.86 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 226; th = 182.66 # [mV]
# NO SIGNAL HERE! frame = 227; th = 73.86 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 252; th = 137.86 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 269; th = 131.46 # [mV]
# NO SIGNAL HERE! frame = 284; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 286; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 293; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 298; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 321; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 350; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 351; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 363; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 375; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 376; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 391; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 399; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 402; th = 73.86 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 411; th = 227.46 # [mV]
# NO SIGNAL HERE! frame = 413; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 420; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 457; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 472; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 473; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 480; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 495; th = 73.86 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 514; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 520; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 530; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 533; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 543; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 552; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 569; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 586; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 598; th = 73.86 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 618; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 661; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 669; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 675; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 683; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 685; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 687; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 693; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 697; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 699; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 706; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 708; th = 73.86 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 716; th = 144.26 # [mV]
# NO SIGNAL HERE! frame = 744; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 745; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 748; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 756; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 795; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 800; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 833; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 834; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 849; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 850; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 860; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 880; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 888; th = 73.86 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 892; th = 240.26 # [mV]
# NO SIGNAL HERE! frame = 893; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 914; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 929; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 949; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 968; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 981; th = 73.86 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 1000; th = 93.06 # [mV]
# NO SIGNAL HERE! frame = 1014; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1017; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1028; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1033; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1049; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1050; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1076; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1097; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1099; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1100; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1104; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1113; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1116; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1124; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1127; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1128; th = 73.86 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 1137; th = 137.86 # [mV]
# NO SIGNAL HERE! frame = 1139; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1150; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1173; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1177; th = 73.86 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 1178; th = 80.26 # [mV]
# NO SIGNAL HERE! frame = 1181; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1188; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1219; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1235; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1240; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1246; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1248; th = 73.86 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 1250; th = 118.66 # [mV]
# NO SIGNAL HERE! frame = 1256; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1264; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1267; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1301; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1309; th = 73.86 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 1318; th = 137.86 # [mV]
# NO SIGNAL HERE! frame = 1324; th = 73.86 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 1325; th = 137.86 # [mV]
# NO SIGNAL HERE! frame = 1352; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1362; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1380; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1382; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1386; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1418; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1419; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1423; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1429; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1430; th = 73.86 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 1431; th = 131.46 # [mV]
# NO SIGNAL HERE! frame = 1433; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1440; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1444; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1461; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1473; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1504; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1513; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1521; th = 73.86 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 1524; th = 253.06 # [mV]
# NO SIGNAL HERE! frame = 1530; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1531; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1536; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1541; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1553; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1554; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1555; th = 73.86 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 1571; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1581; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1583; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1602; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1614; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1618; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1626; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1643; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1660; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1662; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1668; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1674; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1714; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1716; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1719; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1722; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1730; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1749; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1771; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1779; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1782; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1790; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1800; th = 73.86 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 1810; th = 189.06 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 1813; th = 131.46 # [mV]
# NO SIGNAL HERE! frame = 1841; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1845; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1850; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1886; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1892; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1900; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1903; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1904; th = 73.86 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 1905; th = 131.46 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 1906; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1908; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1910; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1915; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1944; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1946; th = 73.86 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 1958; th = 93.06 # [mV]
# NO SIGNAL HERE! frame = 1979; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 1988; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2004; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2011; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2020; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2027; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2038; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2045; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2057; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2071; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2073; th = 73.86 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 2078; th = 112.26 # [mV]
# NO SIGNAL HERE! frame = 2079; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2087; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2091; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2099; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2105; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2114; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2126; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2127; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2131; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2143; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2168; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2170; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2189; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2190; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2192; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2206; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2208; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2221; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2229; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2255; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2282; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2283; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2297; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2303; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2308; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2338; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2356; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2359; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2362; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2363; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2367; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2388; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2401; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2414; th = 73.86 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 2428; th = 99.46 # [mV]
# NO SIGNAL HERE! frame = 2434; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2441; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2446; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2466; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2471; th = 73.86 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 2472; th = 182.66 # [mV]
# NO SIGNAL HERE! frame = 2474; th = 73.86 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 2482; th = 125.06 # [mV]
# NO SIGNAL HERE! frame = 2493; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2501; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2512; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2524; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2532; th = 73.86 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 2534; th = 163.46 # [mV]
# NO SIGNAL HERE! frame = 2559; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2562; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2564; th = 73.86 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 2580; th = 150.66 # [mV]
# NO SIGNAL HERE! frame = 2589; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2591; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2598; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2602; th = 73.86 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 2632; th = 93.06 # [mV]
# NO SIGNAL HERE! frame = 2636; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2658; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2688; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2698; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2713; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2723; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2725; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2731; th = 73.86 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 2732; th = 227.46 # [mV]
# NO SIGNAL HERE! frame = 2738; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2759; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2760; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2776; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2781; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2789; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2793; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2804; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2811; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2816; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2818; th = 73.86 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 2830; th = 131.46 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 2857; th = 99.46 # [mV]
# NO SIGNAL HERE! frame = 2860; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2861; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2866; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2870; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2879; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2890; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2902; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2906; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2909; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2941; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2950; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2957; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2962; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2969; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2972; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2978; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2982; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 2989; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 3000; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 3019; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 3031; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 3041; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 3046; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 3052; th = 73.86 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 3058; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 3091; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 3103; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 3132; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 3153; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 3156; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 3171; th = 73.86 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 3177; th = 157.06 # [mV]
# NO SIGNAL HERE! frame = 3179; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 3195; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 3197; th = 73.86 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 3206; th = 125.06 # [mV]
# NO SIGNAL HERE! frame = 3211; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 3212; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 3220; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 3225; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 3232; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 3240; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 3255; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 3264; th = 73.86 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 3274; th = 157.06 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 3303; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 3306; th = 73.86 # [mV]
# NO SIGNAL HERE! frame = 3316; th = 73.86 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 3325; th = 125.06 # [mV]

# %% [markdown]
# <p style="font-size: 17px; color: black;"> Peak identification

# %%
mask_pe = []
for i in range(n_pe):
#     mask_pe.append(np.fabs(s_peak - signal_pe[i]) <= dV) # for fixed dV
    mask_pe.append(np.fabs(s_peak - signal_pe[i]) <= accept_region[i]) # for fixed number of bins

# %%
fig, ax = plt.subplots(1, 1, figsize = (15, 10), constrained_layout=True)

#______________________plot settings________________________________________________________

x_ax = np.arange(len(s_peak))

ax.plot(x_ax, s_peak, 'o', label = 'All peaks')

for ii in range(len(mask_pe)):
    ax.plot(x_ax[mask_pe[ii]], s_peak[mask_pe[ii]], 'o', label = '%s pe'%(ii + 1))

ax.set_ylabel('Waveform peak [mV]');
ax.set_xlabel('N_event');

# ax.set_xlim([0, 20])
# ax.set_ylim([s_peak.min(), 150])
ax.legend(loc = 'best')

# %% [markdown]
# <p style="font-size: 17px; color: black;"> Time resolution calculation

# %%
from scipy.stats import chisquare

observed = np.array([10, 20, 30])
expected = np.array([15, 15, 30])

chi2, p_value = chisquare(observed, expected)

print('chi^2 =', chi2)
print('p-value =', p_value)
# Out:
# chi^2 = 3.3333333333333335
# p-value = 0.1888756028375618

# %%
len(events), len(bins[:-1]), len(x_ax)
# Out:
# (100, 100, 2998)

# %%
fig, ax = plt.subplots(nrows = math.ceil(n_pe/2.), ncols = 2, figsize=(10,10), constrained_layout=True)

n_row = 0

t_res = np.zeros(n_pe)
t_res_err = np.zeros(n_pe)

for pe in range(n_pe):
# for pe in range(8, 9):
    
    n_col = pe%2
    
    N_ev = len(dt[mask_pe[pe]])
    n_bins = int(np.sqrt(N_ev))
    n_bins = 10*int(np.sqrt(N_ev))
#     n_bins = 100
    
    region_min = 0.022
    region_max = .06
    if (pe + 1 >= 6):
        region_max = 0.045
    if (pe + 1 > 7):
        region_max = 0.04
    
    events, bins, bars = ax[n_row, n_col].hist(dt[mask_pe[pe]], n_bins, 
                                               density=False,
#                                                range=(region_min, region_max),
                                               label='dt distribution', 
                                               histtype='step')
    
    x_ax = np.linspace(bins.min(), bins.max(), len(bins)-1)
    y_err = np.sqrt(events)
    
    ev_th = 0
    if pe == 7 - 1:
        ev_th = 2
    else:
        ev_th = 5
    
    # gaussian fit
    popt, pcov = scipy.optimize.curve_fit(gauss, x_ax, events, 
                                          sigma = np.where(y_err > 0., y_err, 1e-3),
                                          p0=[events.sum(), (bins[:-1])[events > ev_th].mean(), 0.001]) 
#                                           bounds=([1,  0.9*bins.mean(), 1e-4], [3., bins.mean(), 1e-2])) 


#     best_fit_line = gauss(x_ax, *popt)
    best_fit_line = gauss(x_ax, *popt)*events.sum()/gauss(x_ax, *popt).sum()
    a, mu, sigma = popt
    
    param_err = np.sqrt(np.diag(pcov))
    a_err, mu_err, sigma_err = param_err
    
    # Calculate p-value and chi-square
    fit_norm = gauss(x_ax, *popt)*events.sum()/gauss(x_ax, *popt).sum() # need to normalize the fit 
    chi2, p_value = stats.chisquare(f_obs = events, f_exp = fit_norm, axis = None)
    chi2 = chi2/events.sum()
    
    t_res[pe] = sigma
    t_res_err[pe] = sigma_err

    #_________plot_settings_________________________________________________

    ax[n_row, n_col].plot(x_ax, gauss(x_ax, a, mu, sigma), '-', 
                          label='$\mu$ = %.2f, $\sigma$ = %.2E, $\chi^{2}$ = %.2E'%(mu, sigma, chi2))
    ax[n_row, n_col].plot(x_ax, fit_norm, '-', 
                          label='fit_norm')
    
    ax[n_row, n_col].text(0.05, .9, str(pe+1) + ' pe', transform=ax[n_row, n_col].transAxes,
                fontsize=10, verticalalignment='top', fontfamily='serif',
                bbox=dict(facecolor='1.', edgecolor='none', pad=3.0))

    ax[n_row, n_col].set_ylabel('Counts')
    ax[n_row, n_col].set_xlabel('dt [us]')

    ax[n_row, n_col].legend(fontsize=7, loc='upper right')
    
    n_row += pe%2
# Out:
# /home/investigator/miniconda3/envs/IC-3.8-2022-04-13/lib/python3.8/site-packages/scipy/stats/stats.py:6707: RuntimeWarning: divide by zero encountered in true_divide
#   terms = (f_obs_float - f_exp)**2 / f_exp
# /home/investigator/miniconda3/envs/IC-3.8-2022-04-13/lib/python3.8/site-packages/scipy/stats/stats.py:6707: RuntimeWarning: overflow encountered in true_divide
#   terms = (f_obs_float - f_exp)**2 / f_exp
# /home/investigator/miniconda3/envs/IC-3.8-2022-04-13/lib/python3.8/site-packages/scipy/stats/stats.py:6707: RuntimeWarning: invalid value encountered in true_divide
#   terms = (f_obs_float - f_exp)**2 / f_exp
# /home/investigator/miniconda3/envs/IC-3.8-2022-04-13/lib/python3.8/site-packages/scipy/stats/stats.py:6707: RuntimeWarning: divide by zero encountered in true_divide
#   terms = (f_obs_float - f_exp)**2 / f_exp
# /home/investigator/miniconda3/envs/IC-3.8-2022-04-13/lib/python3.8/site-packages/scipy/stats/stats.py:6707: RuntimeWarning: overflow encountered in true_divide
#   terms = (f_obs_float - f_exp)**2 / f_exp
# /home/investigator/miniconda3/envs/IC-3.8-2022-04-13/lib/python3.8/site-packages/scipy/stats/stats.py:6707: RuntimeWarning: invalid value encountered in true_divide
#   terms = (f_obs_float - f_exp)**2 / f_exp
# /home/investigator/miniconda3/envs/IC-3.8-2022-04-13/lib/python3.8/site-packages/scipy/stats/stats.py:6707: RuntimeWarning: divide by zero encountered in true_divide
#   terms = (f_obs_float - f_exp)**2 / f_exp
# /home/investigator/miniconda3/envs/IC-3.8-2022-04-13/lib/python3.8/site-packages/scipy/stats/stats.py:6707: RuntimeWarning: invalid value encountered in true_divide
#   terms = (f_obs_float - f_exp)**2 / f_exp
# /home/investigator/miniconda3/envs/IC-3.8-2022-04-13/lib/python3.8/site-packages/scipy/stats/stats.py:6707: RuntimeWarning: divide by zero encountered in true_divide
#   terms = (f_obs_float - f_exp)**2 / f_exp
# /home/investigator/miniconda3/envs/IC-3.8-2022-04-13/lib/python3.8/site-packages/scipy/stats/stats.py:6707: RuntimeWarning: invalid value encountered in true_divide
#   terms = (f_obs_float - f_exp)**2 / f_exp
# /home/investigator/miniconda3/envs/IC-3.8-2022-04-13/lib/python3.8/site-packages/scipy/stats/stats.py:6707: RuntimeWarning: divide by zero encountered in true_divide
#   terms = (f_obs_float - f_exp)**2 / f_exp
# /home/investigator/miniconda3/envs/IC-3.8-2022-04-13/lib/python3.8/site-packages/scipy/stats/stats.py:6707: RuntimeWarning: divide by zero encountered in true_divide
#   terms = (f_obs_float - f_exp)**2 / f_exp
# /home/investigator/miniconda3/envs/IC-3.8-2022-04-13/lib/python3.8/site-packages/scipy/stats/stats.py:6707: RuntimeWarning: invalid value encountered in true_divide
#   terms = (f_obs_float - f_exp)**2 / f_exp

# %%
fig, ax = plt.subplots(nrows = math.ceil(n_pe/2.), ncols = 2, figsize=(10,10), constrained_layout=True)

n_row = 0

t_res = np.zeros(n_pe)
t_res_err = np.zeros(n_pe)

for pe in range(n_pe):
# for pe in range(8, 9):
    
    n_col = pe%2
    
    N_ev = len(dt[mask_pe[pe]])
    n_bins = int(np.sqrt(N_ev))
    n_bins = 10*int(np.sqrt(N_ev))
#     n_bins = 100
    
    region_min = 0.022
    region_max = .06
    if (pe + 1 >= 6):
        region_max = 0.045
    if (pe + 1 > 7):
        region_max = 0.04
    
    events, bins, bars = ax[n_row, n_col].hist(dt[mask_pe[pe]], n_bins, 
                                               density=False,
#                                                range=(region_min, region_max),
                                               label='dt distribution', 
                                               histtype='step')
    
    x_ax = np.linspace(bins.min(), bins.max(), len(bins)-1)
    y_err = np.sqrt(events)
    
    ev_th = 0
    if pe == 7 - 1:
        ev_th = 2
    else:
        ev_th = 5
    
    # gaussian fit
    popt, pcov = scipy.optimize.curve_fit(gauss, x_ax, events, 
                                          sigma = np.where(y_err > 0., y_err, 1e-3),
                                          p0=[events.sum(), (bins[:-1])[events > ev_th].mean(), 0.001]) 
#                                           bounds=([1,  0.9*bins.mean(), 1e-4], [3., bins.mean(), 1e-2])) 


#     best_fit_line = gauss(x_ax, *popt)
    best_fit_line = gauss(x_ax, *popt)*events.sum()/gauss(x_ax, *popt).sum()
    a, mu, sigma = popt
    
    param_err = np.sqrt(np.diag(pcov))
    a_err, mu_err, sigma_err = param_err
    
    # Calculate p-value and chi-square
    residuals = events - gauss(x_ax, *popt)
    data_err = np.sqrt(events)
    
    chi2 = np.sum( np.where(data_err > 0., (residuals/ data_err)**2, 0.) );
    chi2 /= len(bins)
    
    t_res[pe] = sigma
    t_res_err[pe] = sigma_err

    #_________plot_settings_________________________________________________

    ax[n_row, n_col].plot(x_ax, gauss(x_ax, a, mu, sigma), '-', 
                          label='$\mu$ = %.2f, $\sigma$ = %.2E, $\chi^{2}$ = %.2E'%(mu, sigma, chi2))
    
    ax[n_row, n_col].text(0.05, .9, str(pe+1) + ' pe', transform=ax[n_row, n_col].transAxes,
                fontsize=10, verticalalignment='top', fontfamily='serif',
                bbox=dict(facecolor='1.', edgecolor='none', pad=3.0))

    ax[n_row, n_col].set_ylabel('Counts')
    ax[n_row, n_col].set_xlabel('dt [us]')

    ax[n_row, n_col].legend(fontsize=7, loc='upper right')
    
    n_row += pe%2
# Out:
# /tmp/ipykernel_4669/547049467.py:58: RuntimeWarning: divide by zero encountered in true_divide
#   chi2 = np.sum( np.where(data_err > 0., (residuals/ data_err)**2, 0.) );
# /tmp/ipykernel_4669/547049467.py:58: RuntimeWarning: invalid value encountered in true_divide
#   chi2 = np.sum( np.where(data_err > 0., (residuals/ data_err)**2, 0.) );
# /tmp/ipykernel_4669/547049467.py:58: RuntimeWarning: divide by zero encountered in true_divide
#   chi2 = np.sum( np.where(data_err > 0., (residuals/ data_err)**2, 0.) );
# /tmp/ipykernel_4669/547049467.py:58: RuntimeWarning: invalid value encountered in true_divide
#   chi2 = np.sum( np.where(data_err > 0., (residuals/ data_err)**2, 0.) );
# /tmp/ipykernel_4669/547049467.py:58: RuntimeWarning: divide by zero encountered in true_divide
#   chi2 = np.sum( np.where(data_err > 0., (residuals/ data_err)**2, 0.) );
# /tmp/ipykernel_4669/547049467.py:58: RuntimeWarning: invalid value encountered in true_divide
#   chi2 = np.sum( np.where(data_err > 0., (residuals/ data_err)**2, 0.) );
# /tmp/ipykernel_4669/547049467.py:58: RuntimeWarning: divide by zero encountered in true_divide
#   chi2 = np.sum( np.where(data_err > 0., (residuals/ data_err)**2, 0.) );
# /tmp/ipykernel_4669/547049467.py:58: RuntimeWarning: invalid value encountered in true_divide
#   chi2 = np.sum( np.where(data_err > 0., (residuals/ data_err)**2, 0.) );
# /tmp/ipykernel_4669/547049467.py:58: RuntimeWarning: divide by zero encountered in true_divide
#   chi2 = np.sum( np.where(data_err > 0., (residuals/ data_err)**2, 0.) );
# /tmp/ipykernel_4669/547049467.py:58: RuntimeWarning: divide by zero encountered in true_divide
#   chi2 = np.sum( np.where(data_err > 0., (residuals/ data_err)**2, 0.) );
# /tmp/ipykernel_4669/547049467.py:58: RuntimeWarning: invalid value encountered in true_divide
#   chi2 = np.sum( np.where(data_err > 0., (residuals/ data_err)**2, 0.) );

# %%
fig, ax = plt.subplots(nrows = math.ceil(n_pe/2.), ncols = 2, figsize=(10,10), constrained_layout=True)

n_row = 0

t_res = np.zeros(n_pe)
t_res_err = np.zeros(n_pe)

for pe in range(n_pe):
# for pe in range(8, 9):
    
    n_col = pe%2
    
    N_ev = len(dt[mask_pe[pe]])
    n_bins = int(np.sqrt(N_ev))
    n_bins = 10*int(np.sqrt(N_ev))
#     n_bins = 100
    
    region_min = 0.5
    region_max = .58
#     if (pe + 1 >= 6):
#         region_max = 0.045
#     if (pe + 1 > 7):
#         region_max = 0.04
    
    events, bins, bars = ax[n_row, n_col].hist(dt[mask_pe[pe]], n_bins, 
                                               density=False,
#                                                range=(region_min, region_max),
                                               label='dt distribution', 
                                               histtype='step')
    
    x_ax = np.linspace(bins.min(), bins.max(), len(bins)-1)
    y_err = np.where(events > 0., np.sqrt(events), 1.)
    
    ev_th = 0
    if pe == 7 - 1:
        ev_th = 2
    else:
        ev_th = 5
    
    # gaussian fit
    popt, pcov = scipy.optimize.curve_fit(gauss, x_ax, events, 
                                          sigma = np.where(y_err > 0., y_err, 1e-3),
                                          p0=[events.sum(), (bins[:-1])[events > ev_th].mean(), 0.001]) 
#                                           bounds=([1,  0.9*bins.mean(), 1e-4], [3., bins.mean(), 1e-2])) 


#     best_fit_line = gauss(x_ax, *popt)
    best_fit_line = gauss(x_ax, *popt)*events.sum()/gauss(x_ax, *popt).sum()
    a, mu, sigma = popt
    
    
    param_err = np.sqrt(np.diag(pcov))
    a_err, mu_err, sigma_err = param_err
    
    # Calculate p-value and chi-square
    fit_norm = gauss(x_ax, *popt)*events.sum()/gauss(x_ax, *popt).sum() # need to normalize the fit 
    chi2, p_value = stats.chisquare(f_obs = events, f_exp = fit_norm, axis = None)
    
    t_res[pe] = sigma
    t_res_err[pe] = sigma_err

    #_________plot_settings_________________________________________________

    ax[n_row, n_col].plot(x_ax, gauss(x_ax, a, mu, sigma), '-', 
                          label='$\mu$ = %.2f, $\sigma$ = %.2E, $\chi^{2}$ = %.2E'%(mu, sigma, chi2))
    
    ax[n_row, n_col].text(0.05, .9, str(pe+1) + ' pe', transform=ax[n_row, n_col].transAxes,
                fontsize=10, verticalalignment='top', fontfamily='serif',
                bbox=dict(facecolor='1.', edgecolor='none', pad=3.0))

    ax[n_row, n_col].set_ylabel('Counts')
    ax[n_row, n_col].set_xlabel('dt [us]')

    ax[n_row, n_col].legend(fontsize=7, loc='upper right')
    
    n_row += pe%2
# Out:
# /home/investigator/miniconda3/envs/IC-3.8-2022-04-13/lib/python3.8/site-packages/scipy/stats/stats.py:6707: RuntimeWarning: divide by zero encountered in true_divide
#   terms = (f_obs_float - f_exp)**2 / f_exp
# /home/investigator/miniconda3/envs/IC-3.8-2022-04-13/lib/python3.8/site-packages/scipy/stats/stats.py:6707: RuntimeWarning: overflow encountered in true_divide
#   terms = (f_obs_float - f_exp)**2 / f_exp
# /home/investigator/miniconda3/envs/IC-3.8-2022-04-13/lib/python3.8/site-packages/scipy/stats/stats.py:6707: RuntimeWarning: invalid value encountered in true_divide
#   terms = (f_obs_float - f_exp)**2 / f_exp
# /home/investigator/miniconda3/envs/IC-3.8-2022-04-13/lib/python3.8/site-packages/scipy/stats/stats.py:6707: RuntimeWarning: divide by zero encountered in true_divide
#   terms = (f_obs_float - f_exp)**2 / f_exp
# /home/investigator/miniconda3/envs/IC-3.8-2022-04-13/lib/python3.8/site-packages/scipy/stats/stats.py:6707: RuntimeWarning: overflow encountered in true_divide
#   terms = (f_obs_float - f_exp)**2 / f_exp
# /home/investigator/miniconda3/envs/IC-3.8-2022-04-13/lib/python3.8/site-packages/scipy/stats/stats.py:6707: RuntimeWarning: invalid value encountered in true_divide
#   terms = (f_obs_float - f_exp)**2 / f_exp
# /home/investigator/miniconda3/envs/IC-3.8-2022-04-13/lib/python3.8/site-packages/scipy/stats/stats.py:6707: RuntimeWarning: divide by zero encountered in true_divide
#   terms = (f_obs_float - f_exp)**2 / f_exp
# /home/investigator/miniconda3/envs/IC-3.8-2022-04-13/lib/python3.8/site-packages/scipy/stats/stats.py:6707: RuntimeWarning: overflow encountered in true_divide
#   terms = (f_obs_float - f_exp)**2 / f_exp
# /home/investigator/miniconda3/envs/IC-3.8-2022-04-13/lib/python3.8/site-packages/scipy/stats/stats.py:6707: RuntimeWarning: invalid value encountered in true_divide
#   terms = (f_obs_float - f_exp)**2 / f_exp
# /home/investigator/miniconda3/envs/IC-3.8-2022-04-13/lib/python3.8/site-packages/scipy/stats/stats.py:6707: RuntimeWarning: divide by zero encountered in true_divide
#   terms = (f_obs_float - f_exp)**2 / f_exp
# /home/investigator/miniconda3/envs/IC-3.8-2022-04-13/lib/python3.8/site-packages/scipy/stats/stats.py:6707: RuntimeWarning: invalid value encountered in true_divide
#   terms = (f_obs_float - f_exp)**2 / f_exp

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10,5), constrained_layout=True)

x_ax = np.arange(len(t_res)) + 1

ax.errorbar(x_ax, t_res*1e3, yerr = t_res_err*1e3, fmt = '-o', label = 'Time resolution vs number of photoelectrons')

ax.set_ylabel('Time resolution [ns]')
ax.set_xlabel('Number of photoelectrons')


# Resolution fit
#     popt, pcov = scipy.optimize.curve_fit(gauss, x_ax, events, p0=[1, bins.mean(), 20.]) 
popt, pcov = scipy.optimize.curve_fit(resolution_eq, x_ax, t_res*1e3, 
                                      bounds=([0., 0., 0.], [np.inf, np.inf, np.inf])) 

aa, bb, cc = popt


# Calculate the residuals and chi-square
residuals = t_res*1e3 - resolution_eq(x_ax, *popt)
data_err = t_res_err*1e3

chi2 = np.sum(np.where(data_err > 0., (residuals/ data_err)**2, 0.))


x_ax_fit = np.linspace(x_ax.min(), x_ax.max(), 100)
best_fit_line = resolution_eq(x_ax_fit, aa, bb, cc)

ax.plot(x_ax_fit, best_fit_line, '-', 
        label='Theoretical fit: a = %.2E, b = %.2f, c = %.2f; $\chi^{2} = %.2f$'%(aa, bb, cc, chi2))

ax.legend(loc = 'best')

# %% [markdown]
# <p style="font-size: 17px; color: black;"> Energy resolution calculation

# %%
fig, ax = plt.subplots(nrows=int(np.ceil(n_pe/2)), ncols=2, figsize=(10,10), constrained_layout=True)

n_row = 0

e_res = np.zeros(n_pe)
e_res_err = np.zeros(n_pe)

for pe in range(n_pe):
    
    n_col = pe%2
    
    N_ev = len(s_peak[mask_pe[pe]])
#     n_bins = 5*int(np.sqrt(N_ev))
    n_bins = int(np.sqrt(N_ev))
    
    events, bins, bars = ax[n_row, n_col].hist(s_peak[mask_pe[pe]], n_bins, 
                                     density=False, 
#                                                range=(0.08, 0.15),
                                     label='Peak distribution', 
                                     histtype='step')
    x_ax = np.linspace(bins.min(), bins.max(), len(bins)-1)

#     # gaussian fit
#     popt, pcov = scipy.optimize.curve_fit(gauss, x_ax, events, p0=[1, bins.mean(), 20.]) 
    popt, pcov = scipy.optimize.curve_fit(gauss, x_ax, events, 
                                          sigma = np.where(events > 0., np.sqrt(events), 1e-3),
                                          bounds=([events.sum(),  0.9*bins.mean(), 10.], [np.inf, bins.mean(), 60.])) 
    
    best_fit_line = gauss(x_ax, *popt)
    a, mu, sigma = popt
    
    print(events.sum(), best_fit_line.sum(), a)
    
    param_err = np.sqrt(np.diag(pcov))
    a_err, mu_err, sigma_err = param_err
    
#     # Calculate the residuals and chi-square
#     residuals = events - gauss(x_ax, *popt)
#     data_err = np.sqrt(events)
    
#     chi2 = np.sum(np.where(data_err > 0., (residuals/ data_err)**2, 0.))
    
    # Calculate p-value and chi-square
    fit_norm = best_fit_line*events.sum()/best_fit_line.sum() # need to normalize the fit 
    chi2, p_value = stats.chisquare(f_obs = events, f_exp = fit_norm, axis = None)
#     chi2, p_value = stats.chisquare(f_obs = events, f_exp = best_fit_line, axis = None)
    
    e_res[pe] = 100*sigma/mu
    e_res_err[pe] = 100*np.sqrt( (sigma_err/mu)**2 + (sigma*mu_err/mu**2)**2 )

    #_________plot_settings_________________________________________________

    ax[n_row, n_col].plot(x_ax, best_fit_line, '-', 
                          label='$\mu$ = %.2f, $\sigma$ = %.2E, $\chi^{2}$ = %.2f'%(mu, sigma, chi2))
    
    ax[n_row, n_col].text(0.05, .9, str(pe+1) + ' pe', transform=ax[n_row, n_col].transAxes,
                fontsize=10, verticalalignment='top', fontfamily='serif',
                bbox=dict(facecolor='1.', edgecolor='none', pad=3.0))

    ax[n_row, n_col].set_ylabel('Counts')
    ax[n_row, n_col].set_xlabel('Peak Voltage [mV]')

    ax[n_row, n_col].legend(fontsize=7, loc='best')
    
    n_row += pe%2
# Out:
# 628.0 628.0000000000001 628.0000000000001
# 763.0 763.0 763.0000000000001
# 563.0 563.0000000000001 563.0000000000001
# 299.0 299.00000000000006 299.00000000000006
# 170.0 170.00000000000006 170.00000000000003
# 46.0 46.0 46.00000000000001

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10,5), constrained_layout=True)

x_ax = np.arange(len(e_res)) + 1


ax.errorbar(x_ax, e_res, yerr = e_res_err, fmt = '-o', label = 'Energy resolution vs number of photoelectrons')

ax.set_ylabel('Energy resolution [%]')
ax.set_xlabel('Number of photoelectrons')



# Resolution fit
#     popt, pcov = scipy.optimize.curve_fit(gauss, x_ax, events, p0=[1, bins.mean(), 20.]) 
popt, pcov = scipy.optimize.curve_fit(resolution_eq, x_ax, e_res, 
                                      bounds=([0., 0., 0.], [np.inf, np.inf, np.inf])) 

aa, bb, cc = popt


# Calculate the residuals and chi-square
residuals = e_res - resolution_eq(x_ax, *popt)
data_err = e_res_err

chi2 = np.sum(np.where(data_err > 0., (residuals/ data_err)**2, 0.))


x_ax_fit = np.linspace(x_ax.min(), x_ax.max(), 100)
best_fit_line = resolution_eq(x_ax_fit, aa, bb, cc)

ax.plot(x_ax_fit, best_fit_line, '-', 
        label='Theoretical fit: a = %.2E, b = %.2f, c = %.2f; $\chi^{2} = %.2f$'%(aa, bb, cc, chi2))

    
ax.legend(loc = 'best')
