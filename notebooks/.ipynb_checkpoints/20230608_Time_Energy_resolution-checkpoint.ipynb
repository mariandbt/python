# %% [markdown]
# <h1> ______________________________________ </h1>
#
# <h1> Time and Energy resolution calculation </h1>
# <h1> ______________________________________ </h1>
#
# <p style="font-size: 17px; color: black;"> In this Notebook we calculate the energy and time resolution of our photosensor (SiPM Hamamatsu in this case) the following way:</p>
#
# - <p style="font-size: 17px; color: black; font-weight: bold;"> Time resolution: </p>
# <p style="font-size: 17px; color: black;"> We set a voltage threshold and we measure the time difference between when our signal and our trigger waveform pass that threshold. The std of that time difference distribution will be our time resolution. The time resolution is not the same for all signals so we differentiate among signals of 1pe, 2pe, 3pe, etc. </p>
#
#
# - <p style="font-size: 17px; color: black; font-weight: bold;"> Energy resolution: </p>
# <p style="font-size: 17px; color: black;"> We save for each waveform the value of the peak, then we do the distribution of that value for each waveform type, ie we do different distributions separating waveforms corresponding to 1pe, 2pe, 3pe, etc. The std of that peak distribution will be our energy resolution. </p>

# %% [markdown]
# <h1> ____________ </h1>
# <h2> This version </h2>
# <h1> ____________ </h1>
#
# -  <p style="font-size: 17px; color: black;"> In this notebook we don't save all the waveforms, but rather work with them re-reading the files. This might take more time but less memory, preventing the laptop to collapse. </p>
# -  <p style="font-size: 17px; color: black;"> Unified Y11 and B2 notebook. </p>
# -  <p style="font-size: 17px; color: black;"> 10K events each fibers. </p>
# -  <p style="font-size: 17px; color: black;"> Let's try and work with ALL events. </p>
# -  <p style="font-size: 17px; color: black;"> The photosensor signal saturates (there are values considered inf). </p>
# -  <p style="font-size: 17px; color: black;"> Waveforms include just 1 peak. </p>
# -  <p style="font-size: 17px; color: black;"> Signal happens AFTER THE TRIGGER. </p>
#
#
# -  <p style="font-size: 17px; color: black;"> Use interpolation to get the EXACT time at which the waveform cuts the threshold. This way we can basically work with a function intead of the data. </p>
#
#
# -  <p style="font-size: 17px; color: black;"> Calculate chi2 manually cause to use the built in function, the fit has to be normalized and we don't understand why. </p>
# -  <p style="font-size: 17px; color: black;"> Variable bining in the distributions as sqrt(Nevents). </p>
#
#
# -  <p style="font-size: 17px; color: black;"> Instead of obtaining the Npe peaks ad hoc we do it finding the peaks in the maximums distribution. </p>
# -  <p style="font-size: 17px; color: black;"> Same way use this distribution to determine dV from each peak to get rid of the in between events. </p>
#
#
# -  <p style="font-size: 17px; color: black;"> We can choose between a variable or a fixed threshold with fix_th = True/False. </p>
#
#
# -  <p style="font-size: 17px; color: black;"> Energy distribution in % instead of absolute values. </p>
# -  <p style="font-size: 17px; color: black;"> Fit the sigma vs $ N_{pe} $ plot to the corresponding cuadratic sum of terms. </p>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
import math

# %%
import scipy
from scipy import stats, integrate
from scipy.signal import find_peaks
from scipy.interpolate import interp1d
from scipy.optimize import root, root_scalar

# %%
import os

# %% [markdown]
# <h1> _________________________________________________________________________________________________________ </h1>

# %% [markdown]
# <h1> __________________________ </h1>
# <h2> Functions </h2>
#
# -  <p style="font-size: 17px; color: black;"> <b> gauss(x, a,  mu, sigma): </b> Gaussian normalized to $a$. </p>
#
#
# -  <p style="font-size: 17px; color: black;"> <b> f_cut(x, f, val): </b> To find the cut of a $f(x)$ function with a certain value $val$ we first use <b> f_cut </b> to move $f(x) \rightarrow f(x) - val$ and then find it's roots, ie, $f(x) - val = 0$. </p>
#
#
# -  <p style="font-size: 17px; color: black;"> <b> resolution_eq(E, a, b, c): </b> Resolution equation to which our results should fit. </p>

# %%
# Gaussian
# note: pdf are normilized to 1 so we have yo add an amplitude param
def gauss(x, a,  mu, sigma):
# def gauss(x,  mu, sigma):
    
    gaussian = stats.norm.pdf(np.sort(x), mu, sigma) 
    
    return (a/gaussian.sum())*gaussian 
#     return (x.sum()/gaussian.sum())*gaussian 

# Function offsetting
# To find the cut of a function with a certain value first we offset the function then find the roots
def f_cut(x, f, val):
    return f(x) - val

# Resolution equation
def resolution_eq(E, a, b, c):
    
    res = np.sqrt( (a/np.sqrt(E))**2 + (b/E)**2 + c**2)
    
    return res

# %% [markdown]
# -  <p style="font-size: 17px; color: black;"> <b> wave_prep(file): </b> Take a waveform and prepare it to work with it by separating the different variables, correcting offset and possible signal saturation. </p>

# %%
def wave_prep(file_name, fiber, waveform_saturation = np.inf):
    
    input_file = os.path.join(path[fiber], file_name)
    
    # Read the CSV file using pandas
    df = pd.read_csv(input_file, header=14)
    
    time = np.array(df['TIME']*1e6) # [us]
    signal = np.array(df['CH1']*1e3) # [mV]
    LED = np.array(df['CH2']*1e3) # [mV]

    # Offsets
    offset_LED = LED[LED < 0].mean(); LED = LED - offset_LED

    offset_signal = signal[signal < 0].mean(); signal = signal - offset_signal
    
    
    # Saturation
    signal = np.where(signal < waveform_saturation, 
                      signal,
                      signal[signal < waveform_saturation].max())
    
    return time, signal, LED

# %% [markdown]
# <h1> __________________________ </h1>
# <h2> Data </h2>

# %% [markdown]
# -  <p style="font-size: 17px; color: black;"> <b> Reading the file </b> </p>

# %% [markdown]
# -  <p style="font-size: 17px; color: black;"> File's path </p>

# %%
# filename = []
path = {}

init_path = '/home/investigator/mariandbt/python/data/'

path['y11'] = init_path + '20230508/'
path['b2'] = init_path + '20230525' + '_t_res_b2/'

# %% [markdown]
# -  <p style="font-size: 17px; color: black;"> Parameters to read the file. </p>

# %%
files = {}

# %%
# Get all files in the folder
files['y11'] = os.listdir(path['y11'])
files['b2'] = os.listdir(path['b2'])

# %% [markdown]
# -  <p style="font-size: 17px; color: black;"> Parameters of the read file. </p>

# %%
n_frames = int(len(files['y11']))
n_points = int(6250)

print('n_points = ', n_points)
print('n_frames = ', n_frames)
# Out:
# n_points =  6250
# n_frames =  10000

# %% [markdown]
# <h1> __________________________ </h1>
# <h2> Global parameters </h2>

# %% [markdown]
# -  <p style="font-size: 17px; color: black;"> <b> Analysis parameters </b> </p>
#
#  -  <p style="font-size: 17px; color: black;"> <b> dV: </b> When separating signals to differentiate between different photo-electron signals we define a validity region around the selected $N_{pe}$ value with width $dV$. </p>
#
#  -  <p style="font-size: 17px; color: black;"> <b> fix_th: </b> True if we want to use a fixed threshold (determined after the multi-pe peaks). If not, the threshold at which to measure the time difference between signal and trigger is variable depending on each waveform. </p>

# %%
dV = 30 # [mV] Voltage difference from the multi-pe peaks we're considering

# %%
fix_th = False # True if we want to use a fixed threshold (determined after the multi-pe peaks)

# %% [markdown]
# <h1> __________________________ </h1>
# <h2> Analysis </h2>

# %% [markdown]
# <h2> Determination of the $N_{pe}$ peaks </h2>

# %% [markdown]
# -  <p style="font-size: 17px; color: black;"> Use a peak distribution and select this distribution peaks as the $N_{pe}$ values and $dV$ as the validity region around these value to consider a certain signal part of that $N_{pe}$ group. </p>

# %% [markdown]
# -  <p style="font-size: 17px; color: black;"> Save the maximum of each waveform to do the distribution later. Since there are some waveforms that saturate we pick the second highest valid value. </p>

# %%
pe_peaks = {}
pe_peaks['y11'] = []
pe_peaks['b2'] = []

# %%
for fiber in ['y11', 'b2']:
    for ii, file_name in enumerate(files[fiber]):
        
        _, ss, _ = wave_prep(file_name, fiber, waveform_saturation = np.inf)
        pe_peaks[fiber].append(ss.max())
        
    pe_peaks[fiber] = np.array(pe_peaks[fiber])
    print(f'Done with {fiber} fibers!')
# Out:
# Done with y11 fibers!
# Done with b2 fibers!

# %% [markdown]
# -  <p style="font-size: 17px; color: black;"> Set the parameters to later find the peaks in the distribution and determine the acceptance region around this peak. </p>

# %%
height_min = {} # height threshold to which consider a peak
height_min = {} # height threshold to which consider a peak
dist_min = {} # min distance between peaks required
dif_min = {} # min height difference between the peak point and their neighbours

# %%
height_min['y11'] = n_frames/250. # height threshold to which consider a peak
height_min['y11'] = 10. # height threshold to which consider a peak
dist_min['y11'] = 5. # min distance between peaks required
dif_min['y11'] = None # min height difference between the peak point and their neighbours

# %%
height_min['b2'] = n_frames/250. # height threshold to which consider a peak
height_min['b2'] = 10. # height threshold to which consider a peak
dist_min['b2'] = 5. # min distance between peaks required
dif_min['b2'] = None # min height difference between the peak point and their neighbours

# %% [markdown]
# - <p style="font-size: 17px; color: black;"> Waveform's maximums distribution and location of the photo-electrons peaks and the acceptance region around.

# %%
fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(10,7), constrained_layout=True)

x_ax = {}
peaks = {}

for i, key in enumerate(['y11', 'b2']):

    events, bins, bars = ax[i].hist(pe_peaks[key], 100, 
                                 density=False, 
                                 label='Multi-photo-electron spectrum', 
                                 histtype='step')
    x_ax[key] = bins[:-1]
    diffs = np.abs(np.diff(bins))
    # accept_region = np.array(dV/diffs, dtype = int) # instead of defining the acceptance region by Voltage we define it in terms of bins
    accept_region = dV*np.ones(len(x_ax[key]))

    peaks[key], _ = find_peaks(events, height=height_min[key], threshold=dif_min[key], distance=dist_min[key])

    for ii in range(len(peaks[key])):
        ax[i].fill_between([(x_ax[key][peaks[key]] - accept_region[peaks[key]])[ii], 
                         (x_ax[key][peaks[key]] + accept_region[peaks[key]])[ii]], 
                        events[peaks[key]].max(), 
                        color = 'magenta', alpha = 0.3, label = r'Peak regions ($\pm$ %.2f mV)'%(dV)) 

    ax[i].plot(x_ax[key][peaks[key]], events[peaks[key]], 'o', label = 'Identified peaks')
    ax[i].plot(x_ax[key], height_min[key]*np.ones(len(x_ax[key])), label = 'Minimum height considered for a peak')

    ax[i].set_xlabel('Pe signal [mV]')
    ax[i].set_ylabel('Counts')
    ax[i].set_title(key)

    hand, labl = ax[i].get_legend_handles_labels()
    hand, labl = np.array(hand), np.array(labl)
    not_duplicated = ~pd.DataFrame(labl).duplicated()

    ax[i].legend(hand[not_duplicated], labl[not_duplicated], loc = 'best')
    # ax[i].legend(loc='best')

# %%
signal_pe = {}
n_pe = {}

# %%
for key in ['y11', 'b2']:
    signal_pe[key] = x_ax[key][peaks[key]]
    signal_pe[key] = signal_pe[key][signal_pe[key] > 50] # to make sure not to include the 0 pe
    n_pe[key] = len(signal_pe[key])
    
    print(r'Npe for %s fibers = '%(key), n_pe[key])
# print('Npe values = ', signal_pe)
# Out:
# Npe for y11 fibers =  11
# Npe for b2 fibers =  8

# %%
import matplotlib as mpl
import copy

my_cmap = copy.copy(plt.get_cmap('plasma')) # copy the default cmap
my_cmap.set_bad(my_cmap.colors[0]) #  set the color of invalid or masked values in the colormap

t_peak = {}
t_peak['y11'] = 0.53
t_peak['b2'] = 0.083

# %%
time = {}
signal = {}
LED = {}

top = 1000

for fiber in ['y11', 'b2']:
    
    t = []
    s = []
    l = []
    
    for file_name in files[fiber][:top]:
        
        tt, ss, ll = wave_prep(file_name, fiber, waveform_saturation = np.inf)
        
        t.append(tt)
        s.append(ss)
        l.append(ll)
    
    time[fiber] = np.concatenate(t)    
    signal[fiber] = np.concatenate(s)    
    LED[fiber] = np.concatenate(l)

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(15,5), constrained_layout=True)

for i, key in enumerate(['y11', 'b2']):

    counts, xedges, yedges, im = ax[i].hist2d(time[key], signal[key], 
                                           bins=100, rasterized=True, 
                                           range=((time[key].min(),time[key].max()), 
                                                  (signal[key].min(), 1.1*signal[key].max())), 
                                           cmap=my_cmap, norm=mpl.colors.LogNorm(vmin = 1))

    for ii in range(n_pe[key]):
        ax[i].plot(t_peak[key], signal_pe[key][ii], 'ow', markersize = 3, label = '%s pe'%(ii))



    ax[i].set_xlabel(r"Time [$\mathrm{\mu}$s]", size='larger')
    ax[i].set_ylabel("Voltage [mV]", size='larger')
    ax[i].set_title(key)
    
    # ax[i].legend(loc = 'best')

fig.colorbar(im, ax = ax, orientation='vertical')
# fig.savefig("waveforms.pdf")

# %% [markdown]
# - <p style="font-size: 17px; color: black;"> Set fixed threshold to 50% of the single photo-electron.

# %%
th_fixed = .5*signal_pe['y11'][0] # [mV] Height at which we measure the time difference between LED and Signal

# %% [markdown]
# <h2> Waveform </h2>

# %% [markdown]
# -  <p style="font-size: 17px; color: black;"> Interpolate the waveform to create a function. </p>

# %%
frame = 23
# frame = 789
# frame = 3151
# frame = 1755; th = 57.38 # [mV]
# frame = 2031; th = 131.43 # [mV]
# frame = 266; th = 114.13 # [mV]
# frame = 1712
# frame = 4954

# %%
tt = {}
ss = {}
ll = {}

# %%
for fiber in ['y11', 'b2']:
    
    file_name = files[fiber][frame]

    tt[fiber], ss[fiber], ll[fiber] = wave_prep(file_name, fiber, waveform_saturation = np.inf)

# %% [markdown]
# -  <p style="font-size: 17px; color: black;"> Time region where to look for signal. </p>

# %%
tt_min = {}
tt_max = {}
tt_region_mask = {}

# %%
tt_min['y11'] = 0.45 # [us]
tt_max['y11'] = 0.7 # [us]

tt_min['b2'] = 0. # [us]
tt_max['b2'] = 0.4 # [us]

# %%
for key in ['y11', 'b2']:
    tt_region_mask[key] = (tt[key] > tt_min[key]) & (tt[key] < tt_max[key]) # Where to look for the signal

# %% [markdown]
# - <p style="font-size: 17px; color: black;"> Threshold to consider a peak in this waveform.

# %%
th = {}

# %%
for key in ['y11', 'b2']:

    th[key] = max(0.8*signal_pe[key][0], min(0.8*ss[key][tt_region_mask[key]].max(), 0.8*ll[key].max()))

    if fix_th:
        th[key] = th_fixed

    print('threshold for %s fibers = %.2f mV'%(key, th[key]))
# Out:
# threshold for y11 fibers = 251.66 mV
# threshold for b2 fibers = 190.96 mV

# %% [markdown]
# <p style="font-size: 17px; color: black;"> Data waveform

# %%
fig, ax = plt.subplots(2, 1, figsize = (15, 10), constrained_layout=True)

for i, key in enumerate(['y11', 'b2']):

    ax[i].plot(tt[key], ll[key], label = 'LED')
    ax[i].plot(tt[key], ss[key], label = 'signal')
    ax[i].plot(tt[key], th[key]*np.ones(len(tt[key])), label = 'threshold')

    ax[i].fill_between([tt_min[key], tt_max[key]], max(ll[key].max(), ss[key].max()), 
                    color = 'peachpuff', alpha = 0.5, label = r'Time region for signal') 

    ax[i].set_ylabel('Voltage [mV]');
    ax[i].set_xlabel('Time [us]');
    ax[i].set_title('Data waveform with %s fibers'%(key), size = 20);
    ax[i].legend(loc = 'best')

# %% [markdown]
# - <p style="font-size: 17px; color: black;"> Waveform interpolation and finding the cut with the threshold.

# %%
f_ss = {}
f_ll = {}

root_ss = {}
root_ll = {}

dt = {}

# %%
for key in ['y11', 'b2']:
    
    # Define the interpolation functions
    f_ss[key] = interp1d(tt[key], ss[key])
    f_ll[key] = interp1d(tt[key], ll[key])

    # Define the intervals where to search for roots
    t0 = tt[key][ss[key] - th[key] < 0.][0]
    tf_ss = tt[key][(tt[key] > tt_min[key]) & (ss[key] - th[key] > 0.)][0]
    tf_ll = tt[key][ll[key] - th[key] > 0.][0]

    # Find the roots of the new function for val = th
    root_ss[key] = root_scalar(f_cut, args=(f_ss[key], th[key],), bracket=[t0, tf_ss]).root
    root_ll[key] = root_scalar(f_cut, args=(f_ll[key], th[key],), bracket=[tt[key].min(), tf_ll]).root

    dt[key] = np.fabs(root_ss[key] - root_ll[key])
    print('dt[%s] = %.2f us'%(key, dt[key]))
# Out:
# dt[y11] = 0.52 us
# dt[b2] = 0.08 us

# %%
fig, ax = plt.subplots(2, 1, figsize = (15, 10), constrained_layout=True)

for i, key in enumerate(['y11', 'b2']):

    ax[i].plot(tt[key], f_ll[key](tt[key]), label = 'LED interpolation')
    ax[i].plot(tt[key], f_ss[key](tt[key]), label = 'Signal interpolation')
    ax[i].plot(tt[key], th[key]*np.ones(len(tt[key])), label = 'threshold')

    ax[i].fill_between([tt_min[key], tt_max[key]], max(ll[key].max(), ss[key].max()), 
                    color = 'peachpuff', alpha = 0.5, label = r'Time region for signal') 

    ax[i].plot(root_ss[key], th[key], 'o', markersize = 5, label = 'Signal cut with threshold')
    ax[i].plot(root_ll[key], th[key], 'o', markersize = 5, label = 'LED cut with threshold')
    ax[i].plot(np.linspace(root_ss[key], root_ll[key], len(tt[key])), 
               th[key]*np.ones(len(tt[key])), '-m', label = 'dt = %.2f us'%(dt[key]))

    ax[i].set_ylabel('Voltage [mV]');
    ax[i].set_xlabel('Time [us]');
    ax[i].set_title('Interpolated waveform for %s fibers'%(key), size = 20);
    ax[i].legend(loc = 'best')

# %% [markdown]
# <h2> Difference in time calculation for all frames </h2>

# %% [markdown]
# - <p style="font-size: 17px; color: black;"> Note how we're working with the fact that the signal appears in a certain time region to constrain the valid region of signal we use using the mask.

# %%
f_ss = {}
f_ll = {}

root_ss = {}
root_ll = {}

dt = {'y11':[], 'b2':[]}

s_peak = {'y11':[], 'b2':[]}


for key in ['y11', 'b2']:
    print('\n%s fibers_______________________________________'%(key))
    try:
        for frame in range(n_frames):
            
            file_name = files[key][frame]

            tt, ss, ll = wave_prep(file_name, fiber = key, waveform_saturation = np.inf)

            
            tt_region_mask = (tt > tt_min[key]) & (tt < tt_max[key]) # Where to look for the signal

            th = max(0.8*signal_pe[key][0], min(0.8*ss[tt_region_mask].max(), 0.8*ll.max()))

            if fix_th:
                th = th_fixed

            if ss[tt_region_mask].max() < th: 
                print('NO SIGNAL HERE! frame = %s; th = %.2f # [mV]'%(frame, th))
                continue

            if ss[tt_region_mask][0] > th: 
                print('This is not signal, it is the tail of a noise pulse! frame = %s; th = %.2f # [mV]'%(frame, th))
                continue

            # Define the interpolation functions
            f_ss = interp1d(tt, ss) 
            f_ll = interp1d(tt, ll)

            # Define the intervals where to search for roots
            t0 = tt[ss - th < 0.][0]
            tf_ss = tt[(tt > tt_min[key]) & (ss - th > 0.)][0]
            tf_ll = tt[ll - th > 0.][0]

            # Find the roots of the new function for val = th
            root_ss = root_scalar(f_cut, args=(f_ss, th,), bracket=[t0, tf_ss]).root
            root_ll = root_scalar(f_cut, args=(f_ll, th,), bracket=[tt.min(), tf_ll]).root

            s_peak[key].append(ss.max())
            dt[key].append(np.fabs(root_ss - root_ll))

    except Exception as e:
        print("Python sais:", str(e))
        print("Marian sais: Error accured for fiber %s in frame %s"%(key, frame))

    dt[key] = np.array(dt[key])
    s_peak[key] = np.array(s_peak[key])
# Out:
# y11 fibers_______________________________________
# NO SIGNAL HERE! frame = 1; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 2; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 12; th = 55.51 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 27; th = 326.10 # [mV]
# NO SIGNAL HERE! frame = 32; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 60; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 61; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 94; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 118; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 125; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 126; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 142; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 158; th = 55.51 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 170; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 176; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 193; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 201; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 254; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 285; th = 55.51 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 392; th = 112.87 # [mV]
# NO SIGNAL HERE! frame = 399; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 431; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 532; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 550; th = 55.51 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 559; th = 105.65 # [mV]
# NO SIGNAL HERE! frame = 584; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 652; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 678; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 684; th = 55.51 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 731; th = 102.68 # [mV]
# NO SIGNAL HERE! frame = 734; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 739; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 746; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 756; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 814; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 821; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 827; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 835; th = 55.51 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 894; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 917; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 979; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 992; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 1104; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 1148; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 1306; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 1329; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 1377; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 1437; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 1483; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 1565; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 1569; th = 55.51 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 1590; th = 122.93 # [mV]
# NO SIGNAL HERE! frame = 1602; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 1634; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 1680; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 1693; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 1788; th = 55.51 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 1823; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 1865; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 1935; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 1940; th = 55.51 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 1958; th = 88.53 # [mV]
# NO SIGNAL HERE! frame = 1982; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 2001; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 2005; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 2052; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 2069; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 2076; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 2144; th = 55.51 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 2171; th = 62.74 # [mV]
# NO SIGNAL HERE! frame = 2253; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 2270; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 2331; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 2334; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 2337; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 2353; th = 55.51 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 2392; th = 58.47 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 2406; th = 88.73 # [mV]
# NO SIGNAL HERE! frame = 2409; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 2435; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 2505; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 2568; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 2577; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 2606; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 2612; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 2614; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 2651; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 2676; th = 55.51 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 2681; th = 64.54 # [mV]
# NO SIGNAL HERE! frame = 2691; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 2702; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 2762; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 2810; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 2847; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 2851; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 2960; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 2989; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 3036; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 3055; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 3085; th = 55.51 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 3148; th = 72.08 # [mV]
# NO SIGNAL HERE! frame = 3152; th = 55.51 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 3154; th = 110.36 # [mV]
# NO SIGNAL HERE! frame = 3174; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 3226; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 3289; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 3295; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 3390; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 3426; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 3432; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 3438; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 3544; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 3616; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 3617; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 3637; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 3641; th = 55.51 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 3731; th = 63.96 # [mV]
# NO SIGNAL HERE! frame = 3737; th = 55.51 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 3764; th = 58.33 # [mV]
# NO SIGNAL HERE! frame = 3795; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 3823; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 3886; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 3971; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 3972; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 3983; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 4004; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 4019; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 4024; th = 55.51 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 4034; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 4069; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 4178; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 4188; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 4258; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 4287; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 4292; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 4322; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 4376; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 4377; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 4478; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 4520; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 4552; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 4604; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 4771; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 4800; th = 55.51 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 4805; th = 317.52 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 4825; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 4827; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 4840; th = 55.51 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 4854; th = 109.42 # [mV]
# NO SIGNAL HERE! frame = 4930; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 4985; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 4991; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 5007; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 5028; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 5041; th = 55.51 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 5076; th = 109.91 # [mV]
# NO SIGNAL HERE! frame = 5119; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 5123; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 5128; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 5143; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 5151; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 5171; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 5205; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 5231; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 5263; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 5311; th = 55.51 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 5331; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 5337; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 5342; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 5355; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 5367; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 5382; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 5386; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 5405; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 5444; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 5452; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 5497; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 5528; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 5562; th = 55.51 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 5576; th = 102.76 # [mV]
# NO SIGNAL HERE! frame = 5713; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 5714; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 5782; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 5799; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 5823; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 5862; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 5866; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 5877; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 5953; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 5972; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 5993; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 6027; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 6028; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 6032; th = 55.51 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 6084; th = 61.36 # [mV]
# NO SIGNAL HERE! frame = 6096; th = 55.51 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 6097; th = 108.02 # [mV]
# NO SIGNAL HERE! frame = 6111; th = 55.51 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 6133; th = 61.85 # [mV]
# NO SIGNAL HERE! frame = 6177; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 6251; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 6258; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 6266; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 6282; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 6321; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 6342; th = 55.51 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 6415; th = 208.29 # [mV]
# NO SIGNAL HERE! frame = 6485; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 6489; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 6535; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 6556; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 6581; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 6605; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 6654; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 6688; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 6703; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 6733; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 6791; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 6794; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 6846; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 6849; th = 55.51 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 6863; th = 145.52 # [mV]
# NO SIGNAL HERE! frame = 6935; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 6939; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 6940; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 6982; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 7008; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 7023; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 7033; th = 55.51 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 7173; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 7256; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 7269; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 7308; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 7334; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 7372; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 7388; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 7403; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 7449; th = 55.51 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 7459; th = 117.74 # [mV]
# NO SIGNAL HERE! frame = 7472; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 7494; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 7495; th = 55.51 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 7526; th = 105.64 # [mV]
# NO SIGNAL HERE! frame = 7589; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 7647; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 7653; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 7654; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 7669; th = 55.51 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 7672; th = 72.18 # [mV]
# NO SIGNAL HERE! frame = 7685; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 7705; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 7711; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 7737; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 7745; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 7775; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 7844; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 7919; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 7978; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 7994; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 8007; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 8022; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 8026; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 8100; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 8106; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 8263; th = 55.51 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 8277; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 8307; th = 55.51 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 8343; th = 115.27 # [mV]
# NO SIGNAL HERE! frame = 8344; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 8368; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 8419; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 8426; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 8459; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 8562; th = 55.51 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 8588; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 8598; th = 55.51 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 8607; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 8618; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 8663; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 8729; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 8786; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 8789; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 8801; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 8826; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 8852; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 8861; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 8890; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 8981; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 9033; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 9054; th = 55.51 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 9057; th = 101.72 # [mV]
# NO SIGNAL HERE! frame = 9153; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 9159; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 9166; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 9181; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 9184; th = 55.51 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 9191; th = 110.92 # [mV]
# NO SIGNAL HERE! frame = 9221; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 9337; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 9425; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 9458; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 9487; th = 55.51 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 9508; th = 118.42 # [mV]
# NO SIGNAL HERE! frame = 9544; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 9547; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 9582; th = 55.51 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 9590; th = 112.13 # [mV]
# NO SIGNAL HERE! frame = 9604; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 9638; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 9651; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 9659; th = 55.51 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 9675; th = 56.18 # [mV]
# NO SIGNAL HERE! frame = 9761; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 9801; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 9802; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 9814; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 9830; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 9845; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 9848; th = 55.51 # [mV]
# NO SIGNAL HERE! frame = 9857; th = 55.51 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 9942; th = 107.30 # [mV]
# NO SIGNAL HERE! frame = 9972; th = 55.51 # [mV]
#
# b2 fibers_______________________________________
# This is not signal, it is the tail of a noise pulse! frame = 4; th = 134.03 # [mV]
# NO SIGNAL HERE! frame = 33; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 43; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 47; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 53; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 64; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 65; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 66; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 73; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 80; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 93; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 113; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 132; th = 128.14 # [mV]
# NO SIGNAL HERE! frame = 140; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 144; th = 129.65 # [mV]
# NO SIGNAL HERE! frame = 160; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 162; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 193; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 226; th = 176.33 # [mV]
# NO SIGNAL HERE! frame = 227; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 252; th = 133.11 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 269; th = 136.23 # [mV]
# NO SIGNAL HERE! frame = 284; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 286; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 293; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 298; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 321; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 350; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 351; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 363; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 375; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 376; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 391; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 399; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 402; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 413; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 420; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 457; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 473; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 480; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 495; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 514; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 520; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 530; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 533; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 543; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 552; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 569; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 586; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 598; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 618; th = 70.53 # [mV]
# NO SIGNAL HERE! frame = 661; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 669; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 675; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 683; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 685; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 687; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 693; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 697; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 699; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 706; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 708; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 716; th = 142.22 # [mV]
# NO SIGNAL HERE! frame = 744; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 745; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 748; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 756; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 795; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 800; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 833; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 834; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 849; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 850; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 880; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 888; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 892; th = 231.82 # [mV]
# NO SIGNAL HERE! frame = 893; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 914; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 929; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 949; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 968; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 981; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 1000; th = 95.14 # [mV]
# NO SIGNAL HERE! frame = 1014; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1017; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1028; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1033; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1049; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1050; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1076; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1097; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1099; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1100; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1104; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1113; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1116; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1127; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1128; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 1137; th = 140.18 # [mV]
# NO SIGNAL HERE! frame = 1139; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1150; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1173; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1177; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 1178; th = 78.16 # [mV]
# NO SIGNAL HERE! frame = 1181; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1188; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1219; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1235; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1240; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1246; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1248; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 1250; th = 118.73 # [mV]
# NO SIGNAL HERE! frame = 1256; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1264; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1267; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1301; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1309; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 1318; th = 132.46 # [mV]
# NO SIGNAL HERE! frame = 1324; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 1325; th = 126.89 # [mV]
# NO SIGNAL HERE! frame = 1352; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1362; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1380; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1382; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1386; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1418; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1419; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1423; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1429; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1430; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 1431; th = 126.15 # [mV]
# NO SIGNAL HERE! frame = 1433; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1440; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1444; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1461; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1473; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1504; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1513; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1521; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 1524; th = 254.94 # [mV]
# NO SIGNAL HERE! frame = 1530; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1531; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1536; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1541; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1553; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1554; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1555; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 1571; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1581; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1583; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1602; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1618; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1626; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1643; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1660; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1662; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1668; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1674; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1714; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1716; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1719; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1722; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1730; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1749; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1771; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1779; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1782; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1790; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1800; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 1810; th = 186.34 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 1813; th = 130.64 # [mV]
# NO SIGNAL HERE! frame = 1841; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1850; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1886; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1892; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1900; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1903; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1904; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 1905; th = 125.74 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 1906; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1908; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1910; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1915; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1944; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1946; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 1958; th = 92.45 # [mV]
# NO SIGNAL HERE! frame = 1979; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 1988; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2004; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2011; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2020; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2027; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2038; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2045; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2057; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2071; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2073; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 2078; th = 110.96 # [mV]
# NO SIGNAL HERE! frame = 2079; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2087; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2091; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2099; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2105; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2114; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2126; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2127; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2131; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2143; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2168; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2170; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2189; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2190; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2192; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2206; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2208; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2221; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2255; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2282; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2283; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2297; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2303; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2308; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2338; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2356; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2359; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2362; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2363; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2367; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2388; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2401; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2414; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 2428; th = 96.84 # [mV]
# NO SIGNAL HERE! frame = 2434; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2441; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2446; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2466; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2471; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 2472; th = 183.14 # [mV]
# NO SIGNAL HERE! frame = 2474; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 2482; th = 121.18 # [mV]
# NO SIGNAL HERE! frame = 2493; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2501; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2512; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2524; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2532; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 2534; th = 163.10 # [mV]
# NO SIGNAL HERE! frame = 2559; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2562; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2564; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 2580; th = 149.16 # [mV]
# NO SIGNAL HERE! frame = 2589; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2591; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2598; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2602; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 2632; th = 86.78 # [mV]
# NO SIGNAL HERE! frame = 2636; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2658; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 2673; th = 68.73 # [mV]
# NO SIGNAL HERE! frame = 2688; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2698; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2713; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2723; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2725; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2731; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 2732; th = 234.23 # [mV]
# NO SIGNAL HERE! frame = 2738; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2759; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2760; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2776; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2781; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2789; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2793; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2804; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2811; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2816; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2818; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 2830; th = 122.79 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 2857; th = 102.21 # [mV]
# NO SIGNAL HERE! frame = 2860; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2861; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2866; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2870; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2879; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2890; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2902; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2906; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2909; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2941; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2950; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2957; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2962; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2969; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2972; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2978; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2982; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 2989; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 3000; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 3019; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 3031; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 3041; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 3046; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 3052; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 3058; th = 73.44 # [mV]
# NO SIGNAL HERE! frame = 3091; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 3103; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 3153; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 3156; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 3177; th = 156.74 # [mV]
# NO SIGNAL HERE! frame = 3179; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 3195; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 3197; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 3206; th = 131.83 # [mV]
# NO SIGNAL HERE! frame = 3211; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 3212; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 3220; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 3225; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 3232; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 3240; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 3255; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 3264; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 3274; th = 156.78 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 3303; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 3306; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 3316; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 3325; th = 129.52 # [mV]
# NO SIGNAL HERE! frame = 3343; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 3349; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 3388; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 3392; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 3401; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 3416; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 3417; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 3479; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 3495; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 3503; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 3505; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 3514; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 3516; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 3550; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 3577; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 3581; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 3582; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 3595; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 3612; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 3619; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 3630; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 3643; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 3645; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 3655; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 3656; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 3657; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 3662; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 3679; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 3690; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 3695; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 3738; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 3765; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 3767; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 3774; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 3795; th = 154.01 # [mV]
# NO SIGNAL HERE! frame = 3801; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 3813; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 3840; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 3841; th = 134.58 # [mV]
# NO SIGNAL HERE! frame = 3856; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 3881; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 3890; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 3912; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 3916; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 3926; th = 74.43 # [mV]
# NO SIGNAL HERE! frame = 3930; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 3943; th = 85.87 # [mV]
# NO SIGNAL HERE! frame = 3951; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 3964; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 3966; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 3967; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 3968; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 3997; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4004; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4018; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4034; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4035; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4036; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4049; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4050; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4073; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4078; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4085; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4089; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4094; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4098; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4116; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4119; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4120; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4158; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4160; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4165; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4176; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4179; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 4212; th = 138.55 # [mV]
# NO SIGNAL HERE! frame = 4224; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4241; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4254; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4258; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4266; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4285; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4305; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4306; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4310; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4317; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4325; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4331; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4340; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4346; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4352; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4366; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4372; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4414; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4440; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4442; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4443; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4447; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4487; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4494; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 4526; th = 68.47 # [mV]
# NO SIGNAL HERE! frame = 4530; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4543; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4544; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4548; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4590; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4597; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4609; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4629; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4635; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4644; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4653; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4680; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4698; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4705; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 4714; th = 78.46 # [mV]
# NO SIGNAL HERE! frame = 4717; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4728; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4772; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 4774; th = 138.91 # [mV]
# NO SIGNAL HERE! frame = 4781; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4794; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4797; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4816; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4820; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4821; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4833; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4834; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4860; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4861; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4862; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4866; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4872; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4894; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4902; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4905; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4917; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4925; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4938; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4944; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4952; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 4954; th = 142.14 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 4972; th = 73.32 # [mV]
# NO SIGNAL HERE! frame = 4973; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 4987; th = 140.30 # [mV]
# NO SIGNAL HERE! frame = 4992; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 4994; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 5010; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 5011; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 5030; th = 69.87 # [mV]
# NO SIGNAL HERE! frame = 5031; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 5032; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 5039; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 5054; th = 98.03 # [mV]
# NO SIGNAL HERE! frame = 5066; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 5093; th = 140.89 # [mV]
# NO SIGNAL HERE! frame = 5101; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 5106; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 5110; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 5111; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 5114; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 5128; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 5133; th = 68.64 # [mV]
# NO SIGNAL HERE! frame = 5144; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 5145; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 5156; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 5162; th = 132.80 # [mV]
# NO SIGNAL HERE! frame = 5164; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 5165; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 5167; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 5173; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 5174; th = 135.98 # [mV]
# NO SIGNAL HERE! frame = 5184; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 5193; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 5197; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 5214; th = 68.78 # [mV]
# NO SIGNAL HERE! frame = 5224; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 5231; th = 127.87 # [mV]
# NO SIGNAL HERE! frame = 5237; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 5239; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 5243; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 5279; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 5295; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 5301; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 5335; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 5348; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 5349; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 5353; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 5359; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 5411; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 5421; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 5433; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 5435; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 5456; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 5471; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 5477; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 5504; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 5508; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 5521; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 5529; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 5536; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 5540; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 5541; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 5560; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 5570; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 5581; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 5584; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 5619; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 5628; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 5631; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 5642; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 5672; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 5705; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 5714; th = 153.21 # [mV]
# NO SIGNAL HERE! frame = 5720; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 5726; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 5727; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 5730; th = 69.71 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 5741; th = 116.33 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 5742; th = 90.00 # [mV]
# NO SIGNAL HERE! frame = 5749; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 5778; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 5779; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 5789; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 5807; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 5809; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 5819; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 5824; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 5829; th = 170.04 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 5842; th = 120.89 # [mV]
# NO SIGNAL HERE! frame = 5843; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 5857; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 5858; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 5860; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 5885; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 5902; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 5903; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 5915; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 5940; th = 122.78 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 5941; th = 184.16 # [mV]
# NO SIGNAL HERE! frame = 5944; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 5954; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 5957; th = 72.15 # [mV]
# NO SIGNAL HERE! frame = 5965; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 5969; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 5972; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 5983; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 5991; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 5993; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 5995; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 6001; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 6008; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 6022; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 6031; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 6032; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 6041; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 6056; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 6060; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 6089; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 6093; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 6103; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 6107; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 6115; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 6121; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 6130; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 6141; th = 68.38 # [mV]
# ...
# NO SIGNAL HERE! frame = 7074; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7081; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7085; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7090; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7095; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7105; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7107; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 7115; th = 147.30 # [mV]
# NO SIGNAL HERE! frame = 7123; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7126; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7128; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7132; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7173; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 7181; th = 80.87 # [mV]
# NO SIGNAL HERE! frame = 7195; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7203; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7205; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7208; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7217; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7218; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7225; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 7226; th = 248.39 # [mV]
# NO SIGNAL HERE! frame = 7231; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7234; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7263; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7283; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7309; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7312; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7316; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7321; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7326; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7327; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7329; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7335; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7339; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7340; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7351; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7355; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7360; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7367; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7374; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7378; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7405; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7410; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7424; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7430; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7446; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7447; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7456; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7467; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7481; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7485; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 7499; th = 140.15 # [mV]
# NO SIGNAL HERE! frame = 7526; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7529; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7550; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7557; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7561; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7566; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7615; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7616; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7628; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7634; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7662; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7669; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7671; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7709; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7713; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 7732; th = 134.74 # [mV]
# NO SIGNAL HERE! frame = 7736; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7768; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7775; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7778; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7815; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7827; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7828; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7834; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7835; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7838; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7850; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7858; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7861; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7862; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7868; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7874; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7878; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7880; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7892; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7893; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7903; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7907; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7909; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7910; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7912; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7916; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7926; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7935; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7951; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 7965; th = 102.22 # [mV]
# NO SIGNAL HERE! frame = 7977; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7986; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7992; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 7996; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8010; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8032; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 8061; th = 88.04 # [mV]
# NO SIGNAL HERE! frame = 8065; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8078; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8087; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8092; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8095; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8096; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8098; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8105; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8108; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8132; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8140; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8158; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8178; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8179; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8196; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8211; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8214; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 8256; th = 85.78 # [mV]
# NO SIGNAL HERE! frame = 8291; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8292; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8303; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8313; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8323; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8328; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8329; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8331; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8333; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 8342; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8352; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8358; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 8361; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8373; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8375; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8381; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8382; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8387; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8397; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8413; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8417; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8422; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8431; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8437; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8442; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8444; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8455; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8458; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8469; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8479; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8482; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 8484; th = 92.77 # [mV]
# NO SIGNAL HERE! frame = 8489; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 8491; th = 124.74 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 8503; th = 126.13 # [mV]
# NO SIGNAL HERE! frame = 8532; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8542; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8544; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8560; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 8566; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8568; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8573; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8579; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8603; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8613; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8615; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8632; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8635; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8648; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8668; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8669; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8671; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8676; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8715; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8730; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8738; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8777; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8786; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8795; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8799; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8800; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8811; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8828; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8833; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8838; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8840; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8896; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8897; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8919; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8924; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8930; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8933; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8934; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8956; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8969; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8975; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 8979; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9005; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9009; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9022; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9023; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9050; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9055; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9063; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9067; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9069; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9088; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9090; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9097; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9111; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9122; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9124; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9132; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9145; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9171; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 9176; th = 162.78 # [mV]
# NO SIGNAL HERE! frame = 9179; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9180; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9182; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9211; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9229; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9245; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9257; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 9264; th = 91.90 # [mV]
# NO SIGNAL HERE! frame = 9273; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9286; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9299; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 9321; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9345; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9347; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9361; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9368; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9385; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9386; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 9389; th = 162.73 # [mV]
# NO SIGNAL HERE! frame = 9403; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9409; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 9411; th = 106.62 # [mV]
# NO SIGNAL HERE! frame = 9433; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9484; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9498; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9504; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 9511; th = 162.68 # [mV]
# NO SIGNAL HERE! frame = 9519; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9529; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9530; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9535; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9570; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9588; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9590; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9592; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9595; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9603; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9604; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9605; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9644; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9654; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9657; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9668; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 9669; th = 131.56 # [mV]
# NO SIGNAL HERE! frame = 9671; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 9680; th = 87.91 # [mV]
# NO SIGNAL HERE! frame = 9685; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9695; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9697; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9704; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9711; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9713; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9718; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9732; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9733; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9740; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9748; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9754; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9755; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9758; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9762; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9763; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9772; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9774; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 9779; th = 86.29 # [mV]
# NO SIGNAL HERE! frame = 9796; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9800; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9804; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9808; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9813; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9822; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9827; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9832; th = 68.38 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 9840; th = 79.66 # [mV]
# This is not signal, it is the tail of a noise pulse! frame = 9876; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9878; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9880; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9894; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9898; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9901; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9910; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9912; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9916; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9919; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9923; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9940; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9948; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9953; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9957; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9959; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9963; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9981; th = 68.38 # [mV]
# NO SIGNAL HERE! frame = 9995; th = 68.38 # [mV]

# %% [markdown]
# <h2> Peak identification </h2>

# %%
mask_pe = {'y11':[], 'b2':[]}

for key in ['y11', 'b2']:
    for i in range(n_pe[key]):
        mask_pe[key].append(np.fabs(s_peak[key] - signal_pe[key][i]) <= dV) # for fixed dV
#         mask_pe[key].append(np.fabs(s_peak[key] - signal_pe[key][i]) <= accept_region[i]) # for fixed number of bins

# %%
fig, ax = plt.subplots(2, 1, figsize = (15, 20), constrained_layout=True)

for i, key in enumerate(['y11', 'b2']):

    #______________________plot settings________________________________________________________

    x_ax = np.arange(len(s_peak[key]))

    ax[i].plot(x_ax, s_peak[key], 'o', label = 'All peaks')

    for ii in range(len(mask_pe[key])):
        ax[i].plot(x_ax[mask_pe[key][ii]], s_peak[key][mask_pe[key][ii]], 'o', label = '%s pe'%(ii + 1))

    ax[i].set_ylabel('Waveform peak [mV]');
    ax[i].set_xlabel('N_event');
    ax[i].set_title(key);

    # ax[i].set_xlim([0, 20])
    # ax[i].set_ylim([s_peak[key].min(), 150])
    ax[i].legend(loc = 'best')

# %% [markdown]
# <h2> Time resolution calculation </h2>

# %%
t_res = {}
t_res_err = {}

for key in ['y11', 'b2']:
    
    t_res[key] = np.zeros(n_pe[key])
    t_res_err[key] = np.zeros(n_pe[key])

# %% [markdown]
# - <p style="font-size: 17px; color: black;"> Y11 fibers $dt$ distribution.

# %%
key = 'y11'

# %%
fig, ax = plt.subplots(nrows = math.ceil(n_pe[key]/2.), ncols = 2, figsize=(10,15), constrained_layout=True)

n_row = 0

for pe in range(n_pe[key]):
    
    n_col = pe%2
    
    N_ev = len(dt[key][mask_pe[key][pe]])
    n_bins = int(np.sqrt(N_ev))
    n_bins = 10*int(np.sqrt(N_ev))
#     n_bins = 100

    reg_dif = 15

    region_min = dt[key][mask_pe[key][pe]].mean()*(1 - 1/reg_dif)
    region_max = dt[key][mask_pe[key][pe]].mean()*(1 + 1/reg_dif)
    
    events, bins, bars = ax[n_row, n_col].hist(dt[key][mask_pe[key][pe]], n_bins, 
                                               density=False,
                                               range=(region_min, region_max),
                                               label='dt distribution', 
                                               histtype='step')
    
    x_ax = np.linspace(bins.min(), bins.max(), len(bins)-1)
    y_err = np.sqrt(events)
    
    ev_th = events.sum()*2/100
        
    # gaussian fit
    popt, pcov = scipy.optimize.curve_fit(gauss, x_ax, events, 
                                          sigma = np.where(y_err > 0., y_err, 1e-3),
                                          p0=[events.sum(), (bins[:-1])[events > ev_th].mean(), 0.001]) 
#                                           bounds=([1,  0.9*bins.mean(), 1e-4], [3., bins.mean(), 1e-2])) 


#     best_fit_line = gauss(x_ax, *popt)
    best_fit_line = gauss(x_ax, *popt)*events.sum()/gauss(x_ax, *popt).sum()
    a, mu, sigma = popt
    
    param_err = np.sqrt(np.diag(pcov))
    a_err, mu_err, sigma_err = param_err
    
    # Calculate p-value and chi-square
    residuals = events - gauss(x_ax, *popt)
    data_err = np.sqrt(events)
    
    chi2 = np.sum( np.where(data_err > 0., (residuals/ data_err)**2, 0.) );
    chi2 /= len(bins)
    
    t_res[key][pe] = sigma
    t_res_err[key][pe] = sigma_err

    #_________plot_settings_________________________________________________

    ax[n_row, n_col].plot(x_ax, gauss(x_ax, a, mu, sigma), '-', 
                          label='$\mu$ = %.2f, $\sigma$ = %.2E, $\chi^{2}$ = %.2E'%(mu, sigma, chi2))
    
    ax[n_row, n_col].text(0.05, .9, str(pe+1) + ' pe', transform=ax[n_row, n_col].transAxes,
                fontsize=10, verticalalignment='top', fontfamily='serif',
                bbox=dict(facecolor='1.', edgecolor='none', pad=3.0))

    ax[n_row, n_col].set_ylabel('Counts')
    ax[n_row, n_col].set_xlabel('dt [us]')
    ax[n_row, n_col].set_title(key)

    ax[n_row, n_col].legend(fontsize=7, loc='upper right')
    
    n_row += pe%2
# Out:
# /tmp/ipykernel_56431/2163955253.py:48: RuntimeWarning: divide by zero encountered in true_divide
#   chi2 = np.sum( np.where(data_err > 0., (residuals/ data_err)**2, 0.) );
# /tmp/ipykernel_56431/2163955253.py:48: RuntimeWarning: divide by zero encountered in true_divide
#   chi2 = np.sum( np.where(data_err > 0., (residuals/ data_err)**2, 0.) );
# /tmp/ipykernel_56431/2163955253.py:48: RuntimeWarning: divide by zero encountered in true_divide
#   chi2 = np.sum( np.where(data_err > 0., (residuals/ data_err)**2, 0.) );
# /tmp/ipykernel_56431/2163955253.py:48: RuntimeWarning: divide by zero encountered in true_divide
#   chi2 = np.sum( np.where(data_err > 0., (residuals/ data_err)**2, 0.) );
# /tmp/ipykernel_56431/2163955253.py:48: RuntimeWarning: divide by zero encountered in true_divide
#   chi2 = np.sum( np.where(data_err > 0., (residuals/ data_err)**2, 0.) );
# /tmp/ipykernel_56431/2163955253.py:48: RuntimeWarning: divide by zero encountered in true_divide
#   chi2 = np.sum( np.where(data_err > 0., (residuals/ data_err)**2, 0.) );
# /tmp/ipykernel_56431/2163955253.py:48: RuntimeWarning: divide by zero encountered in true_divide
#   chi2 = np.sum( np.where(data_err > 0., (residuals/ data_err)**2, 0.) );
# /tmp/ipykernel_56431/2163955253.py:48: RuntimeWarning: divide by zero encountered in true_divide
#   chi2 = np.sum( np.where(data_err > 0., (residuals/ data_err)**2, 0.) );
# /tmp/ipykernel_56431/2163955253.py:48: RuntimeWarning: divide by zero encountered in true_divide
#   chi2 = np.sum( np.where(data_err > 0., (residuals/ data_err)**2, 0.) );
# /tmp/ipykernel_56431/2163955253.py:48: RuntimeWarning: divide by zero encountered in true_divide
#   chi2 = np.sum( np.where(data_err > 0., (residuals/ data_err)**2, 0.) );
# /tmp/ipykernel_56431/2163955253.py:48: RuntimeWarning: divide by zero encountered in true_divide
#   chi2 = np.sum( np.where(data_err > 0., (residuals/ data_err)**2, 0.) );

# %% [markdown]
# - <p style="font-size: 17px; color: black;"> B2 fibers $dt$ distribution.

# %%
key = 'b2'

# %%
fig, ax = plt.subplots(nrows = math.ceil(n_pe[key]/2.), ncols = 2, figsize=(10,10), constrained_layout=True)

n_row = 0

for pe in range(n_pe[key]):
    
    n_col = pe%2
    
    N_ev = len(dt[key][mask_pe[key][pe]])
    n_bins = int(np.sqrt(N_ev))
    n_bins = 10*int(np.sqrt(N_ev))
#     n_bins = 100


    reg_dif = 2

    region_min = dt[key][mask_pe[key][pe]].mean()*(1 - 1/reg_dif)
    region_max = dt[key][mask_pe[key][pe]].mean()*(1 + 1/reg_dif)
    
    events, bins, bars = ax[n_row, n_col].hist(dt[key][mask_pe[key][pe]], n_bins, 
                                               density=False,
                                               range=(region_min, region_max),
                                               label='dt distribution', 
                                               histtype='step')
    
    x_ax = np.linspace(bins.min(), bins.max(), len(bins)-1)
    y_err = np.sqrt(events)
    
    ev_th = events.sum()*2/100
    
    # gaussian fit
    popt, pcov = scipy.optimize.curve_fit(gauss, x_ax, events, 
                                          sigma = np.where(y_err > 0., y_err, 1e-3),
                                          p0=[events.sum(), (bins[:-1])[events > ev_th].mean(), 0.001]) 
#                                           bounds=([1,  0.9*bins.mean(), 1e-4], [3., bins.mean(), 1e-2])) 


#     best_fit_line = gauss(x_ax, *popt)
    best_fit_line = gauss(x_ax, *popt)*events.sum()/gauss(x_ax, *popt).sum()
    a, mu, sigma = popt
    
    param_err = np.sqrt(np.diag(pcov))
    a_err, mu_err, sigma_err = param_err
    
    # Calculate p-value and chi-square
    residuals = events - gauss(x_ax, *popt)
    data_err = np.sqrt(events)
    
    chi2 = np.sum( np.where(data_err > 0., (residuals/ data_err)**2, 0.) );
    chi2 /= len(bins)
    
    t_res[key][pe] = sigma
    t_res_err[key][pe] = sigma_err

    #_________plot_settings_________________________________________________

    ax[n_row, n_col].plot(x_ax, gauss(x_ax, a, mu, sigma), '-', 
                          label='$\mu$ = %.2f, $\sigma$ = %.2E, $\chi^{2}$ = %.2E'%(mu, sigma, chi2))
    
    ax[n_row, n_col].text(0.05, .9, str(pe+1) + ' pe', transform=ax[n_row, n_col].transAxes,
                fontsize=10, verticalalignment='top', fontfamily='serif',
                bbox=dict(facecolor='1.', edgecolor='none', pad=3.0))

    ax[n_row, n_col].set_ylabel('Counts')
    ax[n_row, n_col].set_xlabel('dt [us]')
    ax[n_row, n_col].set_title(key)

    ax[n_row, n_col].legend(fontsize=7, loc='upper right')
    
    n_row += pe%2
# Out:
# /tmp/ipykernel_56431/2648448637.py:49: RuntimeWarning: divide by zero encountered in true_divide
#   chi2 = np.sum( np.where(data_err > 0., (residuals/ data_err)**2, 0.) );
# /tmp/ipykernel_56431/2648448637.py:49: RuntimeWarning: divide by zero encountered in true_divide
#   chi2 = np.sum( np.where(data_err > 0., (residuals/ data_err)**2, 0.) );
# /tmp/ipykernel_56431/2648448637.py:49: RuntimeWarning: divide by zero encountered in true_divide
#   chi2 = np.sum( np.where(data_err > 0., (residuals/ data_err)**2, 0.) );
# /tmp/ipykernel_56431/2648448637.py:49: RuntimeWarning: divide by zero encountered in true_divide
#   chi2 = np.sum( np.where(data_err > 0., (residuals/ data_err)**2, 0.) );
# /tmp/ipykernel_56431/2648448637.py:49: RuntimeWarning: divide by zero encountered in true_divide
#   chi2 = np.sum( np.where(data_err > 0., (residuals/ data_err)**2, 0.) );
# /tmp/ipykernel_56431/2648448637.py:49: RuntimeWarning: divide by zero encountered in true_divide
#   chi2 = np.sum( np.where(data_err > 0., (residuals/ data_err)**2, 0.) );
# /tmp/ipykernel_56431/2648448637.py:49: RuntimeWarning: divide by zero encountered in true_divide
#   chi2 = np.sum( np.where(data_err > 0., (residuals/ data_err)**2, 0.) );
# /tmp/ipykernel_56431/2648448637.py:49: RuntimeWarning: divide by zero encountered in true_divide
#   chi2 = np.sum( np.where(data_err > 0., (residuals/ data_err)**2, 0.) );

# %% [markdown]
# - <p style="font-size: 17px; color: black;"> Time resolution vs $N_{pe}$.

# %%
colors = {'y11':'g', 'b2':'b'}

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10,5), constrained_layout=True)

for key in ['y11', 'b2']:
    
    x_ax = np.arange(len(t_res[key])) + 1

    ax.errorbar(x_ax, t_res[key]*1e3, 
#                 yerr = 0., 
                yerr = t_res_err[key]*1e3, 
                fmt = '-o', color = colors[key], 
                label = 'Time resolution vs number of photoelectrons for %s fibers'%(key))

    ax.set_ylabel('Time resolution [ns]')
    ax.set_xlabel('Number of photoelectrons')


    # Resolution fit
    #     popt, pcov = scipy.optimize.curve_fit(gauss, x_ax, events, p0=[1, bins.mean(), 20.]) 
    popt, pcov = scipy.optimize.curve_fit(resolution_eq, x_ax, t_res[key]*1e3, 
                                          bounds=([0., 0., 0.], [np.inf, np.inf, np.inf])) 

    aa, bb, cc = popt


    # Calculate the residuals and chi-square
    residuals = t_res[key]*1e3 - resolution_eq(x_ax, *popt)
    data_err = t_res_err[key]*1e3

    chi2 = np.sum(np.where(data_err > 0., (residuals/ data_err)**2, 0.))


    x_ax_fit = np.linspace(x_ax.min(), x_ax.max(), 100)
    best_fit_line = resolution_eq(x_ax_fit, aa, bb, cc)

    ax.plot(x_ax_fit, best_fit_line, '--', color = colors[key], 
            label='Theoretical fit for %s: a = %.2E, b = %.2E, c = %.2f; $\chi^{2} = %.2f$'%(key, aa, bb, cc, chi2))

    ax.legend(loc = 'best')

# %% [markdown]
# <p style="font-size: 17px; color: black;"> Energy resolution calculation

# %%
key = 'y11'

# %%
fig, ax = plt.subplots(nrows=int(np.ceil(n_pe[key]/2)), ncols=2, figsize=(10,10), constrained_layout=True)

n_row = 0

e_res = np.zeros(n_pe[key])
e_res_err = np.zeros(n_pe[key])

for pe in range(n_pe[key]):
    
    n_col = pe%2
    
    N_ev = len(s_peak[key][mask_pe[key][pe]])
#     n_bins = 5*int(np.sqrt(N_ev))
    n_bins = int(np.sqrt(N_ev))
    
    events, bins, bars = ax[n_row, n_col].hist(s_peak[key][mask_pe[key][pe]], n_bins, 
                                     density=False, 
#                                                range=(0.08, 0.15),
                                     label='Peak distribution', 
                                     histtype='step')
    x_ax = np.linspace(bins.min(), bins.max(), len(bins)-1)

#     # gaussian fit
#     popt, pcov = scipy.optimize.curve_fit(gauss, x_ax, events, p0=[1, bins.mean(), 20.]) 
    popt, pcov = scipy.optimize.curve_fit(gauss, x_ax, events, 
                                          sigma = np.where(events > 0., np.sqrt(events), 1e-3),
                                          bounds=([events.sum(),  0.9*bins.mean(), 10.], [np.inf, bins.mean(), 60.])) 
    
    best_fit_line = gauss(x_ax, *popt)
    a, mu, sigma = popt
    
    print(events.sum(), best_fit_line.sum(), a)
    
    param_err = np.sqrt(np.diag(pcov))
    a_err, mu_err, sigma_err = param_err
    
#     # Calculate the residuals and chi-square
#     residuals = events - gauss(x_ax, *popt)
#     data_err = np.sqrt(events)
    
#     chi2 = np.sum(np.where(data_err > 0., (residuals/ data_err)**2, 0.))
    
    # Calculate p-value and chi-square
    fit_norm = best_fit_line*events.sum()/best_fit_line.sum() # need to normalize the fit 
    chi2, p_value = stats.chisquare(f_obs = events, f_exp = fit_norm, axis = None)
#     chi2, p_value = stats.chisquare(f_obs = events, f_exp = best_fit_line, axis = None)
    
    e_res[pe] = 100*sigma/mu
    e_res_err[pe] = 100*np.sqrt( (sigma_err/mu)**2 + (sigma*mu_err/mu**2)**2 )

    #_________plot_settings_________________________________________________

    ax[n_row, n_col].plot(x_ax, best_fit_line, '-', 
                          label='$\mu$ = %.2f, $\sigma$ = %.2E, $\chi^{2}$ = %.2f'%(mu, sigma, chi2))
    
    ax[n_row, n_col].text(0.05, .9, str(pe+1) + ' pe', transform=ax[n_row, n_col].transAxes,
                fontsize=10, verticalalignment='top', fontfamily='serif',
                bbox=dict(facecolor='1.', edgecolor='none', pad=3.0))

    ax[n_row, n_col].set_ylabel('Counts')
    ax[n_row, n_col].set_xlabel('Peak Voltage [mV]')

    ax[n_row, n_col].legend(fontsize=7, loc='best')
    
    n_row += pe%2
# Out:
# 638.0 638.0000000000002 638.0000000000001
# 1510.0 1509.9999999999998 1510.0000000000002
# 1696.0 1696.0000000000005 1696.0000000000002
# 1528.0 1527.9999999999998 1528.0000000000002
# 1207.0 1207.0000000000002 1207.0000000000002
# 843.0 843.0 843.0000000000001
# 510.0 509.99999999999994 510.00000000000006
# 268.0 268.0000000000001 268.00000000000006
# 121.0 120.99999999999999 121.00000000000001
# 64.0 64.00000000000003 64.00000000000001
# 24.0 24.000000000000004 24.000000000000004

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10,5), constrained_layout=True)

x_ax = np.arange(len(e_res)) + 1


ax.errorbar(x_ax, e_res, yerr = e_res_err, fmt = '-o', label = 'Energy resolution vs number of photoelectrons')

ax.set_ylabel('Energy resolution [%]')
ax.set_xlabel('Number of photoelectrons')



# Resolution fit
#     popt, pcov = scipy.optimize.curve_fit(gauss, x_ax, events, p0=[1, bins.mean(), 20.]) 
popt, pcov = scipy.optimize.curve_fit(resolution_eq, x_ax, e_res, 
                                      bounds=([0., 0., 0.], [np.inf, np.inf, np.inf])) 

aa, bb, cc = popt


# Calculate the residuals and chi-square
residuals = e_res - resolution_eq(x_ax, *popt)
data_err = e_res_err

chi2 = np.sum(np.where(data_err > 0., (residuals/ data_err)**2, 0.))


x_ax_fit = np.linspace(x_ax.min(), x_ax.max(), 100)
best_fit_line = resolution_eq(x_ax_fit, aa, bb, cc)

ax.plot(x_ax_fit, best_fit_line, '-', 
        label='Theoretical fit: a = %.2E, b = %.2f, c = %.2f; $\chi^{2} = %.2f$'%(aa, bb, cc, chi2))

    
ax.legend(loc = 'best')
