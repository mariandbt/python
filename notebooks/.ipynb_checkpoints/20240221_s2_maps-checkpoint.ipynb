# %% [markdown]
# <h1> ______________________________________ </h1>
#
# <h1> Maps using the modules </h1>
# <h1> ______________________________________ </h1>
#
# <p style="font-size: 17px; color: black;"> Patata. </p>

# %% [markdown]
# <h1> ____________ </h1>
# <h2> This version </h2>
# <h1> ____________ </h1>
#
# -  <p style="font-size: 17px; color: black;"> s2 maps. </p>

# %%
import sys
sys.path.append('/home/investigator/mariandbt/python/notebooks/modules')

# %%
from import_modules import *

# %%
import set_up as setup
import s2_table as s2tab

# %%
# Data reading
# ________________________________________________________________________________________________________________

path = '/home/investigator/mariandbt/python/data'
path = path + '/20231025_NEXT100_full_mapping'
file_path = os.path.join(path, "Next100_full_mapp_s2_inicioEL_100Kev.next.h5")

# %%
# Data reading
# ________________________________________________________________________________________________________________

particles = pd.read_hdf(file_path, "/MC/particles")
sns_positions, sns_response = setup.read_fiber_sens(file_path)
# Out:
# /home/investigator/miniconda3/envs/IC-3.8-2022-04-13/lib/python3.8/site-packages/pandas/io/pytables.py:3523: IncompatibilityWarning:
# where criteria is being ignored as this version [0.0.0] is too old (or
# not-defined), read the file in and write it out to a new file to upgrade (with
# the copy_to method)
#
#   warnings.warn(ws, IncompatibilityWarning)

# %%
# Global params
# ________________________________________________________________________________________________________________

bin_width = 10 # [mm]
yield_ = 1050 # ph/e⁻

# %%
_ = setup.print_sens_geometry(file_path)
# Out:
# /home/investigator/miniconda3/envs/IC-3.8-2022-04-13/lib/python3.8/site-packages/pandas/io/pytables.py:3523: IncompatibilityWarning:
# where criteria is being ignored as this version [0.0.0] is too old (or
# not-defined), read the file in and write it out to a new file to upgrade (with
# the copy_to method)
#
#   warnings.warn(ws, IncompatibilityWarning)

# %%
selected_sens = 258

# %%
_, bins, maps = s2tab.create_response_maps(particles, sns_response, selected_sens, bin_width)
# Out:
# /home/investigator/mariandbt/python/notebooks/modules/s2_table.py:171: RuntimeWarning: invalid value encountered in double_scalars
#   std_value*100/(np.sqrt(entries_value)*mean_value),
#             Maps created! Access the different maps following:
#             maps[0] = mean_per_bin
#             maps[1] = std_per_bin
#             maps[2] = mean_per_bin_err
#             maps[3] = entries_per_bin

# %%
s2tab.print_response_maps(selected_sens, bins, maps, yield_)

# %%
mean_per_bin = maps[0]

# %%
s2tab.print_sensor_map(particles, sns_positions, selected_sens, bins, mean_per_bin)

# %%
# s2tab.create_s2_table(file_path, bin_width, s2_table_id = 20240221) # we use the current date as s2_table_id
