# %% [markdown]
# <h1> ______________________________________ </h1>
#
# <h1> Maps using the modules </h1>
# <h1> ______________________________________ </h1>
#
# <p style="font-size: 17px; color: black;"> Patata. </p>

# %% [markdown]
# <h1> ____________ </h1>
# <h2> This version </h2>
# <h1> ____________ </h1>
#
# -  <p style="font-size: 17px; color: black;"> s2 maps. </p>

# %%
import sys
sys.path.append('/home/investigator/mariandbt/python/notebooks/modules')

from import_modules import *

import set_up as setup
import s2_table as s2tab

# %%
# Data reading
# ________________________________________________________________________________________________________________

path = '/home/investigator/mariandbt/python/data'
path = path + '/20231025_NEXT100_full_mapping'

# file_path = os.path.join(path, "Next100_full_mapp_s2_inicioEL_100Kev.next.h5")
# list_of_ie_file_paths = [file_path]

list_of_ie_file_paths = []
for i in range(3):
    file_path = os.path.join(path, f'20240215_Next100_ie_s2_{i+1}.next.h5')
    list_of_ie_file_paths.append(file_path)

# %%
selected_file = 1

particles = pd.read_hdf(list_of_ie_file_paths[selected_file], "/MC/particles")
sns_positions, sns_response = setup.read_fiber_sens(list_of_ie_file_paths[selected_file])
# Out:
# /home/investigator/miniconda3/envs/IC-3.8-2022-04-13/lib/python3.8/site-packages/pandas/io/pytables.py:3523: IncompatibilityWarning:
# where criteria is being ignored as this version [0.0.0] is too old (or
# not-defined), read the file in and write it out to a new file to upgrade (with
# the copy_to method)
#
#   warnings.warn(ws, IncompatibilityWarning)

# %%
particles # [1]
# Out:
#        event_id  particle_id particle_name  primary  mother_id   initial_x  \
# 0             0            1           ie-        1          0  484.710022
# 1             1            1           ie-        1          0  314.893158
# 2             2            1           ie-        1          0  286.434082
# 3             3            1           ie-        1          0  289.037109
# 4             4            1           ie-        1          0  373.835754
# ...         ...          ...           ...      ...        ...         ...
# 99995     99995            1           ie-        1          0  443.487793
# 99996     99996            1           ie-        1          0  259.414764
# 99997     99997            1           ie-        1          0  419.128448
# 99998     99998            1           ie-        1          0  298.447937
# 99999     99999            1           ie-        1          0  387.769257
#
#        initial_y   initial_z  initial_t     final_x  ...  initial_momentum_x  \
# 0      -3.927752  596.424988        0.0  484.710022  ...            0.000227
# 1     -30.042877  596.424988        0.0  314.893158  ...           -0.000447
# 2      31.880100  596.424988        0.0  286.434082  ...            0.000668
# 3      34.952240  596.424988        0.0  289.037109  ...           -0.000684
# 4     -10.041302  596.424988        0.0  373.835754  ...           -0.000281
# ...          ...         ...        ...         ...  ...                 ...
# 99995 -37.447773  596.424988        0.0  443.487793  ...            0.000475
# 99996  26.120518  596.424988        0.0  259.414764  ...           -0.000417
# 99997  69.483063  596.424988        0.0  419.128448  ...            0.000808
# 99998 -37.230518  596.424988        0.0  298.447937  ...           -0.000079
# 99999 -13.309403  596.424988        0.0  387.769257  ...            0.000464
#
#        initial_momentum_y  initial_momentum_z final_momentum_x  \
# 0            7.743814e-04           -0.000609         0.000227
# 1           -8.313195e-04           -0.000362        -0.000447
# 2           -4.545649e-04            0.000608         0.000668
# 3           -7.420148e-04            0.000056        -0.000684
# 4            1.230414e-04            0.000963        -0.000281
# ...                   ...                 ...              ...
# 99995       -8.515786e-04            0.000268         0.000475
# 99996        9.105796e-08           -0.000921        -0.000417
# 99997       -3.582131e-04            0.000491         0.000808
# 99998        3.810358e-04           -0.000933        -0.000079
# 99999       -4.559329e-04           -0.000774         0.000464
#
#       final_momentum_y  final_momentum_z  kin_energy  length  creator_proc  \
# 0         7.743814e-04         -0.000609    0.000001    11.1          none
# 1        -8.313195e-04         -0.000362    0.000001    11.1          none
# 2        -4.545649e-04          0.000608    0.000001    11.1          none
# 3        -7.420148e-04          0.000056    0.000001    11.1          none
# 4         1.230414e-04          0.000963    0.000001    11.1          none
# ...                ...               ...         ...     ...           ...
# 99995    -8.515786e-04          0.000268    0.000001    11.1          none
# 99996     9.105796e-08         -0.000921    0.000001    11.1          none
# 99997    -3.582131e-04          0.000491    0.000001    11.1          none
# 99998     3.810358e-04         -0.000933    0.000001    11.1          none
# 99999    -4.559329e-04         -0.000774    0.000001    11.1          none
#
#        final_proc
# 0           Drift
# 1           Drift
# 2           Drift
# 3           Drift
# 4           Drift
# ...           ...
# 99995       Drift
# 99996       Drift
# 99997       Drift
# 99998       Drift
# 99999       Drift
#
# [100000 rows x 25 columns]

# %%
particles # [0]
# Out:
#        event_id  particle_id particle_name  primary  mother_id   initial_x  \
# 0             0            1           ie-        1          0  484.710022
# 1             1            1           ie-        1          0  314.893158
# 2             2            1           ie-        1          0  286.434082
# 3             3            1           ie-        1          0  289.037109
# 4             4            1           ie-        1          0  373.835754
# ...         ...          ...           ...      ...        ...         ...
# 99995     99995            1           ie-        1          0  443.487793
# 99996     99996            1           ie-        1          0  259.414764
# 99997     99997            1           ie-        1          0  419.128448
# 99998     99998            1           ie-        1          0  298.447937
# 99999     99999            1           ie-        1          0  387.769257
#
#        initial_y   initial_z  initial_t     final_x  ...  initial_momentum_x  \
# 0      -3.927752  596.424988        0.0  484.710022  ...            0.000227
# 1     -30.042877  596.424988        0.0  314.893158  ...           -0.000447
# 2      31.880100  596.424988        0.0  286.434082  ...            0.000668
# 3      34.952240  596.424988        0.0  289.037109  ...           -0.000684
# 4     -10.041302  596.424988        0.0  373.835754  ...           -0.000281
# ...          ...         ...        ...         ...  ...                 ...
# 99995 -37.447773  596.424988        0.0  443.487793  ...            0.000475
# 99996  26.120518  596.424988        0.0  259.414764  ...           -0.000417
# 99997  69.483063  596.424988        0.0  419.128448  ...            0.000808
# 99998 -37.230518  596.424988        0.0  298.447937  ...           -0.000079
# 99999 -13.309403  596.424988        0.0  387.769257  ...            0.000464
#
#        initial_momentum_y  initial_momentum_z final_momentum_x  \
# 0            7.743814e-04           -0.000609         0.000227
# 1           -8.313195e-04           -0.000362        -0.000447
# 2           -4.545649e-04            0.000608         0.000668
# 3           -7.420148e-04            0.000056        -0.000684
# 4            1.230414e-04            0.000963        -0.000281
# ...                   ...                 ...              ...
# 99995       -8.515786e-04            0.000268         0.000475
# 99996        9.105796e-08           -0.000921        -0.000417
# 99997       -3.582131e-04            0.000491         0.000808
# 99998        3.810358e-04           -0.000933        -0.000079
# 99999       -4.559329e-04           -0.000774         0.000464
#
#       final_momentum_y  final_momentum_z  kin_energy  length  creator_proc  \
# 0         7.743814e-04         -0.000609    0.000001    11.1          none
# 1        -8.313195e-04         -0.000362    0.000001    11.1          none
# 2        -4.545649e-04          0.000608    0.000001    11.1          none
# 3        -7.420148e-04          0.000056    0.000001    11.1          none
# 4         1.230414e-04          0.000963    0.000001    11.1          none
# ...                ...               ...         ...     ...           ...
# 99995    -8.515786e-04          0.000268    0.000001    11.1          none
# 99996     9.105796e-08         -0.000921    0.000001    11.1          none
# 99997    -3.582131e-04          0.000491    0.000001    11.1          none
# 99998     3.810358e-04         -0.000933    0.000001    11.1          none
# 99999    -4.559329e-04         -0.000774    0.000001    11.1          none
#
#        final_proc
# 0           Drift
# 1           Drift
# 2           Drift
# 3           Drift
# 4           Drift
# ...           ...
# 99995       Drift
# 99996       Drift
# 99997       Drift
# 99998       Drift
# 99999       Drift
#
# [100000 rows x 25 columns]

# %%
# Global params
# ________________________________________________________________________________________________________________
x_min = 0
x_max = 490
# x_max = 500
y_min = -84
y_max = 84

bin_width = 10 # [mm]
yield_ = 1050 # ph/e⁻

# %%
s2tab.set_map_specs(globals(), x_min = x_min, x_max = x_max, 
                    y_min = y_min, y_max = y_max, bin_width_in_mm = bin_width)
# Out:
# Global parameters set successfully :)
# /home/investigator/miniconda3/envs/IC-3.8-2022-04-13/lib/python3.8/site-packages/numpy/core/_asarray.py:102: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order)

# %%
# _ = setup.print_sens_geometry(file_path, 258)

# %%
selected_sens = 258

# %%
[list_of_ie_file_paths[0]]
# Out:
# '/home/investigator/mariandbt/python/data/20231025_NEXT100_full_mapping/20240215_Next100_ie_s2_1.next.h5'

# %%
_, bins, maps = s2tab.create_response_maps([list_of_ie_file_paths[0]], selected_sens)
# Out:
# /home/investigator/miniconda3/envs/IC-3.8-2022-04-13/lib/python3.8/site-packages/pandas/io/pytables.py:3523: IncompatibilityWarning:
# where criteria is being ignored as this version [0.0.0] is too old (or
# not-defined), read the file in and write it out to a new file to upgrade (with
# the copy_to method)
#
#   warnings.warn(ws, IncompatibilityWarning)
#             Maps created! Access the different maps following:
#             maps[0] = mean_per_bin
#             maps[1] = std_per_bin
#             maps[2] = mean_per_bin_err
#             maps[3] = entries_per_bin
# /home/investigator/mariandbt/python/notebooks/modules/s2_table.py:126: RuntimeWarning: invalid value encountered in true_divide
#   mean_per_bin = np.where(counts_per_bin > 0., charge_per_bin / counts_per_bin, 0.);
# /home/investigator/mariandbt/python/notebooks/modules/s2_table.py:131: RuntimeWarning: invalid value encountered in true_divide
#   std_per_bin*100/(np.sqrt(entries_per_bin)*mean_per_bin),

# %%
s2tab.print_response_maps(selected_sens, bins, maps, yield_) # 2 files

# %%
s2tab.print_response_maps(selected_sens, bins, maps, yield_) # 3 files

# %%
s2tab.print_response_maps(selected_sens, bins, maps, yield_)

# %%
mean_per_bin = maps[0]

# %%
s2tab.print_sensor_map(particles, sns_positions, selected_sens, bins, mean_per_bin)

# %%
s2tab.create_s2_table(list_of_ie_file_paths, s2_table_id = 20240227) # we use the current date as s2_table_id
# Out:
# /home/investigator/miniconda3/envs/IC-3.8-2022-04-13/lib/python3.8/site-packages/pandas/io/pytables.py:3523: IncompatibilityWarning:
# where criteria is being ignored as this version [0.0.0] is too old (or
# not-defined), read the file in and write it out to a new file to upgrade (with
# the copy_to method)
#
#   warnings.warn(ws, IncompatibilityWarning)
# Processing file 1/1
# /home/investigator/miniconda3/envs/IC-3.8-2022-04-13/lib/python3.8/site-packages/pandas/io/pytables.py:3523: IncompatibilityWarning:
# where criteria is being ignored as this version [0.0.0] is too old (or
# not-defined), read the file in and write it out to a new file to upgrade (with
# the copy_to method)
#
#   warnings.warn(ws, IncompatibilityWarning)
# Creating table ...
# Sensor 1/90
# /home/investigator/mariandbt/python/notebooks/modules/s2_table.py:311: RuntimeWarning: invalid value encountered in true_divide
#   mean_per_bin = np.where(counts_per_bin[selected_sens] > 0., charge_per_bin[selected_sens] / counts_per_bin[selected_sens], 0.);
# /home/investigator/mariandbt/python/notebooks/modules/s2_table.py:316: RuntimeWarning: invalid value encountered in true_divide
#   std_per_bin*100/(np.sqrt(entries_per_bin)*mean_per_bin),
# Sensor 2/90
# Sensor 3/90
# Sensor 4/90
# Sensor 5/90
# Sensor 6/90
# Sensor 7/90
# Sensor 8/90
# Sensor 9/90
# Sensor 10/90
# Sensor 11/90
# Sensor 12/90
# Sensor 13/90
# Sensor 14/90
# Sensor 15/90
# Sensor 16/90
# Sensor 17/90
# Sensor 18/90
# Sensor 19/90
# Sensor 20/90
# Sensor 21/90
# Sensor 22/90
# Sensor 23/90
# Sensor 24/90
# Sensor 25/90
# Sensor 26/90
# Sensor 27/90
# Sensor 28/90
# Sensor 29/90
# Sensor 30/90
# Sensor 31/90
# Sensor 32/90
# Sensor 33/90
# Sensor 34/90
# Sensor 35/90
# Sensor 36/90
# Sensor 37/90
# Sensor 38/90
# Sensor 39/90
# Sensor 40/90
# Sensor 41/90
# Sensor 42/90
# Sensor 43/90
# Sensor 44/90
# Sensor 45/90
# Sensor 46/90
# Sensor 47/90
# Sensor 48/90
# Sensor 49/90
# Sensor 50/90
# Sensor 51/90
# Sensor 52/90
# Sensor 53/90
# Sensor 54/90
# Sensor 55/90
# Sensor 56/90
# Sensor 57/90
# Sensor 58/90
# Sensor 59/90
# Sensor 60/90
# Sensor 61/90
# Sensor 62/90
# Sensor 63/90
# Sensor 64/90
# Sensor 65/90
# Sensor 66/90
# Sensor 67/90
# Sensor 68/90
# Sensor 69/90
# Sensor 70/90
# Sensor 71/90
# Sensor 72/90
# Sensor 73/90
# Sensor 74/90
# Sensor 75/90
# Sensor 76/90
# Sensor 77/90
# Sensor 78/90
# Sensor 79/90
# Sensor 80/90
# Sensor 81/90
# Sensor 82/90
# Sensor 83/90
# Sensor 84/90
# Sensor 85/90
# Sensor 86/90
# Sensor 87/90
# Sensor 88/90
# Sensor 89/90
# Sensor 90/90
# Done! s2 table created :)
