# %% [markdown]
# # $\beta$ $\beta$ offline signal reconstruction

# %%
# S2 signal script
import sys
sys.path.append('/home/investigator/mariandbt/python/notebooks/modules')

from import_modules import *

import s2_simulation as s2sim
from s2_simulation import unit

# %%
path = '/home/investigator/mariandbt/python/data'
path = path + '/20240313_s2simulation'

# %%
sns_path = os.path.join(path, "ie/20240405_Next100_ie_s2_1.next.h5")
s2_table_path = os.path.join(path, "s2tab/20240405_s2_table.h5")
event_path = os.path.join(path, "bb/20240710_Next100_3ev_ELon_bb_1.next.h5") # 3 full bb w s2
# event_path = os.path.join(path, "Kr/20240724_Next100_10ev_ELoff_Kr_1.next.h5")

# %%
event, sensor = 0, 202

# %%
# Create TPC
TPC     = s2sim.HPGXeTPC()
TPC.SetDefaults(sns_path)
# Out:
# Default parameters set succesfully :) TPC ready to use
# /home/investigator/miniconda3/envs/IC-3.8-2022-04-13/lib/python3.8/site-packages/pandas/io/pytables.py:3523: IncompatibilityWarning:
# where criteria is being ignored as this version [0.0.0] is too old (or
# not-defined), read the file in and write it out to a new file to upgrade (with
# the copy_to method)
#
#   warnings.warn(ws, IncompatibilityWarning)

# %%
nexusEvent = s2sim.nexusEvent(event_path, event)
nexusEvent.AddDriftAndDiffusion(TPC)

# %%
s2table = s2sim.s2Table(s2_table_path)

# %%
# %%timeit # (~4mins) (~25s no sé why...)
s2signal = s2sim.s2Signal(s2table, TPC, nexusEvent)
# Out:
# Creating signal (Processing sensor 108/108)... Signal created succesfully :)

# %%
# %%timeit # (~4mins/sensor for t_bin = 0.1ns; 35.1s in total for t_bin = 1ns)
s2signal.AddShapinAndSamplin(shapin_rise = 12 *unit.ns, shapin_tau = 28 *unit.ns, 
                             samplin_rate = 25 *unit.ns, t_binin = 1 *unit.ns)
# Out:
# Shaping and sampling (Processing sensor 1/108)...
# /home/investigator/mariandbt/python/notebooks/modules/s2_simulation.py:326: RuntimeWarning: overflow encountered in exp
#   rise_term = 1 - np.exp(-(t - t0) / rise_time)
# /home/investigator/mariandbt/python/notebooks/modules/s2_simulation.py:327: RuntimeWarning: overflow encountered in exp
#   decay_term = np.exp(-(t - t0) / decay_time)
# /home/investigator/mariandbt/python/notebooks/modules/s2_simulation.py:329: RuntimeWarning: overflow encountered in multiply
#   signal = (rise_term * decay_term)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 2
#       1 # %%timeit # (~4mins/sensor for t_bin = 0.1ns; 35.1s in total for t_bin = 1ns)
# ----> 2 s2signal.AddShapinAndSamplin(shapin_rise = 12 *unit.ns, shapin_tau = 28 *unit.ns,
# ...

# %%
t, waveform, ax = s2signal.PrintWaveform(sensor, shaped_and_sampled = False, bin_width = 1 *unit.us)
ax.legend();
waveform.sum()

# %%
t, waveform, ax = s2signal.PrintWaveform(sensor, shaped_and_sampled = True, units = 'pes/ns')
ax.legend()
np.trapz(y = waveform, x = t.to(unit.ns).magnitude)

# %%
t, waveform, ax = s2signal.PrintWaveform(sensor, shaped_and_sampled = True, units ='mA')
ax.legend()

# %%
t, waveform, ax = s2signal.PrintWaveform(sensor, shaped_and_sampled = True, units = 'mV')
ax.legend()

# %% [markdown]
# # $\beta$ $\beta$ offline dynamic range

# %%
# S2 signal script
import sys
sys.path.append('/home/investigator/mariandbt/python/notebooks/modules')

from import_modules import *

import s2_simulation as s2sim
from s2_simulation import unit

# %%
path = '/home/investigator/mariandbt/python/data'
path = path + '/20240313_s2simulation'

# %%
sns_path = os.path.join(path, "ie/20240405_Next100_ie_s2_1.next.h5")
s2_table_path = os.path.join(path, "s2tab/20240405_s2_table.h5")
event_path = os.path.join(path, "bb/20240710_Next100_3ev_ELon_bb_1.next.h5") # 3 full bb w s2
event_path2 = os.path.join(path, "bb/20240306_Next100_200ev_ELoff_bb_1.next.h5") # 200 evs w/o s2

# %%
# Create TPC
TPC     = s2sim.HPGXeTPC()
TPC.SetDefaults(sns_path)
# Out:
# Default parameters set succesfully :) TPC ready to use
# /home/investigator/miniconda3/envs/IC-3.8-2022-04-13/lib/python3.8/site-packages/pandas/io/pytables.py:3523: IncompatibilityWarning:
# where criteria is being ignored as this version [0.0.0] is too old (or
# not-defined), read the file in and write it out to a new file to upgrade (with
# the copy_to method)
#
#   warnings.warn(ws, IncompatibilityWarning)

# %%
s2table = s2sim.s2Table(s2_table_path)

# %%
list_of_bb = [event_path, event_path2]
list_of_bb = [event_path]
# list_of_bb = [event_path2]

# %%
# %%timeit # (37.1s /event)
DynamicRange = s2sim.DynamicRange(s2table, 
                                  TPC, 
                                  List_bb_Paths = list_of_bb,
                                  fiducial_radio = 490 *unit.mm,
                                  shapin_tau = 155 *unit.ns,
                                  samplin_rate = 25*unit.ns,
                                  t_binin = 1*unit.ns,
                                  units = 'mV',
                                  impedance_in_ohm = 50 # only used if units = mV
                                 )
# Out:
# Dynamic range (Processing event 1/10 in file 1/1...)
# Dynamic range (Processing event 2/10 in file 1/1...)
# Dynamic range (Processing event 3/10 in file 1/1...)
# Dynamic range (Processing event 4/10 in file 1/1...)
# Dynamic range (Processing event 5/10 in file 1/1...)
# Dynamic range (Processing event 6/10 in file 1/1...)
# Dynamic range (Processing event 7/10 in file 1/1...)
# Shaping and sampling (Processing sensor 1/108)...
# /home/investigator/mariandbt/python/notebooks/modules/s2_simulation.py:328: RuntimeWarning: overflow encountered in multiply
#   signal = (rise_term * decay_term)
# Dynamic range (Processing event 8/10 in file 1/1...)
# Dynamic range (Processing event 9/10 in file 1/1...)
# Dynamic range (Processing event 10/10 in file 1/1...)
# Shaping and sampling (Processing sensor 108/108)... Shapin and samplin done succesfully :)

# %%
events, bins, ax = DynamicRange.PrintHist(bin_width = 10, logscale = False)

# %% [markdown]
# # $\beta$ $\beta$ waveform + diff: nexus vs offline

# %%
# S2 signal script
import sys
sys.path.append('/home/investigator/mariandbt/python/notebooks/modules')

from import_modules import *
import set_up as setup

import s2_simulation as s2sim
from s2_simulation import unit

# %%
path = '/home/investigator/mariandbt/python/data'
path = path + '/20240313_s2simulation'

# %%
sns_path = os.path.join(path, "ie/20240405_Next100_ie_s2_1.next.h5")
s2_table_path = os.path.join(path, "s2tab/20240405_s2_table.h5")
# event_path = os.path.join(path, "bb/20240228_Next100_10ev_ELon_bb_1.next.h5") # 10 full bb w s2 (ONLY 90 SENSs)
# event_path = os.path.join(path, "bb/20240710_Next100_3ev_ELon_bb_1.next.h5") # 3 full bb w s2
event_path = os.path.join(path, "bb/20240712_Next100_10ev_ELon_bb_1.next.h5") # 10 full bb w s2

# event_path = os.path.join(path, "Kr/20240724_Next100_10ev_ELoff_Kr_1.next.h5") 
# event_path = os.path.join(path, "Kr/20240828_Next100_10ev_ELon_Kr_1.next.h5")

# %%
event, sensor = 6, 202

# %%
ax = setup.print_sens_geometry(sns_path, sensor)

# Access the figure through the ax object
fig = ax.figure
fig.set_size_inches(11, 11)  # Set new width and height in inches

ax.legend(loc= 'upper left')
# Out:
# /home/investigator/miniconda3/envs/IC-3.8-2022-04-13/lib/python3.8/site-packages/pandas/io/pytables.py:3523: IncompatibilityWarning:
# where criteria is being ignored as this version [0.0.0] is too old (or
# not-defined), read the file in and write it out to a new file to upgrade (with
# the copy_to method)
#
#   warnings.warn(ws, IncompatibilityWarning)

# %%
# Create TPC
TPC     = s2sim.HPGXeTPC()
TPC.SetDefaults(sns_path)
TPC.SetRecombinationFactor(0)
# Out:
# Default parameters set succesfully :) TPC ready to use
# /home/investigator/miniconda3/envs/IC-3.8-2022-04-13/lib/python3.8/site-packages/pandas/io/pytables.py:3523: IncompatibilityWarning:
# where criteria is being ignored as this version [0.0.0] is too old (or
# not-defined), read the file in and write it out to a new file to upgrade (with
# the copy_to method)
#
#   warnings.warn(ws, IncompatibilityWarning)

# %%
s2table = s2sim.s2Table(s2_table_path)

# %%
hits = pd.read_hdf(event_path, "/MC/hits")
hits = hits.query(f'event_id == {event}')

# %%
particles = pd.read_hdf(event_path, "/MC/particles")
particles = particles.query(f'event_id == {event}')

ie        = particles.query(f'particle_name == "ie-"')

# %%
# sns_response

# %%
ax = setup.print_sens_geometry(sns_path, sensor)

ax.plot(ie.final_x, ie.final_y, 'o', label = 'final position ie⁻')
# ax.plot(prim_e.final_x, prim_e.final_y, 'o', label = 'final position e⁻')

# Access the figure through the ax object
fig = ax.figure

# Modify the size of the figure
fig.set_size_inches(5, 5)  # Set new width and height in inches

ax.legend(loc= 'upper left')
# Out:
# /home/investigator/miniconda3/envs/IC-3.8-2022-04-13/lib/python3.8/site-packages/pandas/io/pytables.py:3523: IncompatibilityWarning:
# where criteria is being ignored as this version [0.0.0] is too old (or
# not-defined), read the file in and write it out to a new file to upgrade (with
# the copy_to method)
#
#   warnings.warn(ws, IncompatibilityWarning)

# %%
sns_positions, sns_response = setup.read_fiber_sens(event_path)
sns_response = sns_response.query(f'event_id == {event}')
# Out:
# /home/investigator/miniconda3/envs/IC-3.8-2022-04-13/lib/python3.8/site-packages/pandas/io/pytables.py:3523: IncompatibilityWarning:
# where criteria is being ignored as this version [0.0.0] is too old (or
# not-defined), read the file in and write it out to a new file to upgrade (with
# the copy_to method)
#
#   warnings.warn(ws, IncompatibilityWarning)

# %%
nexusEvent = s2sim.nexusEvent(event_path, event)
nexusEvent.AddDriftAndDiffusion(TPC)

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(10,5), constrained_layout=True, sharex=False, sharey=False)

font_size = 20

# nexus
_, _, _, figure_map = ax[0].hist2d(ie.final_x, 
                                   ie.final_y, 
                                   bins = 100, cmap='inferno', label = 'nexus');

fig.colorbar(figure_map, ax = ax[0]);
ax[0].set_title('nexus', fontsize = font_size)

# Offline simulation
_, _, _, figure_map = ax[1].hist2d(nexusEvent.ElectronsFinalX.magnitude, 
                                   nexusEvent.ElectronsFinalY.magnitude, 
                                   bins = 100, cmap='inferno', label = 'nexus');
fig.colorbar(figure_map, ax = ax[1]);
ax[1].set_title('Offline', fontsize = font_size)


for axis in ax:

    axis.set_xlabel('X [mm]', fontsize = font_size);
    axis.set_ylabel('Y [mm]', fontsize = font_size);
    axis.tick_params(axis='both', labelsize = font_size*2/3)

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(10,5), constrained_layout=True, sharex=False, sharey=False)

font_size = 20

# nexus
nexus_t = ie.final_t*1e-3 # [us]
_, _, _, figure_map = ax[0].hist2d(nexus_t, 
                                   ie.final_y, 
                                   bins = 100, cmap='inferno', label = 'nexus');

fig.colorbar(figure_map, ax = ax[0]);
ax[0].set_title('nexus', fontsize = font_size)

# Offline simulation
_, _, _, figure_map = ax[1].hist2d(nexusEvent.ElectronsMeasurementTime.to(unit.us).magnitude, 
                                   nexusEvent.ElectronsFinalY.magnitude, 
                                   bins = 100, cmap='inferno', label = 'nexus');
fig.colorbar(figure_map, ax = ax[1]);
ax[1].set_title('Offline', fontsize = font_size)


for axis in ax:

    axis.set_xlabel('t [us]', fontsize = font_size);
    axis.set_ylabel('Y [mm]', fontsize = font_size);
    axis.tick_params(axis='both', labelsize = font_size*2/3)

# %%
# %%timeit # (~4mins) (~25s no sé why...)
s2signal = s2sim.s2Signal(s2table, TPC, nexusEvent)
# Out:
# Creating signal (Processing sensor 37/108)...

# %%
TPC.RecombinationFactor

# %%
sensor = 202

# %%
online_signal = sns_response.query(f'sensor_id == {sensor}').copy()
t_binnin = 0.1 # [ns]
online_signal.time_bin = online_signal.time_bin*t_binnin # [ns]

# %%
nexus_t = online_signal.time_bin*1e-3 # [us]
nexus_s2 = online_signal.charge # [pes]

# %%
# online_signal

# %%
# sns_response

# %%
t, waveform, ax = s2signal.PrintWaveform(sensor, bin_width = 1*unit.us, shaped_and_sampled = False)


nexus_s2 = nexus_s2[nexus_t > 100] # exclude s1
nexus_t = nexus_t[nexus_t > 100] # exclude s1

# both histograms should have the same binning
bin_width   = 1 *unit.us # [us]
binin       = np.arange(t.magnitude.min() - bin_width.magnitude, t.magnitude.max() + 2*bin_width.magnitude, bin_width.magnitude)


events, bins, bars = ax.hist(nexus_t, binin,
                             weights = nexus_s2,
                             density=False,
                             histtype='step',
                             label = f'nexus'
                            )

# ax.text(0.08, .85, f'Independent reconstruction without recombination and lifetime effects',
# transform=ax.transAxes, fontsize=0.7*font_size, bbox=dict(facecolor='1.', edgecolor='none', pad=3.0))

ax.text(0.03, .8, f'Npes independent = {waveform.sum()}',
transform=ax.transAxes, fontsize=0.7*font_size, bbox=dict(facecolor='1.', edgecolor='none', pad=3.0, alpha = 0))

ax.text(0.03, .75, f'Npes nexus = {events.sum()}',
transform=ax.transAxes, fontsize=0.7*font_size, bbox=dict(facecolor='1.', edgecolor='none', pad=3.0, alpha = 0))

# Add the initial legend
legend = ax.legend()
# Modify the legend labels
new_labels = ['Independent simulation', legend.get_texts()[1].get_text()]
ax.legend(handles=legend.legendHandles, labels=new_labels);

ax.legend(loc = 'upper left');
# ax.set_ylim(0, 1900)

# %% [markdown]
# # $\beta$ $\beta$ energy resolution

# %%
# S2 signal script
import sys
sys.path.append('/home/investigator/mariandbt/python/notebooks/modules')

from import_modules import *

import s2_simulation as s2sim
from s2_simulation import unit

# %%
path = '/home/investigator/mariandbt/python/data'
path = path + '/20240313_s2simulation'

# %%
sns_path = os.path.join(path, "ie/20240405_Next100_ie_s2_1.next.h5")
s2_table_path = os.path.join(path, "s2tab/20240405_s2_table.h5")
event_path = os.path.join(path, "bb/20240710_Next100_3ev_ELon_bb_1.next.h5") # 10 full bb w s2
event_path2 = os.path.join(path, "bb/20240306_Next100_200ev_ELoff_bb_1.next.h5") # 200 evs w/o s2

# %%
# Create TPC
TPC     = s2sim.HPGXeTPC()
TPC.SetDefaults(sns_path)
# Out:
# /home/investigator/miniconda3/envs/IC-3.8-2022-04-13/lib/python3.8/site-packages/pandas/io/pytables.py:3523: IncompatibilityWarning:
# where criteria is being ignored as this version [0.0.0] is too old (or
# not-defined), read the file in and write it out to a new file to upgrade (with
# the copy_to method)
#
#   warnings.warn(ws, IncompatibilityWarning)
# Default parameters set succesfully :) TPC ready to use

# %%
s2table = s2sim.s2Table(s2_table_path)

# %%
list_of_bb = [event_path, event_path2]
list_of_bb = [event_path]
# list_of_bb = [event_path2]

# %%
# %%timeit # (37.1s /event)
EnergyResolution = s2sim.EnergyResolution(s2table, 
                                          TPC, 
                                          List_Events_Paths = list_of_bb,
                                          fiducial_radio = 490 *unit.mm,
                                          shaped = False
                                         )
# Out:
# Energy resolution (Processing event 1/3 in file 1/1...)
# Energy resolution (Processing event 2/3 in file 1/1...)
# Energy resolution (Processing event 3/3 in file 1/1...)
# Creating signal (Processing sensor 108/108)... Signal created succesfully :)

# %%
events, bins, ax = EnergyResolution.PrintSpectrum(bin_width = 100, logscale = False)

ax.set_xlabel(f'Event energy [pes]', fontsize = 20);

# %% [markdown]
# # $\beta$ $\beta$ s2 storage

# %%
# S2 signal script
import sys
sys.path.append('/home/investigator/mariandbt/python/notebooks/modules')

from import_modules import *
import set_up as setup

import s2_simulation as s2sim
from s2_simulation import unit

# %%
path = '/home/investigator/mariandbt/python/data'
path = path + '/20240313_s2simulation'

# %%
sns_path = os.path.join(path, "ie/20240405_Next100_ie_s2_1.next.h5")
s2_table_path = os.path.join(path, "s2tab/20240405_s2_table.h5")
event_path = os.path.join(path, "bb/20240710_Next100_3ev_ELon_bb_1.next.h5") # 3 full bb w s2
event_path2 = os.path.join(path, "bb/20240306_Next100_200ev_ELoff_bb_1.next.h5") # 200 evs w/o s2

# %%
# Create TPC
TPC     = s2sim.HPGXeTPC()
TPC.SetDefaults(sns_path)
# Out:
# /home/investigator/miniconda3/envs/IC-3.8-2022-04-13/lib/python3.8/site-packages/pandas/io/pytables.py:3523: IncompatibilityWarning:
# where criteria is being ignored as this version [0.0.0] is too old (or
# not-defined), read the file in and write it out to a new file to upgrade (with
# the copy_to method)
#
#   warnings.warn(ws, IncompatibilityWarning)
# Default parameters set succesfully :) TPC ready to use

# %%
s2table = s2sim.s2Table(s2_table_path)

# %%
# List_bb_Paths = [event_path, event_path2]
List_bb_Paths = [event_path]
# List_bb_Paths = [event_path2]

# %%
Events_Dict             = {}
Events_Dict['bb0nu']    = List_bb_Paths
# Events_Dict['Kr']     = [event_path]

# %%
# output_file_path = os.path.join(path, 's2signals/20240620_TEST2_bb0nu_3ev_ELoff_s2_signal_20240405s2table.h5')
output_file_path = os.path.join(path, 's2signals/TEST1.h5')

# %%
s2sim.CreateSignalHDF5(output_file_path, 
                       s2table, 
                       TPC, 
                       Events_Dict,
                       fiducial_radio     = 490 *unit.mm,
                       shapin_rise        = 12    *unit.ns,
                       shapin_tau         = 28    *unit.ns,
                       samplin_rate       = 25*unit.ns,
                       t_binin            = 1*unit.ns,
                       units              = 'pes/ns',
                       impedance_in_ohm   = 50 # only used if units = mV
                       )
# Out:
# Storing bb0nu's signal in a DF (Processing event 1/3 in file 1/1...)
# Storing bb0nu's signal in a DF (Processing event 2/3 in file 1/1...)
# Storing bb0nu's signal in a DF (Processing event 3/3 in file 1/1...)
# Data has been written to /home/investigator/mariandbt/python/data/20240313_s2simulation/s2signals/TEST0.h5 :)

# %%
setup.check_h5(output_file_path)
# Out:
# /home/investigator/mariandbt/python/data/20240313_s2simulation/s2signals/TEST1.h5 (File) ''
# Last modif.: '2024-07-24T14:36:00+00:00'
# Object Tree:
# / (RootGroup) ''
# /s2simulation (Group) ''
# /s2simulation/configuration (Group) ''
# /s2simulation/configuration/table (Table(10,)) ''
# /s2simulation/events (Group) ''
# /s2simulation/events/table (Table(3,)) ''
# /s2simulation/s2 (Group) ''
# /s2simulation/s2/table (Table(15123,)) ''

# %%
gg_config = pd.read_hdf(output_file_path, "/s2simulation/configuration")
gg_evs = pd.read_hdf(output_file_path, "/s2simulation/events")
gg_s2 = pd.read_hdf(output_file_path, "/s2simulation/s2")

# %%
gg_config
# Out:
#            ParameterName  ParameterValue ParameterUnits
# 0                NEvents             3.0  dimensionless
# 1               NSensors           108.0  dimensionless
# 2           S2LightYield          1050.0    photons/ie⁻
# 3      S2TableStatistics      50000000.0            ie⁻
# 4          FiducialRadio           490.0     millimeter
# 5    Time (see s2 table)             NaN     nanosecond
# 6  Signal (see s2 table)             NaN         pes/ns
# 7           SamplingRate            25.0     nanosecond
# 8        ShapingRiseTime            12.0     nanosecond
# 9       ShapingDecayTime            28.0     nanosecond

# %%
gg_evs
# Out:
#    event_id    N_ie event_type  radial_coordinate_in_mm
# 0         0  108430         Kr               337.932556
# 0         1   79304         Kr               257.497101
# 0         2  108232         Kr               457.273712

# %%
gg_s2
# Out:
#       event_id         time  sensor298_s2  sensor204_s2  sensor219_s2  \
# 0            0  584330.6250  0.000000e+00  0.000000e+00  0.000000e+00
# 1            0  584355.6250  0.000000e+00  1.850429e-02  0.000000e+00
# 2            0  584380.6250  0.000000e+00  8.566814e-03  0.000000e+00
# 3            0  584405.6250  0.000000e+00  3.558431e-03  0.000000e+00
# 4            0  584430.6250  0.000000e+00  1.459694e-03  0.000000e+00
# ...        ...          ...           ...           ...           ...
# 2677         2  637549.6250  3.788679e-32  2.418741e-26  2.358385e-42
# 2678         2  637574.6875  1.551404e-32  9.904359e-27  9.654946e-43
# 2679         2  637599.6875  6.352753e-33  4.055678e-27  3.951662e-43
# 2680         2  637624.6875  2.601351e-33  1.660736e-27  1.625506e-43
# 2681         2  637649.6875  1.065212e-33  6.800449e-28  6.586103e-44
#
#       sensor243_s2  sensor304_s2  sensor296_s2  sensor210_s2  sensor303_s2  \
# ...

# %%
event = 2
vv = gg_s2.loc[gg_s2.event_id == event].copy()
plt.plot(vv.time, vv.sensor220_s2)

# %%
zz = np.array(gg_s2.loc[gg_s2.event_id == event].filter(like='sensor')).sum(axis = 1)

# %%
plt.plot(vv.time, zz)

# %% [markdown]
# # $\beta$ $\beta$ s2 files analysis

# %% [markdown]
# - <p style="font-size: 25px; color: black; "> <b> Waveform </b>

# %%
# S2 signal script
import sys
sys.path.append('/home/investigator/mariandbt/python/notebooks/modules')

from import_modules import *
import set_up as setup

import s2_simulation as s2sim
from s2_simulation import unit

# %%
path = '/home/investigator/mariandbt/python/data'
path = path + '/20240313_s2simulation'

# %%
sns_path = os.path.join(path, "ie/20240405_Next100_ie_s2_1.next.h5")
s2_table_path = os.path.join(path, "s2tab/20240405_s2_table.h5")
event_path = os.path.join(path, "bb/20240614_Next100_bb_300ev_ELoff_1.next.h5") # 3 full bb w s2

# %%
# Create TPC
TPC     = s2sim.HPGXeTPC()
TPC.SetDefaults(sns_path)
# Out:
# /home/investigator/miniconda3/envs/IC-3.8-2022-04-13/lib/python3.8/site-packages/pandas/io/pytables.py:3523: IncompatibilityWarning:
# where criteria is being ignored as this version [0.0.0] is too old (or
# not-defined), read the file in and write it out to a new file to upgrade (with
# the copy_to method)
#
#   warnings.warn(ws, IncompatibilityWarning)
# Default parameters set succesfully :) TPC ready to use

# %%
s2table = s2sim.s2Table(s2_table_path)

# %%
nexusEvent = s2sim.nexusEvent(event_path, event)
nexusEvent.AddDriftAndDiffusion(TPC)

# %%
s2signal = s2sim.s2Signal(s2table, TPC, nexusEvent)
# Out:
# Creating signal (Processing sensor 108/108)... Signal created succesfully :)

# %%
signal_paths_list = []
for i in range(10):
    signal_paths_list.append(os.path.join(path, 
#         f"s2signals/20240701_bb0nu_300ev_ELoff_s2_signal_20240405s2table_{i+1}.h5"))
        f"s2signals/20240724_bb0nu_300ev_ELoff_s2_signal_20240405s2table_{i+1}.h5"))

signal_path = signal_paths_list[0]

# %%
setup.check_h5(signal_path)
# Out:
# /home/investigator/mariandbt/python/data/20240313_s2simulation/s2signals/20240724_bb0nu_300ev_ELoff_s2_signal_20240405s2table_1.h5 (File) ''
# Last modif.: '2024-08-21T08:32:18+00:00'
# Object Tree:
# / (RootGroup) ''
# /s2simulation (Group) ''
# /s2simulation/configuration (Group) ''
# /s2simulation/configuration/table (Table(10,)) ''
# /s2simulation/events (Group) ''
# /s2simulation/events/table (Table(294,)) ''
# /s2simulation/s2 (Group) ''
# /s2simulation/s2/table (Table(1255712,)) ''

# %%
config_info = pd.read_hdf(signal_path, "/s2simulation/configuration")
events_info = pd.read_hdf(signal_path, "/s2simulation/events")
signal_info = pd.read_hdf(signal_path, "/s2simulation/s2")

# %%
config_info
# Out:
#            ParameterName  ParameterValue ParameterUnits
# 0                NEvents           294.0  dimensionless
# 1               NSensors           108.0  dimensionless
# 2           S2LightYield          1050.0    photons/ie⁻
# 3      S2TableStatistics      50000000.0            ie⁻
# 4          FiducialRadio           490.0     millimeter
# 5    Time (see s2 table)             NaN     nanosecond
# 6  Signal (see s2 table)             NaN         pes/ns
# 7           SamplingRate            25.0     nanosecond
# 8        ShapingRiseTime            12.0     nanosecond
# 9       ShapingDecayTime            28.0     nanosecond

# %%
events_info
# Out:
#     event_id    N_ie event_type  radial_coordinate_in_mm
# 0          0  108402      bb0nu               337.932556
# 0          1   20367      bb0nu               459.161011
# 0          2   50449      bb0nu               452.161743
# 0          3  108469      bb0nu               430.495667
# 0          4  108509      bb0nu               230.694031
# ..       ...     ...        ...                      ...
# 0        289  108275      bb0nu               404.581329
# 0        290  108250      bb0nu               350.892914
# 0        291  108305      bb0nu               418.292694
# 0        292  101077      bb0nu               419.017517
# 0        293  108395      bb0nu               288.760773
#
# [294 rows x 4 columns]

# %%
signal_info
# Out:
#       event_id         time  sensor298_s2  sensor204_s2  sensor219_s2  \
# 0            0  583253.3750  0.000000e+00      0.000000  0.000000e+00
# 1            0  583278.3750  0.000000e+00      0.018504  0.000000e+00
# 2            0  583303.3750  0.000000e+00      0.008567  0.000000e+00
# 3            0  583328.3750  0.000000e+00      0.003558  0.000000e+00
# 4            0  583353.3750  0.000000e+00      0.001460  0.000000e+00
# ...        ...          ...           ...           ...           ...
# 2558       293  653422.6250  2.414614e-18      0.003434  7.000352e-07
# 2559       293  653447.6875  9.887460e-19      0.001409  2.866533e-07
# 2560       293  653472.6875  4.048758e-19      0.000577  1.173800e-07
# 2561       293  653497.6875  1.657902e-19      0.000236  4.806524e-08
# 2562       293  653522.6875  6.788846e-20      0.000097  1.968195e-08
#
#       sensor243_s2  sensor304_s2  sensor296_s2  sensor210_s2  sensor303_s2  \
# ...

# %%
event, sensor   = 0, 202

# %%
selected_signal = signal_info.loc[signal_info.event_id == event].copy()
event_type      = events_info.loc[events_info.event_id == event].event_type.values[0]

# %%
t, waveform, ax = s2signal.PrintWaveform(sensor, bin_width = 1*unit.us, shaped_and_sampled = False)

font_size = 20

signal = selected_signal[f'sensor{sensor}_s2']

value = np.array(config_info.loc[config_info.ParameterName == 'FiducialRadio'].ParameterValue)[0]
units = np.array(config_info.loc[config_info.ParameterName == 'FiducialRadio'].ParameterUnits)[0]
fiducial_radio = f'{value} [{units}]'


# Access the figure through the ax object
fig = ax.figure

# Modify the size of the figure
fig.set_size_inches(10, 10)  # Set new width and height in inches

ax.set_title(f'Event nº{event} in sensor {sensor}', fontsize = font_size);
ax.set_xlabel(r'Time [ns]', fontsize = font_size);
ax.set_ylabel('S2 [pes/ns]', fontsize = font_size);


ax.legend(['s2 Waveform \nUn-shaped \nUn-sampled'],fontsize=0.7*font_size, loc='upper left')

ax.tick_params(axis='both', labelsize = font_size*2/3)

# %%
config_info
# Out:
#            ParameterName  ParameterValue ParameterUnits
# 0                NEvents           294.0  dimensionless
# 1               NSensors           108.0  dimensionless
# 2           S2LightYield          1050.0    photons/ie⁻
# 3      S2TableStatistics      50000000.0            ie⁻
# 4          FiducialRadio           490.0     millimeter
# 5    Time (see s2 table)             NaN     nanosecond
# 6  Signal (see s2 table)             NaN         pes/ns
# 7           SamplingRate            25.0     nanosecond
# 8        ShapingRiseTime            12.0     nanosecond
# 9       ShapingDecayTime            28.0     nanosecond

# %%
samplin_rate = np.array(config_info.loc[config_info.ParameterName == 'SamplingRate'].ParameterValue)[0]
tau = np.array(config_info.loc[config_info.ParameterName == 'ShapingDecayTime'].ParameterValue)[0]
rise_time = np.array(config_info.loc[config_info.ParameterName == 'ShapingRiseTime'].ParameterValue)[0]

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 1, figsize=(10, 10), constrained_layout=True)

font_size = 20
margen = 0.02

signal = selected_signal[f'sensor{sensor}_s2']

ax.plot(selected_signal.time, signal, label = f'SiPM response: \nEvent type = {event_type} \nRise time ={rise_time} [ns] \nDecay time = {tau} [ns] \nSampling rate = {samplin_rate} [ns]')

value = np.array(config_info.loc[config_info.ParameterName == 'FiducialRadio'].ParameterValue)[0]
units = np.array(config_info.loc[config_info.ParameterName == 'FiducialRadio'].ParameterUnits)[0]
units = 'mm'
fiducial_radio = f'{value} [{units}]'


ax.text(0.03, .6, f'Fiducial radio cut = {fiducial_radio}',
transform=ax.transAxes, fontsize=0.7*font_size, bbox=dict(facecolor='1.', edgecolor='none', pad=3.0, alpha = 0.))


ax.set_title(f'Event nº{event} in sensor {sensor}', fontsize = font_size);
ax.set_xlabel(r'Time [ns]', fontsize = font_size);
ax.set_ylabel('S2 [pes/ns]', fontsize = font_size);

ax.set_ylim(signal.min() - margen, signal.max() + 3*margen)

ax.legend(fontsize=0.7*font_size, loc='upper left')

ax.tick_params(axis='both', labelsize = font_size*2/3)

# %% [markdown]
# - <p style="font-size: 25px; color: black; "> <b> Dynamic Range </b>

# %%
# S2 signal script
import sys
sys.path.append('/home/investigator/mariandbt/python/notebooks/modules')

from import_modules import *
import set_up as setup

import s2_simulation as s2sim
from s2_simulation import unit

# %%
path = '/home/investigator/mariandbt/python/data'
path = path + '/20240313_s2simulation'

# %%
signal_paths_list = []
for i in range(10):
    signal_paths_list.append(os.path.join(path, 
#         f"s2signals/20240701_bb0nu_300ev_ELoff_s2_signal_20240405s2table_{i+1}.h5"))
        f"s2signals/20240724_bb0nu_300ev_ELoff_s2_signal_20240405s2table_{i+1}.h5"))

signal_path = signal_paths_list[0]

# %%
setup.check_h5(signal_path)
# Out:
# /home/investigator/mariandbt/python/data/20240313_s2simulation/s2signals/20240724_bb0nu_300ev_ELoff_s2_signal_20240405s2table_1.h5 (File) ''
# Last modif.: '2024-08-21T08:32:18+00:00'
# Object Tree:
# / (RootGroup) ''
# /s2simulation (Group) ''
# /s2simulation/configuration (Group) ''
# /s2simulation/configuration/table (Table(10,)) ''
# /s2simulation/events (Group) ''
# /s2simulation/events/table (Table(294,)) ''
# /s2simulation/s2 (Group) ''
# /s2simulation/s2/table (Table(1255712,)) ''

# %%
config_info = pd.read_hdf(signal_path, "/s2simulation/configuration")
events_info = pd.read_hdf(signal_path, "/s2simulation/events")
signal_info = pd.read_hdf(signal_path, "/s2simulation/s2")

# %%
dyn_range = np.array([])
for file in signal_paths_list:
    print(file)    
    
    signal_info = pd.read_hdf(file, "/s2simulation/s2")
    aux = signal_info.groupby('event_id').max()
    aux = np.array(aux.filter(like='sensor')).max(axis = 1)
    
    dyn_range = np.concatenate((dyn_range, aux))
# Out:
# /home/investigator/mariandbt/python/data/20240313_s2simulation/s2signals/20240724_bb0nu_300ev_ELoff_s2_signal_20240405s2table_1.h5
# /home/investigator/mariandbt/python/data/20240313_s2simulation/s2signals/20240724_bb0nu_300ev_ELoff_s2_signal_20240405s2table_2.h5
# /home/investigator/mariandbt/python/data/20240313_s2simulation/s2signals/20240724_bb0nu_300ev_ELoff_s2_signal_20240405s2table_3.h5
# /home/investigator/mariandbt/python/data/20240313_s2simulation/s2signals/20240724_bb0nu_300ev_ELoff_s2_signal_20240405s2table_4.h5
# /home/investigator/mariandbt/python/data/20240313_s2simulation/s2signals/20240724_bb0nu_300ev_ELoff_s2_signal_20240405s2table_5.h5
# /home/investigator/mariandbt/python/data/20240313_s2simulation/s2signals/20240724_bb0nu_300ev_ELoff_s2_signal_20240405s2table_6.h5
# /home/investigator/mariandbt/python/data/20240313_s2simulation/s2signals/20240724_bb0nu_300ev_ELoff_s2_signal_20240405s2table_7.h5
# ...

# %%
dyn_range_in_pesns = dyn_range

# %%
dyn_range_in_mV = s2sim.ConvertTomV(dyn_range)

# %%
shapin_tau = 155 
shaping_rise = shapin_tau
t_binin = 0.1

# %%
time_data   = np.array([1, 500, 1000]) # [ns]

# for the s2 as deltas
tail_in_ns  = shapin_tau*30 # [ns]
bin_edges   = np.arange(time_data.min(), time_data.max() + tail_in_ns, t_binin)

# for the Shaping
bin_means               = (bin_edges[:-1] + bin_edges[1:])/2
generic_sipm_response   = s2sim.ResponseSiPM(1, bin_means, bin_means.mean(), shaping_rise, shapin_tau)

# s2 as deltas
s2_deltas, _    = np.histogram(time_data, bins=bin_edges, weights = [0, 1, 0])

# Shaping
s2_data_shaped          = np.convolve(s2_deltas, generic_sipm_response, mode='same')

# %%
spe_max_in_pesns = s2_data_shaped.max()
spe_max_in_mV = s2sim.ConvertTomV(s2_data_shaped).max()

# %%
spe_max_in_pesns, spe_max_in_mV
# Out:
# (0.003225806562068269, 0.10322580998618461)

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 1, figsize=(10, 10), constrained_layout=True)
font_size = 20

bin_width = 10 # [mV]

value = np.array(config_info.loc[config_info.ParameterName == 'FiducialRadio'].ParameterValue)[0]
units = np.array(config_info.loc[config_info.ParameterName == 'FiducialRadio'].ParameterUnits)[0]
fiducial_radio = f'{value} [{unit(units).units:~}]'
NSensors = int(np.array(config_info.loc[config_info.ParameterName == 'NSensors'].ParameterValue)[0])
NEvents = int(np.array(config_info.loc[config_info.ParameterName == 'NEvents'].ParameterValue)[0])


# dyn_range = dyn_range_in_mV/spe_max_in_mV
dyn_range = dyn_range_in_pesns/spe_max_in_pesns

n_events = len(dyn_range)
binin = np.arange(dyn_range.min() - bin_width, dyn_range.max() + 2*bin_width, bin_width)


events, bins, bars = ax.hist(dyn_range, binin,
                             density=False,
                             label=r'$\frac{s2^{max}}{single^{max}}$',
                             histtype='stepfilled')


ax.text(0.45, .85, f'Values range = ({dyn_range.min():.2f}, {dyn_range.max():.2f})',
transform=ax.transAxes, fontsize=0.7*font_size, bbox=dict(facecolor='1.', edgecolor='none', pad=3.0))

ax.text(0.45, .8, '$\mu$ = %.2f'%(dyn_range.mean()),
transform=ax.transAxes, fontsize=0.7*font_size, bbox=dict(facecolor='1.', edgecolor='none', pad=3.0))

ax.text(0.45, .75, '$\sigma$ = %.2f'%(dyn_range.std()),
transform=ax.transAxes, fontsize=0.7*font_size, bbox=dict(facecolor='1.', edgecolor='none', pad=3.0))

ax.text(0.45, .7, '$N_{entries}$ = %s'%(int(events.sum())),
transform=ax.transAxes, fontsize=0.7*font_size, bbox=dict(facecolor='1.', edgecolor='none', pad=3.0))

ax.text(0.45, .65, f'Fiducial radio cut = {fiducial_radio}',
transform=ax.transAxes, fontsize=0.7*font_size, bbox=dict(facecolor='1.', edgecolor='none', pad=3.0))


ax.set_title(f'Max s2 signal of all {NSensors} sensors for {int(events.sum())} events', fontsize = font_size);
ax.set_xlabel(r'Dynamic range', fontsize = font_size);
ax.set_ylabel('Counts', fontsize = font_size);


ax.legend(fontsize=0.9*font_size, loc=(0.45, 0.9))

ax.tick_params(axis='both', labelsize = font_size*2/3)

# %%
dyn_range
# Out:
# array([1016.84777593,  945.10734421, 1252.00615411, ...,  125.14036972,
#        1827.2945732 , 2054.33588623])

# %%
def signal_cut_eff(dyn_range, cuts):
    
    s2 = dyn_range

    eff_dict = {}

    for ii, cut in enumerate(cuts):

        s2_cut = s2[s2 < cut]

        eff = len(s2_cut)*100/len(s2)

        eff_dict[cut] = eff

    
    return eff_dict

# %%
cut_90 = min(eff_dict, key=lambda k: abs(eff_dict[k] - 90))# cut in [pes] at which we get 90% of signal

# %%
max(eff_dict.keys())
# Out:
# 3479.065003477137

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 1, figsize=(7, 7), constrained_layout=True)
font_size = 20

cut_step_in_pes = 50

cuts = np.arange(dyn_range.max(), dyn_range.min(), -cut_step_in_pes)

eff_dict = signal_cut_eff(dyn_range, cuts)
cut_90 = min(eff_dict, key=lambda k: abs(eff_dict[k] - 90))# cut in [pes] at which we get 90% of signal


ax.plot(eff_dict.keys(), eff_dict.values(), 'o', label = 'Cut efficiency')
ax.plot(np.linspace(0, cut_90, 10), 90*np.ones(10), '--r', label = '90% efficieny cut')
ax.plot(cut_90*np.ones(10), np.linspace(-1, 90, 10), '--r')

ax.set_title('Cut in the signal', fontsize = font_size)
ax.set_ylabel('Efficieny [%]', fontsize = font_size)
ax.set_xlabel('Cut [pes]', fontsize = font_size)

ax.set_ylim(-1, 102)
ax.set_xlim(0, 3500)

ax.tick_params(axis='both', labelsize = font_size*2/3)


ax.legend(fontsize=0.8*font_size, loc=(0.45, 0.6))

# %% [markdown]
# - <p style="font-size: 25px; color: black; "> <b> Detection efficiency </b>

# %%
# S2 signal script
import sys
sys.path.append('/home/investigator/mariandbt/python/notebooks/modules')

from import_modules import *
import set_up as setup

import s2_simulation as s2sim
from s2_simulation import unit

# %%
path = '/home/investigator/mariandbt/python/data'
path = path + '/20240313_s2simulation'

# %%
signal_paths_list = []
for i in range(10):
    signal_paths_list.append(os.path.join(path, 
#         f"s2signals/20240701_bb0nu_300ev_ELoff_s2_signal_20240405s2table_{i+1}.h5"))
        f"s2signals/20240724_bb0nu_300ev_ELoff_s2_signal_20240405s2table_{i+1}.h5"))

signal_path = signal_paths_list[0]

# %%
config_info = pd.read_hdf(signal_path, "/s2simulation/configuration")

# %%
events_info = pd.read_hdf(signal_path, "/s2simulation/events")

# %%
signal_info = pd.read_hdf(signal_path, "/s2simulation/s2")

# %%
config_info
# Out:
#            ParameterName  ParameterValue ParameterUnits
# 0                NEvents           294.0  dimensionless
# 1               NSensors           108.0  dimensionless
# 2           S2LightYield          1050.0    photons/ie⁻
# 3      S2TableStatistics      50000000.0            ie⁻
# 4          FiducialRadio           490.0     millimeter
# 5    Time (see s2 table)             NaN     nanosecond
# 6  Signal (see s2 table)             NaN         pes/ns
# 7           SamplingRate            25.0     nanosecond
# 8        ShapingRiseTime            12.0     nanosecond
# 9       ShapingDecayTime            28.0     nanosecond

# %%
light_yield = np.array(config_info.loc[config_info.ParameterName == 'S2LightYield'].ParameterValue)[0]

# %%
# aa = signal_info.groupby('event_id').get_group(290)
# np.trapz(x = aa.time, y = aa.sensor204_s2)
# Out:
# 37306.67

# %%
# df = pd.DataFrame()

# # Compute the time differences (dt) for each group
# df['event_id'] = signal_info['event_id']
# df['dt'] = signal_info.groupby('event_id')['time'].diff().fillna(0)

# # Extract waveform columns
# waveform_cols = signal_info.filter(like='sensor')

# # Compute the integral for each waveform
# integrals = waveform_cols.multiply(df['dt'], axis=0).groupby(df['event_id']).sum()

# # Reset index to get 'event_id' back as a column
# integrals = integrals.reset_index()
# Out:
# HERE
# HERE

# %%
# efficiency = pd.DataFrame()
# efficiency['event_id'] = np.array(integrals['event_id'])
# efficiency['true_photons'] = np.array(events_info.N_ie*light_yield)
# efficiency['detected_photons'] = np.array(integrals.filter(like='sensor').sum(axis = 1))

# %%
# efficiency['efficiency'] = efficiency.detected_photons/efficiency.true_photons

# %%
# efficiency
# Out:
#      event_id  true_photons  detected_photons  efficiency
# 0           0   113822100.0      1.682290e+06    0.014780
# 1           1    21385350.0      2.119205e+05    0.009910
# 2           2    52971450.0      4.834967e+05    0.009127
# 3           3   113892450.0      1.311007e+06    0.011511
# 4           4   113934450.0      1.555962e+06    0.013657
# ..        ...           ...               ...         ...
# 289       289   113688750.0      1.803195e+06    0.015861
# 290       290   113662500.0      1.556462e+06    0.013694
# 291       291   113720250.0      1.610432e+06    0.014161
# 292       292   106130850.0      1.434583e+06    0.013517
# 293       293   113814750.0      1.642284e+06    0.014429
#
# [294 rows x 4 columns]

# %%
light_collection_efficiency = np.array([])
for file in signal_paths_list:
    print(file)   
    
    events_info = pd.read_hdf(file, "/s2simulation/events")    
    signal_info = pd.read_hdf(file, "/s2simulation/s2")
    
    df = pd.DataFrame()

    # Compute the time differences (dt) for each group
    event_id = signal_info['event_id']
    dt = signal_info.groupby('event_id')['time'].diff().fillna(0)

    # Extract waveform columns
    waveform_cols = signal_info.filter(like='sensor')

    # Compute the integral for each waveform
    integrals = waveform_cols.multiply(dt, axis=0).groupby(event_id).sum()

    # Reset index to get 'event_id' back as a column
    integrals = integrals.reset_index()
    
    true_photons = np.array(events_info.N_ie*light_yield)
    detected_photons = np.array(integrals.filter(like='sensor').sum(axis = 1))
    efficiency = detected_photons/true_photons
    
    light_collection_efficiency = np.concatenate((light_collection_efficiency, efficiency))
# Out:
# /home/investigator/mariandbt/python/data/20240313_s2simulation/s2signals/20240724_bb0nu_300ev_ELoff_s2_signal_20240405s2table_1.h5
# /home/investigator/mariandbt/python/data/20240313_s2simulation/s2signals/20240724_bb0nu_300ev_ELoff_s2_signal_20240405s2table_2.h5
# /home/investigator/mariandbt/python/data/20240313_s2simulation/s2signals/20240724_bb0nu_300ev_ELoff_s2_signal_20240405s2table_3.h5
# /home/investigator/mariandbt/python/data/20240313_s2simulation/s2signals/20240724_bb0nu_300ev_ELoff_s2_signal_20240405s2table_4.h5
# /home/investigator/mariandbt/python/data/20240313_s2simulation/s2signals/20240724_bb0nu_300ev_ELoff_s2_signal_20240405s2table_5.h5
# /home/investigator/mariandbt/python/data/20240313_s2simulation/s2signals/20240724_bb0nu_300ev_ELoff_s2_signal_20240405s2table_6.h5
# /home/investigator/mariandbt/python/data/20240313_s2simulation/s2signals/20240724_bb0nu_300ev_ELoff_s2_signal_20240405s2table_7.h5
# ...

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 1, figsize=(10, 10), constrained_layout=True)
font_size = 20

bin_width = 2e-4 # [mV]

value = np.array(config_info.loc[config_info.ParameterName == 'FiducialRadio'].ParameterValue)[0]
units = np.array(config_info.loc[config_info.ParameterName == 'FiducialRadio'].ParameterUnits)[0]
fiducial_radio = f'{value} [{unit(units).units:~}]'
NSensors = int(np.array(config_info.loc[config_info.ParameterName == 'NSensors'].ParameterValue)[0])
NEvents = int(np.array(config_info.loc[config_info.ParameterName == 'NEvents'].ParameterValue)[0])


n_events = len(light_collection_efficiency)
binin = np.arange(light_collection_efficiency.min() - bin_width, light_collection_efficiency.max() + 2*bin_width, bin_width)


events, bins, bars = ax.hist(light_collection_efficiency, binin,
                             density=False,
                             label='Light detection efficiency',
                             histtype='stepfilled')


ax.text(0.15, .85, f'Values range = ({light_collection_efficiency.min():.3f}, {light_collection_efficiency.max():.3f})',
transform=ax.transAxes, fontsize=0.7*font_size, bbox=dict(facecolor='1.', edgecolor='none', pad=3.0))

ax.text(0.15, .8, fr'$\mu$= {light_collection_efficiency.mean():.3f}',
transform=ax.transAxes, fontsize=0.7*font_size, bbox=dict(facecolor='1.', edgecolor='none', pad=3.0))

ax.text(0.15, .75, fr'$\sigma$= {light_collection_efficiency.std():.3f}',
transform=ax.transAxes, fontsize=0.7*font_size, bbox=dict(facecolor='1.', edgecolor='none', pad=3.0))

ax.text(0.15, .7, '$N_{entries}$ = %s'%(int(events.sum())),
transform=ax.transAxes, fontsize=0.7*font_size, bbox=dict(facecolor='1.', edgecolor='none', pad=3.0))

ax.text(0.15, .65, f'Fiducial radio cut = {fiducial_radio}',
transform=ax.transAxes, fontsize=0.7*font_size, bbox=dict(facecolor='1.', edgecolor='none', pad=3.0))


ax.set_title(f'LDE of all {NSensors} sensors for {int(events.sum())} events', fontsize = font_size);
ax.set_xlabel(r'$\frac{\gamma_{detected}}{\gamma_{produced}}$', fontsize = font_size);
ax.set_ylabel('Counts', fontsize = font_size);
ax.set_yscale('log')

ax.legend(fontsize=0.7*font_size, loc='upper left')

ax.tick_params(axis='both', labelsize = font_size*2/3)
