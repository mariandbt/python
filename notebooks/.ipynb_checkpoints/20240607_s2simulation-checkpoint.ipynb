# %% [markdown]
# # $\beta$ $\beta$ offline signal reconstruction

# %%
# S2 signal script
import sys
sys.path.append('/home/investigator/mariandbt/python/notebooks/modules')

from import_modules import *

import s2_simulation as s2sim
from s2_simulation import unit

# %%
path = '/home/investigator/mariandbt/python/data'
path = path + '/20240313_s2simulation'

# %%
sns_path = os.path.join(path, "ie/20240405_Next100_ie_s2_1.next.h5")
s2_table_path = os.path.join(path, "s2tab/20240405_s2_table.h5")
event_path = os.path.join(path, "bb/20240228_Next100_10ev_ELon_bb_1.next.h5") # 10 full bb w s2

# %%
event, sensor = 6, 202

# %%
# Create TPC
TPC     = s2sim.FiberBarrelTPC()
TPC.SetDefaults(sns_path)
# Out:
# Default parameters set succesfully :) TPC ready to use
# /home/investigator/miniconda3/envs/IC-3.8-2022-04-13/lib/python3.8/site-packages/pandas/io/pytables.py:3523: IncompatibilityWarning:
# where criteria is being ignored as this version [0.0.0] is too old (or
# not-defined), read the file in and write it out to a new file to upgrade (with
# the copy_to method)
#
#   warnings.warn(ws, IncompatibilityWarning)

# %%
nexusEvent = s2sim.nexusEvent(event_path, event)
nexusEvent.AddDriftAndDiffusion(TPC)

# %%
s2table = s2sim.s2Table(s2_table_path)

# %%
# %%timeit # (~4mins)
s2_signal = s2sim.s2Signal(s2table, TPC, nexusEvent)
# Out:
# Creating signal (Processing sensor 108/108)... Signal created succesfully :)

# %%
# %%timeit # (~4mins/sensor for t_bin = 0.1ns; 41s in total for t_bin = 1ns)
s2_signal.AddShapinAndSamplin(samplin_rate = 25*unit.ns, t_binin = 1*unit.ns)
# Out:
# Shaping and sampling (Processing sensor 9/108)...
# /home/investigator/mariandbt/python/notebooks/modules/s2_simulation.py:317: RuntimeWarning: overflow encountered in multiply
#   signal = (rise_term * decay_term)
# Shaping and sampling (Processing sensor 108/108)... Shapin and samplin done succesfully :)

# %%
t, waveform, ax = s2_signal.PrintWaveform(sensor, shaped_and_sampled = False)
# ax.legend();
waveform.sum()
# Out:
# 32639.0

# %%
t, waveform, ax = s2_signal.PrintWaveform(sensor, shaped_and_sampled = True, units = 'pes/ns')
ax.legend()
np.trapz(y = waveform, x = t.to(unit.ns).magnitude)
# Out:
# 40805.91413672085

# %%
t, waveform, ax = s2_signal.PrintWaveform(sensor, shaped_and_sampled = True, units ='mA')
ax.legend()

# %%
t, waveform, ax = s2_signal.PrintWaveform(sensor, shaped_and_sampled = True, units = 'mV')
ax.legend()

# %%
list_of_bb = [event_path, event_path]

# %%
dyn_range = s2sim.DynamicRange(s2table, 
                               TPC, 
                               list_of_bb,
                               shapin_tau = 155 *unit.ns,
                               samplin_rate = 25*unit.ns,
                               t_binin = 10*unit.ns,
                               units = 'mV'
                              )
# Out:
# Processing event 1/10 in file 1/2...
# Processing event 2/10 in file 1/2...                                    one succesfully :)
# Creating signal (Processing sensor 106/108)...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 dyn_range = s2sim.DynamicRange(s2table,
#       2                                TPC,
#       3                                list_of_bb,
#       4                                shapin_tau = 155 *unit.ns,
#       5                                samplin_rate = 25*unit.ns,
#       6                                t_binin = 10*unit.ns,
#       7                                units = 'mV'
#       8                               )
#
# File ~/mariandbt/python/notebooks/modules/s2_simulation.py:542, in DynamicRange(s2table, TPC, list_of_bb_paths, shapin_tau, samplin_rate, t_binin, units, impedance_in_ohm)
#     539 NexusEvent = nexusEvent(event_path, event)
#     540 NexusEvent.AddDriftAndDiffusion(TPC)
# --> 542 s2signal = s2Signal(s2table, TPC, NexusEvent)
#     543 s2signal.AddShapinAndSamplin(shapin_tau, samplin_rate, t_binin)
#     545 if units == 'mV':
#
# File ~/mariandbt/python/notebooks/modules/s2_simulation.py:378, in s2Signal.__init__(self, s2Table, TPC, nexusEvent)
#     375     processing_message = f'Creating signal (Processing sensor {jj+1}/{TPC.NSensors})...'
#     376     print(processing_message + ' '*len(processing_message), end = '\r')
# --> 378 s2_data     = FindS2(sens_id, nexusEvent, s2Table, TPC)
#     379 s2_values   = s2_data.astype(np.float32) # [pes]
#     381 self.SensorResponse[sens_id]    = s2_values # [pes]
#
# File ~/mariandbt/python/notebooks/modules/s2_simulation.py:271, in FindS2(sensor_id, nexusEvent, s2Table, TPC)
#     269 def FindS2(sensor_id, nexusEvent, s2Table, TPC):
# --> 271     rotation    = FindRotation(nexusEvent.ElectronsFinalAlpha.magnitude, TPC)
#     273     new_alpha   = nexusEvent.ElectronsFinalAlpha - rotation * TPC.DeltaTheta
#     274     new_xx      = nexusEvent.ElectronsFinalR * np.cos(new_alpha)
#
# File ~/miniconda3/envs/IC-3.8-2022-04-13/lib/python3.8/site-packages/numpy/lib/function_base.py:2113, in vectorize.__call__(self, *args, **kwargs)
#    2110     vargs = [args[_i] for _i in inds]
#    2111     vargs.extend([kwargs[_n] for _n in names])
# -> 2113 return self._vectorize_call(func=func, args=vargs)
#
# File ~/miniconda3/envs/IC-3.8-2022-04-13/lib/python3.8/site-packages/numpy/lib/function_base.py:2197, in vectorize._vectorize_call(self, func, args)
#    2193 # Convert args to object arrays first
#    2194 inputs = [array(a, copy=False, subok=True, dtype=object)
#    2195           for a in args]
# -> 2197 outputs = ufunc(*inputs)
#    2199 if ufunc.nout == 1:
#    2200     res = array(outputs, copy=False, subok=True, dtype=otypes[0])
#
# File ~/mariandbt/python/notebooks/modules/s2_simulation.py:228, in FindRotation(electron_final_alpha, TPC)
#     224 def FindRotation(electron_final_alpha, TPC):
#     226     dtheta = TPC.DeltaTheta.magnitude
# --> 228     rot = np.where(electron_final_alpha > 0,
#     229                    int((electron_final_alpha + dtheta/2)/dtheta),
#     230                    int((electron_final_alpha - dtheta/2)/dtheta)
#     231                   )
#     232     return rot
#
# File <__array_function__ internals>:5, in where(*args, **kwargs)
#
# KeyboardInterrupt:
