# %% [markdown]
# # $\beta$ $\beta$ offline signal reconstruction

# %%
# S2 signal script
import sys
sys.path.append('/home/investigator/mariandbt/python/notebooks/modules')

from import_modules import *

import s2_simulation as s2sim
from s2_simulation import unit

# %%
path = '/home/investigator/mariandbt/python/data'
path = path + '/20240313_s2simulation'

# %%
sns_path = os.path.join(path, "ie/20240405_Next100_ie_s2_1.next.h5")
s2_table_path = os.path.join(path, "s2tab/20240405_s2_table.h5")
event_path = os.path.join(path, "bb/20240228_Next100_10ev_ELon_bb_1.next.h5") # 10 full bb w s2

# %%
event, sensor = 0, 202

# %%
# Create TPC
TPC     = s2sim.HPGXeTPC()
TPC.SetDefaults(sns_path)
# Out:
# /home/investigator/miniconda3/envs/IC-3.8-2022-04-13/lib/python3.8/site-packages/pandas/io/pytables.py:3523: IncompatibilityWarning:
# where criteria is being ignored as this version [0.0.0] is too old (or
# not-defined), read the file in and write it out to a new file to upgrade (with
# the copy_to method)
#
#   warnings.warn(ws, IncompatibilityWarning)
# Default parameters set succesfully :) TPC ready to use

# %%
nexusEvent = s2sim.nexusEvent(event_path, event)
nexusEvent.AddDriftAndDiffusion(TPC)

# %%
s2table = s2sim.s2Table(s2_table_path)

# %%
# %%timeit # (~4mins) (~25s no sé why...)
s2signal = s2sim.s2Signal(s2table, TPC, nexusEvent)
# Out:
# Creating signal (Processing sensor 108/108)... Signal created succesfully :)

# %%
# %%timeit # (~4mins/sensor for t_bin = 0.1ns; 35.1s in total for t_bin = 1ns)
s2signal.AddShapinAndSamplin(samplin_rate = 25*unit.ns, t_binin = 1*unit.ns)
# Out:
# Shaping and sampling (Processing sensor 108/108)... Shapin and samplin done succesfully :)

# %%
t, waveform, ax = s2signal.PrintWaveform(sensor, shaped_and_sampled = False, bin_width = 1 *unit.us)
ax.legend();
waveform.sum()
# Out:
# 14210.0

# %%
t, waveform, ax = s2signal.PrintWaveform(sensor, shaped_and_sampled = True, units = 'pes/ns')
ax.legend()
np.trapz(y = waveform, x = t.to(unit.ns).magnitude)
# Out:
# 14213.125907689813

# %%
t, waveform, ax = s2signal.PrintWaveform(sensor, shaped_and_sampled = True, units ='mA')
ax.legend()

# %%
t, waveform, ax = s2signal.PrintWaveform(sensor, shaped_and_sampled = True, units = 'mV')
ax.legend()

# %% [markdown]
# # $\beta$ $\beta$ offline dynamic range

# %%
# S2 signal script
import sys
sys.path.append('/home/investigator/mariandbt/python/notebooks/modules')

from import_modules import *

import s2_simulation as s2sim
from s2_simulation import unit

# %%
path = '/home/investigator/mariandbt/python/data'
path = path + '/20240313_s2simulation'

# %%
sns_path = os.path.join(path, "ie/20240405_Next100_ie_s2_1.next.h5")
s2_table_path = os.path.join(path, "s2tab/20240405_s2_table.h5")
event_path = os.path.join(path, "bb/20240228_Next100_10ev_ELon_bb_1.next.h5") # 10 full bb w s2
event_path2 = os.path.join(path, "bb/20240306_Next100_200ev_ELoff_bb_1.next.h5") # 200 evs w/o s2

# %%
# Create TPC
TPC     = s2sim.HPGXeTPC()
TPC.SetDefaults(sns_path)
# Out:
# Default parameters set succesfully :) TPC ready to use
# /home/investigator/miniconda3/envs/IC-3.8-2022-04-13/lib/python3.8/site-packages/pandas/io/pytables.py:3523: IncompatibilityWarning:
# where criteria is being ignored as this version [0.0.0] is too old (or
# not-defined), read the file in and write it out to a new file to upgrade (with
# the copy_to method)
#
#   warnings.warn(ws, IncompatibilityWarning)

# %%
s2table = s2sim.s2Table(s2_table_path)

# %%
list_of_bb = [event_path, event_path2]
# list_of_bb = [event_path]
# list_of_bb = [event_path2]

# %%
# %%timeit # (37.1s /event)
DynamicRange = s2sim.DynamicRange(s2table, 
                                  TPC, 
                                  List_bb_Paths = list_of_bb,
                                  fiducial_radio = 490 *unit.mm,
                                  shapin_tau = 155 *unit.ns,
                                  samplin_rate = 25*unit.ns,
                                  t_binin = 1*unit.ns,
                                  units = 'mV',
                                  impedance_in_ohm = 50 # only used if units = mV
                                 )
# Out:
# Dynamic range (Processing event 1/10 in file 1/2...)
# Dynamic range (Processing event 2/10 in file 1/2...)
# Dynamic range (Processing event 3/10 in file 1/2...)
# Dynamic range (Processing event 4/10 in file 1/2...)
# Dynamic range (Processing event 5/10 in file 1/2...)
# Dynamic range (Processing event 6/10 in file 1/2...)
# Dynamic range (Processing event 7/10 in file 1/2...)
# Shaping and sampling (Processing sensor 1/108)...
# /home/investigator/mariandbt/python/notebooks/modules/s2_simulation.py:327: RuntimeWarning: overflow encountered in multiply
#   signal = (rise_term * decay_term)
# Dynamic range (Processing event 8/10 in file 1/2...)
# Dynamic range (Processing event 9/10 in file 1/2...)
# Dynamic range (Processing event 10/10 in file 1/2...)
# Dynamic range (Processing event 1/200 in file 2/2...)
# Dynamic range (Processing event 2/200 in file 2/2...)
# Dynamic range (Processing event 3/200 in file 2/2...)
# Shaping and sampling (Processing sensor 1/108)...
# /home/investigator/mariandbt/python/notebooks/modules/s2_simulation.py:324: RuntimeWarning: overflow encountered in exp
#   rise_term = 1 - np.exp(-(t - t0) / (tau * rise_time))
# /home/investigator/mariandbt/python/notebooks/modules/s2_simulation.py:325: RuntimeWarning: overflow encountered in exp
#   decay_term = np.exp(-(t - t0) / tau)
# Dynamic range (Processing event 4/200 in file 2/2...)
# Dynamic range (Processing event 5/200 in file 2/2...)
# Dynamic range (Processing event 6/200 in file 2/2...)
# Dynamic range (Processing event 7/200 in file 2/2...)
# Dynamic range (Processing event 8/200 in file 2/2...)
# Dynamic range (Processing event 9/200 in file 2/2...)
# Dynamic range (Processing event 10/200 in file 2/2...)
# Dynamic range (Processing event 11/200 in file 2/2...)
# Dynamic range (Processing event 12/200 in file 2/2...)
# Dynamic range (Processing event 13/200 in file 2/2...)
# Dynamic range (Processing event 14/200 in file 2/2...)
# Dynamic range (Processing event 15/200 in file 2/2...)
# Dynamic range (Processing event 16/200 in file 2/2...)
# Dynamic range (Processing event 17/200 in file 2/2...)
# Dynamic range (Processing event 18/200 in file 2/2...)
# Dynamic range (Processing event 19/200 in file 2/2...)
# Dynamic range (Processing event 20/200 in file 2/2...)
# Dynamic range (Processing event 21/200 in file 2/2...)
# Dynamic range (Processing event 22/200 in file 2/2...)
# Dynamic range (Processing event 23/200 in file 2/2...)
# Dynamic range (Processing event 24/200 in file 2/2...)
# Dynamic range (Processing event 25/200 in file 2/2...)
# Dynamic range (Processing event 26/200 in file 2/2...)
# Dynamic range (Processing event 27/200 in file 2/2...)
# Dynamic range (Processing event 28/200 in file 2/2...)
# Dynamic range (Processing event 29/200 in file 2/2...)
# Dynamic range (Processing event 30/200 in file 2/2...)
# Dynamic range (Processing event 31/200 in file 2/2...)
# Dynamic range (Processing event 32/200 in file 2/2...)
# Dynamic range (Processing event 33/200 in file 2/2...)
# Dynamic range (Processing event 34/200 in file 2/2...)
# Dynamic range (Processing event 35/200 in file 2/2...)
# Dynamic range (Processing event 36/200 in file 2/2...)
# Dynamic range (Processing event 37/200 in file 2/2...)
# Dynamic range (Processing event 38/200 in file 2/2...)
# Dynamic range (Processing event 39/200 in file 2/2...)
# Dynamic range (Processing event 40/200 in file 2/2...)
# Dynamic range (Processing event 41/200 in file 2/2...)
# Dynamic range (Processing event 42/200 in file 2/2...)
# Dynamic range (Processing event 43/200 in file 2/2...)
# Dynamic range (Processing event 44/200 in file 2/2...)
# Dynamic range (Processing event 45/200 in file 2/2...)
# Dynamic range (Processing event 46/200 in file 2/2...)
# Dynamic range (Processing event 47/200 in file 2/2...)
# Dynamic range (Processing event 48/200 in file 2/2...)
# Dynamic range (Processing event 49/200 in file 2/2...)
# Dynamic range (Processing event 50/200 in file 2/2...)
# Dynamic range (Processing event 51/200 in file 2/2...)
# Dynamic range (Processing event 52/200 in file 2/2...)
# Dynamic range (Processing event 53/200 in file 2/2...)
# Dynamic range (Processing event 54/200 in file 2/2...)
# Dynamic range (Processing event 55/200 in file 2/2...)
# Dynamic range (Processing event 56/200 in file 2/2...)
# Dynamic range (Processing event 57/200 in file 2/2...)
# Dynamic range (Processing event 58/200 in file 2/2...)
# This event is empty... Try another, this one won't take you far :(
# Dynamic range (Processing event 59/200 in file 2/2...)
# Dynamic range (Processing event 60/200 in file 2/2...)
# Dynamic range (Processing event 61/200 in file 2/2...)
# Dynamic range (Processing event 62/200 in file 2/2...)
# Dynamic range (Processing event 63/200 in file 2/2...)
# Dynamic range (Processing event 64/200 in file 2/2...)
# Dynamic range (Processing event 65/200 in file 2/2...)
# Dynamic range (Processing event 66/200 in file 2/2...)
# Dynamic range (Processing event 67/200 in file 2/2...)
# Dynamic range (Processing event 68/200 in file 2/2...)
# Dynamic range (Processing event 69/200 in file 2/2...)
# Dynamic range (Processing event 70/200 in file 2/2...)
# Dynamic range (Processing event 71/200 in file 2/2...)
# Dynamic range (Processing event 72/200 in file 2/2...)
# Dynamic range (Processing event 73/200 in file 2/2...)
# Dynamic range (Processing event 74/200 in file 2/2...)
# Dynamic range (Processing event 75/200 in file 2/2...)
# Dynamic range (Processing event 76/200 in file 2/2...)
# Dynamic range (Processing event 77/200 in file 2/2...)
# Dynamic range (Processing event 78/200 in file 2/2...)
# Dynamic range (Processing event 79/200 in file 2/2...)
# Dynamic range (Processing event 80/200 in file 2/2...)
# Dynamic range (Processing event 81/200 in file 2/2...)
# Dynamic range (Processing event 82/200 in file 2/2...)
# Dynamic range (Processing event 83/200 in file 2/2...)
# Dynamic range (Processing event 84/200 in file 2/2...)
# Dynamic range (Processing event 85/200 in file 2/2...)
# Dynamic range (Processing event 86/200 in file 2/2...)
# Dynamic range (Processing event 87/200 in file 2/2...)
# Dynamic range (Processing event 88/200 in file 2/2...)
# Dynamic range (Processing event 89/200 in file 2/2...)
# Dynamic range (Processing event 90/200 in file 2/2...)
# Dynamic range (Processing event 91/200 in file 2/2...)
# Dynamic range (Processing event 92/200 in file 2/2...)
# Dynamic range (Processing event 93/200 in file 2/2...)
# Dynamic range (Processing event 94/200 in file 2/2...)
# Dynamic range (Processing event 95/200 in file 2/2...)
# Dynamic range (Processing event 96/200 in file 2/2...)
# This event is empty... Try another, this one won't take you far :(
# Dynamic range (Processing event 97/200 in file 2/2...)
# Dynamic range (Processing event 98/200 in file 2/2...)
# Dynamic range (Processing event 99/200 in file 2/2...)
# Dynamic range (Processing event 100/200 in file 2/2...)
# Dynamic range (Processing event 101/200 in file 2/2...)
# Dynamic range (Processing event 102/200 in file 2/2...)
# Dynamic range (Processing event 103/200 in file 2/2...)
# Dynamic range (Processing event 104/200 in file 2/2...)
# Dynamic range (Processing event 105/200 in file 2/2...)
# Dynamic range (Processing event 106/200 in file 2/2...)
# Dynamic range (Processing event 107/200 in file 2/2...)
# Dynamic range (Processing event 108/200 in file 2/2...)
# Dynamic range (Processing event 109/200 in file 2/2...)
# Dynamic range (Processing event 110/200 in file 2/2...)
# Dynamic range (Processing event 111/200 in file 2/2...)
# Dynamic range (Processing event 112/200 in file 2/2...)
# This event is empty... Try another, this one won't take you far :(
# Dynamic range (Processing event 113/200 in file 2/2...)
# Dynamic range (Processing event 114/200 in file 2/2...)
# Dynamic range (Processing event 115/200 in file 2/2...)
# Dynamic range (Processing event 116/200 in file 2/2...)
# Dynamic range (Processing event 117/200 in file 2/2...)
# Dynamic range (Processing event 118/200 in file 2/2...)
# Dynamic range (Processing event 119/200 in file 2/2...)
# Dynamic range (Processing event 120/200 in file 2/2...)
# Dynamic range (Processing event 121/200 in file 2/2...)
# Dynamic range (Processing event 122/200 in file 2/2...)
# Dynamic range (Processing event 123/200 in file 2/2...)
# Dynamic range (Processing event 124/200 in file 2/2...)
# Dynamic range (Processing event 125/200 in file 2/2...)
# Dynamic range (Processing event 126/200 in file 2/2...)
# Dynamic range (Processing event 127/200 in file 2/2...)
# Dynamic range (Processing event 128/200 in file 2/2...)
# Dynamic range (Processing event 129/200 in file 2/2...)
# Dynamic range (Processing event 130/200 in file 2/2...)
# Dynamic range (Processing event 131/200 in file 2/2...)
# Dynamic range (Processing event 132/200 in file 2/2...)
# Dynamic range (Processing event 133/200 in file 2/2...)
# Dynamic range (Processing event 134/200 in file 2/2...)
# Dynamic range (Processing event 135/200 in file 2/2...)
# Dynamic range (Processing event 136/200 in file 2/2...)
# Dynamic range (Processing event 137/200 in file 2/2...)
# Dynamic range (Processing event 138/200 in file 2/2...)
# Dynamic range (Processing event 139/200 in file 2/2...)
# Dynamic range (Processing event 140/200 in file 2/2...)
# Dynamic range (Processing event 141/200 in file 2/2...)
# Dynamic range (Processing event 142/200 in file 2/2...)
# Dynamic range (Processing event 143/200 in file 2/2...)
# Dynamic range (Processing event 144/200 in file 2/2...)
# Dynamic range (Processing event 145/200 in file 2/2...)
# Dynamic range (Processing event 146/200 in file 2/2...)
# Dynamic range (Processing event 147/200 in file 2/2...)
# Dynamic range (Processing event 148/200 in file 2/2...)
# Dynamic range (Processing event 149/200 in file 2/2...)
# Dynamic range (Processing event 150/200 in file 2/2...)
# Dynamic range (Processing event 151/200 in file 2/2...)
# Dynamic range (Processing event 152/200 in file 2/2...)
# Dynamic range (Processing event 153/200 in file 2/2...)
# Dynamic range (Processing event 154/200 in file 2/2...)
# Dynamic range (Processing event 155/200 in file 2/2...)
# Dynamic range (Processing event 156/200 in file 2/2...)
# This event is empty... Try another, this one won't take you far :(
# Dynamic range (Processing event 157/200 in file 2/2...)
# Dynamic range (Processing event 158/200 in file 2/2...)
# Dynamic range (Processing event 159/200 in file 2/2...)
# Dynamic range (Processing event 160/200 in file 2/2...)
# Dynamic range (Processing event 161/200 in file 2/2...)
# Dynamic range (Processing event 162/200 in file 2/2...)
# Dynamic range (Processing event 163/200 in file 2/2...)
# Dynamic range (Processing event 164/200 in file 2/2...)
# Dynamic range (Processing event 165/200 in file 2/2...)
# Dynamic range (Processing event 166/200 in file 2/2...)
# Dynamic range (Processing event 167/200 in file 2/2...)
# Dynamic range (Processing event 168/200 in file 2/2...)
# Dynamic range (Processing event 169/200 in file 2/2...)
# Dynamic range (Processing event 170/200 in file 2/2...)
# Dynamic range (Processing event 171/200 in file 2/2...)
# Dynamic range (Processing event 172/200 in file 2/2...)
# Dynamic range (Processing event 173/200 in file 2/2...)
# Dynamic range (Processing event 174/200 in file 2/2...)
# Dynamic range (Processing event 175/200 in file 2/2...)
# Dynamic range (Processing event 176/200 in file 2/2...)
# Dynamic range (Processing event 177/200 in file 2/2...)
# Dynamic range (Processing event 178/200 in file 2/2...)
# Dynamic range (Processing event 179/200 in file 2/2...)
# Dynamic range (Processing event 180/200 in file 2/2...)
# Dynamic range (Processing event 181/200 in file 2/2...)
# Dynamic range (Processing event 182/200 in file 2/2...)
# Dynamic range (Processing event 183/200 in file 2/2...)
# Dynamic range (Processing event 184/200 in file 2/2...)
# Dynamic range (Processing event 185/200 in file 2/2...)
# Dynamic range (Processing event 186/200 in file 2/2...)
# Dynamic range (Processing event 187/200 in file 2/2...)
# Dynamic range (Processing event 188/200 in file 2/2...)
# Dynamic range (Processing event 189/200 in file 2/2...)
# Dynamic range (Processing event 190/200 in file 2/2...)
# Dynamic range (Processing event 191/200 in file 2/2...)
# Dynamic range (Processing event 192/200 in file 2/2...)
# Dynamic range (Processing event 193/200 in file 2/2...)
# Dynamic range (Processing event 194/200 in file 2/2...)
# Dynamic range (Processing event 195/200 in file 2/2...)
# Dynamic range (Processing event 196/200 in file 2/2...)
# Dynamic range (Processing event 197/200 in file 2/2...)
# Dynamic range (Processing event 198/200 in file 2/2...)
# Dynamic range (Processing event 199/200 in file 2/2...)
# Dynamic range (Processing event 200/200 in file 2/2...)
# Shaping and sampling (Processing sensor 108/108)... Shapin and samplin done succesfully :)

# %%
events, bins, ax = DynamicRange.PrintHist(bin_width = 10, logscale = False)

# %% [markdown]
# # $\beta$ $\beta$ waveform + diff: nexus vs offline

# %%
# S2 signal script
import sys
sys.path.append('/home/investigator/mariandbt/python/notebooks/modules')

from import_modules import *
import set_up as setup

import s2_simulation as s2sim
from s2_simulation import unit

# %%
event, sensor = 0, 202

# %%
path = '/home/investigator/mariandbt/python/data'
path = path + '/20240313_s2simulation'

# %%
sns_path = os.path.join(path, "ie/20240405_Next100_ie_s2_1.next.h5")
s2_table_path = os.path.join(path, "s2tab/20240405_s2_table.h5")
event_path = os.path.join(path, "bb/20240228_Next100_10ev_ELon_bb_1.next.h5") # 10 full bb w s2

# %%
# Create TPC
TPC     = s2sim.HPGXeTPC()
TPC.SetDefaults(sns_path)
# Out:
# /home/investigator/miniconda3/envs/IC-3.8-2022-04-13/lib/python3.8/site-packages/pandas/io/pytables.py:3523: IncompatibilityWarning:
# where criteria is being ignored as this version [0.0.0] is too old (or
# not-defined), read the file in and write it out to a new file to upgrade (with
# the copy_to method)
#
#   warnings.warn(ws, IncompatibilityWarning)
# Default parameters set succesfully :) TPC ready to use

# %%
s2table = s2sim.s2Table(s2_table_path)

# %%
hits = pd.read_hdf(event_path, "/MC/hits")
hits = hits.query(f'event_id == {event}')

# %%
particles = pd.read_hdf(event_path, "/MC/particles")
particles = particles.query(f'event_id == {event}')

ie        = particles.query(f'particle_name == "ie-"')

# %%
sns_response = pd.read_hdf(event_path, "/MC/sns_response")
sns_response = sns_response.query(f'event_id == {event}')

# %%
nexusEvent = s2sim.nexusEvent(event_path, event)
nexusEvent.AddDriftAndDiffusion(TPC)

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(10,5), constrained_layout=True, sharex=False, sharey=False)

font_size = 20

# nexus
_, _, _, figure_map = ax[0].hist2d(ie.final_x, 
                                   ie.final_y, 
                                   bins = 100, cmap='inferno', label = 'nexus');

fig.colorbar(figure_map, ax = ax[0]);
ax[0].set_title('nexus', fontsize = font_size)

# Offline simulation
_, _, _, figure_map = ax[1].hist2d(nexusEvent.ElectronsFinalX.magnitude, 
                                   nexusEvent.ElectronsFinalY.magnitude, 
                                   bins = 100, cmap='inferno', label = 'nexus');
fig.colorbar(figure_map, ax = ax[1]);
ax[1].set_title('Offline', fontsize = font_size)


for axis in ax:

    axis.set_xlabel('X [mm]', fontsize = font_size);
    axis.set_ylabel('Y [mm]', fontsize = font_size);
    axis.tick_params(axis='both', labelsize = font_size*2/3)

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(10,5), constrained_layout=True, sharex=False, sharey=False)

font_size = 20

# nexus
nexus_t = ie.final_t*1e-3 # [us]
_, _, _, figure_map = ax[0].hist2d(nexus_t, 
                                   ie.final_y, 
                                   bins = 100, cmap='inferno', label = 'nexus');

fig.colorbar(figure_map, ax = ax[0]);
ax[0].set_title('nexus', fontsize = font_size)

# Offline simulation
_, _, _, figure_map = ax[1].hist2d(nexusEvent.ElectronsMeasurementTime.to(unit.us).magnitude, 
                                   nexusEvent.ElectronsFinalY.magnitude, 
                                   bins = 100, cmap='inferno', label = 'nexus');
fig.colorbar(figure_map, ax = ax[1]);
ax[1].set_title('Offline', fontsize = font_size)


for axis in ax:

    axis.set_xlabel('t [us]', fontsize = font_size);
    axis.set_ylabel('Y [mm]', fontsize = font_size);
    axis.tick_params(axis='both', labelsize = font_size*2/3)

# %%
online_signal = sns_response.query(f'sensor_id == {sensor}').copy()
t_binnin = 0.1 # [ns]
online_signal.time_bin = online_signal.time_bin*t_binnin # [ns]

# %%
nexus_t = online_signal.time_bin*1e-3 # [us]
nexus_s2 = online_signal.charge # [pes]

# %%
# %%timeit # (~4mins) (~25s no sé why...)
s2signal = s2sim.s2Signal(s2table, TPC, nexusEvent)
# Out:
# Creating signal (Processing sensor 108/108)... Signal created succesfully :)

# %%
t, waveform, ax = s2signal.PrintWaveform(sensor, shaped_and_sampled = False)
waveform.sum()


nexus_s2 = nexus_s2[nexus_t > 100] # exclude s1
nexus_t = nexus_t[nexus_t > 100] # exclude s1

bin_width = 1 # [us]
binin = np.arange(nexus_t.min() - bin_width, nexus_t.max() + 2*bin_width, bin_width)
events, bins, bars = ax.hist(nexus_t, binin,
                             weights = nexus_s2,
                             density=False,
                             histtype='step',
                             label = f'nexus'
                            )


# Add the initial legend
legend = ax.legend()
# Modify the legend labels
new_labels = ['Offline simulation', legend.get_texts()[1].get_text()]
ax.legend(handles=legend.legendHandles, labels=new_labels);

# ax.legend();
