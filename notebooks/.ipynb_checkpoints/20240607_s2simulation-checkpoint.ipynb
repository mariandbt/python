# %% [markdown]
# # $\beta$ $\beta$ offline signal reconstruction

# %%
# S2 signal script
import sys
sys.path.append('/home/investigator/mariandbt/python/notebooks/modules')

from import_modules import *

import s2_simulation as s2sim
from s2_simulation import unit

# %%
path = '/home/investigator/mariandbt/python/data'
path = path + '/20240313_s2simulation'

# %%
sns_path = os.path.join(path, "ie/20240405_Next100_ie_s2_1.next.h5")
s2_table_path = os.path.join(path, "s2tab/20240405_s2_table.h5")
event_path = os.path.join(path, "bb/20240228_Next100_10ev_ELon_bb_1.next.h5") # 10 full bb w s2

# %%
event, sensor = 0, 202

# %%
# Create TPC
TPC     = s2sim.HPGXeTPC()
TPC.SetDefaults(sns_path)
# Out:
# Default parameters set succesfully :) TPC ready to use
# /home/investigator/miniconda3/envs/IC-3.8-2022-04-13/lib/python3.8/site-packages/pandas/io/pytables.py:3523: IncompatibilityWarning:
# where criteria is being ignored as this version [0.0.0] is too old (or
# not-defined), read the file in and write it out to a new file to upgrade (with
# the copy_to method)
#
#   warnings.warn(ws, IncompatibilityWarning)

# %%
nexusEvent = s2sim.nexusEvent(event_path, event)
nexusEvent.AddDriftAndDiffusion(TPC)

# %%
s2table = s2sim.s2Table(s2_table_path)

# %%
# %%timeit # (~4mins) (~25s no sé why...)
s2signal = s2sim.s2Signal(s2table, TPC, nexusEvent)
# Out:
# Creating signal (Processing sensor 108/108)... Signal created succesfully :)

# %%
# %%timeit # (~4mins/sensor for t_bin = 0.1ns; 35.1s in total for t_bin = 1ns)
s2signal.AddShapinAndSamplin(samplin_rate = 25*unit.ns, t_binin = 1*unit.ns)
# Out:
# Shaping and sampling (Processing sensor 108/108)... Shapin and samplin done succesfully :)

# %%
t, waveform, ax = s2signal.PrintWaveform(sensor, shaped_and_sampled = False, bin_width = 1 *unit.us)
ax.legend();
waveform.sum()
# Out:
# 14344.0

# %%
t, waveform, ax = s2signal.PrintWaveform(sensor, shaped_and_sampled = True, units = 'pes/ns')
ax.legend()
np.trapz(y = waveform, x = t.to(unit.ns).magnitude)
# Out:
# 14347.510431190429

# %%
t, waveform, ax = s2signal.PrintWaveform(sensor, shaped_and_sampled = True, units ='mA')
ax.legend()

# %%
t, waveform, ax = s2signal.PrintWaveform(sensor, shaped_and_sampled = True, units = 'mV')
ax.legend()

# %% [markdown]
# # $\beta$ $\beta$ offline dynamic range

# %%
# S2 signal script
import sys
sys.path.append('/home/investigator/mariandbt/python/notebooks/modules')

from import_modules import *

import s2_simulation as s2sim
from s2_simulation import unit

# %%
path = '/home/investigator/mariandbt/python/data'
path = path + '/20240313_s2simulation'

# %%
sns_path = os.path.join(path, "ie/20240405_Next100_ie_s2_1.next.h5")
s2_table_path = os.path.join(path, "s2tab/20240405_s2_table.h5")
event_path = os.path.join(path, "bb/20240228_Next100_10ev_ELon_bb_1.next.h5") # 10 full bb w s2
event_path2 = os.path.join(path, "bb/20240306_Next100_200ev_ELoff_bb_1.next.h5") # 200 evs w/o s2

# %%
# Create TPC
TPC     = s2sim.HPGXeTPC()
TPC.SetDefaults(sns_path)
# Out:
# Default parameters set succesfully :) TPC ready to use
# /home/investigator/miniconda3/envs/IC-3.8-2022-04-13/lib/python3.8/site-packages/pandas/io/pytables.py:3523: IncompatibilityWarning:
# where criteria is being ignored as this version [0.0.0] is too old (or
# not-defined), read the file in and write it out to a new file to upgrade (with
# the copy_to method)
#
#   warnings.warn(ws, IncompatibilityWarning)

# %%
s2table = s2sim.s2Table(s2_table_path)

# %%
list_of_bb = [event_path, event_path2]
list_of_bb = [event_path]
# list_of_bb = [event_path2]

# %%
# %%timeit # (37.1s /event)
DynamicRange = s2sim.DynamicRange(s2table, 
                                  TPC, 
                                  List_bb_Paths = list_of_bb,
                                  fiducial_radio = 490 *unit.mm,
                                  shapin_tau = 155 *unit.ns,
                                  samplin_rate = 25*unit.ns,
                                  t_binin = 1*unit.ns,
                                  units = 'mV',
                                  impedance_in_ohm = 50 # only used if units = mV
                                 )
# Out:
# Dynamic range (Processing event 1/10 in file 1/1...)
# Dynamic range (Processing event 2/10 in file 1/1...)
# Dynamic range (Processing event 3/10 in file 1/1...)
# Dynamic range (Processing event 4/10 in file 1/1...)
# Dynamic range (Processing event 5/10 in file 1/1...)
# Dynamic range (Processing event 6/10 in file 1/1...)
# Dynamic range (Processing event 7/10 in file 1/1...)
# Shaping and sampling (Processing sensor 1/108)...
# /home/investigator/mariandbt/python/notebooks/modules/s2_simulation.py:328: RuntimeWarning: overflow encountered in multiply
#   signal = (rise_term * decay_term)
# Dynamic range (Processing event 8/10 in file 1/1...)
# Dynamic range (Processing event 9/10 in file 1/1...)
# Dynamic range (Processing event 10/10 in file 1/1...)
# Shaping and sampling (Processing sensor 108/108)... Shapin and samplin done succesfully :)

# %%
events, bins, ax = DynamicRange.PrintHist(bin_width = 10, logscale = False)

# %% [markdown]
# # $\beta$ $\beta$ waveform + diff: nexus vs offline

# %%
# S2 signal script
import sys
sys.path.append('/home/investigator/mariandbt/python/notebooks/modules')

from import_modules import *
import set_up as setup

import s2_simulation as s2sim
from s2_simulation import unit

# %%
event, sensor = 0, 202

# %%
path = '/home/investigator/mariandbt/python/data'
path = path + '/20240313_s2simulation'

# %%
sns_path = os.path.join(path, "ie/20240405_Next100_ie_s2_1.next.h5")
s2_table_path = os.path.join(path, "s2tab/20240405_s2_table.h5")
event_path = os.path.join(path, "bb/20240228_Next100_10ev_ELon_bb_1.next.h5") # 10 full bb w s2

# %%
# Create TPC
TPC     = s2sim.HPGXeTPC()
TPC.SetDefaults(sns_path)
# Out:
# /home/investigator/miniconda3/envs/IC-3.8-2022-04-13/lib/python3.8/site-packages/pandas/io/pytables.py:3523: IncompatibilityWarning:
# where criteria is being ignored as this version [0.0.0] is too old (or
# not-defined), read the file in and write it out to a new file to upgrade (with
# the copy_to method)
#
#   warnings.warn(ws, IncompatibilityWarning)
# Default parameters set succesfully :) TPC ready to use

# %%
s2table = s2sim.s2Table(s2_table_path)

# %%
hits = pd.read_hdf(event_path, "/MC/hits")
hits = hits.query(f'event_id == {event}')

# %%
particles = pd.read_hdf(event_path, "/MC/particles")
particles = particles.query(f'event_id == {event}')

ie        = particles.query(f'particle_name == "ie-"')

# %%
sns_response = pd.read_hdf(event_path, "/MC/sns_response")
sns_response = sns_response.query(f'event_id == {event}')

# %%
nexusEvent = s2sim.nexusEvent(event_path, event)
nexusEvent.AddDriftAndDiffusion(TPC)

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(10,5), constrained_layout=True, sharex=False, sharey=False)

font_size = 20

# nexus
_, _, _, figure_map = ax[0].hist2d(ie.final_x, 
                                   ie.final_y, 
                                   bins = 100, cmap='inferno', label = 'nexus');

fig.colorbar(figure_map, ax = ax[0]);
ax[0].set_title('nexus', fontsize = font_size)

# Offline simulation
_, _, _, figure_map = ax[1].hist2d(nexusEvent.ElectronsFinalX.magnitude, 
                                   nexusEvent.ElectronsFinalY.magnitude, 
                                   bins = 100, cmap='inferno', label = 'nexus');
fig.colorbar(figure_map, ax = ax[1]);
ax[1].set_title('Offline', fontsize = font_size)


for axis in ax:

    axis.set_xlabel('X [mm]', fontsize = font_size);
    axis.set_ylabel('Y [mm]', fontsize = font_size);
    axis.tick_params(axis='both', labelsize = font_size*2/3)

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(10,5), constrained_layout=True, sharex=False, sharey=False)

font_size = 20

# nexus
nexus_t = ie.final_t*1e-3 # [us]
_, _, _, figure_map = ax[0].hist2d(nexus_t, 
                                   ie.final_y, 
                                   bins = 100, cmap='inferno', label = 'nexus');

fig.colorbar(figure_map, ax = ax[0]);
ax[0].set_title('nexus', fontsize = font_size)

# Offline simulation
_, _, _, figure_map = ax[1].hist2d(nexusEvent.ElectronsMeasurementTime.to(unit.us).magnitude, 
                                   nexusEvent.ElectronsFinalY.magnitude, 
                                   bins = 100, cmap='inferno', label = 'nexus');
fig.colorbar(figure_map, ax = ax[1]);
ax[1].set_title('Offline', fontsize = font_size)


for axis in ax:

    axis.set_xlabel('t [us]', fontsize = font_size);
    axis.set_ylabel('Y [mm]', fontsize = font_size);
    axis.tick_params(axis='both', labelsize = font_size*2/3)

# %%
online_signal = sns_response.query(f'sensor_id == {sensor}').copy()
t_binnin = 0.1 # [ns]
online_signal.time_bin = online_signal.time_bin*t_binnin # [ns]

# %%
nexus_t = online_signal.time_bin*1e-3 # [us]
nexus_s2 = online_signal.charge # [pes]

# %%
# %%timeit # (~4mins) (~25s no sé why...)
s2signal = s2sim.s2Signal(s2table, TPC, nexusEvent)
# Out:
# Creating signal (Processing sensor 108/108)... Signal created succesfully :)

# %%
t, waveform, ax = s2signal.PrintWaveform(sensor, shaped_and_sampled = False)
waveform.sum()


nexus_s2 = nexus_s2[nexus_t > 100] # exclude s1
nexus_t = nexus_t[nexus_t > 100] # exclude s1

bin_width = 1 # [us]
binin = np.arange(nexus_t.min() - bin_width, nexus_t.max() + 2*bin_width, bin_width)
events, bins, bars = ax.hist(nexus_t, binin,
                             weights = nexus_s2,
                             density=False,
                             histtype='step',
                             label = f'nexus'
                            )


# Add the initial legend
legend = ax.legend()
# Modify the legend labels
new_labels = ['Offline simulation', legend.get_texts()[1].get_text()]
ax.legend(handles=legend.legendHandles, labels=new_labels);

# ax.legend();

# %% [markdown]
# # $\beta$ $\beta$ energy resolution

# %%
# S2 signal script
import sys
sys.path.append('/home/investigator/mariandbt/python/notebooks/modules')

from import_modules import *

import s2_simulation as s2sim
from s2_simulation import unit

# %%
path = '/home/investigator/mariandbt/python/data'
path = path + '/20240313_s2simulation'

# %%
sns_path = os.path.join(path, "ie/20240405_Next100_ie_s2_1.next.h5")
s2_table_path = os.path.join(path, "s2tab/20240405_s2_table.h5")
event_path = os.path.join(path, "bb/20240228_Next100_10ev_ELon_bb_1.next.h5") # 10 full bb w s2
event_path2 = os.path.join(path, "bb/20240306_Next100_200ev_ELoff_bb_1.next.h5") # 200 evs w/o s2

# %%
# Create TPC
TPC     = s2sim.HPGXeTPC()
TPC.SetDefaults(sns_path)
# Out:
# /home/investigator/miniconda3/envs/IC-3.8-2022-04-13/lib/python3.8/site-packages/pandas/io/pytables.py:3523: IncompatibilityWarning:
# where criteria is being ignored as this version [0.0.0] is too old (or
# not-defined), read the file in and write it out to a new file to upgrade (with
# the copy_to method)
#
#   warnings.warn(ws, IncompatibilityWarning)
# Default parameters set succesfully :) TPC ready to use

# %%
s2table = s2sim.s2Table(s2_table_path)

# %%
list_of_bb = [event_path, event_path2]
list_of_bb = [event_path]
# list_of_bb = [event_path2]

# %%
# %%timeit # (37.1s /event)
EnergyResolution = s2sim.EnergyResolution(s2table, 
                                          TPC, 
                                          List_bb_Paths = list_of_bb,
                                          fiducial_radio = 490 *unit.mm,
                                          shaped = False
                                         )
# Out:
# Energy resolution (Processing event 1/10 in file 1/2...)
# Energy resolution (Processing event 2/10 in file 1/2...)
# Energy resolution (Processing event 3/10 in file 1/2...)
# Energy resolution (Processing event 4/10 in file 1/2...)
# Energy resolution (Processing event 5/10 in file 1/2...)
# Energy resolution (Processing event 6/10 in file 1/2...)
# Energy resolution (Processing event 7/10 in file 1/2...)
# Energy resolution (Processing event 8/10 in file 1/2...)
# Energy resolution (Processing event 9/10 in file 1/2...)
# Energy resolution (Processing event 10/10 in file 1/2...)
# Energy resolution (Processing event 1/200 in file 2/2...)
# Energy resolution (Processing event 2/200 in file 2/2...)
# Energy resolution (Processing event 3/200 in file 2/2...)
# Energy resolution (Processing event 4/200 in file 2/2...)
# Energy resolution (Processing event 5/200 in file 2/2...)
# Energy resolution (Processing event 6/200 in file 2/2...)
# Energy resolution (Processing event 7/200 in file 2/2...)
# Energy resolution (Processing event 8/200 in file 2/2...)
# Energy resolution (Processing event 9/200 in file 2/2...)
# Energy resolution (Processing event 10/200 in file 2/2...)
# Energy resolution (Processing event 11/200 in file 2/2...)
# Energy resolution (Processing event 12/200 in file 2/2...)
# Energy resolution (Processing event 13/200 in file 2/2...)
# Energy resolution (Processing event 14/200 in file 2/2...)
# Energy resolution (Processing event 15/200 in file 2/2...)
# Energy resolution (Processing event 16/200 in file 2/2...)
# Energy resolution (Processing event 17/200 in file 2/2...)
# Energy resolution (Processing event 18/200 in file 2/2...)
# Energy resolution (Processing event 19/200 in file 2/2...)
# Energy resolution (Processing event 20/200 in file 2/2...)
# Energy resolution (Processing event 21/200 in file 2/2...)
# Energy resolution (Processing event 22/200 in file 2/2...)
# Energy resolution (Processing event 23/200 in file 2/2...)
# Energy resolution (Processing event 24/200 in file 2/2...)
# Energy resolution (Processing event 25/200 in file 2/2...)
# Energy resolution (Processing event 26/200 in file 2/2...)
# Energy resolution (Processing event 27/200 in file 2/2...)
# Energy resolution (Processing event 28/200 in file 2/2...)
# Energy resolution (Processing event 29/200 in file 2/2...)
# Energy resolution (Processing event 30/200 in file 2/2...)
# Energy resolution (Processing event 31/200 in file 2/2...)
# Energy resolution (Processing event 32/200 in file 2/2...)
# Energy resolution (Processing event 33/200 in file 2/2...)
# Energy resolution (Processing event 34/200 in file 2/2...)
# Energy resolution (Processing event 35/200 in file 2/2...)
# Energy resolution (Processing event 36/200 in file 2/2...)
# Energy resolution (Processing event 37/200 in file 2/2...)
# Energy resolution (Processing event 38/200 in file 2/2...)
# Energy resolution (Processing event 39/200 in file 2/2...)
# Energy resolution (Processing event 40/200 in file 2/2...)
# Energy resolution (Processing event 41/200 in file 2/2...)
# Energy resolution (Processing event 42/200 in file 2/2...)
# Energy resolution (Processing event 43/200 in file 2/2...)
# Energy resolution (Processing event 44/200 in file 2/2...)
# Energy resolution (Processing event 45/200 in file 2/2...)
# Energy resolution (Processing event 46/200 in file 2/2...)
# Energy resolution (Processing event 47/200 in file 2/2...)
# Energy resolution (Processing event 48/200 in file 2/2...)
# Energy resolution (Processing event 49/200 in file 2/2...)
# Energy resolution (Processing event 50/200 in file 2/2...)
# Energy resolution (Processing event 51/200 in file 2/2...)
# Energy resolution (Processing event 52/200 in file 2/2...)
# Energy resolution (Processing event 53/200 in file 2/2...)
# Energy resolution (Processing event 54/200 in file 2/2...)
# Energy resolution (Processing event 55/200 in file 2/2...)
# Energy resolution (Processing event 56/200 in file 2/2...)
# Energy resolution (Processing event 57/200 in file 2/2...)
# Energy resolution (Processing event 58/200 in file 2/2...)
# This event is empty... Try another, this one won't take you far :(
# Energy resolution (Processing event 59/200 in file 2/2...)
# Energy resolution (Processing event 60/200 in file 2/2...)
# Energy resolution (Processing event 61/200 in file 2/2...)
# Energy resolution (Processing event 62/200 in file 2/2...)
# Energy resolution (Processing event 63/200 in file 2/2...)
# Energy resolution (Processing event 64/200 in file 2/2...)
# Energy resolution (Processing event 65/200 in file 2/2...)
# Energy resolution (Processing event 66/200 in file 2/2...)
# Energy resolution (Processing event 67/200 in file 2/2...)
# Energy resolution (Processing event 68/200 in file 2/2...)
# Energy resolution (Processing event 69/200 in file 2/2...)
# Energy resolution (Processing event 70/200 in file 2/2...)
# Energy resolution (Processing event 71/200 in file 2/2...)
# Energy resolution (Processing event 72/200 in file 2/2...)
# Energy resolution (Processing event 73/200 in file 2/2...)
# Energy resolution (Processing event 74/200 in file 2/2...)
# Energy resolution (Processing event 75/200 in file 2/2...)
# Energy resolution (Processing event 76/200 in file 2/2...)
# Energy resolution (Processing event 77/200 in file 2/2...)
# Energy resolution (Processing event 78/200 in file 2/2...)
# Energy resolution (Processing event 79/200 in file 2/2...)
# Energy resolution (Processing event 80/200 in file 2/2...)
# Energy resolution (Processing event 81/200 in file 2/2...)
# Energy resolution (Processing event 82/200 in file 2/2...)
# Energy resolution (Processing event 83/200 in file 2/2...)
# Energy resolution (Processing event 84/200 in file 2/2...)
# Energy resolution (Processing event 85/200 in file 2/2...)
# Energy resolution (Processing event 86/200 in file 2/2...)
# Energy resolution (Processing event 87/200 in file 2/2...)
# Energy resolution (Processing event 88/200 in file 2/2...)
# Energy resolution (Processing event 89/200 in file 2/2...)
# Energy resolution (Processing event 90/200 in file 2/2...)
# Energy resolution (Processing event 91/200 in file 2/2...)
# Energy resolution (Processing event 92/200 in file 2/2...)
# Energy resolution (Processing event 93/200 in file 2/2...)
# Energy resolution (Processing event 94/200 in file 2/2...)
# Energy resolution (Processing event 95/200 in file 2/2...)
# Energy resolution (Processing event 96/200 in file 2/2...)
# This event is empty... Try another, this one won't take you far :(
# Energy resolution (Processing event 97/200 in file 2/2...)
# Energy resolution (Processing event 98/200 in file 2/2...)
# Energy resolution (Processing event 99/200 in file 2/2...)
# Energy resolution (Processing event 100/200 in file 2/2...)
# Energy resolution (Processing event 101/200 in file 2/2...)
# Energy resolution (Processing event 102/200 in file 2/2...)
# Energy resolution (Processing event 103/200 in file 2/2...)
# Energy resolution (Processing event 104/200 in file 2/2...)
# Energy resolution (Processing event 105/200 in file 2/2...)
# Energy resolution (Processing event 106/200 in file 2/2...)
# Energy resolution (Processing event 107/200 in file 2/2...)
# Energy resolution (Processing event 108/200 in file 2/2...)
# Energy resolution (Processing event 109/200 in file 2/2...)
# Energy resolution (Processing event 110/200 in file 2/2...)
# Energy resolution (Processing event 111/200 in file 2/2...)
# Energy resolution (Processing event 112/200 in file 2/2...)
# This event is empty... Try another, this one won't take you far :(
# Energy resolution (Processing event 113/200 in file 2/2...)
# Energy resolution (Processing event 114/200 in file 2/2...)
# Energy resolution (Processing event 115/200 in file 2/2...)
# Energy resolution (Processing event 116/200 in file 2/2...)
# Energy resolution (Processing event 117/200 in file 2/2...)
# Energy resolution (Processing event 118/200 in file 2/2...)
# Energy resolution (Processing event 119/200 in file 2/2...)
# Energy resolution (Processing event 120/200 in file 2/2...)
# Energy resolution (Processing event 121/200 in file 2/2...)
# Energy resolution (Processing event 122/200 in file 2/2...)
# Energy resolution (Processing event 123/200 in file 2/2...)
# Energy resolution (Processing event 124/200 in file 2/2...)
# Energy resolution (Processing event 125/200 in file 2/2...)
# Energy resolution (Processing event 126/200 in file 2/2...)
# Energy resolution (Processing event 127/200 in file 2/2...)
# Energy resolution (Processing event 128/200 in file 2/2...)
# Energy resolution (Processing event 129/200 in file 2/2...)
# Energy resolution (Processing event 130/200 in file 2/2...)
# Energy resolution (Processing event 131/200 in file 2/2...)
# Energy resolution (Processing event 132/200 in file 2/2...)
# Energy resolution (Processing event 133/200 in file 2/2...)
# Energy resolution (Processing event 134/200 in file 2/2...)
# Energy resolution (Processing event 135/200 in file 2/2...)
# Energy resolution (Processing event 136/200 in file 2/2...)
# Energy resolution (Processing event 137/200 in file 2/2...)
# Energy resolution (Processing event 138/200 in file 2/2...)
# Energy resolution (Processing event 139/200 in file 2/2...)
# Energy resolution (Processing event 140/200 in file 2/2...)
# Energy resolution (Processing event 141/200 in file 2/2...)
# Energy resolution (Processing event 142/200 in file 2/2...)
# Energy resolution (Processing event 143/200 in file 2/2...)
# Energy resolution (Processing event 144/200 in file 2/2...)
# Energy resolution (Processing event 145/200 in file 2/2...)
# Energy resolution (Processing event 146/200 in file 2/2...)
# Energy resolution (Processing event 147/200 in file 2/2...)
# Energy resolution (Processing event 148/200 in file 2/2...)
# Energy resolution (Processing event 149/200 in file 2/2...)
# Energy resolution (Processing event 150/200 in file 2/2...)
# Energy resolution (Processing event 151/200 in file 2/2...)
# Energy resolution (Processing event 152/200 in file 2/2...)
# Energy resolution (Processing event 153/200 in file 2/2...)
# Energy resolution (Processing event 154/200 in file 2/2...)
# Energy resolution (Processing event 155/200 in file 2/2...)
# Energy resolution (Processing event 156/200 in file 2/2...)
# This event is empty... Try another, this one won't take you far :(
# Energy resolution (Processing event 157/200 in file 2/2...)
# Energy resolution (Processing event 158/200 in file 2/2...)
# Energy resolution (Processing event 159/200 in file 2/2...)
# Energy resolution (Processing event 160/200 in file 2/2...)
# Energy resolution (Processing event 161/200 in file 2/2...)
# Energy resolution (Processing event 162/200 in file 2/2...)
# Energy resolution (Processing event 163/200 in file 2/2...)
# Energy resolution (Processing event 164/200 in file 2/2...)
# Energy resolution (Processing event 165/200 in file 2/2...)
# Energy resolution (Processing event 166/200 in file 2/2...)
# Energy resolution (Processing event 167/200 in file 2/2...)
# Energy resolution (Processing event 168/200 in file 2/2...)
# Energy resolution (Processing event 169/200 in file 2/2...)
# Energy resolution (Processing event 170/200 in file 2/2...)
# Energy resolution (Processing event 171/200 in file 2/2...)
# Energy resolution (Processing event 172/200 in file 2/2...)
# Energy resolution (Processing event 173/200 in file 2/2...)
# Energy resolution (Processing event 174/200 in file 2/2...)
# Energy resolution (Processing event 175/200 in file 2/2...)
# Energy resolution (Processing event 176/200 in file 2/2...)
# Energy resolution (Processing event 177/200 in file 2/2...)
# Energy resolution (Processing event 178/200 in file 2/2...)
# Energy resolution (Processing event 179/200 in file 2/2...)
# Energy resolution (Processing event 180/200 in file 2/2...)
# Energy resolution (Processing event 181/200 in file 2/2...)
# Energy resolution (Processing event 182/200 in file 2/2...)
# Energy resolution (Processing event 183/200 in file 2/2...)
# Energy resolution (Processing event 184/200 in file 2/2...)
# Energy resolution (Processing event 185/200 in file 2/2...)
# Energy resolution (Processing event 186/200 in file 2/2...)
# Energy resolution (Processing event 187/200 in file 2/2...)
# Energy resolution (Processing event 188/200 in file 2/2...)
# Energy resolution (Processing event 189/200 in file 2/2...)
# Energy resolution (Processing event 190/200 in file 2/2...)
# Energy resolution (Processing event 191/200 in file 2/2...)
# Energy resolution (Processing event 192/200 in file 2/2...)
# Energy resolution (Processing event 193/200 in file 2/2...)
# Energy resolution (Processing event 194/200 in file 2/2...)
# Energy resolution (Processing event 195/200 in file 2/2...)
# Energy resolution (Processing event 196/200 in file 2/2...)
# Energy resolution (Processing event 197/200 in file 2/2...)
# Energy resolution (Processing event 198/200 in file 2/2...)
# Energy resolution (Processing event 199/200 in file 2/2...)
# Energy resolution (Processing event 200/200 in file 2/2...)
# Creating signal (Processing sensor 108/108)... Signal created succesfully :)

# %%
events, bins, ax = EnergyResolution.PrintSpectrum(bin_width = 50, logscale = False)

ax.set_xlabel(f'Event energy [pes]', fontsize = 20);

# %% [markdown]
# # $\beta$ $\beta$ s2 storage

# %%
# S2 signal script
import sys
sys.path.append('/home/investigator/mariandbt/python/notebooks/modules')

from import_modules import *
import set_up as setup

import s2_simulation as s2sim
from s2_simulation import unit

# %%
path = '/home/investigator/mariandbt/python/data'
path = path + '/20240313_s2simulation'

# %%
sns_path = os.path.join(path, "ie/20240405_Next100_ie_s2_1.next.h5")
s2_table_path = os.path.join(path, "s2tab/20240405_s2_table.h5")
event_path = os.path.join(path, "bb/20240228_Next100_10ev_ELon_bb_1.next.h5") # 10 full bb w s2
event_path2 = os.path.join(path, "bb/20240306_Next100_200ev_ELoff_bb_1.next.h5") # 200 evs w/o s2

# %%
# Create TPC
TPC     = s2sim.HPGXeTPC()
TPC.SetDefaults(sns_path)
# Out:
# /home/investigator/miniconda3/envs/IC-3.8-2022-04-13/lib/python3.8/site-packages/pandas/io/pytables.py:3523: IncompatibilityWarning:
# where criteria is being ignored as this version [0.0.0] is too old (or
# not-defined), read the file in and write it out to a new file to upgrade (with
# the copy_to method)
#
#   warnings.warn(ws, IncompatibilityWarning)
# Default parameters set succesfully :) TPC ready to use

# %%
s2table = s2sim.s2Table(s2_table_path)

# %%
# List_bb_Paths = [event_path, event_path2]
List_bb_Paths = [event_path]
# List_bb_Paths = [event_path2]

# %%
Events_Dict             = {}
Events_Dict['bb0nu']    = List_bb_Paths
# Events_Dict['Kr']     = [event_path]

# %%
# output_file_path = os.path.join(path, 's2signals/20240620_TEST2_bb0nu_10ev_ELoff_s2_signal_20240405s2table.h5')
output_file_path = os.path.join(path, 's2signals/TEST1.h5')

# %%
s2sim.CreateSignalHDF5(output_file_path, 
                       s2table, 
                       TPC, 
                       Events_Dict,
                       fiducial_radio     = 490 *unit.mm,
                       shapin_tau         = 155 *unit.ns,
                       samplin_rate       = 25*unit.ns,
                       t_binin            = 1*unit.ns,
                       units              = 'pes/ns',
                       impedance_in_ohm   = 50 # only used if units = mV
                       )

# %%
setup.check_h5(output_file_path)
# Out:
# /home/investigator/mariandbt/python/data/20240313_s2simulation/s2signals/TEST0.h5 (File) ''
# Last modif.: '2024-06-25T14:16:36+00:00'
# Object Tree:
# / (RootGroup) ''
# /s2simulation (Group) ''
# /s2simulation/configuration (Group) ''
# /s2simulation/configuration/table (Table(9,)) ''
# /s2simulation/events (Group) ''
# /s2simulation/events/table (Table(1,)) ''
# /s2simulation/s2 (Group) ''
# /s2simulation/s2/table (Table(1999,)) ''

# %%
gg = pd.read_hdf(output_file_path, "/s2simulation/s2")

# %%
gg
# Out:
#            ParameterName  ParameterValue ParameterUnits
# 0                NEvents             1.0  dimensionless
# 1               NSensors           108.0  dimensionless
# 2           S2LightYield          1050.0    photons/ie⁻
# 3      S2TableStatistics         50000.0            ie⁻
# 4          FiducialRadio           490.0     millimeter
# 5    Time (see s2 table)             NaN     nanosecond
# 6  Signal (see s2 table)             NaN         pes/ns
# 7           SamplingRate            25.0     nanosecond
# 8   ShapingDecayConstant           155.0     nanosecond

# %%
gg
# Out:
#    event_id   N_ie event_type
# 0         0  84352         Kr

# %%
gg
# Out:
#       event_id          time  sensor298_s2  sensor204_s2  sensor219_s2  \
# 0            0  503766.53125      0.000000      0.000000      0.000000
# 1            0  503791.53125      0.000000      0.000000      0.000000
# 2            0  503816.53125      0.000000      0.000000      0.000000
# 3            0  503841.56250      0.000000      0.000000      0.000000
# 4            0  503866.56250      0.000000      0.000000      0.000000
# ...        ...           ...           ...           ...           ...
# 1809         9  630097.00000      0.000003      0.001509      0.000004
# 1810         9  630122.00000      0.000003      0.001290      0.000004
# 1811         9  630147.06250      0.000002      0.001103      0.000003
# 1812         9  630172.06250      0.000002      0.000942      0.000003
# 1813         9  630197.06250      0.000002      0.000804      0.000002
#
#       sensor243_s2  sensor304_s2  sensor296_s2  sensor210_s2  sensor303_s2  \
# 0         0.000000      0.000000      0.000000  0.000000e+00      0.000000
# 1         0.000000      0.000000      0.004832  0.000000e+00      0.000000
# 2         0.000000      0.000000      0.007689  0.000000e+00      0.000000
# 3         0.000000      0.000000      0.009135  0.000000e+00      0.000000
# 4         0.000000      0.000000      0.009651  0.000000e+00      0.000000
# ...            ...           ...           ...           ...           ...
# 1809      0.000439      0.000461      0.000004  4.754009e-07      0.000021
# 1810      0.000376      0.000394      0.000004  4.045892e-07      0.000018
# 1811      0.000321      0.000337      0.000003  3.443247e-07      0.000016
# 1812      0.000274      0.000288      0.000003  2.930367e-07      0.000013
# 1813      0.000234      0.000246      0.000002  2.493880e-07      0.000011
#
#       ...  sensor262_s2  sensor217_s2  sensor284_s2  sensor225_s2  \
# 0     ...      0.000000  0.000000e+00  0.000000e+00  0.000000e+00
# 1     ...      0.000000  0.000000e+00  1.610695e-03  0.000000e+00
# 2     ...      0.000000  0.000000e+00  2.563145e-03  0.000000e+00
# 3     ...      0.000000  0.000000e+00  3.044959e-03  0.000000e+00
# 4     ...      0.000000  0.000000e+00  3.216889e-03  0.000000e+00
# ...   ...           ...           ...           ...           ...
# 1809  ...      0.000022  4.689400e-09  1.958272e-09  4.153739e-07
# 1810  ...      0.000019  3.990890e-09  1.666577e-09  3.535035e-07
# 1811  ...      0.000016  3.396427e-09  1.418332e-09  3.008485e-07
# 1812  ...      0.000014  2.890512e-09  1.207065e-09  2.560365e-07
# 1813  ...      0.000012  2.459956e-09  1.027266e-09  2.178992e-07
#
#       sensor275_s2  sensor212_s2  sensor253_s2  sensor282_s2  sensor294_s2  \
# 0     0.000000e+00  0.000000e+00      0.000000  0.000000e+00      0.000000
# 1     0.000000e+00  1.610695e-03      0.001611  0.000000e+00      0.000000
# 2     0.000000e+00  2.563145e-03      0.002563  0.000000e+00      0.000000
# 3     0.000000e+00  3.044959e-03      0.003045  0.000000e+00      0.000000
# 4     0.000000e+00  3.216889e-03      0.003217  0.000000e+00      0.000000
# ...            ...           ...           ...           ...           ...
# 1809  1.448240e-07  1.440185e-07      0.000017  9.732526e-09      0.000018
# 1810  1.232520e-07  1.225664e-07      0.000015  8.282818e-09      0.000015
# 1811  1.048931e-07  1.043097e-07      0.000013  7.049051e-09      0.000013
# 1812  8.926884e-08  8.877231e-08      0.000011  5.999059e-09      0.000011
# 1813  7.597188e-08  7.554930e-08      0.000009  5.105470e-09      0.000009
#
#       sensor285_s2
# 0     0.000000e+00
# 1     0.000000e+00
# 2     0.000000e+00
# 3     0.000000e+00
# 4     0.000000e+00
# ...            ...
# 1809  5.533793e-07
# 1810  4.709524e-07
# 1811  4.008030e-07
# 1812  3.411023e-07
# 1813  2.902941e-07
#
# [31133 rows x 110 columns]

# %%
event = 6
vv = gg.loc[gg.event_id == event].copy()
plt.plot(vv.time, vv.sensor220_s2)

# %%
zz = np.array(gg.loc[gg.event_id == event].filter(like='sensor')).sum(axis = 1)

# %%
plt.plot(vv.time, zz)
