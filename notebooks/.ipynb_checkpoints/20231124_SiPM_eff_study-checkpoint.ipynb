# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas             as pd

import scipy
from scipy import stats, integrate
import os

import tables             as tb

# %%
import time
t0 = time.perf_counter()

# %% [markdown]
# # Global parameters

# %%
signal = np.zeros(2)

"""
ch = 1: Trigger
ch = 2: SiPM signal

fib = 0: NO
fib = 1: YES
"""
detect = ['index', 'trigger', 'SiPM'] 

ch = 2

fibers = [' without fibers', ' with fibers']
n_fibers = 36

# baseline_corrected = True
baseline_corrected = False

# integr_method = 'integrate around the peak'
# integr_method = 'integrate in a fixed window t1-t2'  
integr_method = 'integrate ALL waveform'

# %%
detect
# Out:
# ['index', 'trigger', 'SiPM']

# %% [markdown]
# # Data

# %%
filename = ['', '']

path = '/home/investigator/mariandbt/python/data'
path = path + '/20231124_eff_study'

filename[0] = os.path.join(path, 'fiber_eff_no_epoxy_LED.h5') # W/O fibers
filename[1] = os.path.join(path, 'fibers_eff_no_epoxy_fibers_readout_grease.h5') # WITH fibers

# %%
with tb.open_file(filename[0]) as file:
    print(file)
# Out:
# /home/investigator/mariandbt/python/data/20231124_eff_study/fiber_eff_no_epoxy_LED.h5 (File) ''
# Last modif.: '2023-11-23T14:58:31+00:00'
# Object Tree:
# / (RootGroup) ''
# /events (Group) 'Events'
# /events/event_1 (Group) 'Event 1'
# /events/event_1/time (Array(2500,)) ''
# /events/event_1/voltage_ch1 (Array(2500,)) ''
# /events/event_1/voltage_ch2 (Array(2500,)) ''
# /events/event_10 (Group) 'Event 10'
# /events/event_10/time (Array(2500,)) ''
# /events/event_10/voltage_ch1 (Array(2500,)) ''
# /events/event_10/voltage_ch2 (Array(2500,)) ''
# /events/event_100 (Group) 'Event 100'
# /events/event_100/time (Array(2500,)) ''
# /events/event_100/voltage_ch1 (Array(2500,)) ''
# /events/event_100/voltage_ch2 (Array(2500,)) ''
# /events/event_1000 (Group) 'Event 1000'
# /events/event_1000/time (Array(2500,)) ''
# /events/event_1000/voltage_ch1 (Array(2500,)) ''
# /events/event_1000/voltage_ch2 (Array(2500,)) ''
# /events/event_1001 (Group) 'Event 1001'
# /events/event_1001/time (Array(2500,)) ''
# /events/event_1001/voltage_ch1 (Array(2500,)) ''
# /events/event_1001/voltage_ch2 (Array(2500,)) ''
# /events/event_1002 (Group) 'Event 1002'
# /events/event_1002/time (Array(2500,)) ''
# /events/event_1002/voltage_ch1 (Array(2500,)) ''
# /events/event_1002/voltage_ch2 (Array(2500,)) ''
# /events/event_1003 (Group) 'Event 1003'
# /events/event_1003/time (Array(2500,)) ''
# /events/event_1003/voltage_ch1 (Array(2500,)) ''
# /events/event_1003/voltage_ch2 (Array(2500,)) ''
# /events/event_1004 (Group) 'Event 1004'
# /events/event_1004/time (Array(2500,)) ''
# /events/event_1004/voltage_ch1 (Array(2500,)) ''
# /events/event_1004/voltage_ch2 (Array(2500,)) ''
# /events/event_1005 (Group) 'Event 1005'
# /events/event_1005/time (Array(2500,)) ''
# /events/event_1005/voltage_ch1 (Array(2500,)) ''
# /events/event_1005/voltage_ch2 (Array(2500,)) ''
# /events/event_1006 (Group) 'Event 1006'
# /events/event_1006/time (Array(2500,)) ''
# /events/event_1006/voltage_ch1 (Array(2500,)) ''
# /events/event_1006/voltage_ch2 (Array(2500,)) ''
# /events/event_1007 (Group) 'Event 1007'
# /events/event_1007/time (Array(2500,)) ''
# /events/event_1007/voltage_ch1 (Array(2500,)) ''
# /events/event_1007/voltage_ch2 (Array(2500,)) ''
# /events/event_1008 (Group) 'Event 1008'
# /events/event_1008/time (Array(2500,)) ''
# /events/event_1008/voltage_ch1 (Array(2500,)) ''
# /events/event_1008/voltage_ch2 (Array(2500,)) ''
# /events/event_1009 (Group) 'Event 1009'
# /events/event_1009/time (Array(2500,)) ''
# /events/event_1009/voltage_ch1 (Array(2500,)) ''
# /events/event_1009/voltage_ch2 (Array(2500,)) ''
# /events/event_101 (Group) 'Event 101'
# /events/event_101/time (Array(2500,)) ''
# /events/event_101/voltage_ch1 (Array(2500,)) ''
# /events/event_101/voltage_ch2 (Array(2500,)) ''
# /events/event_1010 (Group) 'Event 1010'
# /events/event_1010/time (Array(2500,)) ''
# /events/event_1010/voltage_ch1 (Array(2500,)) ''
# /events/event_1010/voltage_ch2 (Array(2500,)) ''
# /events/event_1011 (Group) 'Event 1011'
# /events/event_1011/time (Array(2500,)) ''
# /events/event_1011/voltage_ch1 (Array(2500,)) ''
# /events/event_1011/voltage_ch2 (Array(2500,)) ''
# /events/event_1012 (Group) 'Event 1012'
# /events/event_1012/time (Array(2500,)) ''
# /events/event_1012/voltage_ch1 (Array(2500,)) ''
# /events/event_1012/voltage_ch2 (Array(2500,)) ''
# /events/event_1013 (Group) 'Event 1013'
# /events/event_1013/time (Array(2500,)) ''
# /events/event_1013/voltage_ch1 (Array(2500,)) ''
# /events/event_1013/voltage_ch2 (Array(2500,)) ''
# /events/event_1014 (Group) 'Event 1014'
# /events/event_1014/time (Array(2500,)) ''
# /events/event_1014/voltage_ch1 (Array(2500,)) ''
# /events/event_1014/voltage_ch2 (Array(2500,)) ''
# /events/event_1015 (Group) 'Event 1015'
# /events/event_1015/time (Array(2500,)) ''
# /events/event_1015/voltage_ch1 (Array(2500,)) ''
# /events/event_1015/voltage_ch2 (Array(2500,)) ''
# /events/event_1016 (Group) 'Event 1016'
# /events/event_1016/time (Array(2500,)) ''
# /events/event_1016/voltage_ch1 (Array(2500,)) ''
# /events/event_1016/voltage_ch2 (Array(2500,)) ''
# /events/event_1017 (Group) 'Event 1017'
# /events/event_1017/time (Array(2500,)) ''
# /events/event_1017/voltage_ch1 (Array(2500,)) ''
# /events/event_1017/voltage_ch2 (Array(2500,)) ''
# /events/event_1018 (Group) 'Event 1018'
# /events/event_1018/time (Array(2500,)) ''
# /events/event_1018/voltage_ch1 (Array(2500,)) ''
# /events/event_1018/voltage_ch2 (Array(2500,)) ''
# /events/event_1019 (Group) 'Event 1019'
# /events/event_1019/time (Array(2500,)) ''
# /events/event_1019/voltage_ch1 (Array(2500,)) ''
# /events/event_1019/voltage_ch2 (Array(2500,)) ''
# /events/event_102 (Group) 'Event 102'
# /events/event_102/time (Array(2500,)) ''
# /events/event_102/voltage_ch1 (Array(2500,)) ''
# /events/event_102/voltage_ch2 (Array(2500,)) ''
# /events/event_1020 (Group) 'Event 1020'
# /events/event_1020/time (Array(2500,)) ''
# /events/event_1020/voltage_ch1 (Array(2500,)) ''
# /events/event_1020/voltage_ch2 (Array(2500,)) ''
# /events/event_1021 (Group) 'Event 1021'
# /events/event_1021/time (Array(2500,)) ''
# /events/event_1021/voltage_ch1 (Array(2500,)) ''
# /events/event_1021/voltage_ch2 (Array(2500,)) ''
# /events/event_1022 (Group) 'Event 1022'
# /events/event_1022/time (Array(2500,)) ''
# /events/event_1022/voltage_ch1 (Array(2500,)) ''
# /events/event_1022/voltage_ch2 (Array(2500,)) ''
# /events/event_1023 (Group) 'Event 1023'
# /events/event_1023/time (Array(2500,)) ''
# /events/event_1023/voltage_ch1 (Array(2500,)) ''
# /events/event_1023/voltage_ch2 (Array(2500,)) ''
# /events/event_1024 (Group) 'Event 1024'
# /events/event_1024/time (Array(2500,)) ''
# /events/event_1024/voltage_ch1 (Array(2500,)) ''
# /events/event_1024/voltage_ch2 (Array(2500,)) ''
# /events/event_1025 (Group) 'Event 1025'
# /events/event_1025/time (Array(2500,)) ''
# /events/event_1025/voltage_ch1 (Array(2500,)) ''
# /events/event_1025/voltage_ch2 (Array(2500,)) ''
# /events/event_1026 (Group) 'Event 1026'
# /events/event_1026/time (Array(2500,)) ''
# /events/event_1026/voltage_ch1 (Array(2500,)) ''
# /events/event_1026/voltage_ch2 (Array(2500,)) ''
# /events/event_1027 (Group) 'Event 1027'
# /events/event_1027/time (Array(2500,)) ''
# /events/event_1027/voltage_ch1 (Array(2500,)) ''
# /events/event_1027/voltage_ch2 (Array(2500,)) ''
# /events/event_1028 (Group) 'Event 1028'
# /events/event_1028/time (Array(2500,)) ''
# /events/event_1028/voltage_ch1 (Array(2500,)) ''
# /events/event_1028/voltage_ch2 (Array(2500,)) ''
# /events/event_1029 (Group) 'Event 1029'
# /events/event_1029/time (Array(2500,)) ''
# /events/event_1029/voltage_ch1 (Array(2500,)) ''
# /events/event_1029/voltage_ch2 (Array(2500,)) ''
# /events/event_103 (Group) 'Event 103'
# /events/event_103/time (Array(2500,)) ''
# /events/event_103/voltage_ch1 (Array(2500,)) ''
# /events/event_103/voltage_ch2 (Array(2500,)) ''
# /events/event_1030 (Group) 'Event 1030'
# /events/event_1030/time (Array(2500,)) ''
# /events/event_1030/voltage_ch1 (Array(2500,)) ''
# /events/event_1030/voltage_ch2 (Array(2500,)) ''
# /events/event_1031 (Group) 'Event 1031'
# /events/event_1031/time (Array(2500,)) ''
# /events/event_1031/voltage_ch1 (Array(2500,)) ''
# /events/event_1031/voltage_ch2 (Array(2500,)) ''
# /events/event_1032 (Group) 'Event 1032'
# /events/event_1032/time (Array(2500,)) ''
# /events/event_1032/voltage_ch1 (Array(2500,)) ''
# /events/event_1032/voltage_ch2 (Array(2500,)) ''
# /events/event_1033 (Group) 'Event 1033'
# /events/event_1033/time (Array(2500,)) ''
# /events/event_1033/voltage_ch1 (Array(2500,)) ''
# /events/event_1033/voltage_ch2 (Array(2500,)) ''
# /events/event_1034 (Group) 'Event 1034'
# /events/event_1034/time (Array(2500,)) ''
# /events/event_1034/voltage_ch1 (Array(2500,)) ''
# /events/event_1034/voltage_ch2 (Array(2500,)) ''
# /events/event_1035 (Group) 'Event 1035'
# /events/event_1035/time (Array(2500,)) ''
# /events/event_1035/voltage_ch1 (Array(2500,)) ''
# /events/event_1035/voltage_ch2 (Array(2500,)) ''
# /events/event_1036 (Group) 'Event 1036'
# /events/event_1036/time (Array(2500,)) ''
# /events/event_1036/voltage_ch1 (Array(2500,)) ''
# /events/event_1036/voltage_ch2 (Array(2500,)) ''
# /events/event_1037 (Group) 'Event 1037'
# /events/event_1037/time (Array(2500,)) ''
# /events/event_1037/voltage_ch1 (Array(2500,)) ''
# /events/event_1037/voltage_ch2 (Array(2500,)) ''
# /events/event_1038 (Group) 'Event 1038'
# /events/event_1038/time (Array(2500,)) ''
# /events/event_1038/voltage_ch1 (Array(2500,)) ''
# /events/event_1038/voltage_ch2 (Array(2500,)) ''
# /events/event_1039 (Group) 'Event 1039'
# /events/event_1039/time (Array(2500,)) ''
# /events/event_1039/voltage_ch1 (Array(2500,)) ''
# /events/event_1039/voltage_ch2 (Array(2500,)) ''
# /events/event_104 (Group) 'Event 104'
# /events/event_104/time (Array(2500,)) ''
# /events/event_104/voltage_ch1 (Array(2500,)) ''
# /events/event_104/voltage_ch2 (Array(2500,)) ''
# /events/event_1040 (Group) 'Event 1040'
# /events/event_1040/time (Array(2500,)) ''
# /events/event_1040/voltage_ch1 (Array(2500,)) ''
# /events/event_1040/voltage_ch2 (Array(2500,)) ''
# /events/event_1041 (Group) 'Event 1041'
# /events/event_1041/time (Array(2500,)) ''
# /events/event_1041/voltage_ch1 (Array(2500,)) ''
# /events/event_1041/voltage_ch2 (Array(2500,)) ''
# /events/event_1042 (Group) 'Event 1042'
# /events/event_1042/time (Array(2500,)) ''
# /events/event_1042/voltage_ch1 (Array(2500,)) ''
# /events/event_1042/voltage_ch2 (Array(2500,)) ''
# /events/event_1043 (Group) 'Event 1043'
# /events/event_1043/time (Array(2500,)) ''
# /events/event_1043/voltage_ch1 (Array(2500,)) ''
# /events/event_1043/voltage_ch2 (Array(2500,)) ''
# /events/event_1044 (Group) 'Event 1044'
# /events/event_1044/time (Array(2500,)) ''
# /events/event_1044/voltage_ch1 (Array(2500,)) ''
# /events/event_1044/voltage_ch2 (Array(2500,)) ''
# /events/event_1045 (Group) 'Event 1045'
# /events/event_1045/time (Array(2500,)) ''
# /events/event_1045/voltage_ch1 (Array(2500,)) ''
# /events/event_1045/voltage_ch2 (Array(2500,)) ''
# /events/event_1046 (Group) 'Event 1046'
# /events/event_1046/time (Array(2500,)) ''
# /events/event_1046/voltage_ch1 (Array(2500,)) ''
# /events/event_1046/voltage_ch2 (Array(2500,)) ''
# /events/event_1047 (Group) 'Event 1047'
# /events/event_1047/time (Array(2500,)) ''
# /events/event_1047/voltage_ch1 (Array(2500,)) ''
# /events/event_1047/voltage_ch2 (Array(2500,)) ''
# /events/event_1048 (Group) 'Event 1048'
# /events/event_1048/time (Array(2500,)) ''
# /events/event_1048/voltage_ch1 (Array(2500,)) ''
# /events/event_1048/voltage_ch2 (Array(2500,)) ''
# /events/event_1049 (Group) 'Event 1049'
# /events/event_1049/time (Array(2500,)) ''
# /events/event_1049/voltage_ch1 (Array(2500,)) ''
# /events/event_1049/voltage_ch2 (Array(2500,)) ''
# /events/event_105 (Group) 'Event 105'
# /events/event_105/time (Array(2500,)) ''
# /events/event_105/voltage_ch1 (Array(2500,)) ''
# /events/event_105/voltage_ch2 (Array(2500,)) ''
# /events/event_1050 (Group) 'Event 1050'
# /events/event_1050/time (Array(2500,)) ''
# /events/event_1050/voltage_ch1 (Array(2500,)) ''
# /events/event_1050/voltage_ch2 (Array(2500,)) ''
# /events/event_1051 (Group) 'Event 1051'
# /events/event_1051/time (Array(2500,)) ''
# /events/event_1051/voltage_ch1 (Array(2500,)) ''
# /events/event_1051/voltage_ch2 (Array(2500,)) ''
# /events/event_1052 (Group) 'Event 1052'
# /events/event_1052/time (Array(2500,)) ''
# /events/event_1052/voltage_ch1 (Array(2500,)) ''
# /events/event_1052/voltage_ch2 (Array(2500,)) ''
# /events/event_1053 (Group) 'Event 1053'
# /events/event_1053/time (Array(2500,)) ''
# /events/event_1053/voltage_ch1 (Array(2500,)) ''
# /events/event_1053/voltage_ch2 (Array(2500,)) ''
# /events/event_1054 (Group) 'Event 1054'
# /events/event_1054/time (Array(2500,)) ''
# /events/event_1054/voltage_ch1 (Array(2500,)) ''
# /events/event_1054/voltage_ch2 (Array(2500,)) ''
# /events/event_1055 (Group) 'Event 1055'
# /events/event_1055/time (Array(2500,)) ''
# /events/event_1055/voltage_ch1 (Array(2500,)) ''
# /events/event_1055/voltage_ch2 (Array(2500,)) ''
# /events/event_1056 (Group) 'Event 1056'
# /events/event_1056/time (Array(2500,)) ''
# /events/event_1056/voltage_ch1 (Array(2500,)) ''
# /events/event_1056/voltage_ch2 (Array(2500,)) ''
# /events/event_1057 (Group) 'Event 1057'
# /events/event_1057/time (Array(2500,)) ''
# /events/event_1057/voltage_ch1 (Array(2500,)) ''
# /events/event_1057/voltage_ch2 (Array(2500,)) ''
# /events/event_1058 (Group) 'Event 1058'
# /events/event_1058/time (Array(2500,)) ''
# /events/event_1058/voltage_ch1 (Array(2500,)) ''
# /events/event_1058/voltage_ch2 (Array(2500,)) ''
# /events/event_1059 (Group) 'Event 1059'
# /events/event_1059/time (Array(2500,)) ''
# /events/event_1059/voltage_ch1 (Array(2500,)) ''
# /events/event_1059/voltage_ch2 (Array(2500,)) ''
# /events/event_106 (Group) 'Event 106'
# /events/event_106/time (Array(2500,)) ''
# /events/event_106/voltage_ch1 (Array(2500,)) ''
# /events/event_106/voltage_ch2 (Array(2500,)) ''
# /events/event_1060 (Group) 'Event 1060'
# /events/event_1060/time (Array(2500,)) ''
# /events/event_1060/voltage_ch1 (Array(2500,)) ''
# /events/event_1060/voltage_ch2 (Array(2500,)) ''
# /events/event_1061 (Group) 'Event 1061'
# /events/event_1061/time (Array(2500,)) ''
# /events/event_1061/voltage_ch1 (Array(2500,)) ''
# /events/event_1061/voltage_ch2 (Array(2500,)) ''
# /events/event_1062 (Group) 'Event 1062'
# /events/event_1062/time (Array(2500,)) ''
# /events/event_1062/voltage_ch1 (Array(2500,)) ''
# /events/event_1062/voltage_ch2 (Array(2500,)) ''
# /events/event_1063 (Group) 'Event 1063'
# /events/event_1063/time (Array(2500,)) ''
# /events/event_1063/voltage_ch1 (Array(2500,)) ''
# /events/event_1063/voltage_ch2 (Array(2500,)) ''
# /events/event_1064 (Group) 'Event 1064'
# /events/event_1064/time (Array(2500,)) ''
# /events/event_1064/voltage_ch1 (Array(2500,)) ''
# /events/event_1064/voltage_ch2 (Array(2500,)) ''
# /events/event_1065 (Group) 'Event 1065'
# /events/event_1065/time (Array(2500,)) ''
# /events/event_1065/voltage_ch1 (Array(2500,)) ''
# /events/event_1065/voltage_ch2 (Array(2500,)) ''
# /events/event_1066 (Group) 'Event 1066'
# /events/event_1066/time (Array(2500,)) ''
# /events/event_1066/voltage_ch1 (Array(2500,)) ''
# /events/event_1066/voltage_ch2 (Array(2500,)) ''
# /events/event_1067 (Group) 'Event 1067'
# /events/event_1067/time (Array(2500,)) ''
# /events/event_1067/voltage_ch1 (Array(2500,)) ''
# /events/event_1067/voltage_ch2 (Array(2500,)) ''
# /events/event_1068 (Group) 'Event 1068'
# /events/event_1068/time (Array(2500,)) ''
# /events/event_1068/voltage_ch1 (Array(2500,)) ''
# /events/event_1068/voltage_ch2 (Array(2500,)) ''
# /events/event_1069 (Group) 'Event 1069'
# /events/event_1069/time (Array(2500,)) ''
# /events/event_1069/voltage_ch1 (Array(2500,)) ''
# /events/event_1069/voltage_ch2 (Array(2500,)) ''
# /events/event_107 (Group) 'Event 107'
# /events/event_107/time (Array(2500,)) ''
# /events/event_107/voltage_ch1 (Array(2500,)) ''
# /events/event_107/voltage_ch2 (Array(2500,)) ''
# /events/event_1070 (Group) 'Event 1070'
# /events/event_1070/time (Array(2500,)) ''
# /events/event_1070/voltage_ch1 (Array(2500,)) ''
# /events/event_1070/voltage_ch2 (Array(2500,)) ''
# /events/event_1071 (Group) 'Event 1071'
# /events/event_1071/time (Array(2500,)) ''
# /events/event_1071/voltage_ch1 (Array(2500,)) ''
# /events/event_1071/voltage_ch2 (Array(2500,)) ''
# /events/event_1072 (Group) 'Event 1072'
# /events/event_1072/time (Array(2500,)) ''
# /events/event_1072/voltage_ch1 (Array(2500,)) ''
# /events/event_1072/voltage_ch2 (Array(2500,)) ''
# /events/event_1073 (Group) 'Event 1073'
# /events/event_1073/time (Array(2500,)) ''
# /events/event_1073/voltage_ch1 (Array(2500,)) ''
# /events/event_1073/voltage_ch2 (Array(2500,)) ''
# /events/event_1074 (Group) 'Event 1074'
# /events/event_1074/time (Array(2500,)) ''
# /events/event_1074/voltage_ch1 (Array(2500,)) ''
# /events/event_1074/voltage_ch2 (Array(2500,)) ''
# /events/event_1075 (Group) 'Event 1075'
# /events/event_1075/time (Array(2500,)) ''
# /events/event_1075/voltage_ch1 (Array(2500,)) ''
# /events/event_1075/voltage_ch2 (Array(2500,)) ''
# /events/event_1076 (Group) 'Event 1076'
# /events/event_1076/time (Array(2500,)) ''
# /events/event_1076/voltage_ch1 (Array(2500,)) ''
# /events/event_1076/voltage_ch2 (Array(2500,)) ''
# /events/event_1077 (Group) 'Event 1077'
# /events/event_1077/time (Array(2500,)) ''
# /events/event_1077/voltage_ch1 (Array(2500,)) ''
# /events/event_1077/voltage_ch2 (Array(2500,)) ''
# /events/event_1078 (Group) 'Event 1078'
# /events/event_1078/time (Array(2500,)) ''
# /events/event_1078/voltage_ch1 (Array(2500,)) ''
# /events/event_1078/voltage_ch2 (Array(2500,)) ''
# /events/event_1079 (Group) 'Event 1079'
# /events/event_1079/time (Array(2500,)) ''
# /events/event_1079/voltage_ch1 (Array(2500,)) ''
# /events/event_1079/voltage_ch2 (Array(2500,)) ''
# /events/event_108 (Group) 'Event 108'
# /events/event_108/time (Array(2500,)) ''
# /events/event_108/voltage_ch1 (Array(2500,)) ''
# /events/event_108/voltage_ch2 (Array(2500,)) ''
# /events/event_1080 (Group) 'Event 1080'
# /events/event_1080/time (Array(2500,)) ''
# /events/event_1080/voltage_ch1 (Array(2500,)) ''
# /events/event_1080/voltage_ch2 (Array(2500,)) ''
# /events/event_1081 (Group) 'Event 1081'
# /events/event_1081/time (Array(2500,)) ''
# /events/event_1081/voltage_ch1 (Array(2500,)) ''
# /events/event_1081/voltage_ch2 (Array(2500,)) ''
# /events/event_1082 (Group) 'Event 1082'
# /events/event_1082/time (Array(2500,)) ''
# /events/event_1082/voltage_ch1 (Array(2500,)) ''
# /events/event_1082/voltage_ch2 (Array(2500,)) ''
# /events/event_1083 (Group) 'Event 1083'
# /events/event_1083/time (Array(2500,)) ''
# /events/event_1083/voltage_ch1 (Array(2500,)) ''
# /events/event_1083/voltage_ch2 (Array(2500,)) ''
# /events/event_1084 (Group) 'Event 1084'
# /events/event_1084/time (Array(2500,)) ''
# /events/event_1084/voltage_ch1 (Array(2500,)) ''
# /events/event_1084/voltage_ch2 (Array(2500,)) ''
# /events/event_1085 (Group) 'Event 1085'
# /events/event_1085/time (Array(2500,)) ''
# /events/event_1085/voltage_ch1 (Array(2500,)) ''
# /events/event_1085/voltage_ch2 (Array(2500,)) ''
# /events/event_1086 (Group) 'Event 1086'
# /events/event_1086/time (Array(2500,)) ''
# /events/event_1086/voltage_ch1 (Array(2500,)) ''
# /events/event_1086/voltage_ch2 (Array(2500,)) ''
# /events/event_1087 (Group) 'Event 1087'
# /events/event_1087/time (Array(2500,)) ''
# /events/event_1087/voltage_ch1 (Array(2500,)) ''
# /events/event_1087/voltage_ch2 (Array(2500,)) ''
# /events/event_1088 (Group) 'Event 1088'
# /events/event_1088/time (Array(2500,)) ''
# /events/event_1088/voltage_ch1 (Array(2500,)) ''
# /events/event_1088/voltage_ch2 (Array(2500,)) ''
# /events/event_1089 (Group) 'Event 1089'
# /events/event_1089/time (Array(2500,)) ''
# /events/event_1089/voltage_ch1 (Array(2500,)) ''
# /events/event_1089/voltage_ch2 (Array(2500,)) ''
# /events/event_109 (Group) 'Event 109'
# /events/event_109/time (Array(2500,)) ''
# /events/event_109/voltage_ch1 (Array(2500,)) ''
# /events/event_109/voltage_ch2 (Array(2500,)) ''
# /events/event_1090 (Group) 'Event 1090'
# /events/event_1090/time (Array(2500,)) ''
# /events/event_1090/voltage_ch1 (Array(2500,)) ''
# /events/event_1090/voltage_ch2 (Array(2500,)) ''
# /events/event_1091 (Group) 'Event 1091'
# /events/event_1091/time (Array(2500,)) ''
# /events/event_1091/voltage_ch1 (Array(2500,)) ''
# /events/event_1091/voltage_ch2 (Array(2500,)) ''
# /events/event_1092 (Group) 'Event 1092'
# /events/event_1092/time (Array(2500,)) ''
# /events/event_1092/voltage_ch1 (Array(2500,)) ''
# /events/event_1092/voltage_ch2 (Array(2500,)) ''
# /events/event_1093 (Group) 'Event 1093'
# /events/event_1093/time (Array(2500,)) ''
# /events/event_1093/voltage_ch1 (Array(2500,)) ''
# /events/event_1093/voltage_ch2 (Array(2500,)) ''
# /events/event_1094 (Group) 'Event 1094'
# /events/event_1094/time (Array(2500,)) ''
# /events/event_1094/voltage_ch1 (Array(2500,)) ''
# /events/event_1094/voltage_ch2 (Array(2500,)) ''
# /events/event_1095 (Group) 'Event 1095'
# /events/event_1095/time (Array(2500,)) ''
# /events/event_1095/voltage_ch1 (Array(2500,)) ''
# /events/event_1095/voltage_ch2 (Array(2500,)) ''
# /events/event_1096 (Group) 'Event 1096'
# /events/event_1096/time (Array(2500,)) ''
# /events/event_1096/voltage_ch1 (Array(2500,)) ''
# /events/event_1096/voltage_ch2 (Array(2500,)) ''
# /events/event_1097 (Group) 'Event 1097'
# /events/event_1097/time (Array(2500,)) ''
# /events/event_1097/voltage_ch1 (Array(2500,)) ''
# /events/event_1097/voltage_ch2 (Array(2500,)) ''
# /events/event_1098 (Group) 'Event 1098'
# /events/event_1098/time (Array(2500,)) ''
# /events/event_1098/voltage_ch1 (Array(2500,)) ''
# /events/event_1098/voltage_ch2 (Array(2500,)) ''
# /events/event_1099 (Group) 'Event 1099'
# /events/event_1099/time (Array(2500,)) ''
# /events/event_1099/voltage_ch1 (Array(2500,)) ''
# /events/event_1099/voltage_ch2 (Array(2500,)) ''
# /events/event_11 (Group) 'Event 11'
# /events/event_11/time (Array(2500,)) ''
# /events/event_11/voltage_ch1 (Array(2500,)) ''
# /events/event_11/voltage_ch2 (Array(2500,)) ''
# /events/event_110 (Group) 'Event 110'
# /events/event_110/time (Array(2500,)) ''
# /events/event_110/voltage_ch1 (Array(2500,)) ''
# /events/event_110/voltage_ch2 (Array(2500,)) ''
# /events/event_1100 (Group) 'Event 1100'
# /events/event_1100/time (Array(2500,)) ''
# /events/event_1100/voltage_ch1 (Array(2500,)) ''
# /events/event_1100/voltage_ch2 (Array(2500,)) ''
# /events/event_1101 (Group) 'Event 1101'
# /events/event_1101/time (Array(2500,)) ''
# /events/event_1101/voltage_ch1 (Array(2500,)) ''
# /events/event_1101/voltage_ch2 (Array(2500,)) ''
# /events/event_1102 (Group) 'Event 1102'
# /events/event_1102/time (Array(2500,)) ''
# /events/event_1102/voltage_ch1 (Array(2500,)) ''
# /events/event_1102/voltage_ch2 (Array(2500,)) ''
# /events/event_1103 (Group) 'Event 1103'
# /events/event_1103/time (Array(2500,)) ''
# /events/event_1103/voltage_ch1 (Array(2500,)) ''
# /events/event_1103/voltage_ch2 (Array(2500,)) ''
# /events/event_1104 (Group) 'Event 1104'
# /events/event_1104/time (Array(2500,)) ''
# /events/event_1104/voltage_ch1 (Array(2500,)) ''
# /events/event_1104/voltage_ch2 (Array(2500,)) ''
# /events/event_1105 (Group) 'Event 1105'
# /events/event_1105/time (Array(2500,)) ''
# /events/event_1105/voltage_ch1 (Array(2500,)) ''
# /events/event_1105/voltage_ch2 (Array(2500,)) ''
# /events/event_1106 (Group) 'Event 1106'
# /events/event_1106/time (Array(2500,)) ''
# /events/event_1106/voltage_ch1 (Array(2500,)) ''
# /events/event_1106/voltage_ch2 (Array(2500,)) ''
# /events/event_1107 (Group) 'Event 1107'
# /events/event_1107/time (Array(2500,)) ''
# /events/event_1107/voltage_ch1 (Array(2500,)) ''
# /events/event_1107/voltage_ch2 (Array(2500,)) ''
# /events/event_1108 (Group) 'Event 1108'
# /events/event_1108/time (Array(2500,)) ''
# /events/event_1108/voltage_ch1 (Array(2500,)) ''
# /events/event_1108/voltage_ch2 (Array(2500,)) ''
# /events/event_1109 (Group) 'Event 1109'
# /events/event_1109/time (Array(2500,)) ''
# /events/event_1109/voltage_ch1 (Array(2500,)) ''
# /events/event_1109/voltage_ch2 (Array(2500,)) ''
# /events/event_111 (Group) 'Event 111'
# /events/event_111/time (Array(2500,)) ''
# /events/event_111/voltage_ch1 (Array(2500,)) ''
# /events/event_111/voltage_ch2 (Array(2500,)) ''
# /events/event_1110 (Group) 'Event 1110'
# /events/event_1110/time (Array(2500,)) ''
# /events/event_1110/voltage_ch1 (Array(2500,)) ''
# /events/event_1110/voltage_ch2 (Array(2500,)) ''
# /events/event_1111 (Group) 'Event 1111'
# /events/event_1111/time (Array(2500,)) ''
# /events/event_1111/voltage_ch1 (Array(2500,)) ''
# /events/event_1111/voltage_ch2 (Array(2500,)) ''
# /events/event_1112 (Group) 'Event 1112'
# /events/event_1112/time (Array(2500,)) ''
# /events/event_1112/voltage_ch1 (Array(2500,)) ''
# /events/event_1112/voltage_ch2 (Array(2500,)) ''
# /events/event_1113 (Group) 'Event 1113'
# /events/event_1113/time (Array(2500,)) ''
# /events/event_1113/voltage_ch1 (Array(2500,)) ''
# /events/event_1113/voltage_ch2 (Array(2500,)) ''
# /events/event_1114 (Group) 'Event 1114'
# /events/event_1114/time (Array(2500,)) ''
# /events/event_1114/voltage_ch1 (Array(2500,)) ''
# /events/event_1114/voltage_ch2 (Array(2500,)) ''
# /events/event_1115 (Group) 'Event 1115'
# /events/event_1115/time (Array(2500,)) ''
# /events/event_1115/voltage_ch1 (Array(2500,)) ''
# /events/event_1115/voltage_ch2 (Array(2500,)) ''
# /events/event_1116 (Group) 'Event 1116'
# /events/event_1116/time (Array(2500,)) ''
# /events/event_1116/voltage_ch1 (Array(2500,)) ''
# /events/event_1116/voltage_ch2 (Array(2500,)) ''
# /events/event_1117 (Group) 'Event 1117'
# /events/event_1117/time (Array(2500,)) ''
# /events/event_1117/voltage_ch1 (Array(2500,)) ''
# /events/event_1117/voltage_ch2 (Array(2500,)) ''
# /events/event_1118 (Group) 'Event 1118'
# /events/event_1118/time (Array(2500,)) ''
# /events/event_1118/voltage_ch1 (Array(2500,)) ''
# /events/event_1118/voltage_ch2 (Array(2500,)) ''
# /events/event_1119 (Group) 'Event 1119'
# /events/event_1119/time (Array(2500,)) ''
# /events/event_1119/voltage_ch1 (Array(2500,)) ''
# /events/event_1119/voltage_ch2 (Array(2500,)) ''
# /events/event_112 (Group) 'Event 112'
# /events/event_112/time (Array(2500,)) ''
# /events/event_112/voltage_ch1 (Array(2500,)) ''
# /events/event_112/voltage_ch2 (Array(2500,)) ''
# /events/event_1120 (Group) 'Event 1120'
# /events/event_1120/time (Array(2500,)) ''
# /events/event_1120/voltage_ch1 (Array(2500,)) ''
# /events/event_1120/voltage_ch2 (Array(2500,)) ''
# /events/event_1121 (Group) 'Event 1121'
# /events/event_1121/time (Array(2500,)) ''
# /events/event_1121/voltage_ch1 (Array(2500,)) ''
# /events/event_1121/voltage_ch2 (Array(2500,)) ''
# /events/event_1122 (Group) 'Event 1122'
# /events/event_1122/time (Array(2500,)) ''
# /events/event_1122/voltage_ch1 (Array(2500,)) ''
# /events/event_1122/voltage_ch2 (Array(2500,)) ''
# /events/event_1123 (Group) 'Event 1123'
# /events/event_1123/time (Array(2500,)) ''
# /events/event_1123/voltage_ch1 (Array(2500,)) ''
# /events/event_1123/voltage_ch2 (Array(2500,)) ''
# /events/event_1124 (Group) 'Event 1124'
# /events/event_1124/time (Array(2500,)) ''
# /events/event_1124/voltage_ch1 (Array(2500,)) ''
# /events/event_1124/voltage_ch2 (Array(2500,)) ''
# /events/event_1125 (Group) 'Event 1125'
# /events/event_1125/time (Array(2500,)) ''
# /events/event_1125/voltage_ch1 (Array(2500,)) ''
# /events/event_1125/voltage_ch2 (Array(2500,)) ''
# /events/event_1126 (Group) 'Event 1126'
# /events/event_1126/time (Array(2500,)) ''
# /events/event_1126/voltage_ch1 (Array(2500,)) ''
# /events/event_1126/voltage_ch2 (Array(2500,)) ''
# /events/event_1127 (Group) 'Event 1127'
# /events/event_1127/time (Array(2500,)) ''
# /events/event_1127/voltage_ch1 (Array(2500,)) ''
# /events/event_1127/voltage_ch2 (Array(2500,)) ''
# /events/event_1128 (Group) 'Event 1128'
# /events/event_1128/time (Array(2500,)) ''
# /events/event_1128/voltage_ch1 (Array(2500,)) ''
# /events/event_1128/voltage_ch2 (Array(2500,)) ''
# /events/event_1129 (Group) 'Event 1129'
# /events/event_1129/time (Array(2500,)) ''
# /events/event_1129/voltage_ch1 (Array(2500,)) ''
# /events/event_1129/voltage_ch2 (Array(2500,)) ''
# /events/event_113 (Group) 'Event 113'
# /events/event_113/time (Array(2500,)) ''
# /events/event_113/voltage_ch1 (Array(2500,)) ''
# /events/event_113/voltage_ch2 (Array(2500,)) ''
# /events/event_1130 (Group) 'Event 1130'
# /events/event_1130/time (Array(2500,)) ''
# /events/event_1130/voltage_ch1 (Array(2500,)) ''
# /events/event_1130/voltage_ch2 (Array(2500,)) ''
# /events/event_1131 (Group) 'Event 1131'
# /events/event_1131/time (Array(2500,)) ''
# /events/event_1131/voltage_ch1 (Array(2500,)) ''
# /events/event_1131/voltage_ch2 (Array(2500,)) ''
# /events/event_1132 (Group) 'Event 1132'
# /events/event_1132/time (Array(2500,)) ''
# /events/event_1132/voltage_ch1 (Array(2500,)) ''
# /events/event_1132/voltage_ch2 (Array(2500,)) ''
# /events/event_1133 (Group) 'Event 1133'
# /events/event_1133/time (Array(2500,)) ''
# /events/event_1133/voltage_ch1 (Array(2500,)) ''
# /events/event_1133/voltage_ch2 (Array(2500,)) ''
# /events/event_1134 (Group) 'Event 1134'
# /events/event_1134/time (Array(2500,)) ''
# /events/event_1134/voltage_ch1 (Array(2500,)) ''
# /events/event_1134/voltage_ch2 (Array(2500,)) ''
# /events/event_1135 (Group) 'Event 1135'
# /events/event_1135/time (Array(2500,)) ''
# /events/event_1135/voltage_ch1 (Array(2500,)) ''
# /events/event_1135/voltage_ch2 (Array(2500,)) ''
# /events/event_1136 (Group) 'Event 1136'
# /events/event_1136/time (Array(2500,)) ''
# /events/event_1136/voltage_ch1 (Array(2500,)) ''
# /events/event_1136/voltage_ch2 (Array(2500,)) ''
# /events/event_1137 (Group) 'Event 1137'
# /events/event_1137/time (Array(2500,)) ''
# /events/event_1137/voltage_ch1 (Array(2500,)) ''
# /events/event_1137/voltage_ch2 (Array(2500,)) ''
# /events/event_1138 (Group) 'Event 1138'
# /events/event_1138/time (Array(2500,)) ''
# /events/event_1138/voltage_ch1 (Array(2500,)) ''
# /events/event_1138/voltage_ch2 (Array(2500,)) ''
# /events/event_1139 (Group) 'Event 1139'
# /events/event_1139/time (Array(2500,)) ''
# /events/event_1139/voltage_ch1 (Array(2500,)) ''
# /events/event_1139/voltage_ch2 (Array(2500,)) ''
# /events/event_114 (Group) 'Event 114'
# /events/event_114/time (Array(2500,)) ''
# /events/event_114/voltage_ch1 (Array(2500,)) ''
# /events/event_114/voltage_ch2 (Array(2500,)) ''
# /events/event_1140 (Group) 'Event 1140'
# /events/event_1140/time (Array(2500,)) ''
# /events/event_1140/voltage_ch1 (Array(2500,)) ''
# /events/event_1140/voltage_ch2 (Array(2500,)) ''
# /events/event_1141 (Group) 'Event 1141'
# /events/event_1141/time (Array(2500,)) ''
# /events/event_1141/voltage_ch1 (Array(2500,)) ''
# /events/event_1141/voltage_ch2 (Array(2500,)) ''
# /events/event_1142 (Group) 'Event 1142'
# /events/event_1142/time (Array(2500,)) ''
# /events/event_1142/voltage_ch1 (Array(2500,)) ''
# /events/event_1142/voltage_ch2 (Array(2500,)) ''
# /events/event_1143 (Group) 'Event 1143'
# /events/event_1143/time (Array(2500,)) ''
# /events/event_1143/voltage_ch1 (Array(2500,)) ''
# /events/event_1143/voltage_ch2 (Array(2500,)) ''
# /events/event_1144 (Group) 'Event 1144'
# /events/event_1144/time (Array(2500,)) ''
# /events/event_1144/voltage_ch1 (Array(2500,)) ''
# /events/event_1144/voltage_ch2 (Array(2500,)) ''
# /events/event_1145 (Group) 'Event 1145'
# /events/event_1145/time (Array(2500,)) ''
# /events/event_1145/voltage_ch1 (Array(2500,)) ''
# /events/event_1145/voltage_ch2 (Array(2500,)) ''
# /events/event_1146 (Group) 'Event 1146'
# /events/event_1146/time (Array(2500,)) ''
# /events/event_1146/voltage_ch1 (Array(2500,)) ''
# /events/event_1146/voltage_ch2 (Array(2500,)) ''
# /events/event_1147 (Group) 'Event 1147'
# /events/event_1147/time (Array(2500,)) ''
# /events/event_1147/voltage_ch1 (Array(2500,)) ''
# /events/event_1147/voltage_ch2 (Array(2500,)) ''
# /events/event_1148 (Group) 'Event 1148'
# /events/event_1148/time (Array(2500,)) ''
# /events/event_1148/voltage_ch1 (Array(2500,)) ''
# /events/event_1148/voltage_ch2 (Array(2500,)) ''
# /events/event_1149 (Group) 'Event 1149'
# /events/event_1149/time (Array(2500,)) ''
# /events/event_1149/voltage_ch1 (Array(2500,)) ''
# /events/event_1149/voltage_ch2 (Array(2500,)) ''
# /events/event_115 (Group) 'Event 115'
# /events/event_115/time (Array(2500,)) ''
# /events/event_115/voltage_ch1 (Array(2500,)) ''
# /events/event_115/voltage_ch2 (Array(2500,)) ''
# /events/event_1150 (Group) 'Event 1150'
# /events/event_1150/time (Array(2500,)) ''
# /events/event_1150/voltage_ch1 (Array(2500,)) ''
# /events/event_1150/voltage_ch2 (Array(2500,)) ''
# /events/event_1151 (Group) 'Event 1151'
# /events/event_1151/time (Array(2500,)) ''
# /events/event_1151/voltage_ch1 (Array(2500,)) ''
# /events/event_1151/voltage_ch2 (Array(2500,)) ''
# /events/event_1152 (Group) 'Event 1152'
# /events/event_1152/time (Array(2500,)) ''
# /events/event_1152/voltage_ch1 (Array(2500,)) ''
# /events/event_1152/voltage_ch2 (Array(2500,)) ''
# /events/event_1153 (Group) 'Event 1153'
# /events/event_1153/time (Array(2500,)) ''
# /events/event_1153/voltage_ch1 (Array(2500,)) ''
# /events/event_1153/voltage_ch2 (Array(2500,)) ''
# /events/event_1154 (Group) 'Event 1154'
# /events/event_1154/time (Array(2500,)) ''
# /events/event_1154/voltage_ch1 (Array(2500,)) ''
# /events/event_1154/voltage_ch2 (Array(2500,)) ''
# /events/event_1155 (Group) 'Event 1155'
# /events/event_1155/time (Array(2500,)) ''
# /events/event_1155/voltage_ch1 (Array(2500,)) ''
# /events/event_1155/voltage_ch2 (Array(2500,)) ''
# /events/event_1156 (Group) 'Event 1156'
# /events/event_1156/time (Array(2500,)) ''
# /events/event_1156/voltage_ch1 (Array(2500,)) ''
# /events/event_1156/voltage_ch2 (Array(2500,)) ''
# /events/event_1157 (Group) 'Event 1157'
# /events/event_1157/time (Array(2500,)) ''
# /events/event_1157/voltage_ch1 (Array(2500,)) ''
# /events/event_1157/voltage_ch2 (Array(2500,)) ''
# /events/event_1158 (Group) 'Event 1158'
# /events/event_1158/time (Array(2500,)) ''
# /events/event_1158/voltage_ch1 (Array(2500,)) ''
# /events/event_1158/voltage_ch2 (Array(2500,)) ''
# /events/event_1159 (Group) 'Event 1159'
# /events/event_1159/time (Array(2500,)) ''
# /events/event_1159/voltage_ch1 (Array(2500,)) ''
# /events/event_1159/voltage_ch2 (Array(2500,)) ''
# /events/event_116 (Group) 'Event 116'
# /events/event_116/time (Array(2500,)) ''
# /events/event_116/voltage_ch1 (Array(2500,)) ''
# /events/event_116/voltage_ch2 (Array(2500,)) ''
# /events/event_1160 (Group) 'Event 1160'
# /events/event_1160/time (Array(2500,)) ''
# /events/event_1160/voltage_ch1 (Array(2500,)) ''
# /events/event_1160/voltage_ch2 (Array(2500,)) ''
# /events/event_1161 (Group) 'Event 1161'
# /events/event_1161/time (Array(2500,)) ''
# /events/event_1161/voltage_ch1 (Array(2500,)) ''
# /events/event_1161/voltage_ch2 (Array(2500,)) ''
# /events/event_1162 (Group) 'Event 1162'
# /events/event_1162/time (Array(2500,)) ''
# /events/event_1162/voltage_ch1 (Array(2500,)) ''
# /events/event_1162/voltage_ch2 (Array(2500,)) ''
# /events/event_1163 (Group) 'Event 1163'
# /events/event_1163/time (Array(2500,)) ''
# /events/event_1163/voltage_ch1 (Array(2500,)) ''
# /events/event_1163/voltage_ch2 (Array(2500,)) ''
# /events/event_1164 (Group) 'Event 1164'
# /events/event_1164/time (Array(2500,)) ''
# /events/event_1164/voltage_ch1 (Array(2500,)) ''
# /events/event_1164/voltage_ch2 (Array(2500,)) ''
# /events/event_1165 (Group) 'Event 1165'
# /events/event_1165/time (Array(2500,)) ''
# /events/event_1165/voltage_ch1 (Array(2500,)) ''
# /events/event_1165/voltage_ch2 (Array(2500,)) ''
# /events/event_1166 (Group) 'Event 1166'
# /events/event_1166/time (Array(2500,)) ''
# /events/event_1166/voltage_ch1 (Array(2500,)) ''
# /events/event_1166/voltage_ch2 (Array(2500,)) ''
# /events/event_1167 (Group) 'Event 1167'
# /events/event_1167/time (Array(2500,)) ''
# /events/event_1167/voltage_ch1 (Array(2500,)) ''
# /events/event_1167/voltage_ch2 (Array(2500,)) ''
# /events/event_1168 (Group) 'Event 1168'
# /events/event_1168/time (Array(2500,)) ''
# /events/event_1168/voltage_ch1 (Array(2500,)) ''
# /events/event_1168/voltage_ch2 (Array(2500,)) ''
# /events/event_1169 (Group) 'Event 1169'
# /events/event_1169/time (Array(2500,)) ''
# /events/event_1169/voltage_ch1 (Array(2500,)) ''
# /events/event_1169/voltage_ch2 (Array(2500,)) ''
# /events/event_117 (Group) 'Event 117'
# /events/event_117/time (Array(2500,)) ''
# /events/event_117/voltage_ch1 (Array(2500,)) ''
# /events/event_117/voltage_ch2 (Array(2500,)) ''
# /events/event_1170 (Group) 'Event 1170'
# /events/event_1170/time (Array(2500,)) ''
# /events/event_1170/voltage_ch1 (Array(2500,)) ''
# /events/event_1170/voltage_ch2 (Array(2500,)) ''
# /events/event_1171 (Group) 'Event 1171'
# /events/event_1171/time (Array(2500,)) ''
# /events/event_1171/voltage_ch1 (Array(2500,)) ''
# /events/event_1171/voltage_ch2 (Array(2500,)) ''
# /events/event_1172 (Group) 'Event 1172'
# /events/event_1172/time (Array(2500,)) ''
# /events/event_1172/voltage_ch1 (Array(2500,)) ''
# /events/event_1172/voltage_ch2 (Array(2500,)) ''
# /events/event_1173 (Group) 'Event 1173'
# /events/event_1173/time (Array(2500,)) ''
# /events/event_1173/voltage_ch1 (Array(2500,)) ''
# /events/event_1173/voltage_ch2 (Array(2500,)) ''
# /events/event_1174 (Group) 'Event 1174'
# /events/event_1174/time (Array(2500,)) ''
# /events/event_1174/voltage_ch1 (Array(2500,)) ''
# /events/event_1174/voltage_ch2 (Array(2500,)) ''
# /events/event_1175 (Group) 'Event 1175'
# /events/event_1175/time (Array(2500,)) ''
# /events/event_1175/voltage_ch1 (Array(2500,)) ''
# /events/event_1175/voltage_ch2 (Array(2500,)) ''
# /events/event_1176 (Group) 'Event 1176'
# /events/event_1176/time (Array(2500,)) ''
# /events/event_1176/voltage_ch1 (Array(2500,)) ''
# /events/event_1176/voltage_ch2 (Array(2500,)) ''
# /events/event_1177 (Group) 'Event 1177'
# /events/event_1177/time (Array(2500,)) ''
# /events/event_1177/voltage_ch1 (Array(2500,)) ''
# /events/event_1177/voltage_ch2 (Array(2500,)) ''
# /events/event_1178 (Group) 'Event 1178'
# /events/event_1178/time (Array(2500,)) ''
# /events/event_1178/voltage_ch1 (Array(2500,)) ''
# /events/event_1178/voltage_ch2 (Array(2500,)) ''
# /events/event_1179 (Group) 'Event 1179'
# /events/event_1179/time (Array(2500,)) ''
# /events/event_1179/voltage_ch1 (Array(2500,)) ''
# /events/event_1179/voltage_ch2 (Array(2500,)) ''
# /events/event_118 (Group) 'Event 118'
# /events/event_118/time (Array(2500,)) ''
# /events/event_118/voltage_ch1 (Array(2500,)) ''
# /events/event_118/voltage_ch2 (Array(2500,)) ''
# /events/event_1180 (Group) 'Event 1180'
# /events/event_1180/time (Array(2500,)) ''
# /events/event_1180/voltage_ch1 (Array(2500,)) ''
# /events/event_1180/voltage_ch2 (Array(2500,)) ''
# /events/event_1181 (Group) 'Event 1181'
# /events/event_1181/time (Array(2500,)) ''
# /events/event_1181/voltage_ch1 (Array(2500,)) ''
# /events/event_1181/voltage_ch2 (Array(2500,)) ''
# /events/event_1182 (Group) 'Event 1182'
# /events/event_1182/time (Array(2500,)) ''
# /events/event_1182/voltage_ch1 (Array(2500,)) ''
# /events/event_1182/voltage_ch2 (Array(2500,)) ''
# /events/event_1183 (Group) 'Event 1183'
# /events/event_1183/time (Array(2500,)) ''
# /events/event_1183/voltage_ch1 (Array(2500,)) ''
# /events/event_1183/voltage_ch2 (Array(2500,)) ''
# /events/event_1184 (Group) 'Event 1184'
# /events/event_1184/time (Array(2500,)) ''
# /events/event_1184/voltage_ch1 (Array(2500,)) ''
# /events/event_1184/voltage_ch2 (Array(2500,)) ''
# /events/event_1185 (Group) 'Event 1185'
# /events/event_1185/time (Array(2500,)) ''
# /events/event_1185/voltage_ch1 (Array(2500,)) ''
# /events/event_1185/voltage_ch2 (Array(2500,)) ''
# /events/event_1186 (Group) 'Event 1186'
# /events/event_1186/time (Array(2500,)) ''
# /events/event_1186/voltage_ch1 (Array(2500,)) ''
# /events/event_1186/voltage_ch2 (Array(2500,)) ''
# /events/event_1187 (Group) 'Event 1187'
# /events/event_1187/time (Array(2500,)) ''
# /events/event_1187/voltage_ch1 (Array(2500,)) ''
# /events/event_1187/voltage_ch2 (Array(2500,)) ''
# /events/event_1188 (Group) 'Event 1188'
# /events/event_1188/time (Array(2500,)) ''
# /events/event_1188/voltage_ch1 (Array(2500,)) ''
# /events/event_1188/voltage_ch2 (Array(2500,)) ''
# /events/event_1189 (Group) 'Event 1189'
# /events/event_1189/time (Array(2500,)) ''
# /events/event_1189/voltage_ch1 (Array(2500,)) ''
# /events/event_1189/voltage_ch2 (Array(2500,)) ''
# /events/event_119 (Group) 'Event 119'
# /events/event_119/time (Array(2500,)) ''
# /events/event_119/voltage_ch1 (Array(2500,)) ''
# /events/event_119/voltage_ch2 (Array(2500,)) ''
# /events/event_1190 (Group) 'Event 1190'
# /events/event_1190/time (Array(2500,)) ''
# /events/event_1190/voltage_ch1 (Array(2500,)) ''
# /events/event_1190/voltage_ch2 (Array(2500,)) ''
# /events/event_1191 (Group) 'Event 1191'
# /events/event_1191/time (Array(2500,)) ''
# /events/event_1191/voltage_ch1 (Array(2500,)) ''
# /events/event_1191/voltage_ch2 (Array(2500,)) ''
# /events/event_1192 (Group) 'Event 1192'
# /events/event_1192/time (Array(2500,)) ''
# /events/event_1192/voltage_ch1 (Array(2500,)) ''
# /events/event_1192/voltage_ch2 (Array(2500,)) ''
# /events/event_1193 (Group) 'Event 1193'
# /events/event_1193/time (Array(2500,)) ''
# /events/event_1193/voltage_ch1 (Array(2500,)) ''
# /events/event_1193/voltage_ch2 (Array(2500,)) ''
# /events/event_1194 (Group) 'Event 1194'
# /events/event_1194/time (Array(2500,)) ''
# /events/event_1194/voltage_ch1 (Array(2500,)) ''
# /events/event_1194/voltage_ch2 (Array(2500,)) ''
# /events/event_1195 (Group) 'Event 1195'
# /events/event_1195/time (Array(2500,)) ''
# /events/event_1195/voltage_ch1 (Array(2500,)) ''
# /events/event_1195/voltage_ch2 (Array(2500,)) ''
# /events/event_1196 (Group) 'Event 1196'
# /events/event_1196/time (Array(2500,)) ''
# /events/event_1196/voltage_ch1 (Array(2500,)) ''
# /events/event_1196/voltage_ch2 (Array(2500,)) ''
# /events/event_1197 (Group) 'Event 1197'
# /events/event_1197/time (Array(2500,)) ''
# /events/event_1197/voltage_ch1 (Array(2500,)) ''
# /events/event_1197/voltage_ch2 (Array(2500,)) ''
# /events/event_1198 (Group) 'Event 1198'
# /events/event_1198/time (Array(2500,)) ''
# /events/event_1198/voltage_ch1 (Array(2500,)) ''
# /events/event_1198/voltage_ch2 (Array(2500,)) ''
# /events/event_1199 (Group) 'Event 1199'
# /events/event_1199/time (Array(2500,)) ''
# /events/event_1199/voltage_ch1 (Array(2500,)) ''
# /events/event_1199/voltage_ch2 (Array(2500,)) ''
# /events/event_12 (Group) 'Event 12'
# /events/event_12/time (Array(2500,)) ''
# /events/event_12/voltage_ch1 (Array(2500,)) ''
# /events/event_12/voltage_ch2 (Array(2500,)) ''
# /events/event_120 (Group) 'Event 120'
# /events/event_120/time (Array(2500,)) ''
# /events/event_120/voltage_ch1 (Array(2500,)) ''
# /events/event_120/voltage_ch2 (Array(2500,)) ''
# /events/event_1200 (Group) 'Event 1200'
# /events/event_1200/time (Array(2500,)) ''
# /events/event_1200/voltage_ch1 (Array(2500,)) ''
# /events/event_1200/voltage_ch2 (Array(2500,)) ''
# /events/event_1201 (Group) 'Event 1201'
# /events/event_1201/time (Array(2500,)) ''
# /events/event_1201/voltage_ch1 (Array(2500,)) ''
# /events/event_1201/voltage_ch2 (Array(2500,)) ''
# /events/event_1202 (Group) 'Event 1202'
# /events/event_1202/time (Array(2500,)) ''
# /events/event_1202/voltage_ch1 (Array(2500,)) ''
# /events/event_1202/voltage_ch2 (Array(2500,)) ''
# /events/event_1203 (Group) 'Event 1203'
# /events/event_1203/time (Array(2500,)) ''
# /events/event_1203/voltage_ch1 (Array(2500,)) ''
# /events/event_1203/voltage_ch2 (Array(2500,)) ''
# /events/event_1204 (Group) 'Event 1204'
# /events/event_1204/time (Array(2500,)) ''
# /events/event_1204/voltage_ch1 (Array(2500,)) ''
# /events/event_1204/voltage_ch2 (Array(2500,)) ''
# /events/event_1205 (Group) 'Event 1205'
# /events/event_1205/time (Array(2500,)) ''
# /events/event_1205/voltage_ch1 (Array(2500,)) ''
# /events/event_1205/voltage_ch2 (Array(2500,)) ''
# /events/event_1206 (Group) 'Event 1206'
# /events/event_1206/time (Array(2500,)) ''
# /events/event_1206/voltage_ch1 (Array(2500,)) ''
# /events/event_1206/voltage_ch2 (Array(2500,)) ''
# /events/event_1207 (Group) 'Event 1207'
# /events/event_1207/time (Array(2500,)) ''
# /events/event_1207/voltage_ch1 (Array(2500,)) ''
# /events/event_1207/voltage_ch2 (Array(2500,)) ''
# /events/event_1208 (Group) 'Event 1208'
# /events/event_1208/time (Array(2500,)) ''
# /events/event_1208/voltage_ch1 (Array(2500,)) ''
# /events/event_1208/voltage_ch2 (Array(2500,)) ''
# /events/event_1209 (Group) 'Event 1209'
# /events/event_1209/time (Array(2500,)) ''
# /events/event_1209/voltage_ch1 (Array(2500,)) ''
# /events/event_1209/voltage_ch2 (Array(2500,)) ''
# /events/event_121 (Group) 'Event 121'
# /events/event_121/time (Array(2500,)) ''
# /events/event_121/voltage_ch1 (Array(2500,)) ''
# /events/event_121/voltage_ch2 (Array(2500,)) ''
# /events/event_1210 (Group) 'Event 1210'
# /events/event_1210/time (Array(2500,)) ''
# /events/event_1210/voltage_ch1 (Array(2500,)) ''
# /events/event_1210/voltage_ch2 (Array(2500,)) ''
# /events/event_1211 (Group) 'Event 1211'
# /events/event_1211/time (Array(2500,)) ''
# /events/event_1211/voltage_ch1 (Array(2500,)) ''
# /events/event_1211/voltage_ch2 (Array(2500,)) ''
# /events/event_1212 (Group) 'Event 1212'
# /events/event_1212/time (Array(2500,)) ''
# /events/event_1212/voltage_ch1 (Array(2500,)) ''
# /events/event_1212/voltage_ch2 (Array(2500,)) ''
# /events/event_1213 (Group) 'Event 1213'
# /events/event_1213/time (Array(2500,)) ''
# /events/event_1213/voltage_ch1 (Array(2500,)) ''
# /events/event_1213/voltage_ch2 (Array(2500,)) ''
# /events/event_1214 (Group) 'Event 1214'
# /events/event_1214/time (Array(2500,)) ''
# /events/event_1214/voltage_ch1 (Array(2500,)) ''
# /events/event_1214/voltage_ch2 (Array(2500,)) ''
# /events/event_1215 (Group) 'Event 1215'
# /events/event_1215/time (Array(2500,)) ''
# /events/event_1215/voltage_ch1 (Array(2500,)) ''
# /events/event_1215/voltage_ch2 (Array(2500,)) ''
# /events/event_1216 (Group) 'Event 1216'
# /events/event_1216/time (Array(2500,)) ''
# /events/event_1216/voltage_ch1 (Array(2500,)) ''
# /events/event_1216/voltage_ch2 (Array(2500,)) ''
# /events/event_1217 (Group) 'Event 1217'
# /events/event_1217/time (Array(2500,)) ''
# /events/event_1217/voltage_ch1 (Array(2500,)) ''
# /events/event_1217/voltage_ch2 (Array(2500,)) ''
# /events/event_1218 (Group) 'Event 1218'
# /events/event_1218/time (Array(2500,)) ''
# /events/event_1218/voltage_ch1 (Array(2500,)) ''
# /events/event_1218/voltage_ch2 (Array(2500,)) ''
# /events/event_1219 (Group) 'Event 1219'
# /events/event_1219/time (Array(2500,)) ''
# /events/event_1219/voltage_ch1 (Array(2500,)) ''
# /events/event_1219/voltage_ch2 (Array(2500,)) ''
# /events/event_122 (Group) 'Event 122'
# /events/event_122/time (Array(2500,)) ''
# /events/event_122/voltage_ch1 (Array(2500,)) ''
# /events/event_122/voltage_ch2 (Array(2500,)) ''
# /events/event_1220 (Group) 'Event 1220'
# /events/event_1220/time (Array(2500,)) ''
# /events/event_1220/voltage_ch1 (Array(2500,)) ''
# /events/event_1220/voltage_ch2 (Array(2500,)) ''
# /events/event_1221 (Group) 'Event 1221'
# /events/event_1221/time (Array(2500,)) ''
# /events/event_1221/voltage_ch1 (Array(2500,)) ''
# /events/event_1221/voltage_ch2 (Array(2500,)) ''
# /events/event_1222 (Group) 'Event 1222'
# /events/event_1222/time (Array(2500,)) ''
# /events/event_1222/voltage_ch1 (Array(2500,)) ''
# /events/event_1222/voltage_ch2 (Array(2500,)) ''
# /events/event_1223 (Group) 'Event 1223'
# /events/event_1223/time (Array(2500,)) ''
# /events/event_1223/voltage_ch1 (Array(2500,)) ''
# /events/event_1223/voltage_ch2 (Array(2500,)) ''
# /events/event_1224 (Group) 'Event 1224'
# /events/event_1224/time (Array(2500,)) ''
# /events/event_1224/voltage_ch1 (Array(2500,)) ''
# /events/event_1224/voltage_ch2 (Array(2500,)) ''
# /events/event_1225 (Group) 'Event 1225'
# /events/event_1225/time (Array(2500,)) ''
# /events/event_1225/voltage_ch1 (Array(2500,)) ''
# /events/event_1225/voltage_ch2 (Array(2500,)) ''
# /events/event_1226 (Group) 'Event 1226'
# /events/event_1226/time (Array(2500,)) ''
# /events/event_1226/voltage_ch1 (Array(2500,)) ''
# /events/event_1226/voltage_ch2 (Array(2500,)) ''
# /events/event_1227 (Group) 'Event 1227'
# /events/event_1227/time (Array(2500,)) ''
# /events/event_1227/voltage_ch1 (Array(2500,)) ''
# /events/event_1227/voltage_ch2 (Array(2500,)) ''
# /events/event_1228 (Group) 'Event 1228'
# /events/event_1228/time (Array(2500,)) ''
# /events/event_1228/voltage_ch1 (Array(2500,)) ''
# /events/event_1228/voltage_ch2 (Array(2500,)) ''
# /events/event_1229 (Group) 'Event 1229'
# /events/event_1229/time (Array(2500,)) ''
# /events/event_1229/voltage_ch1 (Array(2500,)) ''
# /events/event_1229/voltage_ch2 (Array(2500,)) ''
# /events/event_123 (Group) 'Event 123'
# /events/event_123/time (Array(2500,)) ''
# /events/event_123/voltage_ch1 (Array(2500,)) ''
# /events/event_123/voltage_ch2 (Array(2500,)) ''
# /events/event_1230 (Group) 'Event 1230'
# /events/event_1230/time (Array(2500,)) ''
# /events/event_1230/voltage_ch1 (Array(2500,)) ''
# /events/event_1230/voltage_ch2 (Array(2500,)) ''
# /events/event_1231 (Group) 'Event 1231'
# /events/event_1231/time (Array(2500,)) ''
# /events/event_1231/voltage_ch1 (Array(2500,)) ''
# /events/event_1231/voltage_ch2 (Array(2500,)) ''
# /events/event_1232 (Group) 'Event 1232'
# /events/event_1232/time (Array(2500,)) ''
# /events/event_1232/voltage_ch1 (Array(2500,)) ''
# /events/event_1232/voltage_ch2 (Array(2500,)) ''
# /events/event_1233 (Group) 'Event 1233'
# /events/event_1233/time (Array(2500,)) ''
# /events/event_1233/voltage_ch1 (Array(2500,)) ''
# /events/event_1233/voltage_ch2 (Array(2500,)) ''
# /events/event_1234 (Group) 'Event 1234'
# /events/event_1234/time (Array(2500,)) ''
# /events/event_1234/voltage_ch1 (Array(2500,)) ''
# /events/event_1234/voltage_ch2 (Array(2500,)) ''
# /events/event_1235 (Group) 'Event 1235'
# /events/event_1235/time (Array(2500,)) ''
# /events/event_1235/voltage_ch1 (Array(2500,)) ''
# /events/event_1235/voltage_ch2 (Array(2500,)) ''
# /events/event_1236 (Group) 'Event 1236'
# /events/event_1236/time (Array(2500,)) ''
# /events/event_1236/voltage_ch1 (Array(2500,)) ''
# /events/event_1236/voltage_ch2 (Array(2500,)) ''
# /events/event_1237 (Group) 'Event 1237'
# /events/event_1237/time (Array(2500,)) ''
# /events/event_1237/voltage_ch1 (Array(2500,)) ''
# /events/event_1237/voltage_ch2 (Array(2500,)) ''
# /events/event_1238 (Group) 'Event 1238'
# /events/event_1238/time (Array(2500,)) ''
# ...
# /events/event_9919 (Group) 'Event 9919'
# /events/event_9919/time (Array(2500,)) ''
# /events/event_9919/voltage_ch1 (Array(2500,)) ''
# /events/event_9919/voltage_ch2 (Array(2500,)) ''
# /events/event_992 (Group) 'Event 992'
# /events/event_992/time (Array(2500,)) ''
# /events/event_992/voltage_ch1 (Array(2500,)) ''
# /events/event_992/voltage_ch2 (Array(2500,)) ''
# /events/event_9920 (Group) 'Event 9920'
# /events/event_9920/time (Array(2500,)) ''
# /events/event_9920/voltage_ch1 (Array(2500,)) ''
# /events/event_9920/voltage_ch2 (Array(2500,)) ''
# /events/event_9921 (Group) 'Event 9921'
# /events/event_9921/time (Array(2500,)) ''
# /events/event_9921/voltage_ch1 (Array(2500,)) ''
# /events/event_9921/voltage_ch2 (Array(2500,)) ''
# /events/event_9922 (Group) 'Event 9922'
# /events/event_9922/time (Array(2500,)) ''
# /events/event_9922/voltage_ch1 (Array(2500,)) ''
# /events/event_9922/voltage_ch2 (Array(2500,)) ''
# /events/event_9923 (Group) 'Event 9923'
# /events/event_9923/time (Array(2500,)) ''
# /events/event_9923/voltage_ch1 (Array(2500,)) ''
# /events/event_9923/voltage_ch2 (Array(2500,)) ''
# /events/event_9924 (Group) 'Event 9924'
# /events/event_9924/time (Array(2500,)) ''
# /events/event_9924/voltage_ch1 (Array(2500,)) ''
# /events/event_9924/voltage_ch2 (Array(2500,)) ''
# /events/event_9925 (Group) 'Event 9925'
# /events/event_9925/time (Array(2500,)) ''
# /events/event_9925/voltage_ch1 (Array(2500,)) ''
# /events/event_9925/voltage_ch2 (Array(2500,)) ''
# /events/event_9926 (Group) 'Event 9926'
# /events/event_9926/time (Array(2500,)) ''
# /events/event_9926/voltage_ch1 (Array(2500,)) ''
# /events/event_9926/voltage_ch2 (Array(2500,)) ''
# /events/event_9927 (Group) 'Event 9927'
# /events/event_9927/time (Array(2500,)) ''
# /events/event_9927/voltage_ch1 (Array(2500,)) ''
# /events/event_9927/voltage_ch2 (Array(2500,)) ''
# /events/event_9928 (Group) 'Event 9928'
# /events/event_9928/time (Array(2500,)) ''
# /events/event_9928/voltage_ch1 (Array(2500,)) ''
# /events/event_9928/voltage_ch2 (Array(2500,)) ''
# /events/event_9929 (Group) 'Event 9929'
# /events/event_9929/time (Array(2500,)) ''
# /events/event_9929/voltage_ch1 (Array(2500,)) ''
# /events/event_9929/voltage_ch2 (Array(2500,)) ''
# /events/event_993 (Group) 'Event 993'
# /events/event_993/time (Array(2500,)) ''
# /events/event_993/voltage_ch1 (Array(2500,)) ''
# /events/event_993/voltage_ch2 (Array(2500,)) ''
# /events/event_9930 (Group) 'Event 9930'
# /events/event_9930/time (Array(2500,)) ''
# /events/event_9930/voltage_ch1 (Array(2500,)) ''
# /events/event_9930/voltage_ch2 (Array(2500,)) ''
# /events/event_9931 (Group) 'Event 9931'
# /events/event_9931/time (Array(2500,)) ''
# /events/event_9931/voltage_ch1 (Array(2500,)) ''
# /events/event_9931/voltage_ch2 (Array(2500,)) ''
# /events/event_9932 (Group) 'Event 9932'
# /events/event_9932/time (Array(2500,)) ''
# /events/event_9932/voltage_ch1 (Array(2500,)) ''
# /events/event_9932/voltage_ch2 (Array(2500,)) ''
# /events/event_9933 (Group) 'Event 9933'
# /events/event_9933/time (Array(2500,)) ''
# /events/event_9933/voltage_ch1 (Array(2500,)) ''
# /events/event_9933/voltage_ch2 (Array(2500,)) ''
# /events/event_9934 (Group) 'Event 9934'
# /events/event_9934/time (Array(2500,)) ''
# /events/event_9934/voltage_ch1 (Array(2500,)) ''
# /events/event_9934/voltage_ch2 (Array(2500,)) ''
# /events/event_9935 (Group) 'Event 9935'
# /events/event_9935/time (Array(2500,)) ''
# /events/event_9935/voltage_ch1 (Array(2500,)) ''
# /events/event_9935/voltage_ch2 (Array(2500,)) ''
# /events/event_9936 (Group) 'Event 9936'
# /events/event_9936/time (Array(2500,)) ''
# /events/event_9936/voltage_ch1 (Array(2500,)) ''
# /events/event_9936/voltage_ch2 (Array(2500,)) ''
# /events/event_9937 (Group) 'Event 9937'
# /events/event_9937/time (Array(2500,)) ''
# /events/event_9937/voltage_ch1 (Array(2500,)) ''
# /events/event_9937/voltage_ch2 (Array(2500,)) ''
# /events/event_9938 (Group) 'Event 9938'
# /events/event_9938/time (Array(2500,)) ''
# /events/event_9938/voltage_ch1 (Array(2500,)) ''
# /events/event_9938/voltage_ch2 (Array(2500,)) ''
# /events/event_9939 (Group) 'Event 9939'
# /events/event_9939/time (Array(2500,)) ''
# /events/event_9939/voltage_ch1 (Array(2500,)) ''
# /events/event_9939/voltage_ch2 (Array(2500,)) ''
# /events/event_994 (Group) 'Event 994'
# /events/event_994/time (Array(2500,)) ''
# /events/event_994/voltage_ch1 (Array(2500,)) ''
# /events/event_994/voltage_ch2 (Array(2500,)) ''
# /events/event_9940 (Group) 'Event 9940'
# /events/event_9940/time (Array(2500,)) ''
# /events/event_9940/voltage_ch1 (Array(2500,)) ''
# /events/event_9940/voltage_ch2 (Array(2500,)) ''
# /events/event_9941 (Group) 'Event 9941'
# /events/event_9941/time (Array(2500,)) ''
# /events/event_9941/voltage_ch1 (Array(2500,)) ''
# /events/event_9941/voltage_ch2 (Array(2500,)) ''
# /events/event_9942 (Group) 'Event 9942'
# /events/event_9942/time (Array(2500,)) ''
# /events/event_9942/voltage_ch1 (Array(2500,)) ''
# /events/event_9942/voltage_ch2 (Array(2500,)) ''
# /events/event_9943 (Group) 'Event 9943'
# /events/event_9943/time (Array(2500,)) ''
# /events/event_9943/voltage_ch1 (Array(2500,)) ''
# /events/event_9943/voltage_ch2 (Array(2500,)) ''
# /events/event_9944 (Group) 'Event 9944'
# /events/event_9944/time (Array(2500,)) ''
# /events/event_9944/voltage_ch1 (Array(2500,)) ''
# /events/event_9944/voltage_ch2 (Array(2500,)) ''
# /events/event_9945 (Group) 'Event 9945'
# /events/event_9945/time (Array(2500,)) ''
# /events/event_9945/voltage_ch1 (Array(2500,)) ''
# /events/event_9945/voltage_ch2 (Array(2500,)) ''
# /events/event_9946 (Group) 'Event 9946'
# /events/event_9946/time (Array(2500,)) ''
# /events/event_9946/voltage_ch1 (Array(2500,)) ''
# /events/event_9946/voltage_ch2 (Array(2500,)) ''
# /events/event_9947 (Group) 'Event 9947'
# /events/event_9947/time (Array(2500,)) ''
# /events/event_9947/voltage_ch1 (Array(2500,)) ''
# /events/event_9947/voltage_ch2 (Array(2500,)) ''
# /events/event_9948 (Group) 'Event 9948'
# /events/event_9948/time (Array(2500,)) ''
# /events/event_9948/voltage_ch1 (Array(2500,)) ''
# /events/event_9948/voltage_ch2 (Array(2500,)) ''
# /events/event_9949 (Group) 'Event 9949'
# /events/event_9949/time (Array(2500,)) ''
# /events/event_9949/voltage_ch1 (Array(2500,)) ''
# /events/event_9949/voltage_ch2 (Array(2500,)) ''
# /events/event_995 (Group) 'Event 995'
# /events/event_995/time (Array(2500,)) ''
# /events/event_995/voltage_ch1 (Array(2500,)) ''
# /events/event_995/voltage_ch2 (Array(2500,)) ''
# /events/event_9950 (Group) 'Event 9950'
# /events/event_9950/time (Array(2500,)) ''
# /events/event_9950/voltage_ch1 (Array(2500,)) ''
# /events/event_9950/voltage_ch2 (Array(2500,)) ''
# /events/event_9951 (Group) 'Event 9951'
# /events/event_9951/time (Array(2500,)) ''
# /events/event_9951/voltage_ch1 (Array(2500,)) ''
# /events/event_9951/voltage_ch2 (Array(2500,)) ''
# /events/event_9952 (Group) 'Event 9952'
# /events/event_9952/time (Array(2500,)) ''
# /events/event_9952/voltage_ch1 (Array(2500,)) ''
# /events/event_9952/voltage_ch2 (Array(2500,)) ''
# /events/event_9953 (Group) 'Event 9953'
# /events/event_9953/time (Array(2500,)) ''
# /events/event_9953/voltage_ch1 (Array(2500,)) ''
# /events/event_9953/voltage_ch2 (Array(2500,)) ''
# /events/event_9954 (Group) 'Event 9954'
# /events/event_9954/time (Array(2500,)) ''
# /events/event_9954/voltage_ch1 (Array(2500,)) ''
# /events/event_9954/voltage_ch2 (Array(2500,)) ''
# /events/event_9955 (Group) 'Event 9955'
# /events/event_9955/time (Array(2500,)) ''
# /events/event_9955/voltage_ch1 (Array(2500,)) ''
# /events/event_9955/voltage_ch2 (Array(2500,)) ''
# /events/event_9956 (Group) 'Event 9956'
# /events/event_9956/time (Array(2500,)) ''
# /events/event_9956/voltage_ch1 (Array(2500,)) ''
# /events/event_9956/voltage_ch2 (Array(2500,)) ''
# /events/event_9957 (Group) 'Event 9957'
# /events/event_9957/time (Array(2500,)) ''
# /events/event_9957/voltage_ch1 (Array(2500,)) ''
# /events/event_9957/voltage_ch2 (Array(2500,)) ''
# /events/event_9958 (Group) 'Event 9958'
# /events/event_9958/time (Array(2500,)) ''
# /events/event_9958/voltage_ch1 (Array(2500,)) ''
# /events/event_9958/voltage_ch2 (Array(2500,)) ''
# /events/event_9959 (Group) 'Event 9959'
# /events/event_9959/time (Array(2500,)) ''
# /events/event_9959/voltage_ch1 (Array(2500,)) ''
# /events/event_9959/voltage_ch2 (Array(2500,)) ''
# /events/event_996 (Group) 'Event 996'
# /events/event_996/time (Array(2500,)) ''
# /events/event_996/voltage_ch1 (Array(2500,)) ''
# /events/event_996/voltage_ch2 (Array(2500,)) ''
# /events/event_9960 (Group) 'Event 9960'
# /events/event_9960/time (Array(2500,)) ''
# /events/event_9960/voltage_ch1 (Array(2500,)) ''
# /events/event_9960/voltage_ch2 (Array(2500,)) ''
# /events/event_9961 (Group) 'Event 9961'
# /events/event_9961/time (Array(2500,)) ''
# /events/event_9961/voltage_ch1 (Array(2500,)) ''
# /events/event_9961/voltage_ch2 (Array(2500,)) ''
# /events/event_9962 (Group) 'Event 9962'
# /events/event_9962/time (Array(2500,)) ''
# /events/event_9962/voltage_ch1 (Array(2500,)) ''
# /events/event_9962/voltage_ch2 (Array(2500,)) ''
# /events/event_9963 (Group) 'Event 9963'
# /events/event_9963/time (Array(2500,)) ''
# /events/event_9963/voltage_ch1 (Array(2500,)) ''
# /events/event_9963/voltage_ch2 (Array(2500,)) ''
# /events/event_9964 (Group) 'Event 9964'
# /events/event_9964/time (Array(2500,)) ''
# /events/event_9964/voltage_ch1 (Array(2500,)) ''
# /events/event_9964/voltage_ch2 (Array(2500,)) ''
# /events/event_9965 (Group) 'Event 9965'
# /events/event_9965/time (Array(2500,)) ''
# /events/event_9965/voltage_ch1 (Array(2500,)) ''
# /events/event_9965/voltage_ch2 (Array(2500,)) ''
# /events/event_9966 (Group) 'Event 9966'
# /events/event_9966/time (Array(2500,)) ''
# /events/event_9966/voltage_ch1 (Array(2500,)) ''
# /events/event_9966/voltage_ch2 (Array(2500,)) ''
# /events/event_9967 (Group) 'Event 9967'
# /events/event_9967/time (Array(2500,)) ''
# /events/event_9967/voltage_ch1 (Array(2500,)) ''
# /events/event_9967/voltage_ch2 (Array(2500,)) ''
# /events/event_9968 (Group) 'Event 9968'
# /events/event_9968/time (Array(2500,)) ''
# /events/event_9968/voltage_ch1 (Array(2500,)) ''
# /events/event_9968/voltage_ch2 (Array(2500,)) ''
# /events/event_9969 (Group) 'Event 9969'
# /events/event_9969/time (Array(2500,)) ''
# /events/event_9969/voltage_ch1 (Array(2500,)) ''
# /events/event_9969/voltage_ch2 (Array(2500,)) ''
# /events/event_997 (Group) 'Event 997'
# /events/event_997/time (Array(2500,)) ''
# /events/event_997/voltage_ch1 (Array(2500,)) ''
# /events/event_997/voltage_ch2 (Array(2500,)) ''
# /events/event_9970 (Group) 'Event 9970'
# /events/event_9970/time (Array(2500,)) ''
# /events/event_9970/voltage_ch1 (Array(2500,)) ''
# /events/event_9970/voltage_ch2 (Array(2500,)) ''
# /events/event_9971 (Group) 'Event 9971'
# /events/event_9971/time (Array(2500,)) ''
# /events/event_9971/voltage_ch1 (Array(2500,)) ''
# /events/event_9971/voltage_ch2 (Array(2500,)) ''
# /events/event_9972 (Group) 'Event 9972'
# /events/event_9972/time (Array(2500,)) ''
# /events/event_9972/voltage_ch1 (Array(2500,)) ''
# /events/event_9972/voltage_ch2 (Array(2500,)) ''
# /events/event_9973 (Group) 'Event 9973'
# /events/event_9973/time (Array(2500,)) ''
# /events/event_9973/voltage_ch1 (Array(2500,)) ''
# /events/event_9973/voltage_ch2 (Array(2500,)) ''
# /events/event_9974 (Group) 'Event 9974'
# /events/event_9974/time (Array(2500,)) ''
# /events/event_9974/voltage_ch1 (Array(2500,)) ''
# /events/event_9974/voltage_ch2 (Array(2500,)) ''
# /events/event_9975 (Group) 'Event 9975'
# /events/event_9975/time (Array(2500,)) ''
# /events/event_9975/voltage_ch1 (Array(2500,)) ''
# /events/event_9975/voltage_ch2 (Array(2500,)) ''
# /events/event_9976 (Group) 'Event 9976'
# /events/event_9976/time (Array(2500,)) ''
# /events/event_9976/voltage_ch1 (Array(2500,)) ''
# /events/event_9976/voltage_ch2 (Array(2500,)) ''
# /events/event_9977 (Group) 'Event 9977'
# /events/event_9977/time (Array(2500,)) ''
# /events/event_9977/voltage_ch1 (Array(2500,)) ''
# /events/event_9977/voltage_ch2 (Array(2500,)) ''
# /events/event_9978 (Group) 'Event 9978'
# /events/event_9978/time (Array(2500,)) ''
# /events/event_9978/voltage_ch1 (Array(2500,)) ''
# /events/event_9978/voltage_ch2 (Array(2500,)) ''
# /events/event_9979 (Group) 'Event 9979'
# /events/event_9979/time (Array(2500,)) ''
# /events/event_9979/voltage_ch1 (Array(2500,)) ''
# /events/event_9979/voltage_ch2 (Array(2500,)) ''
# /events/event_998 (Group) 'Event 998'
# /events/event_998/time (Array(2500,)) ''
# /events/event_998/voltage_ch1 (Array(2500,)) ''
# /events/event_998/voltage_ch2 (Array(2500,)) ''
# /events/event_9980 (Group) 'Event 9980'
# /events/event_9980/time (Array(2500,)) ''
# /events/event_9980/voltage_ch1 (Array(2500,)) ''
# /events/event_9980/voltage_ch2 (Array(2500,)) ''
# /events/event_9981 (Group) 'Event 9981'
# /events/event_9981/time (Array(2500,)) ''
# /events/event_9981/voltage_ch1 (Array(2500,)) ''
# /events/event_9981/voltage_ch2 (Array(2500,)) ''
# /events/event_9982 (Group) 'Event 9982'
# /events/event_9982/time (Array(2500,)) ''
# /events/event_9982/voltage_ch1 (Array(2500,)) ''
# /events/event_9982/voltage_ch2 (Array(2500,)) ''
# /events/event_9983 (Group) 'Event 9983'
# /events/event_9983/time (Array(2500,)) ''
# /events/event_9983/voltage_ch1 (Array(2500,)) ''
# /events/event_9983/voltage_ch2 (Array(2500,)) ''
# /events/event_9984 (Group) 'Event 9984'
# /events/event_9984/time (Array(2500,)) ''
# /events/event_9984/voltage_ch1 (Array(2500,)) ''
# /events/event_9984/voltage_ch2 (Array(2500,)) ''
# /events/event_9985 (Group) 'Event 9985'
# /events/event_9985/time (Array(2500,)) ''
# /events/event_9985/voltage_ch1 (Array(2500,)) ''
# /events/event_9985/voltage_ch2 (Array(2500,)) ''
# /events/event_9986 (Group) 'Event 9986'
# /events/event_9986/time (Array(2500,)) ''
# /events/event_9986/voltage_ch1 (Array(2500,)) ''
# /events/event_9986/voltage_ch2 (Array(2500,)) ''
# /events/event_9987 (Group) 'Event 9987'
# /events/event_9987/time (Array(2500,)) ''
# /events/event_9987/voltage_ch1 (Array(2500,)) ''
# /events/event_9987/voltage_ch2 (Array(2500,)) ''
# /events/event_9988 (Group) 'Event 9988'
# /events/event_9988/time (Array(2500,)) ''
# /events/event_9988/voltage_ch1 (Array(2500,)) ''
# /events/event_9988/voltage_ch2 (Array(2500,)) ''
# /events/event_9989 (Group) 'Event 9989'
# /events/event_9989/time (Array(2500,)) ''
# /events/event_9989/voltage_ch1 (Array(2500,)) ''
# /events/event_9989/voltage_ch2 (Array(2500,)) ''
# /events/event_999 (Group) 'Event 999'
# /events/event_999/time (Array(2500,)) ''
# /events/event_999/voltage_ch1 (Array(2500,)) ''
# /events/event_999/voltage_ch2 (Array(2500,)) ''
# /events/event_9990 (Group) 'Event 9990'
# /events/event_9990/time (Array(2500,)) ''
# /events/event_9990/voltage_ch1 (Array(2500,)) ''
# /events/event_9990/voltage_ch2 (Array(2500,)) ''
# /events/event_9991 (Group) 'Event 9991'
# /events/event_9991/time (Array(2500,)) ''
# /events/event_9991/voltage_ch1 (Array(2500,)) ''
# /events/event_9991/voltage_ch2 (Array(2500,)) ''
# /events/event_9992 (Group) 'Event 9992'
# /events/event_9992/time (Array(2500,)) ''
# /events/event_9992/voltage_ch1 (Array(2500,)) ''
# /events/event_9992/voltage_ch2 (Array(2500,)) ''
# /events/event_9993 (Group) 'Event 9993'
# /events/event_9993/time (Array(2500,)) ''
# /events/event_9993/voltage_ch1 (Array(2500,)) ''
# /events/event_9993/voltage_ch2 (Array(2500,)) ''
# /events/event_9994 (Group) 'Event 9994'
# /events/event_9994/time (Array(2500,)) ''
# /events/event_9994/voltage_ch1 (Array(2500,)) ''
# /events/event_9994/voltage_ch2 (Array(2500,)) ''
# /events/event_9995 (Group) 'Event 9995'
# /events/event_9995/time (Array(2500,)) ''
# /events/event_9995/voltage_ch1 (Array(2500,)) ''
# /events/event_9995/voltage_ch2 (Array(2500,)) ''
# /events/event_9996 (Group) 'Event 9996'
# /events/event_9996/time (Array(2500,)) ''
# /events/event_9996/voltage_ch1 (Array(2500,)) ''
# /events/event_9996/voltage_ch2 (Array(2500,)) ''
# /events/event_9997 (Group) 'Event 9997'
# /events/event_9997/time (Array(2500,)) ''
# /events/event_9997/voltage_ch1 (Array(2500,)) ''
# /events/event_9997/voltage_ch2 (Array(2500,)) ''
# /events/event_9998 (Group) 'Event 9998'
# /events/event_9998/time (Array(2500,)) ''
# /events/event_9998/voltage_ch1 (Array(2500,)) ''
# /events/event_9998/voltage_ch2 (Array(2500,)) ''
# /events/event_9999 (Group) 'Event 9999'
# /events/event_9999/time (Array(2500,)) ''
# /events/event_9999/voltage_ch1 (Array(2500,)) ''
# /events/event_9999/voltage_ch2 (Array(2500,)) ''

# %%
a = tb.open_file(filename[0], 'r')

data = pd.DataFrame([])

for i in range(1, 2):
    event_group_name = f'event_{i}'
    ev_id = i
    time = getattr(getattr(a.root.events, event_group_name), 'time')[:]
    voltage_ch1 = getattr(getattr(a.root.events, event_group_name), 'voltage_ch2')[:]
    voltage_ch2 = getattr(getattr(a.root.events, event_group_name), 'voltage_ch1')[:]
    
    # Create a new DataFrame from the array
    new_rows = pd.DataFrame({'event_id': ev_id,
                             'time' : time,
                             'voltage_ch1' : voltage_ch1,
                             'voltage_ch2' : voltage_ch2
                            })
    
    data = data.append(new_rows, ignore_index=True)
    
a.close()

# %%
tt = data.loc[data.event_id == 1].time
signal = data.loc[data.event_id == 1].voltage_ch1
trigger = data.loc[data.event_id == 1].voltage_ch2

plt.plot(tt, trigger)
plt.plot(tt, signal)
plt.plot(t_peak, v_peak, 'o')

# %% [markdown]
# # Waveform identification

# %%
peak = data.loc[(data.time > 0.) & (data.time < 0.5e-6)]

t_peak = peak.loc[peak.voltage_ch1 == peak.voltage_ch1.max()].time.values
v_peak = peak.loc[peak.voltage_ch1 == peak.voltage_ch1.max()].voltage_ch1.values

# %%
data.voltage_ch1 - v_peak
# Out:
# 0      -0.861250
# 1      -0.861797
# 2      -0.862188
# 3      -0.860391
# 4      -0.861641
#           ...
# 2495   -0.852891
# 2496   -0.851953
# 2497   -0.852266
# 2498   -0.852266
# 2499   -0.852031
# Name: voltage_ch1, Length: 2500, dtype: float64

# %%
peak = data.loc[(np.fabs(data.time - t_peak) < 0.1e-6)]

# %%
plt.plot(tt, trigger)
plt.plot(tt, signal)
plt.plot(peak.time, peak.voltage_ch1)
plt.plot(t_peak, v_peak, 'o')

# %% [markdown]
# # Functions

# %%
# Fitting distributions to define

# note: pdf are normilized to 1 so we have yo add an amplitude param
def gauss(x, a,  mu, sigma):
    return a*stats.norm.pdf(x, mu, sigma) 

def gauss_sum(x, a0,  mu0, sigma0, a1, mu1, sigma1):
    return a0*stats.norm.pdf(x, mu0, sigma0)  + a1*stats.norm.pdf(x, mu1, sigma1)

n_pe = 2

# %% [markdown]
# # Super LOOP

# %%
# %%timeit
fig, ax = plt.subplots(nrows=3, ncols=2, figsize=(15,10), constrained_layout=True)

for fib in [0, 1]:
    #____________________________________________________________________________________________________________________
    #_________________________________Data_______________________________________________________________________________
    #____________________________________________________________________________________________________________________

    data = []
    with open(filename[fib],'r', encoding='ascii') as fp:
        for i, line in enumerate(fp):
            if any(c.isalpha() for c in line) == False:
                data.append(np.asarray(line.split('\t')[:-1], dtype=float))
    fp.close()

    waveform = np.array(data)


    n_points = int(waveform[:, 0].max() + 1)
    n_frames = int(len(waveform)/n_points) 



    #____________________________________________________________________________________________________________________
    #_________________________________Waveform___________________________________________________________________________
    #____________________________________________________________________________________________________________________

    frame = int(n_frames/2); 
    # print('frame = ', frame)

    wave = waveform[frame*n_points: (frame + 1)*n_points].copy()
    x_ax = wave[:, 0]

    #_______________________________________________________________________________

    t1 = 70
    t2 = 90
#     t1 = 150
#     t2 = 200
#     t1 = 0
#     t2 = 1000

    dt_izq = 10
    dt_dch = 10

    #_______________________________________________________________________________

    t0 = t1 + int(np.where(wave[:, ch][t1 : t2] == wave[:, ch][t1 : t2].min())[0][0])

    pre_base = wave[:, ch][:t0 - dt_izq]
    x_ax_pre = x_ax[:t0 - dt_izq]

    peak = wave[:, ch][t0 - dt_izq : t0 + dt_dch].copy()
    x_ax_peak = x_ax[t0 - dt_izq : t0 + dt_dch].copy()

    post_base = wave[:, ch][t0 + dt_dch:]
    x_ax_post = x_ax[t0 + dt_dch:]


    #_________plot_settings_________________________________________________

#     fig, ax = plt.subplots(1, 1, figsize = (15, 5), constrained_layout=True)
    ax[0, 0 + fib].plot(x_ax, wave[:, ch], label = detect[ch])
    ax[0, 0 + fib].set_title(detect[ch] + fibers[fib] + ' Waveform')

#     fig, ax = plt.subplots(1, 1, figsize = (15, 5), constrained_layout=True)
    ax[1, 0 + fib].plot(x_ax, wave[:, ch], label = detect[ch])
    ax[1, 0 + fib].plot(x_ax_peak, peak, label='signal')
    ax[1, 0 + fib].plot(x_ax_pre, pre_base, label = 'noise')
    ax[1, 0 + fib].plot(x_ax_post, post_base, label = 'noise')
    ax[1, 0 + fib].legend(loc = 'best')
    ax[1, 0 + fib].set_title('Waveform identification')



    #____________________________________________________________________________________________________________________
    #_________________________________Integral___________________________________________________________________________
    #____________________________________________________________________________________________________________________

    peak_integr = []
    peak_integr_pos = []

    for frame in range(n_frames):


    #_________baseline_________________________________________________

        wave = waveform[frame*n_points: (frame + 1)*n_points].copy()
        x_ax = wave[:, 0]


        t0 = t1 + int(np.where(wave[:, ch][t1 : t2] == wave[:, ch][t1 : t2].min())[0][0])

        pre_base = wave[:, ch][:t0 - dt_izq].copy()
        x_ax_pre = x_ax[:t0 - dt_izq].copy()

        post_base = wave[:, ch][t0 + dt_dch:].copy()
        x_ax_post = x_ax[t0 + dt_dch:].copy()

        base = []
        base.append(pre_base.mean())
        base.append(post_base.mean())

        baseline = np.array(base).mean()
    #     print(base, baseline)

        if baseline_corrected:
            wave[:, ch] = wave[:, ch] - baseline # NOW THE WAVEFORM IS CORRECTED


    #_________integration_________________________________________________


        if integr_method == 'integrate around the peak':
            peak = wave[:, ch][t0 - dt_izq : t0 + dt_dch].copy()
            x_ax_peak = x_ax[t0 - dt_izq : t0 + dt_dch].copy()
            
            control_peak = wave[:, control_ch][t0 - dt_izq : t0 + dt_dch].copy()

            
        if integr_method == 'integrate in a fixed window t1-t2':  
            peak = wave[:, ch][t1 : t2].copy()
            x_ax_peak = x_ax[t1 : t2].copy()
            
            control_peak = wave[:, control_ch][t1 : t2].copy()
            
            
        if integr_method == 'integrate ALL waveform':
            peak = wave[:, ch].copy()
            x_ax_peak = x_ax.copy()
            
            control_peak = wave[:, control_ch].copy()


            
        integr = np.trapz(peak, x=x_ax_peak)
        control_integr = np.trapz(control_peak, x=x_ax_peak)

        peak_integr.append(integr/control_integr) # normalized to the control PMT
        peak_integr_pos.append([integr, frame])

    #     print(frame)

    peak_integr = np.array(peak_integr)
    peak_integr_pos = np.array(peak_integr_pos)

    # peak_integr.mean()
    # peak_integr
    # peak_integr_pos 
    
    
    
    #_________plot_settings_________________________________________________

    # fig, ax = plt.subplots(1, 1, figsize = (15, 5), constrained_layout=True)
    # ax.plot(x_ax, waveform[frame], label = 'calib PMT')
    # ax.plot(x_ax_pre, pre_base, label = 'PMT noise')
    # ax.plot(x_ax_post, post_base, label = 'PMT noise')
    # ax.plot(x_ax, wave, label = 'Leire\'s PMT corrected by baseline')
    # ax.plot(x_ax_peak, peak, label='signal')

    # ax.set_ylabel('mV')
    # ax.set_xlabel('Index')
    # ax.set_title('LED pulse at 1.47V, 2us, 5%df')
    # ax.text(0.05, .1, 'LED at 992mV, frame %s'%(frame), 
    #         transform=ax.transAxes, # to use (x,y) pos with relative values to the axis and not absolute data points
    #         fontsize=15, verticalalignment='top', fontfamily='serif',
    #         bbox=dict(facecolor='1.', edgecolor='none', pad=3.0))
    # ax.legend(loc = 'best')



    #____________________________________________________________________________________________________________________
    #_________________________________Integrals_distribution_____________________________________________________________
    #____________________________________________________________________________________________________________________

#     fig, ax = plt.subplots(1, 1, figsize = (15, 5), constrained_layout=True)

    # events, bins, bars = plt.hist(peak_integr, 50, density=False, range=(-750, -550), label='Integral distribution')
    events, bins, bars = ax[2, fib].hist(peak_integr, 50, density=True, label='Negative Integral distribution', 
                                  histtype='step')
    x_ax = np.linspace(bins.min(), bins.max(), len(bins)-1)

    # # sum of gaussians fit
   
    # popt, pcov = scipy.optimize.curve_fit(gauss_sum, x_ax, events, bounds=([0, -1, 1, 0, -1, 1], 
    #                                                                        [np.inf, 1e2, 1e2, np.inf, 1e2, 1e2])) 
    # a = np.zeros(n_pe); mu = np.zeros(n_pe); sigma = np.zeros(n_pe)

    # a[0], mu[0], sigma[0], a[1], mu[1], sigma[1] = popt
    # best_fit_line = gauss_sum(x_ax, a[0], mu[0], sigma[0], a[1], mu[1], sigma[1])

    
    # gaussian fit
    
    # popt, pcov = scipy.optimize.curve_fit(gauss, x_ax, events, bounds=([0, 0, 1], [np.inf, 3e3, 1e2])) 
    popt, pcov = scipy.optimize.curve_fit(gauss, x_ax, events, p0=[1, bins.mean(), 1e2]) 

        
#     if ch == 3:
#         popt, pcov = scipy.optimize.curve_fit(gauss, x_ax, events, p0=[1, 1300, 1e2])

    a, mu, sigma = popt
    best_fit_line = gauss(x_ax, a, mu, sigma)

    #_________plot_settings_________________________________________________

    # ax.plot(x_ax, best_fit_line, label='Sum of gaussian fit')
    # ax.plot(x_ax, gauss(x_ax, a[0], mu[0], sigma[0]), '-', label='$\mu$ = %.2f, $\sigma$ = %.2f'%(mu[0], sigma[0]))
    # ax.plot(x_ax, gauss(x_ax, a[1], mu[1], sigma[1]), '-y', label='$\mu$ = %.2f, $\sigma$ = %.2f'%(mu[1], sigma[1]))
    ax[2, fib].plot(x_ax, gauss(x_ax, a, mu, sigma), '-', label='$\mu$ = %.2f, $\sigma$ = %.2f'%(mu, sigma))

    ax[2, fib].set_ylabel('Counts')
    ax[2, fib].set_xlabel('Peak_integral_signal/Peak_integral_control')

    ax[2, fib].text(0.05, .9, detect[ch] + fibers[fib], transform=ax[2, fib].transAxes,
                fontsize=15, verticalalignment='top', fontfamily='serif',
                bbox=dict(facecolor='1.', edgecolor='none', pad=3.0))

#     ax[2, fib].legend(fontsize=10, loc='best')
    ax[2, fib].legend(fontsize=10, loc='right')

    print(detect[ch] + fibers[fib])
    print('Amplification = ', '%.2f'%(a))
    print('Mean value = ', '%.2f'%mu)
    print('Std = %.2f \n'%(sigma))

    signal[fib] = mu
# Out:
# PMT without fibers
# Amplification =  1.04
# Mean value =  2.63
# Std = 0.06
#
# PMT with fibers
# Amplification =  1.04
# Mean value =  0.96
# Std = 0.03

# %% [markdown]
# # Efficiency

# %%
QE = {'LED':0.13, 'Y11':0.18} # Quantum efficiency without and with fibers

fib_area = n_fibers*36
pmt_area = 18*18

n_photon_led = signal[0]/(QE['LED']*pmt_area)
n_photon_fib = signal[1]/(QE['Y11']*fib_area)


eff = QE['Y11']*n_photon_fib/n_photon_led

# %%
print(detect[ch] + ' with fibers efficiency = %.2f %%'%(eff*100))
print('Baseline corrected:', baseline_corrected)
print('Integration method:', integr_method)
# Out:
# PMT with fibers efficiency = 1.19 %
# Baseline corrected: False
# Integration method: integrate ALL waveform

# %% [markdown]
# # Timer

# %%
tf = time.perf_counter()
print('Code timer: %.2f'%(tf-t0))
# Out:
# Code timer: 28435.03
