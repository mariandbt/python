# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy
from scipy import stats
import os

# %%
path = '/home/investigator/mariandbt/python/data/'
filename = os.path.join(path, 'Acq_dig2-192.168.0.254_CH2-19.txt')

with open(filename) as f:
    data = np.loadtxt(f)

# %%
# data

# %% [markdown]
# ### Data mean

# %%
fig, ax = plt.subplots(1,1, constrained_layout=True)
    
ax.plot(np.mean(data, axis=0))
# ax.plot(data[0])
ax.set_aspect('equal')

# %% [markdown]
# #### Peak between 200 and 400 of the mean

# %%
fig, ax = plt.subplots(1,1, constrained_layout=True)
    
# ax.plot(np.mean(data, axis=0))
ax.plot(np.mean(data, axis=0)[200:400])
# ax.plot(data[120])
# ax.plot(data[0][600:800])
ax.set_aspect('equal')

# %%
! pwd
# Out:
# /home/investigator/mariandbt/python/notebooks

# %% [markdown]
# ### Negative Gaussian fit for ONE peak (region) of ONE frame (data slice)

# %% [raw]
# In order to obtain the peaks min we don't actually need a specific x-axis, so we'll just work with the default one that corresponds to the data position in the array (no need to change it to actual time units)

# %%
# data[:][200:400]

# %%
# Fitting distributions to define

# note: pdf are normilized to 1 so we have yo add an amplitude param

def gauss_neg(x, a,  mu, sigma):
    return -a*stats.norm.pdf(x, mu, sigma)

# %%
fig, ax = plt.subplots(1,1, constrained_layout=True)

data_slice = data[0]
data_region = data_slice[200*1:200*(1+1)]
x_ax = range(len(data_region))

ax.plot(data_region)
# ax.plot(data[0])
ax.set_aspect('equal')

# negative gaussian fit
popt, pcov = scipy.optimize.curve_fit(gauss_neg, x_ax, data_region) 
# popt, pcov = scipy.optimize.curve_fit(gauss_neg, range(len(data_region)), data_slice, p0=[3e6, 1e4, 5e2]) 
a, mu, sigma = popt
best_fit_line = gauss_neg(x_ax, a, mu, sigma)


plt.plot(x_ax, best_fit_line, label='gaussian fit')
plt.legend(fontsize=10, loc='best')

# %%
mu, sigma, best_fit_line.min()
# Out:
# (58.84789797990774, 5.122595203065702, -638.1870726023687)

# %% [markdown]
# ### Negative Gaussian fit for the THREE peaks (regions) of ONE frame (data slice)

# %%
# fig = plt.figure(figsize=(13,10))
fig = plt.figure()
data_slice = data[980]
offset = 220

for i in range(1, 4):
    ax = plt.subplot(1, 3, i)

    data_region = data_slice[offset*i:offset*(i+1)]
    x_ax = range(len(data_region))

    ax.plot(data_region)
    # ax.plot(data[0])
    ax.set_aspect('equal')

    # negative gaussian fit
    popt, pcov = scipy.optimize.curve_fit(gauss_neg, x_ax, data_region) 
    # popt, pcov = scipy.optimize.curve_fit(gauss_neg, range(len(data_region)), data_slice, p0=[3e6, 1e4, 5e2]) 
    a, mu, sigma = popt
    best_fit_line = gauss_neg(x_ax, a, mu, sigma)


    ax.plot(x_ax, best_fit_line, label='gaussian fit')
    ax.legend(fontsize=10, loc='best')

# %%
a, mu, sigma
# Out:
# (6785.735428342527, 98.03296002759788, 4.99433942296199)

# %% [markdown]
# ### Negative Gaussian fit for the THREE peaks (regions) of ONE frame (data slice): test for different slices

# %% [markdown]
# #### To obtain the correct fit, the regions where we do it have to be adjusted in some cases, that's why we manually introduce 'offset'

# %%
data_slice[np.where(data_slice == data_slice[200:400].min())]
# Out:
# array([-575.723])

# %%
np.where(data_slice == data_slice[200:400].min())[0][0]
# Out:
# 259

# %%
fig, ax = plt.subplots(1,1, constrained_layout=True)

data_slice = data[1354]
data_slice = data[1215]
data_slice = data[536]
data_slice = data[280]
data_slice = data[380]
ax.plot(data_slice)
ax.set_aspect('equal')

# offset = 215
# offset = 213
# offset = 210

for i in range(1, 4):

#     data_region = data_slice[220*i:200*(i+1)]
#     data_region = data_slice[220*i:220*(i+1)]
    offset = int(np.where(data_slice == data_slice[200*i:200*(i+1)].min())[0])
    data_region = data_slice[offset - 12:offset + 12]
    x_ax = range(len(data_region))

    # negative gaussian fit
    popt, pcov = scipy.optimize.curve_fit(gauss_neg, x_ax, data_region) 
#     popt, pcov = scipy.optimize.curve_fit(gauss_neg, range(len(data_region)), data_region, p0=[3e6, 1e4, 5e2]) 
    a, mu, sigma = popt
    best_fit_line = gauss_neg(x_ax, a, mu, sigma)

#     x_ax = range(220*i, len(data_region) + 220*i)
#     x_ax = range(offset*i, len(data_region) + offset*i)
    x_ax = range(offset - 12, len(data_region) + offset - 12)

    ax.plot(x_ax, best_fit_line, label='gaussian fit: min = %.2f mV' %(best_fit_line.min()))
    ax.legend(fontsize=10, loc='best')

# %%
fig, ax = plt.subplots(1,1, constrained_layout=True)

# data_slice = data[1354]
# data_slice = data[1215]
data_slice = data[536]
# data_slice = data[280]
# data_slice = data[380]
ax.plot(data_slice)
ax.set_aspect('equal')

# offset = 215
# offset = 213
offset = 210

for i in range(1, 4):

#     data_region = data_slice[220*i:200*(i+1)]
#     data_region = data_slice[220*i:220*(i+1)]
    data_region = data_slice[offset*i:offset*(i+1)]
    x_ax = range(len(data_region))

    # negative gaussian fit
    popt, pcov = scipy.optimize.curve_fit(gauss_neg, x_ax, data_region) 
#     popt, pcov = scipy.optimize.curve_fit(gauss_neg, range(len(data_region)), data_region, p0=[3e6, 1e4, 5e2]) 
    a, mu, sigma = popt
    best_fit_line = gauss_neg(x_ax, a, mu, sigma)

#     x_ax = range(220*i, len(data_region) + 220*i)
    x_ax = range(offset*i, len(data_region) + offset*i)

    ax.plot(x_ax, best_fit_line, label='gaussian fit: min = %.2f mV' %(best_fit_line.min()))
    ax.legend(fontsize=10, loc='best')

# %% [markdown]
# #### We now introduce a dinamyc offset that changes when the fit is not correct (min > -100mV) to find a better fit

# %%
fig, ax = plt.subplots(1,1, constrained_layout=True)

data_slice = data[1751]
ax.plot(data_slice)
ax.set_aspect('equal')

gauss_min = []

for i in range(1, 4):
    
    offset = 205
#     offset = 250
    best_min = 0.

#     while best_min > -100.:
    while best_min > -200.:
        
        print(i, offset)
        
        data_region = data_slice[offset*i:offset*(i+1)]
        x_ax = range(len(data_region))

        # negative gaussian fit
        popt, pcov = scipy.optimize.curve_fit(gauss_neg, x_ax, data_region) 
#         popt, pcov = scipy.optimize.curve_fit(gauss_neg, range(len(data_region)), data_region, p0=[3e6, 1e4, 5e2]) 
        a, mu, sigma = popt
        best_fit_line = gauss_neg(x_ax, a, mu, sigma)

        x_ax = range(offset*i, len(data_region) + offset*i)
    
        best_min = best_fit_line.min()
        offset = offset + 10

    gauss_min.append(best_min)
    
    ax.plot(x_ax, best_fit_line, label='gaussian fit: min = %.2f mV' %(best_min))
    ax.legend(fontsize=10, loc='best')
    
gauss_min = np.array(gauss_min)
# Out:
# 1 205
# 2 205
# 3 205
# 3 215
# 3 225
# 3 235

# %%
np.shape(data), len(data)
# Out:
# ((2909, 1000), 2909)

# %% [markdown]
# ### Negative Gaussian fit for the THREE peaks (regions) of ALL frames (data)

# %%
gauss_min = []
gauss_peak_pos = []

for j in range(len(data)):
    

    data_slice = data[j]

    for i in range(1, 4):

        offset = 205
        best_min = 0.

        while best_min > -100.:

#             print(j, i, offset)

            data_region = data_slice[offset*i:offset*(i+1)]
            x_ax = range(len(data_region))

            # negative gaussian fit
            popt, pcov = scipy.optimize.curve_fit(gauss_neg, x_ax, data_region) 
#             popt, pcov = scipy.optimize.curve_fit(gauss_neg, range(len(data_region)), data_region, p0=[3e6, 1e4, 5e2]) 
            a, mu, sigma = popt
            best_fit_line = gauss_neg(x_ax, a, mu, sigma)

            x_ax = range(offset*i, len(data_region) + offset*i)

            best_min = best_fit_line.min()
            offset = offset + 10

        gauss_min.append(best_min)
        gauss_peak_pos.append(j)

    
gauss_min = np.array(gauss_min)
gauss_peak_pos = np.array(gauss_peak_pos)

# fig, ax = plt.subplots(1,1, constrained_layout=True)
# ax.plot(data_slice)
# ax.set_aspect('equal')

# ax.plot(x_ax, best_fit_line, label='gaussian fit: min = %.2f mV' %(best_min))
# ax.legend(fontsize=10, loc='best')

# %%
gauss_min = []
gauss_peak_pos = []

for j in range(len(data)):
    

    data_slice = data[j]

    for i in range(1, 4):

#         data_region = data_slice[220*i:200*(i+1)]
#         data_region = data_slice[220*i:220*(i+1)]
#         offset = int(np.where(data_slice == data_slice[200*i:200*(i+1)].min())[0])
        offset = np.where(data_slice == data_slice[200*i:200*(i+1)].min())[0]
        offset = offset[np.where((offset > 200*i) & (offset < 200*(i+1)))][0]    
        print(j, i, offset)
        
        data_region = data_slice[offset - 12:offset + 12]
        x_ax = range(len(data_region))

        # negative gaussian fit
        popt, pcov = scipy.optimize.curve_fit(gauss_neg, x_ax, data_region) 
#         popt, pcov = scipy.optimize.curve_fit(gauss_neg, range(len(data_region)), data_region, p0=[3e6, 1e4, 5e2]) 
        a, mu, sigma = popt
        best_fit_line = gauss_neg(x_ax, a, mu, sigma)

#         x_ax = range(220*i, len(data_region) + 220*i)
#         x_ax = range(offset*i, len(data_region) + offset*i)
        x_ax = range(offset - 12, len(data_region) + offset - 12)

        ax.plot(x_ax, best_fit_line, label='gaussian fit: min = %.2f mV' %(best_fit_line.min()))
        ax.legend(fontsize=10, loc='best')

        best_min = best_fit_line.min()

        gauss_min.append(best_min)
        gauss_peak_pos.append(j)

    
gauss_min = np.array(gauss_min)
gauss_peak_pos = np.array(gauss_peak_pos)

# fig, ax = plt.subplots(1,1, constrained_layout=True)
# ax.plot(data_slice)
# ax.set_aspect('equal')

# ax.plot(x_ax, best_fit_line, label='gaussian fit: min = %.2f mV' %(best_min))
# ax.legend(fontsize=10, loc='best')
# Out:
# 0 1 258
# 0 2 509
# 0 3 759
# 1 1 259
# 1 2 508
# 1 3 760
# 2 1 259
# 2 2 509
# 400 3 759
# 401 1 258
# 401 2 510
# 401 3 758
# 402 1 258
# 402 2 509
# 402 3 759
# 403 1 259
# 403 2 509
# 403 3 759
# 404 1 259
# 404 2 510
# 404 3 759
# 405 1 259
# 405 2 510
# 405 3 759
# 406 1 259
# 406 2 508
# 406 3 759
# 407 1 260
# 407 2 509
# 407 3 758
# 408 1 259
# 408 2 509
# 408 3 758
# 409 1 259
# 409 2 508
# 409 3 759
# 410 1 259
# 410 2 509
# 410 3 759
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [101], in <cell line: 4>()
#      29 x_ax = range(offset - 12, len(data_region) + offset - 12)
#      31 ax.plot(x_ax, best_fit_line, label='gaussian fit: min = %.2f mV' %(best_fit_line.min()))
# ---> 32 ax.legend(fontsize=10, loc='best')
#      34 best_min = best_fit_line.min()
#      36 gauss_min.append(best_min)
#
# File ~/miniconda/envs/IC-3.8-2022-04-13/lib/python3.8/site-packages/matplotlib/axes/_axes.py:290, in Axes.legend(self, *args, **kwargs)
#     288 if len(extra_args):
#     289     raise TypeError('legend only accepts two non-keyword arguments')
# --> 290 self.legend_ = mlegend.Legend(self, handles, labels, **kwargs)
#     291 self.legend_._remove_method = self._remove_legend
#     292 return self.legend_
#
# File ~/miniconda/envs/IC-3.8-2022-04-13/lib/python3.8/site-packages/matplotlib/legend.py:503, in Legend.__init__(self, parent, handles, labels, loc, numpoints, markerscale, markerfirst, scatterpoints, scatteryoffsets, prop, fontsize, labelcolor, borderpad, labelspacing, handlelength, handleheight, handletextpad, borderaxespad, columnspacing, ncol, mode, fancybox, shadow, title, title_fontsize, framealpha, edgecolor, facecolor, bbox_to_anchor, bbox_transform, frameon, handler_map)
#     500 self._set_artist_props(self.legendPatch)
#     502 # init with null renderer
# --> 503 self._init_legend_box(handles, labels, markerfirst)
#     505 tmp = self._loc_used_default
#     506 self._set_loc(loc)
#
# File ~/miniconda/envs/IC-3.8-2022-04-13/lib/python3.8/site-packages/matplotlib/legend.py:769, in Legend._init_legend_box(self, handles, labels, markerfirst)
#     766         text_list.append(textbox._text)
#     767         # Create the artist for the legend which represents the
#     768         # original artist/handle.
# --> 769         handle_list.append(handler.legend_artist(self, orig_handle,
#     770                                                  fontsize, handlebox))
#     771         handles_and_labels.append((handlebox, textbox))
#     773 if handles_and_labels:
#     774     # We calculate number of rows in each column. The first
#     775     # (num_largecol) columns will have (nrows+1) rows, and remaining
#     776     # (num_smallcol) columns will have (nrows) rows.
#
# File ~/miniconda/envs/IC-3.8-2022-04-13/lib/python3.8/site-packages/matplotlib/legend_handler.py:114, in HandlerBase.legend_artist(self, legend, orig_handle, fontsize, handlebox)
#      90 """
#      91 Return the artist that this HandlerBase generates for the given
#      92 original artist/handle.
#    (...)
#     107
#     108 """
#     109 xdescent, ydescent, width, height = self.adjust_drawing_area(
#     110          legend, orig_handle,
#     111          handlebox.xdescent, handlebox.ydescent,
#     112          handlebox.width, handlebox.height,
#     113          fontsize)
# --> 114 artists = self.create_artists(legend, orig_handle,
#     115                               xdescent, ydescent, width, height,
#     116                               fontsize, handlebox.get_transform())
#     118 # create_artists will return a list of artists.
#     119 for a in artists:
#
# File ~/miniconda/envs/IC-3.8-2022-04-13/lib/python3.8/site-packages/matplotlib/legend_handler.py:241, in HandlerLine2D.create_artists(self, legend, orig_handle, xdescent, ydescent, width, height, fontsize, trans)
#     238 legline.set_drawstyle('default')
#     239 legline.set_marker("")
# --> 241 legline_marker = Line2D(xdata_marker, ydata[:len(xdata_marker)])
#     242 self.update_prop(legline_marker, orig_handle, legend)
#     243 legline_marker.set_linestyle('None')
#
# File ~/miniconda/envs/IC-3.8-2022-04-13/lib/python3.8/site-packages/matplotlib/lines.py:310, in Line2D.__init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     276 def __init__(self, xdata, ydata,
#     277              linewidth=None,  # all Nones default to rc
#     278              linestyle=None,
#    (...)
#     295              **kwargs
#     296              ):
#     297     """
#     298     Create a `.Line2D` instance with *x* and *y* data in sequences of
#     299     *xdata*, *ydata*.
#    (...)
#     308
#     309     """
# --> 310     super().__init__()
#     312     #convert sequences to numpy arrays
#     313     if not np.iterable(xdata):
#
# File ~/miniconda/envs/IC-3.8-2022-04-13/lib/python3.8/site-packages/matplotlib/artist.py:133, in Artist.__init__(self)
#     131 self._sketch = mpl.rcParams['path.sketch']
#     132 self._path_effects = mpl.rcParams['path.effects']
# --> 133 self._sticky_edges = _XYPair([], [])
#     134 self._in_layout = True
#
# File <string>:1, in __new__(_cls, x, y)
#
# KeyboardInterrupt:

# %%
np.where((data_slice == data_slice[200*i:200*(i+1)].min()))[0][0]
# offset = np.where((data_slice == data_slice[200*i:200*(i+1)].min()))[0]
offset = np.where((data_slice == data_slice[200*i:200*(i+1)].min()))
# np.where((offset > 200) & (offset < 400))
# offset = offset[np.where((offset > 200*i) & (offset < 200*(i+1)))][0]
offset
# Out:
# (array([  9, 258]),)

# %%
offset, gauss_min, len(gauss_min)
# Out:
# (215,
#  array([-638.18611471, -518.18775908, -518.56670447, ..., -445.66032558,
#         -472.15724728, -477.11542996]),
#  8727)

# %%
gauss_min.mean()
# Out:
# -502.7946200811561

# %%
gauss_peak_pos[np.where(gauss_min > -200.)], len(gauss_peak_pos[np.where(gauss_min > -200.)])
# Out:
# (array([ 231, 1590, 1751, 1964, 2341]), 5)

# %%
gauss_min[np.where(gauss_min > -200.)], len(gauss_min[np.where(gauss_min > -200.)])
# Out:
# (array([-103.81574712, -106.0566449 , -107.23762476, -101.16478497,
#         -123.89309114]),
#  5)

# %%
np.where(gauss_min > -300.)
# Out:
# (array([ 131,  177,  352,  581,  600,  607,  686,  693,  773,  862, 1091,
#         1151, 1331, 1577, 1755, 2014, 2033, 2059, 2087, 2318, 2625, 2750,
#         2924, 3106, 3183, 3207, 3316, 3328, 3435, 3461, 3505, 3549, 3696,
#         3815, 4153, 4359, 4441, 4625, 4665, 4751, 4770, 4826, 4984, 5024,
#         5092, 5141, 5255, 5393, 5504, 5627, 5719, 5894, 6141, 6174, 6354,
#         6463, 7002, 7023, 7040, 7059, 7082, 7216, 7306, 7606, 7707, 7791,
#         7795, 7803, 7992, 8378, 8421, 8671]),)
