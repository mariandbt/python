# %% [markdown]
# <h1> ______________________________________ </h1>
#
# <h1> Full NEXT100 with fiber panels simulation mapping analysis </h1>
# <h1> ______________________________________ </h1>
#
# <p style="font-size: 17px; color: black;"> In this Notebook we take as input the maps created in the previous notebook and use it to simulate an s2 signal for bb0nu events. </p>

# %% [markdown]
# <h1> ____________ </h1>
# <h2> This version </h2>
# <h1> ____________ </h1>
#
# -  <p style="font-size: 17px; color: black;"> 100 bb0nu events. </p>
# -  <p style="font-size: 17px; color: black;"> Mapping separated by sensors. </p>
#
# -  <p style="font-size: 17px; color: black;"> Geant4 fundamental units: </p>
#
#  -  <p style="font-size: 17px; color: black;"> Length [L]: mm (milimeter) </p>
#  -  <p style="font-size: 17px; color: black;"> Time [T]: ns (nanosecond) </p>
#  -  <p style="font-size: 17px; color: black;"> Energy [E]: MeV (megaelectronvolt) </p>

# %%
import numpy              as np
import pandas             as pd

import scipy              
from scipy                import stats, integrate
from scipy.signal         import convolve

import matplotlib.pyplot  as plt

from matplotlib.ticker    import FormatStrFormatter # to set the format of the plot's axis
from matplotlib.patches   import Rectangle # To add blanck spaces in tabular legends

import os
import math
import tables             as tb

# %% [markdown]
# <h1> __________________________ </h1>
# <h2> Read files </h2>

# %% [markdown]
# -  <p style="font-size: 17px; color: black;"> <b> S2 table </b> </p>

# %%
path = '/home/investigator/mariandbt/python/data'
path = path + '/20231025_NEXT100_full_mapping'

filename = os.path.join(path, "s2_table.h5")


# with tb.open_file(filename) as file:
#     print(file)

# %%
import h5py

# Load the 3D dictionary from the HDF5 file
loaded_data_dict = {}

columns = {0:'bin_initial_x',
           1:'bin_final_x',
           2:'bin_initial_y',
           3:'bin_final_y',
           4:'s2'
          }

with h5py.File(filename, 'r') as file:
    for table_id in file.keys():
        # Get the column names from the HDF5 attributes
        loaded_data_dict[table_id] = pd.DataFrame(file[table_id][:])
        loaded_data_dict[table_id].rename(columns = columns, inplace=True)

# %%
s2_table = loaded_data_dict.copy()

# %%
# s2_table.keys()

# %% [markdown]
# -  <p style="font-size: 17px; color: black;"> <b> bb0nu </b> </p>

# %%
path = '/home/investigator/mariandbt/python/data'
path = path + '/20231025_NEXT100_full_mapping'

# filename = os.path.join(path, "Next100_bb.next.h5")
bb_filename = os.path.join(path, "Next100_bb_100ev.next.h5")

# %%
with tb.open_file(bb_filename) as file:
    print(file)
# Out:
# /home/investigator/mariandbt/python/data/20231025_NEXT100_full_mapping/Next100_bb_100ev.next.h5 (File) ''
# Last modif.: '2023-12-19T09:20:41+00:00'
# Object Tree:
# / (RootGroup) ''
# /MC (Group) ''
# /MC/configuration (Table(46,)) ''
# /MC/hits (Table(74189,)) ''
# /MC/particles (Table(9821806,)) ''
# /MC/sns_positions (Table(2640,)) ''
# /MC/sns_response (Table(130556,)) ''

# %%
# %%timeit # WITH THIS YOU'RE ONLY TIMING, BUT IT DOESN'T REALLY RUN THE COMMANDS YOU TIME
bb_data = pd.read_hdf(bb_filename, "/MC/sns_response")


bb_dst = bb_data.copy()

# %%
# we select the positions of the sensors at the end of the fibers
bb_sensors = pd.read_hdf(bb_filename, "/MC/sns_positions", where='sensor_name == F_SENSOR')

sens_fibers = bb_sensors.copy() # get the positions of said sensors
# Out:
# /home/investigator/miniconda3/envs/IC-3.8-2022-04-13/lib/python3.8/site-packages/pandas/io/pytables.py:3523: IncompatibilityWarning:
# where criteria is being ignored as this version [0.0.0] is too old (or
# not-defined), read the file in and write it out to a new file to upgrade (with
# the copy_to method)
#
#   warnings.warn(ws, IncompatibilityWarning)

# %%
# # we select the information of the ionization electrons only

# n_events = 100
# bb_ie_dict = {}

# chunksize = int(2e5)
# start = 0

# for ii, ev in enumerate(range(n_events)):
    
#     print(int(ii*100/n_events) + 1, ' %')
#     stop = start + chunksize

#     bb_particles = pd.read_hdf(bb_filename, "/MC/particles", 
#                                start = start, stop = stop, 
#                                low_memory=True)
    
#     bb_ie = bb_particles.groupby('event_id').get_group(ev).copy()
#     bb_ie = bb_ie.loc[bb_ie.particle_name == 'ie-']
    
#     if len(bb_ie) > 0:
#         bb_ie_dict[ev] = bb_ie

#     start = start + bb_particles.groupby('event_id').get_group(ev).index.max() - 1

# %%
# bb_ie_dict[0]

# %% [markdown]
# <h1> __________________________ </h1>
# <h2> Global parameters </h2>

# %%
n_panels = 18
n_sensors = 90
dtheta = 2*np.pi/n_panels # rad

dpos = int(n_sensors/n_panels) # number of sensors in 1 panel

# %%
chunksize = int(2e5) # aprox length of an event to read the tables

# %%
# s2 map specs

s2_tab = s2_table[f'sens_200'] # all maps have the same specs, so we get whichever

x_nbins, y_nbins = len(s2_tab.bin_initial_x.unique()), len(s2_tab.bin_initial_y.unique())

x_bin_width = (s2_tab.bin_final_x - s2_tab.bin_initial_x)[0]
y_bin_width = (s2_tab.bin_final_y - s2_tab.bin_initial_y)[0]

x_min = s2_tab.bin_initial_x.min()
y_min = s2_tab.bin_initial_y.min()

x_max = s2_tab.bin_final_x.max()
y_max = s2_tab.bin_final_y.max()

# %% [markdown]
# <h1> __________________________ </h1>
# <h2> Functions </h2>

# %%
def sens_map(selected_id):
    
    # we select the response of the sensors at the end of the fibers
    pp = '/home/investigator/mariandbt/python/data'
    pp = pp + '/20231025_NEXT100_full_mapping'

    flnm = os.path.join(pp, "Next100_full_mapp_s2_inicioEL_100Kev.next.h5")
    sens = pd.read_hdf(flnm, "/MC/sns_positions")
    dst_particle = pd.read_hdf(flnm, "/MC/particles")

    fig, ax = plt.subplots(nrows = 1, ncols = 1, figsize=(10,10), constrained_layout=True)
    
    ax.plot(dst_particle.initial_x, dst_particle.initial_y, 'o')


    fiber_sens_mask = sens.loc[sens.sensor_name == 'F_SENSOR'].sensor_id # ID mask of the sensors at the end of the fibers

    sens_fibers = sens.loc[sens.sensor_id.isin(fiber_sens_mask)] # get the positions of said sensors

    font_size = 11
    ax.plot(sens_fibers.x, sens_fibers.y, 'o', markersize = 2*font_size)

    for sens_id in sens_fibers.sensor_id:
        xx = float(sens_fibers.loc[sens_fibers.sensor_id == sens_id].x)
        yy = float(sens_fibers.loc[sens_fibers.sensor_id == sens_id].y)

        ax.annotate(f'{sens_id:.0f}', (xx, yy),
                    color='black', ha='center', va='center', fontsize = font_size)

    if selected_id in sens_fibers.sensor_id.values:
        ax.plot(sens_fibers.loc[sens_fibers.sensor_id == selected_id].x, 
                sens_fibers.loc[sens_fibers.sensor_id == selected_id].y, 'o', 
                markersize = 2*font_size, label = 'Selected sensor')

        ax.legend(loc = (.4, .6))

    else:
        ax.annotate('Not (valid) sensor ID selected', (0, 100),
                    color='black', ha='center', va='center', fontsize = font_size)

# %%
def find_rot(alpha):
    rot = -10

    while not ((alpha < (dtheta/2 + dtheta*rot)) & 
               (alpha > (-dtheta/2 + dtheta*rot))):
        rot += 1
        if rot > n_panels:
            print('ERROR')
            break

    return rot

# Vectorize the function
vect_find_rot = np.vectorize(find_rot)

# %%
def find_sensor(sensor_id, rot):
    
    theta = theta_dict[sensor_id]
    pos = theta_to_pos_dict[theta]

    new_pos = pos - rot*dpos
    
    if (new_pos == n_sensors/2):
        new_pos = -n_sensors/2
        
    if (new_pos > n_sensors/2):
        new_pos = new_pos%(n_sensors/2)
        
    if (new_pos < -n_sensors/2):
        new_pos = new_pos%(-n_sensors/2)
        
    new_theta = pos_to_theta_dict[new_pos]
    
    new_sens_id = sens_dict[new_theta]

    return new_sens_id

# %%
def find_s2(sens_id, part_id):
#     print(part_id)
    
    rr, alpha = rr_dict[part_id], alpha_dict[part_id]
    rot = rot_dict[part_id]
    new_xx, new_yy = new_xx_dict[part_id], new_yy_dict[part_id]

    new_sens_id = find_sensor(sens_id, rot) 
    s2_tab_matrix = s2_tab_dict[f'sens_{new_sens_id}']


    x_bin = int((new_xx - x_min)//x_bin_width)
    y_bin = int((new_yy - y_min)//y_bin_width)

    if ((new_xx < x_max) & (new_yy < y_max)):
        s2_signal = s2_tab_matrix[x_bin][y_bin]
    else:
        s2_signal = 0.

    return s2_signal

# Vectorize the function
vect_find_s2 = np.vectorize(find_s2)

# %%
def build_particle_dict(bb_ie):
    # particles
    tt_dict = dict(zip(bb_ie['particle_id'], bb_ie['final_t']))
    xx_dict = dict(zip(bb_ie['particle_id'], bb_ie['final_x']))
    yy_dict = dict(zip(bb_ie['particle_id'], bb_ie['final_y']))
    rr_dict = dict(zip(bb_ie['particle_id'], np.sqrt(bb_ie['final_x']**2 + bb_ie['final_y']**2)))
    alpha_dict = dict(zip(bb_ie['particle_id'], np.arctan2(bb_ie['final_y'], bb_ie['final_x'])))


    rr = np.array(list(rr_dict.values()))
    alpha = np.array(list(alpha_dict.values()))
    rotation = vect_find_rot(alpha)

    new_alpha = alpha - rotation * dtheta
    new_xx = rr * np.cos(new_alpha)
    new_yy = rr * np.sin(new_alpha)


    rot_dict = dict(zip(bb_ie['particle_id'], rotation))
    new_xx_dict = dict(zip(bb_ie['particle_id'], new_xx))
    new_yy_dict = dict(zip(bb_ie['particle_id'], new_yy))

    return tt_dict, xx_dict, yy_dict, rr_dict, alpha_dict, rot_dict, new_xx_dict, new_yy_dict

# %%
def find_bb_ie(start, event_id):
    
        stop = start + chunksize

        bb_particles = pd.read_hdf(bb_filename, "/MC/particles", 
                                   start = start, stop = stop, 
                                   low_memory=True)

        bb_ie = bb_particles.query(f'(event_id == {event_id}) & (particle_name == "ie-")')
        
        new_start = start + bb_particles.query(f'(event_id == {event_id})').index.max() - 1 
        
        return new_start, bb_ie

# %% [markdown]
# <h1> __________________________ </h1>
# <h2> Dictionaries </h2>

# %%
# s2 table
s2_tab_dict = {}

for sens_id in s2_table.keys():

    s2_tab = s2_table[sens_id]
    s2_matrix = s2_tab.s2.to_numpy().reshape(x_nbins, y_nbins)
    
    s2_tab_dict[sens_id] = s2_matrix

# %%
# sensors
x_dict = dict(zip(sens_fibers['sensor_id'], sens_fibers['x']))
y_dict = dict(zip(sens_fibers['sensor_id'], sens_fibers['y']))

theta_sens = np.round(np.arctan2(sens_fibers['y'], sens_fibers['x']).tolist(), 3)

theta_dict = dict(zip(sens_fibers['sensor_id'], theta_sens)) # theta vs sensor_id
sens_dict = dict(zip(theta_sens, sens_fibers['sensor_id'])) # sensor_id vs theta

theta_to_pos_dict = dict(zip(sorted(theta_sens), np.arange(int(-n_sensors/2), 
                                                           int(n_sensors/2)))) # theta vs position_id
pos_to_theta_dict = dict(zip(np.arange(int(-n_sensors/2), int(n_sensors/2)), 
                             sorted(theta_sens))) # position_id vs theta

# %% [markdown]
# <h1> __________________________ </h1>

# %% [markdown]
# <h1> __________________________ </h1>

# %% [markdown]
# <h1> __________________________ </h1>

# %%
event_id = 0
start = 0
stop = start + chunksize

bb_particles = pd.read_hdf(bb_filename, "/MC/particles", 
                           start = start, stop = stop, 
                           low_memory=True).query(f'(event_id == {event_id})')
_, bb_ie = find_bb_ie(start, event_id)

# %%
plt.plot(bb_particles.final_x, bb_particles.final_y, 'o', label = 'all particles')
plt.plot(bb_ie.final_x, bb_ie.final_y, 'o', label = 'ie⁻')
plt.plot(bb_particles.loc[bb_particles.primary == 1].final_x, 
         bb_particles.loc[bb_particles.primary == 1].final_y, 'o', label = 'primary e⁻')
plt.legend()
plt.show()

# %%
plt.plot(bb_particles.final_z, bb_particles.final_y, 'o')
plt.plot(bb_ie.final_z, bb_ie.final_y, 'o')
plt.plot(bb_particles.loc[bb_particles.primary == 1].final_z, 
         bb_particles.loc[bb_particles.primary == 1].final_y, 'o')
plt.show()

# %%
event, sens_id, part_id = 27, 244, 139

# %%
(tt_dict, xx_dict, yy_dict, 
 rr_dict, alpha_dict, 
 rot_dict, new_xx_dict, new_yy_dict) = build_particle_dict(bb_ie)

# %%
xx = xx_dict[part_id]
yy = yy_dict[part_id]
alpha = np.arctan2(yy, xx)

sens_map(sens_id)
plt.plot(bb_ie.final_x, bb_ie.final_y, 'o', label = 'full bb0nu event')

plt.plot(xx, yy, 'oy', label = 'ie⁻')

active_diam = 984 # [mm]
radius = np.linspace(0, active_diam/2, 100)
rot = find_rot(alpha)

xx_ = radius*np.cos(dtheta/2 + dtheta*(rot))
plt.plot(xx_ , xx_*np.tan(dtheta/2 + dtheta*(rot)))

xx_ = radius*np.cos(-dtheta/2 + dtheta*(rot))
plt.plot(xx_ , xx_*np.tan(-dtheta/2 + dtheta*(rot)))



plt.legend()
plt.show()

# %%
# %%timeit

# Specify the filename for the HDF5 file
filename = '../data/20231025_NEXT100_full_mapping/20231221_bb0nu_100ev_s2_signal.h5'

n_events = 100
# n_events = 2

chunksize = int(2e5)
start = 0

# Open the HDF5 file in write mode
with h5py.File(filename, 'w') as file:
    # s2_tot_dict = {}

#     for event in bb_ie_dict.keys():
    for event in range(n_events):
    # for event in [0, 1, 2]:
    #     s2_ev_dict = {}
        
        start, bb_ie = find_bb_ie(start, event)
        
        if len(bb_ie) > 0:
            
            group = file.create_group(str(event))

    #         bb_ie = bb_ie_dict[event]

            (tt_dict, xx_dict, yy_dict, 
             rr_dict, alpha_dict, 
             rot_dict, new_xx_dict, new_yy_dict) = build_particle_dict(bb_ie)

            time_data = np.array(list(tt_dict.values()))

            for jj, sens_id in enumerate(sens_fibers.sensor_id[:]):

                print(f'Sensor {jj}/{n_sensors} in event {event}')
                table_id = f'sens_{sens_id}'

                s2_data = vect_find_s2(sens_id, bb_ie['particle_id'])


                # Create the DataFrame after the loop using a dictionary
                table_data = pd.DataFrame({'time': time_data, 's2': s2_data})
        #         s2_ev_dict[table_id] = table_data
                group.create_dataset(table_id, data=table_data)

        #     s2_tot_dict[event] = s2_ev_dict
# Out:
# Sensor 0/90 in event 0
# Sensor 1/90 in event 0
# Sensor 2/90 in event 0
# Sensor 3/90 in event 0
# Sensor 4/90 in event 0
# Sensor 5/90 in event 0
# Sensor 6/90 in event 0
# Sensor 7/90 in event 0
# Sensor 8/90 in event 0
# Sensor 9/90 in event 0
# Sensor 10/90 in event 0
# Sensor 11/90 in event 0
# Sensor 12/90 in event 0
# Sensor 13/90 in event 0
# Sensor 14/90 in event 0
# Sensor 15/90 in event 0
# Sensor 16/90 in event 0
# Sensor 17/90 in event 0
# Sensor 18/90 in event 0
# Sensor 19/90 in event 0
# Sensor 20/90 in event 0
# Sensor 21/90 in event 0
# Sensor 22/90 in event 0
# Sensor 23/90 in event 0
# Sensor 24/90 in event 0
# Sensor 25/90 in event 0
# Sensor 26/90 in event 0
# Sensor 27/90 in event 0
# Sensor 28/90 in event 0
# Sensor 29/90 in event 0
# Sensor 30/90 in event 0
# Sensor 31/90 in event 0
# Sensor 32/90 in event 0
# Sensor 33/90 in event 0
# Sensor 34/90 in event 0
# Sensor 35/90 in event 0
# Sensor 36/90 in event 0
# Sensor 37/90 in event 0
# Sensor 38/90 in event 0
# Sensor 39/90 in event 0
# Sensor 40/90 in event 0
# Sensor 41/90 in event 0
# Sensor 42/90 in event 0
# Sensor 43/90 in event 0
# Sensor 44/90 in event 0
# Sensor 45/90 in event 0
# Sensor 46/90 in event 0
# Sensor 47/90 in event 0
# Sensor 48/90 in event 0
# Sensor 49/90 in event 0
# Sensor 50/90 in event 0
# Sensor 51/90 in event 0
# Sensor 52/90 in event 0
# Sensor 53/90 in event 0
# Sensor 54/90 in event 0
# Sensor 55/90 in event 0
# Sensor 56/90 in event 0
# Sensor 57/90 in event 0
# Sensor 58/90 in event 0
# Sensor 59/90 in event 0
# Sensor 60/90 in event 0
# Sensor 61/90 in event 0
# Sensor 62/90 in event 0
# Sensor 63/90 in event 0
# Sensor 64/90 in event 0
# Sensor 65/90 in event 0
# Sensor 66/90 in event 0
# Sensor 67/90 in event 0
# Sensor 68/90 in event 0
# Sensor 69/90 in event 0
# Sensor 70/90 in event 0
# Sensor 71/90 in event 0
# Sensor 72/90 in event 0
# Sensor 73/90 in event 0
# Sensor 74/90 in event 0
# Sensor 75/90 in event 0
# Sensor 76/90 in event 0
# Sensor 77/90 in event 0
# Sensor 78/90 in event 0
# Sensor 79/90 in event 0
# Sensor 80/90 in event 0
# Sensor 81/90 in event 0
# Sensor 82/90 in event 0
# Sensor 83/90 in event 0
# Sensor 84/90 in event 0
# Sensor 85/90 in event 0
# Sensor 86/90 in event 0
# Sensor 87/90 in event 0
# Sensor 88/90 in event 0
# Sensor 89/90 in event 0
# Sensor 0/90 in event 1
# Sensor 1/90 in event 1
# Sensor 2/90 in event 1
# Sensor 3/90 in event 1
# Sensor 4/90 in event 1
# Sensor 5/90 in event 1
# Sensor 6/90 in event 1
# Sensor 7/90 in event 1
# Sensor 8/90 in event 1
# Sensor 9/90 in event 1
# Sensor 10/90 in event 1
# Sensor 11/90 in event 1
# Sensor 12/90 in event 1
# Sensor 13/90 in event 1
# Sensor 14/90 in event 1
# Sensor 15/90 in event 1
# Sensor 16/90 in event 1
# Sensor 17/90 in event 1
# Sensor 18/90 in event 1
# Sensor 19/90 in event 1
# Sensor 20/90 in event 1
# Sensor 21/90 in event 1
# Sensor 22/90 in event 1
# Sensor 23/90 in event 1
# Sensor 24/90 in event 1
# Sensor 25/90 in event 1
# Sensor 26/90 in event 1
# Sensor 27/90 in event 1
# Sensor 28/90 in event 1
# Sensor 29/90 in event 1
# Sensor 30/90 in event 1
# Sensor 31/90 in event 1
# Sensor 32/90 in event 1
# Sensor 33/90 in event 1
# Sensor 34/90 in event 1
# Sensor 35/90 in event 1
# Sensor 36/90 in event 1
# Sensor 37/90 in event 1
# Sensor 38/90 in event 1
# Sensor 39/90 in event 1
# Sensor 40/90 in event 1
# Sensor 41/90 in event 1
# Sensor 42/90 in event 1
# Sensor 43/90 in event 1
# Sensor 44/90 in event 1
# Sensor 45/90 in event 1
# Sensor 46/90 in event 1
# Sensor 47/90 in event 1
# Sensor 48/90 in event 1
# Sensor 49/90 in event 1
# Sensor 50/90 in event 1
# Sensor 51/90 in event 1
# Sensor 52/90 in event 1
# Sensor 53/90 in event 1
# Sensor 54/90 in event 1
# Sensor 55/90 in event 1
# Sensor 56/90 in event 1
# Sensor 57/90 in event 1
# Sensor 58/90 in event 1
# Sensor 59/90 in event 1
# Sensor 60/90 in event 1
# Sensor 61/90 in event 1
# Sensor 62/90 in event 1
# Sensor 63/90 in event 1
# Sensor 64/90 in event 1
# Sensor 65/90 in event 1
# Sensor 66/90 in event 1
# Sensor 67/90 in event 1
# Sensor 68/90 in event 1
# Sensor 69/90 in event 1
# Sensor 70/90 in event 1
# Sensor 71/90 in event 1
# Sensor 72/90 in event 1
# Sensor 73/90 in event 1
# Sensor 74/90 in event 1
# Sensor 75/90 in event 1
# Sensor 76/90 in event 1
# Sensor 77/90 in event 1
# Sensor 78/90 in event 1
# Sensor 79/90 in event 1
# Sensor 80/90 in event 1
# Sensor 81/90 in event 1
# Sensor 82/90 in event 1
# Sensor 83/90 in event 1
# Sensor 84/90 in event 1
# Sensor 85/90 in event 1
# Sensor 86/90 in event 1
# Sensor 87/90 in event 1
# Sensor 88/90 in event 1
# Sensor 89/90 in event 1
# Sensor 0/90 in event 2
# Sensor 1/90 in event 2
# Sensor 2/90 in event 2
# Sensor 3/90 in event 2
# Sensor 4/90 in event 2
# Sensor 5/90 in event 2
# Sensor 6/90 in event 2
# Sensor 7/90 in event 2
# Sensor 8/90 in event 2
# Sensor 9/90 in event 2
# Sensor 10/90 in event 2
# Sensor 11/90 in event 2
# Sensor 12/90 in event 2
# Sensor 13/90 in event 2
# Sensor 14/90 in event 2
# Sensor 15/90 in event 2
# Sensor 16/90 in event 2
# Sensor 17/90 in event 2
# Sensor 18/90 in event 2
# Sensor 19/90 in event 2
# Sensor 20/90 in event 2
# Sensor 21/90 in event 2
# Sensor 22/90 in event 2
# Sensor 23/90 in event 2
# Sensor 24/90 in event 2
# Sensor 25/90 in event 2
# Sensor 26/90 in event 2
# Sensor 27/90 in event 2
# Sensor 28/90 in event 2
# Sensor 29/90 in event 2
# Sensor 30/90 in event 2
# Sensor 31/90 in event 2
# Sensor 32/90 in event 2
# Sensor 33/90 in event 2
# Sensor 34/90 in event 2
# Sensor 35/90 in event 2
# Sensor 36/90 in event 2
# Sensor 37/90 in event 2
# Sensor 38/90 in event 2
# Sensor 39/90 in event 2
# Sensor 40/90 in event 2
# Sensor 41/90 in event 2
# Sensor 42/90 in event 2
# Sensor 43/90 in event 2
# Sensor 44/90 in event 2
# Sensor 45/90 in event 2
# Sensor 46/90 in event 2
# Sensor 47/90 in event 2
# Sensor 48/90 in event 2
# Sensor 49/90 in event 2
# Sensor 50/90 in event 2
# Sensor 51/90 in event 2
# Sensor 52/90 in event 2
# Sensor 53/90 in event 2
# Sensor 54/90 in event 2
# Sensor 55/90 in event 2
# Sensor 56/90 in event 2
# Sensor 57/90 in event 2
# Sensor 58/90 in event 2
# Sensor 59/90 in event 2
# Sensor 60/90 in event 2
# Sensor 61/90 in event 2
# Sensor 62/90 in event 2
# Sensor 63/90 in event 2
# Sensor 64/90 in event 2
# Sensor 65/90 in event 2
# Sensor 66/90 in event 2
# Sensor 67/90 in event 2
# Sensor 68/90 in event 2
# Sensor 69/90 in event 2
# Sensor 70/90 in event 2
# Sensor 71/90 in event 2
# Sensor 72/90 in event 2
# Sensor 73/90 in event 2
# Sensor 74/90 in event 2
# Sensor 75/90 in event 2
# Sensor 76/90 in event 2
# Sensor 77/90 in event 2
# Sensor 78/90 in event 2
# Sensor 79/90 in event 2
# Sensor 80/90 in event 2
# Sensor 81/90 in event 2
# Sensor 82/90 in event 2
# Sensor 83/90 in event 2
# Sensor 84/90 in event 2
# Sensor 85/90 in event 2
# Sensor 86/90 in event 2
# Sensor 87/90 in event 2
# Sensor 88/90 in event 2
# Sensor 89/90 in event 2
# Sensor 0/90 in event 3
# Sensor 1/90 in event 3
# Sensor 2/90 in event 3
# Sensor 3/90 in event 3
# Sensor 4/90 in event 3
# Sensor 5/90 in event 3
# Sensor 6/90 in event 3
# Sensor 7/90 in event 3
# Sensor 8/90 in event 3
# Sensor 9/90 in event 3
# Sensor 10/90 in event 3
# Sensor 11/90 in event 3
# Sensor 12/90 in event 3
# Sensor 13/90 in event 3
# Sensor 14/90 in event 3
# Sensor 15/90 in event 3
# Sensor 16/90 in event 3
# Sensor 17/90 in event 3
# Sensor 18/90 in event 3
# Sensor 19/90 in event 3
# Sensor 20/90 in event 3
# Sensor 21/90 in event 3
# Sensor 22/90 in event 3
# Sensor 23/90 in event 3
# Sensor 24/90 in event 3
# Sensor 25/90 in event 3
# Sensor 26/90 in event 3
# Sensor 27/90 in event 3
# Sensor 28/90 in event 3
# Sensor 29/90 in event 3
# Sensor 30/90 in event 3
# Sensor 31/90 in event 3
# Sensor 32/90 in event 3
# Sensor 33/90 in event 3
# Sensor 34/90 in event 3
# Sensor 35/90 in event 3
# Sensor 36/90 in event 3
# Sensor 37/90 in event 3
# Sensor 38/90 in event 3
# Sensor 39/90 in event 3
# Sensor 40/90 in event 3
# Sensor 41/90 in event 3
# Sensor 42/90 in event 3
# Sensor 43/90 in event 3
# Sensor 44/90 in event 3
# Sensor 45/90 in event 3
# Sensor 46/90 in event 3
# Sensor 47/90 in event 3
# Sensor 48/90 in event 3
# Sensor 49/90 in event 3
# Sensor 50/90 in event 3
# Sensor 51/90 in event 3
# Sensor 52/90 in event 3
# Sensor 53/90 in event 3
# Sensor 54/90 in event 3
# Sensor 55/90 in event 3
# Sensor 56/90 in event 3
# Sensor 57/90 in event 3
# Sensor 58/90 in event 3
# Sensor 59/90 in event 3
# Sensor 60/90 in event 3
# Sensor 61/90 in event 3
# Sensor 62/90 in event 3
# Sensor 63/90 in event 3
# Sensor 64/90 in event 3
# Sensor 65/90 in event 3
# Sensor 66/90 in event 3
# Sensor 67/90 in event 3
# Sensor 68/90 in event 3
# Sensor 69/90 in event 3
# Sensor 70/90 in event 3
# Sensor 71/90 in event 3
# Sensor 72/90 in event 3
# Sensor 73/90 in event 3
# Sensor 74/90 in event 3
# Sensor 75/90 in event 3
# Sensor 76/90 in event 3
# Sensor 77/90 in event 3
# Sensor 78/90 in event 3
# Sensor 79/90 in event 3
# Sensor 80/90 in event 3
# Sensor 81/90 in event 3
# Sensor 82/90 in event 3
# Sensor 83/90 in event 3
# Sensor 84/90 in event 3
# Sensor 85/90 in event 3
# Sensor 86/90 in event 3
# Sensor 87/90 in event 3
# Sensor 88/90 in event 3
# Sensor 89/90 in event 3
# Sensor 0/90 in event 4
# Sensor 1/90 in event 4
# Sensor 2/90 in event 4
# Sensor 3/90 in event 4
# Sensor 4/90 in event 4
# Sensor 5/90 in event 4
# Sensor 6/90 in event 4
# Sensor 7/90 in event 4
# Sensor 8/90 in event 4
# Sensor 9/90 in event 4
# Sensor 10/90 in event 4
# Sensor 11/90 in event 4
# Sensor 12/90 in event 4
# Sensor 13/90 in event 4
# Sensor 14/90 in event 4
# Sensor 15/90 in event 4
# Sensor 16/90 in event 4
# Sensor 17/90 in event 4
# Sensor 18/90 in event 4
# Sensor 19/90 in event 4
# Sensor 20/90 in event 4
# Sensor 21/90 in event 4
# Sensor 22/90 in event 4
# Sensor 23/90 in event 4
# Sensor 24/90 in event 4
# Sensor 25/90 in event 4
# Sensor 26/90 in event 4
# Sensor 27/90 in event 4
# Sensor 28/90 in event 4
# Sensor 29/90 in event 4
# Sensor 30/90 in event 4
# Sensor 31/90 in event 4
# Sensor 32/90 in event 4
# Sensor 33/90 in event 4
# Sensor 34/90 in event 4
# Sensor 35/90 in event 4
# Sensor 36/90 in event 4
# Sensor 37/90 in event 4
# Sensor 38/90 in event 4
# Sensor 39/90 in event 4
# Sensor 40/90 in event 4
# Sensor 41/90 in event 4
# Sensor 42/90 in event 4
# Sensor 43/90 in event 4
# Sensor 44/90 in event 4
# Sensor 45/90 in event 4
# Sensor 46/90 in event 4
# Sensor 47/90 in event 4
# Sensor 48/90 in event 4
# Sensor 49/90 in event 4
# Sensor 50/90 in event 4
# Sensor 51/90 in event 4
# Sensor 52/90 in event 4
# Sensor 53/90 in event 4
# Sensor 54/90 in event 4
# Sensor 55/90 in event 4
# Sensor 56/90 in event 4
# Sensor 57/90 in event 4
# Sensor 58/90 in event 4
# Sensor 59/90 in event 4
# Sensor 60/90 in event 4
# Sensor 61/90 in event 4
# Sensor 62/90 in event 4
# Sensor 63/90 in event 4
# Sensor 64/90 in event 4
# Sensor 65/90 in event 4
# Sensor 66/90 in event 4
# Sensor 67/90 in event 4
# Sensor 68/90 in event 4
# Sensor 69/90 in event 4
# Sensor 70/90 in event 4
# Sensor 71/90 in event 4
# Sensor 72/90 in event 4
# Sensor 73/90 in event 4
# Sensor 74/90 in event 4
# Sensor 75/90 in event 4
# Sensor 76/90 in event 4
# Sensor 77/90 in event 4
# Sensor 78/90 in event 4
# Sensor 79/90 in event 4
# Sensor 80/90 in event 4
# Sensor 81/90 in event 4
# Sensor 82/90 in event 4
# Sensor 83/90 in event 4
# Sensor 84/90 in event 4
# Sensor 85/90 in event 4
# Sensor 86/90 in event 4
# Sensor 87/90 in event 4
# Sensor 88/90 in event 4
# Sensor 89/90 in event 4
# Sensor 0/90 in event 5
# Sensor 1/90 in event 5
# Sensor 2/90 in event 5
# Sensor 3/90 in event 5
# Sensor 4/90 in event 5
# Sensor 5/90 in event 5
# Sensor 6/90 in event 5
# Sensor 7/90 in event 5
# Sensor 8/90 in event 5
# Sensor 9/90 in event 5
# Sensor 10/90 in event 5
# Sensor 11/90 in event 5
# Sensor 12/90 in event 5
# Sensor 13/90 in event 5
# Sensor 14/90 in event 5
# Sensor 15/90 in event 5
# Sensor 16/90 in event 5
# Sensor 17/90 in event 5
# Sensor 18/90 in event 5
# Sensor 19/90 in event 5
# Sensor 20/90 in event 5
# Sensor 21/90 in event 5
# Sensor 22/90 in event 5
# Sensor 23/90 in event 5
# Sensor 24/90 in event 5
# Sensor 25/90 in event 5
# Sensor 26/90 in event 5
# Sensor 27/90 in event 5
# Sensor 28/90 in event 5
# Sensor 29/90 in event 5
# Sensor 30/90 in event 5
# Sensor 31/90 in event 5
# Sensor 32/90 in event 5
# Sensor 33/90 in event 5
# Sensor 34/90 in event 5
# Sensor 35/90 in event 5
# Sensor 36/90 in event 5
# Sensor 37/90 in event 5
# Sensor 38/90 in event 5
# Sensor 39/90 in event 5
# Sensor 40/90 in event 5
# Sensor 41/90 in event 5
# Sensor 42/90 in event 5
# Sensor 43/90 in event 5
# Sensor 44/90 in event 5
# Sensor 45/90 in event 5
# Sensor 46/90 in event 5
# Sensor 47/90 in event 5
# Sensor 48/90 in event 5
# Sensor 49/90 in event 5
# Sensor 50/90 in event 5
# Sensor 51/90 in event 5
# Sensor 52/90 in event 5
# Sensor 53/90 in event 5
# Sensor 54/90 in event 5
# Sensor 55/90 in event 5
# Sensor 56/90 in event 5
# Sensor 57/90 in event 5
# Sensor 58/90 in event 5
# Sensor 59/90 in event 5
# Sensor 60/90 in event 5
# Sensor 61/90 in event 5
# Sensor 62/90 in event 5
# Sensor 63/90 in event 5
# Sensor 64/90 in event 5
# Sensor 65/90 in event 5
# Sensor 66/90 in event 5
# Sensor 67/90 in event 5
# Sensor 68/90 in event 5
# Sensor 69/90 in event 5
# Sensor 70/90 in event 5
# Sensor 71/90 in event 5
# Sensor 72/90 in event 5
# Sensor 73/90 in event 5
# Sensor 74/90 in event 5
# Sensor 75/90 in event 5
# Sensor 76/90 in event 5
# Sensor 77/90 in event 5
# Sensor 78/90 in event 5
# Sensor 79/90 in event 5
# Sensor 80/90 in event 5
# Sensor 81/90 in event 5
# Sensor 82/90 in event 5
# Sensor 83/90 in event 5
# Sensor 84/90 in event 5
# Sensor 85/90 in event 5
# Sensor 86/90 in event 5
# Sensor 87/90 in event 5
# Sensor 88/90 in event 5
# Sensor 89/90 in event 5
# Sensor 0/90 in event 6
# Sensor 1/90 in event 6
# Sensor 2/90 in event 6
# Sensor 3/90 in event 6
# Sensor 4/90 in event 6
# Sensor 5/90 in event 6
# Sensor 6/90 in event 6
# Sensor 7/90 in event 6
# Sensor 8/90 in event 6
# Sensor 9/90 in event 6
# Sensor 10/90 in event 6
# Sensor 11/90 in event 6
# Sensor 12/90 in event 6
# Sensor 13/90 in event 6
# Sensor 14/90 in event 6
# Sensor 15/90 in event 6
# Sensor 16/90 in event 6
# Sensor 17/90 in event 6
# Sensor 18/90 in event 6
# Sensor 19/90 in event 6
# Sensor 20/90 in event 6
# Sensor 21/90 in event 6
# Sensor 22/90 in event 6
# Sensor 23/90 in event 6
# Sensor 24/90 in event 6
# Sensor 25/90 in event 6
# Sensor 26/90 in event 6
# Sensor 27/90 in event 6
# Sensor 28/90 in event 6
# Sensor 29/90 in event 6
# Sensor 30/90 in event 6
# Sensor 31/90 in event 6
# Sensor 32/90 in event 6
# Sensor 33/90 in event 6
# Sensor 34/90 in event 6
# Sensor 35/90 in event 6
# Sensor 36/90 in event 6
# Sensor 37/90 in event 6
# Sensor 38/90 in event 6
# Sensor 39/90 in event 6
# Sensor 40/90 in event 6
# Sensor 41/90 in event 6
# Sensor 42/90 in event 6
# Sensor 43/90 in event 6
# Sensor 44/90 in event 6
# Sensor 45/90 in event 6
# Sensor 46/90 in event 6
# Sensor 47/90 in event 6
# Sensor 48/90 in event 6
# Sensor 49/90 in event 6
# Sensor 50/90 in event 6
# Sensor 51/90 in event 6
# Sensor 52/90 in event 6
# Sensor 53/90 in event 6
# Sensor 54/90 in event 6
# Sensor 55/90 in event 6
# Sensor 56/90 in event 6
# Sensor 57/90 in event 6
# Sensor 58/90 in event 6
# Sensor 59/90 in event 6
# Sensor 60/90 in event 6
# Sensor 61/90 in event 6
# Sensor 62/90 in event 6
# Sensor 63/90 in event 6
# Sensor 64/90 in event 6
# Sensor 65/90 in event 6
# Sensor 66/90 in event 6
# Sensor 67/90 in event 6
# Sensor 68/90 in event 6
# Sensor 69/90 in event 6
# Sensor 70/90 in event 6
# Sensor 71/90 in event 6
# Sensor 72/90 in event 6
# Sensor 73/90 in event 6
# Sensor 74/90 in event 6
# Sensor 75/90 in event 6
# Sensor 76/90 in event 6
# Sensor 77/90 in event 6
# Sensor 78/90 in event 6
# Sensor 79/90 in event 6
# Sensor 80/90 in event 6
# Sensor 81/90 in event 6
# Sensor 82/90 in event 6
# Sensor 83/90 in event 6
# Sensor 84/90 in event 6
# Sensor 85/90 in event 6
# Sensor 86/90 in event 6
# Sensor 87/90 in event 6
# Sensor 88/90 in event 6
# Sensor 89/90 in event 6
# Sensor 0/90 in event 7
# Sensor 1/90 in event 7
# Sensor 2/90 in event 7
# Sensor 3/90 in event 7
# Sensor 4/90 in event 7
# Sensor 5/90 in event 7
# Sensor 6/90 in event 7
# Sensor 7/90 in event 7
# Sensor 8/90 in event 7
# Sensor 9/90 in event 7
# Sensor 10/90 in event 7
# Sensor 11/90 in event 7
# Sensor 12/90 in event 7
# Sensor 13/90 in event 7
# Sensor 14/90 in event 7
# Sensor 15/90 in event 7
# Sensor 16/90 in event 7
# Sensor 17/90 in event 7
# Sensor 18/90 in event 7
# Sensor 19/90 in event 7
# Sensor 20/90 in event 7
# Sensor 21/90 in event 7
# Sensor 22/90 in event 7
# Sensor 23/90 in event 7
# Sensor 24/90 in event 7
# Sensor 25/90 in event 7
# Sensor 26/90 in event 7
# Sensor 27/90 in event 7
# Sensor 28/90 in event 7
# Sensor 29/90 in event 7
# Sensor 30/90 in event 7
# Sensor 31/90 in event 7
# Sensor 32/90 in event 7
# Sensor 33/90 in event 7
# Sensor 34/90 in event 7
# Sensor 35/90 in event 7
# Sensor 36/90 in event 7
# Sensor 37/90 in event 7
# Sensor 38/90 in event 7
# Sensor 39/90 in event 7
# Sensor 40/90 in event 7
# Sensor 41/90 in event 7
# Sensor 42/90 in event 7
# Sensor 43/90 in event 7
# Sensor 44/90 in event 7
# Sensor 45/90 in event 7
# Sensor 46/90 in event 7
# Sensor 47/90 in event 7
# Sensor 48/90 in event 7
# Sensor 49/90 in event 7
# Sensor 50/90 in event 7
# Sensor 51/90 in event 7
# Sensor 52/90 in event 7
# Sensor 53/90 in event 7
# Sensor 54/90 in event 7
# Sensor 55/90 in event 7
# Sensor 56/90 in event 7
# Sensor 57/90 in event 7
# Sensor 58/90 in event 7
# Sensor 59/90 in event 7
# Sensor 60/90 in event 7
# Sensor 61/90 in event 7
# Sensor 62/90 in event 7
# Sensor 63/90 in event 7
# Sensor 64/90 in event 7
# Sensor 65/90 in event 7
# Sensor 66/90 in event 7
# Sensor 67/90 in event 7
# Sensor 68/90 in event 7
# Sensor 69/90 in event 7
# Sensor 70/90 in event 7
# Sensor 71/90 in event 7
# Sensor 72/90 in event 7
# Sensor 73/90 in event 7
# Sensor 74/90 in event 7
# Sensor 75/90 in event 7
# Sensor 76/90 in event 7
# Sensor 77/90 in event 7
# Sensor 78/90 in event 7
# Sensor 79/90 in event 7
# Sensor 80/90 in event 7
# Sensor 81/90 in event 7
# Sensor 82/90 in event 7
# Sensor 83/90 in event 7
# Sensor 84/90 in event 7
# Sensor 85/90 in event 7
# Sensor 86/90 in event 7
# Sensor 87/90 in event 7
# Sensor 88/90 in event 7
# Sensor 89/90 in event 7
# Sensor 0/90 in event 8
# Sensor 1/90 in event 8
# Sensor 2/90 in event 8
# Sensor 3/90 in event 8
# Sensor 4/90 in event 8
# Sensor 5/90 in event 8
# Sensor 6/90 in event 8
# Sensor 7/90 in event 8
# Sensor 8/90 in event 8
# Sensor 9/90 in event 8
# Sensor 10/90 in event 8
# Sensor 11/90 in event 8
# Sensor 12/90 in event 8
# Sensor 13/90 in event 8
# Sensor 14/90 in event 8
# Sensor 15/90 in event 8
# Sensor 16/90 in event 8
# Sensor 17/90 in event 8
# Sensor 18/90 in event 8
# Sensor 19/90 in event 8
# Sensor 20/90 in event 8
# Sensor 21/90 in event 8
# Sensor 22/90 in event 8
# Sensor 23/90 in event 8
# Sensor 24/90 in event 8
# Sensor 25/90 in event 8
# Sensor 26/90 in event 8
# Sensor 27/90 in event 8
# Sensor 28/90 in event 8
# Sensor 29/90 in event 8
# Sensor 30/90 in event 8
# Sensor 31/90 in event 8
# Sensor 32/90 in event 8
# Sensor 33/90 in event 8
# Sensor 34/90 in event 8
# Sensor 35/90 in event 8
# Sensor 36/90 in event 8
# Sensor 37/90 in event 8
# Sensor 38/90 in event 8
# Sensor 39/90 in event 8
# Sensor 40/90 in event 8
# Sensor 41/90 in event 8
# Sensor 42/90 in event 8
# Sensor 43/90 in event 8
# Sensor 44/90 in event 8
# Sensor 45/90 in event 8
# Sensor 46/90 in event 8
# Sensor 47/90 in event 8
# Sensor 48/90 in event 8
# Sensor 49/90 in event 8
# Sensor 50/90 in event 8
# Sensor 51/90 in event 8
# Sensor 52/90 in event 8
# Sensor 53/90 in event 8
# Sensor 54/90 in event 8
# Sensor 55/90 in event 8
# Sensor 56/90 in event 8
# Sensor 57/90 in event 8
# Sensor 58/90 in event 8
# Sensor 59/90 in event 8
# Sensor 60/90 in event 8
# Sensor 61/90 in event 8
# Sensor 62/90 in event 8
# Sensor 63/90 in event 8
# Sensor 64/90 in event 8
# Sensor 65/90 in event 8
# Sensor 66/90 in event 8
# Sensor 67/90 in event 8
# Sensor 68/90 in event 8
# Sensor 69/90 in event 8
# Sensor 70/90 in event 8
# Sensor 71/90 in event 8
# Sensor 72/90 in event 8
# Sensor 73/90 in event 8
# Sensor 74/90 in event 8
# Sensor 75/90 in event 8
# Sensor 76/90 in event 8
# Sensor 77/90 in event 8
# Sensor 78/90 in event 8
# Sensor 79/90 in event 8
# Sensor 80/90 in event 8
# Sensor 81/90 in event 8
# Sensor 82/90 in event 8
# Sensor 83/90 in event 8
# Sensor 84/90 in event 8
# Sensor 85/90 in event 8
# Sensor 86/90 in event 8
# Sensor 87/90 in event 8
# Sensor 88/90 in event 8
# Sensor 89/90 in event 8
# Sensor 0/90 in event 9
# Sensor 1/90 in event 9
# Sensor 2/90 in event 9
# Sensor 3/90 in event 9
# Sensor 4/90 in event 9
# Sensor 5/90 in event 9
# Sensor 6/90 in event 9
# Sensor 7/90 in event 9
# Sensor 8/90 in event 9
# Sensor 9/90 in event 9
# Sensor 10/90 in event 9
# Sensor 11/90 in event 9
# Sensor 12/90 in event 9
# Sensor 13/90 in event 9
# Sensor 14/90 in event 9
# Sensor 15/90 in event 9
# Sensor 16/90 in event 9
# Sensor 17/90 in event 9
# Sensor 18/90 in event 9
# Sensor 19/90 in event 9
# Sensor 20/90 in event 9
# Sensor 21/90 in event 9
# Sensor 22/90 in event 9
# Sensor 23/90 in event 9
# Sensor 24/90 in event 9
# Sensor 25/90 in event 9
# Sensor 26/90 in event 9
# Sensor 27/90 in event 9
# Sensor 28/90 in event 9
# Sensor 29/90 in event 9
# Sensor 30/90 in event 9
# Sensor 31/90 in event 9
# Sensor 32/90 in event 9
# Sensor 33/90 in event 9
# Sensor 34/90 in event 9
# Sensor 35/90 in event 9
# Sensor 36/90 in event 9
# Sensor 37/90 in event 9
# Sensor 38/90 in event 9
# Sensor 39/90 in event 9
# Sensor 40/90 in event 9
# Sensor 41/90 in event 9
# Sensor 42/90 in event 9
# Sensor 43/90 in event 9
# Sensor 44/90 in event 9
# Sensor 45/90 in event 9
# Sensor 46/90 in event 9
# Sensor 47/90 in event 9
# Sensor 48/90 in event 9
# Sensor 49/90 in event 9
# Sensor 50/90 in event 9
# Sensor 51/90 in event 9
# Sensor 52/90 in event 9
# Sensor 53/90 in event 9
# Sensor 54/90 in event 9
# Sensor 55/90 in event 9
# Sensor 56/90 in event 9
# Sensor 57/90 in event 9
# Sensor 58/90 in event 9
# Sensor 59/90 in event 9
# Sensor 60/90 in event 9
# Sensor 61/90 in event 9
# Sensor 62/90 in event 9
# Sensor 63/90 in event 9
# Sensor 64/90 in event 9
# Sensor 65/90 in event 9
# Sensor 66/90 in event 9
# Sensor 67/90 in event 9
# Sensor 68/90 in event 9
# Sensor 69/90 in event 9
# Sensor 70/90 in event 9
# Sensor 71/90 in event 9
# Sensor 72/90 in event 9
# Sensor 73/90 in event 9
# Sensor 74/90 in event 9
# Sensor 75/90 in event 9
# Sensor 76/90 in event 9
# Sensor 77/90 in event 9
# Sensor 78/90 in event 9
# Sensor 79/90 in event 9
# Sensor 80/90 in event 9
# Sensor 81/90 in event 9
# Sensor 82/90 in event 9
# Sensor 83/90 in event 9
# Sensor 84/90 in event 9
# Sensor 85/90 in event 9
# Sensor 86/90 in event 9
# Sensor 87/90 in event 9
# Sensor 88/90 in event 9
# Sensor 89/90 in event 9
